# %%
import random
import torch
import os
import umap
import time
import glob
import numpy as np
import pandas as pd
import polars as pl
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

from sklearn.decomposition import PCA, FastICA, FactorAnalysis
from sklearn.random_projection import GaussianRandomProjection
from sklearn.manifold import TSNE, trustworthiness
from sklearn.neighbors import NearestNeighbors

# %%
INPUT_DIR = '.'

# %%
# Set random states.
def set_random_states(random_state):
    # Set various random seeds.
    np.random.seed(random_state)
    pl.set_random_seed(random_state)
    pd.core.common.random_state(random_state)
    random.seed(random_state)
    torch.manual_seed(random_state)
    torch.cuda.manual_seed_all(random_state)
    os.environ["PYTHONHASHSEED"] = str(random_state)
    os.environ["TOKENIZERS_PARALLELISM"] = "false"
    try:
        torch.use_deterministic_algorithms(True)
    except Exception:
        pass
    return random_state

RANDOM_STATE = set_random_states(1618)

# %%
# Helper function for KNN evaluation. 
def knn_preservation_score(X_high, X_low, k=5):
    knn_high = NearestNeighbors(n_neighbors=k).fit(X_high)
    knn_low = NearestNeighbors(n_neighbors=k).fit(X_low)
    neighbors_high = knn_high.kneighbors(return_distance=False)
    neighbors_low = knn_low.kneighbors(return_distance=False)
    score = np.mean([
        len(set(high).intersection(set(low))) / k
        for high, low in zip(neighbors_high, neighbors_low)
    ])
    return score


# Helper function for continuity evaluation. 
# Formula adapted from https://link.springer.com/chapter/10.1007/3-540-44668-0_68#preview and https://www.sciencedirect.com/science/article/pii/S0893608006000724 (M2(k) formula)
def continuity(X_high, X_low, k=5):
    # Number of samples.
    n = X_high.shape[0]
    # Build rank matrices.
    nn_high = NearestNeighbors(n_neighbors=n-1).fit(X_high)
    rank_matrix_high = nn_high.kneighbors(return_distance=False)
    nn_low = NearestNeighbors(n_neighbors=k + 1).fit(X_low)
    neighbors_low = nn_low.kneighbors(return_distance=False)[:,1:]
    
    penalty = 0
    for i in range(n):
        ranks = {point: rank for rank, point in enumerate(rank_matrix_high[i], start=1)}
        
        for j in neighbors_low[i]:
            if j not in rank_matrix_high[i][:k]:  # j is not a high-d neighbor
                penalty += ranks.get(j, n) - k

    denom = n * k * (2 * n - 3 * k - 1)
    continuity_score = 1 - (2 / denom) * penalty
    return continuity_score


# Helper function for all dimensionality reduction methods. 
def all_dim_red_methods(inputs_df):
    # Do not need standard scaler as inputs are already z-score normalized. 
    inputs = inputs_df[[f'factor_{i}' for i in range(1, 7)]].values
    methods = {
        "PCA": PCA(n_components=2, random_state=RANDOM_STATE),
        "ICA": FastICA(n_components=2, random_state=RANDOM_STATE),
        "RP": GaussianRandomProjection(n_components=2, random_state=RANDOM_STATE),
        "t-SNE": TSNE(n_components=2, random_state=RANDOM_STATE),
        # 10 neighbors works well in most scenarios - https://umap-learn.readthedocs.io/en/latest/how_umap_works.html
        "UMAP": umap.UMAP(n_components=2, random_state=RANDOM_STATE, n_neighbors=10),
        "FA": FactorAnalysis(n_components=2, random_state=RANDOM_STATE)
    }

    results = []
    for name, model in methods.items():
        start = time.time()
        trans_embeddings = model.fit_transform(inputs)
        end = time.time()
        results.append({
            "Method": name,
            # using k = 5 as it is common (https://www.nature.com/articles/s42003-022-03628-x)
            "Trustworthiness": trustworthiness(inputs, trans_embeddings, n_neighbors=5),
            "KNN Preservation": knn_preservation_score(inputs, trans_embeddings, k=5),
            "Continuity": continuity(inputs, trans_embeddings, k=5),
            "Time": end-start
        })
    return pd.DataFrame(results)

# Helper function for plotting dimensionality reduction results. 
def plot_results(df_results, save=False):
    # make df to work with
    df_normalized = pd.DataFrame()
    df_normalized['Method'] = df_results['Method']
    df_normalized['Normalized Trustworthiness'] = (df_results['Trustworthiness'] - df_results['Trustworthiness'].min()) / (df_results['Trustworthiness'].max() - df_results['Trustworthiness'].min())   
    df_normalized['Normalized KNN Preservation'] = (df_results['KNN Preservation'] - df_results['KNN Preservation'].min()) / (df_results['KNN Preservation'].max() - df_results['KNN Preservation'].min())   
    df_normalized['Normalized Continuity'] = (df_results['Continuity'] - df_results['Continuity'].min()) / (df_results['Continuity'].max() - df_results['Continuity'].min())   
    df_normalized['Normalized Time'] = (df_results['Time'] - df_results['Time'].min()) / (df_results['Time'].max() - df_results['Time'].min())   


    sns.set_theme(style='whitegrid')
    plt.figure(figsize=(16, 12))

    titles = ['Trustworthiness', 'KNN Preservation', 'Continuity', 'Time']

    for i, title in enumerate(titles, start=1):
        plt.subplot(2, 2, i)
        sns.barplot(data=df_results, x="Method", y=title, hue="Method", palette="Set2", dodge=False, legend=False)
        plt.title(title)
        plt.ylim(0, df_results[title].max()+0.1)
        plt.ylabel("Score (0-1)")
        plt.grid(axis='y', linestyle='--', alpha=0.7)

    plt.tight_layout()
    plt.show()

    # save normalized metrics figure
    plt.figure(figsize=(6, 4))

    df_melted = df_normalized.melt(id_vars="Method", var_name="Metric", value_name="Normalized Score")
    sns.barplot(data=df_melted, x="Method", y="Normalized Score", hue="Metric", palette="Set2")
    plt.title("Normalized Metrics")
    plt.ylim(0, 1.05)
    plt.ylabel("Score (0-1)")
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.tight_layout()
    if save:
        # save plot
        if os.path.exists(f'../figures/dimRed/'):
            plt.savefig("../figures/dimRed/normalizedMetricsAllModels.png", bbox_inches='tight', dpi=300, format='png')
        else:
            os.makedirs(f'../figures/dimRed/', exist_ok=False)
            plt.savefig("../figures/dimRed/normalizedMetricsAllModels.png", bbox_inches='tight', dpi=300, format='png')

    plt.show()

# Helper function to make embeddings from chosen dimensionality reduction algorithm.
def put_embeddings_in_df(input_df, method):
    model = method(n_components=2, random_state=RANDOM_STATE)

    trans_embeddings = model.fit_transform(input_df[[f'factor_{i}' for i in range(1, 7)]].values)

    input_df['x'] = [trans_embedding[0] for trans_embedding in trans_embeddings]
    input_df['y'] = [trans_embedding[1] for trans_embedding in trans_embeddings]
    return input_df

# Helper function for drawing dimensionality reduction plot coloured by category. 
def draw_dim_red_plot(df):

    fig = px.scatter(
        df,
        x='x',
        y='y',
        color='category',
        hover_data=['doc_id'],
        opacity=0.8,
        width=800,
        height=600,
        title="Dimensionality Reduction Visualization"
    )

    # Optionally make markers smaller
    fig.update_traces(marker=dict(size=8, line=dict(color='black', width=1)))  # outline each marker

    fig.show()

# %%
# Get all CSV files.
all_files = glob.glob("./outputsTrain/*/mean_model_zero_shot_classification.csv")  # change this to your folder path

# Loop through files.
all_dfs = []

for f in all_files:
    df = pd.read_csv(f)
    # Extract categories from doc_id
    doc_ids = df['doc_id']
    df['category'] = df['doc_id'].apply(lambda x: x.split('_')[0])
    
    # Aggregate numeric factor columns by category
    factor_cols = [f"factor_{i}" for i in range(1, 7)]
    df_agg = df.groupby('category')[factor_cols].mean().reset_index()
    df_agg['doc_id'] = doc_ids
    print(df_agg)
    all_dfs.append(df_agg)

# Concatenate all aggregated DataFrames
dfs = pd.concat(all_dfs, ignore_index=True)

dim_red_results = all_dim_red_methods(dfs)
plot_results(dim_red_results)
# Use UMAP as chosen method.
dfs = put_embeddings_in_df(dfs, umap.UMAP)
draw_dim_red_plot(dfs)
# Out:
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.243501  0.053065  0.084859  0.008117
# 1                       banking77  0.722782 -0.074279 -0.822674 -0.284781
# 2                        clinc150  0.244101  0.063709 -0.341846 -0.079276
# 3  clinicalDialogueSummarizations -0.663170 -0.260931  0.492565 -0.436440
# 4                   dementiaAudio  1.409108  1.294396 -1.618474 -0.161675
# 5                    huffPostNews  0.044183 -0.286798 -0.081602  0.882002
# 6                medicalAbstracts -1.529106 -0.302906  1.197658  0.182275
# 7                          simSUM -0.732204  0.112052  0.931475 -0.803691
# 8     syntheticCareHomeNurseNotes  0.506800  0.625883  0.271420 -0.124606
# 9                           yahoo  0.241007 -1.224191 -0.113381  0.818074
#
#    factor_5  factor_6     doc_id
# 0  0.223089  0.850253  atis_1448
# 1  0.344953 -0.095097  atis_1577
# 2  0.158937  0.622681  atis_1593
# 3 -0.054501 -0.480644  atis_2129
# 4 -0.978406 -0.483692  atis_2325
# 5 -0.465679  0.455667  atis_2450
# 6  0.991469 -0.705329  atis_2451
# 7  0.396725 -0.477301  atis_3431
# 8 -1.008007  0.601666   atis_872
# 9  0.391420 -0.288203   atis_988
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.089493  0.517657 -0.108887  0.124821
# 1                       banking77  0.804675 -0.126321 -0.695274 -0.074866
# 2                        clinc150  0.499701  0.126534 -0.221837 -0.140864
# 3  clinicalDialogueSummarizations -0.833309 -0.107001  0.638076 -0.001933
# 4                   dementiaAudio  0.823034  1.147418 -1.525672  0.058676
# 5                    huffPostNews  0.381062  0.174575 -0.105244  1.101698
# 6                medicalAbstracts -1.551335 -0.694335  1.325266 -0.013021
# 7                          simSUM -0.815073  0.152869  1.076629 -1.222572
# 8     syntheticCareHomeNurseNotes  0.260000 -0.014494 -0.005821 -0.030700
# 9                           yahoo  0.520738 -1.176901 -0.377237  0.198761
#
#    factor_5  factor_6     doc_id
# 0  0.216540  0.825479  atis_1474
# 1  0.591321  0.201856  atis_1558
# 2 -0.086996  0.540090  atis_1691
# 3  0.046427 -0.101892  atis_2064
# 4 -0.763556 -0.238171  atis_2501
# 5 -0.638449  0.570466  atis_3395
# 6  0.788691 -0.632733   atis_455
# 7  0.722459 -0.788762    atis_53
# 8 -1.089480 -0.143913   atis_773
# 9  0.213042 -0.232421    atis_79
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.259732 -0.166116  0.004799  0.261301
# 1                       banking77  0.375000 -0.686410 -0.402578 -0.243322
# 2                        clinc150  0.404150 -0.149007 -0.464182 -0.018563
# 3  clinicalDialogueSummarizations -0.694265 -0.210935  0.634290 -0.664289
# 4                   dementiaAudio  1.433001  1.472728 -1.646162  0.103555
# 5                    huffPostNews  0.345395  0.467495 -0.149876  0.599395
# 6                medicalAbstracts -1.545487 -0.403533  1.121322 -0.209832
# 7                          simSUM -0.747153  0.080017  0.754526 -0.964411
# 8     syntheticCareHomeNurseNotes  0.426584 -0.251254  0.213261  0.100096
# 9                           yahoo  0.262508 -0.152985 -0.065399  1.036070
#
#    factor_5  factor_6     doc_id
# 0  0.037874  0.681374  atis_1145
# 1  0.224358 -0.245957  atis_1216
# 2 -0.000604  0.402919  atis_1807
# 3  0.372833 -0.819267  atis_2418
# 4 -0.675906  0.750613  atis_2507
# 5 -0.293114  0.129026  atis_2721
# 6  0.728411 -0.616514  atis_2932
# 7  0.485403 -0.809170  atis_3186
# 8 -1.123556  0.277043  atis_3231
# 9  0.244301  0.249932   atis_430
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis  0.098262  0.376112 -0.201366  0.348331
# 1                       banking77  0.463369 -0.381226 -0.763198 -0.420726
# 2                        clinc150  0.154548  0.086706  0.003171 -0.170704
# 3  clinicalDialogueSummarizations -0.773369 -0.361614  0.617559 -0.358417
# 4                   dementiaAudio  1.313877  1.326445 -1.338750  0.752091
# 5                    huffPostNews  0.206397 -0.223671 -0.296207  0.509085
# 6                medicalAbstracts -1.463755 -0.428862  1.192917 -0.152866
# 7                          simSUM -0.487584 -0.057107  1.032495 -1.069000
# 8     syntheticCareHomeNurseNotes  0.671850  0.100496 -0.144543 -0.189857
# 9                           yahoo -0.183596 -0.437279 -0.102078  0.752063
#
#    factor_5  factor_6     doc_id
# 0 -0.023528  0.898259  atis_1102
# 1  0.054505 -0.087243  atis_1425
# 2  0.060809  0.375434  atis_1670
# 3  0.280941 -0.556545  atis_3009
# 4 -0.655015  0.789384  atis_3089
# 5 -0.047359 -0.020202  atis_3139
# 6  0.601949 -0.493457  atis_3467
# 7  0.110610 -0.567539    atis_42
# 8 -1.107585  0.247045   atis_773
# 9  0.724672 -0.585135   atis_986
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.010022  0.169981  0.073378  0.115165
# 1                       banking77  0.645944  0.120908 -0.407118  0.350833
# 2                        clinc150  0.547031  0.303021 -0.513459  0.427600
# 3  clinicalDialogueSummarizations -0.581976 -0.599239  0.380786 -0.880642
# 4                   dementiaAudio  0.992310  1.485781 -1.363705  0.147207
# 5                    huffPostNews -0.196315 -0.612994 -0.132869  0.743516
# 6                medicalAbstracts -1.412981  0.003895  1.135623  0.065290
# 7                          simSUM -0.614072  0.115241  0.705066 -0.761382
# 8     syntheticCareHomeNurseNotes  0.593354 -0.185422  0.256103 -0.310876
# 9                           yahoo  0.036726 -0.801173 -0.133806  0.103289
#
#    factor_5  factor_6     doc_id
# 0  0.143932  0.918308  atis_1607
# 1  0.152891  0.035396  atis_1670
# 2 -0.050383  0.871432  atis_1684
# 3 -0.187790 -0.484517  atis_1996
# 4 -0.499480  0.213220  atis_2075
# 5 -0.584969  0.029939  atis_2194
# 6  1.072232 -0.592106  atis_2613
# 7 -0.004531 -0.398941  atis_3179
# 8 -0.318011 -0.213219  atis_3236
# 9  0.276108 -0.379512   atis_431
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.059617  0.459736  0.020982  0.400164
# 1                       banking77  0.591932 -0.258757 -0.675482  0.327556
# 2                        clinc150  0.102163  0.189933 -0.287313 -0.159880
# 3  clinicalDialogueSummarizations -0.788594 -0.192771  0.759410 -0.026275
# 4                   dementiaAudio  0.923393  0.633063 -1.399516 -0.263691
# 5                    huffPostNews  0.315232 -0.025628  0.400825  0.448809
# 6                medicalAbstracts -1.490862 -0.383979  1.132062 -0.048756
# 7                          simSUM -0.635175  0.366965  0.707818 -0.834412
# 8     syntheticCareHomeNurseNotes  0.626849  0.475818 -0.422194 -0.332007
# 9                           yahoo  0.414679 -1.264380 -0.236591  0.488491
#
#    factor_5  factor_6     doc_id
# 0  0.311541  0.849917  atis_1119
# 1  0.315863  0.207037  atis_1989
# 2  0.273067  0.469805  atis_1996
# 3  0.180092 -0.377193  atis_2258
# 4 -0.076027 -0.240156  atis_2818
# 5 -1.003581  0.236193  atis_2902
# 6  0.690482 -0.619623  atis_3171
# 7  0.540957 -0.876266  atis_3231
# 8 -1.021288  0.360852  atis_3250
# 9 -0.211107 -0.010564  atis_3365
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.060007  0.078381 -0.168169  0.175377
# 1                       banking77  0.280846 -0.355111 -0.835419 -0.179287
# 2                        clinc150  0.401711  0.228575 -0.514545 -0.092411
# 3  clinicalDialogueSummarizations -0.876118 -0.580659  0.932813 -0.382569
# 4                   dementiaAudio  0.782102  1.377014 -1.348382 -0.073938
# 5                    huffPostNews  0.630011 -0.147803 -0.111835  0.473978
# 6                medicalAbstracts -1.560657 -0.052891  1.461827 -0.051304
# 7                          simSUM -0.320823 -0.361849  0.782357 -0.737440
# 8     syntheticCareHomeNurseNotes  0.010364 -0.198874  0.163465 -0.319690
# 9                           yahoo  0.712570  0.013218 -0.362113  1.187284
#
#    factor_5  factor_6     doc_id
# 0  0.190138  0.569975  atis_1102
# 1  0.545380 -0.188506  atis_1410
# 2  0.164656  0.273646  atis_1785
# 3 -0.251585  0.011901  atis_2132
# 4 -0.402620  0.055143  atis_2282
# 5 -0.608928  0.634311  atis_2424
# 6  0.990283 -0.612497  atis_2436
# 7  0.404946 -0.750203   atis_422
# 8 -1.019586  0.179851   atis_796
# 9 -0.012683 -0.173620   atis_894
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.338562  0.187469  0.024215  0.188455
# 1                       banking77  0.398780 -0.085777 -0.501905 -0.066122
# 2                        clinc150  0.508669 -0.206355 -0.556399 -0.018851
# 3  clinicalDialogueSummarizations -0.664107 -0.790401  0.817544 -1.120439
# 4                   dementiaAudio  1.229416  1.301826 -1.905242  0.509397
# 5                    huffPostNews  0.105110 -0.370764 -0.005656  0.469520
# 6                medicalAbstracts -1.160729 -0.504961  0.741117  0.042915
# 7                          simSUM -0.524263  0.312772  0.960370 -0.570848
# 8     syntheticCareHomeNurseNotes  0.541696  0.050860  0.297990 -0.245716
# 9                           yahoo -0.096009  0.105331  0.127965  0.811689
#
#    factor_5  factor_6     doc_id
# 0 -0.004774  0.707757  atis_1139
# 1  0.449582 -0.070992  atis_1197
# 2 -0.220674  0.617782  atis_1880
# 3  0.289544 -0.616078  atis_2140
# 4 -1.059478  0.203636  atis_2673
# 5 -0.152129  0.513898  atis_2994
# 6  0.604283 -0.550845  atis_3317
# 7  0.629866 -0.523831   atis_392
# 8 -0.629743 -0.050704    atis_80
# 9  0.093521 -0.230623   atis_864
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.249176 -0.048403  0.058167  0.041356
# 1                       banking77  0.452760 -0.553963 -0.711290  0.008396
# 2                        clinc150  0.329195  0.180911 -0.411145  0.070640
# 3  clinicalDialogueSummarizations -0.879250 -0.704786  0.882203 -0.501004
# 4                   dementiaAudio  1.060030  0.997215 -1.215694 -0.260214
# 5                    huffPostNews  0.515994 -0.061083 -0.411246  1.169620
# 6                medicalAbstracts -1.272443 -0.422154  1.060312 -0.014681
# 7                          simSUM -0.813009 -0.057464  0.984590 -1.239402
# 8     syntheticCareHomeNurseNotes  0.323813  0.109118  0.291022 -0.046865
# 9                           yahoo  0.532086  0.560607 -0.526920  0.772156
#
#    factor_5  factor_6     doc_id
# 0 -0.071358  0.819543  atis_1083
# 1  0.289885 -0.191208  atis_1217
# 2 -0.398731  0.424416  atis_1328
# 3  0.446190 -0.681739  atis_1522
# 4 -0.427557  0.184075   atis_209
# 5 -0.144702  0.447370  atis_2233
# 6  0.541625 -0.453572   atis_284
# 7  0.525918 -0.815862  atis_3479
# 8 -0.720286  0.039348   atis_384
# 9 -0.040984  0.227629   atis_456
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.136039  0.121961 -0.221311  0.102800
# 1                       banking77  0.321474 -0.361798 -0.746976 -0.530647
# 2                        clinc150  0.225374  0.584263 -0.316921  0.384763
# 3  clinicalDialogueSummarizations -0.107909 -0.404357  0.286489 -0.528768
# 4                   dementiaAudio  1.271431  1.187947 -1.364763 -0.158965
# 5                    huffPostNews  0.268833  0.160342  0.301948  0.982810
# 6                medicalAbstracts -1.511160 -0.413834  1.206962  0.095417
# 7                          simSUM -0.839809  0.126257  0.981135 -0.584623
# 8     syntheticCareHomeNurseNotes  0.531749 -0.186782  0.035044 -0.118994
# 9                           yahoo -0.023944 -0.813999 -0.161607  0.356208
#
#    factor_5  factor_6     doc_id
# 0  0.156853  0.475660  atis_1109
# 1  0.971291 -0.475446   atis_113
# 2 -0.305269  0.792934  atis_1153
# 3 -0.443782  0.197885  atis_1944
# 4 -0.806375 -0.281067  atis_2092
# 5 -0.696130  0.460638  atis_2432
# 6  0.496979 -0.434378  atis_2624
# 7  0.940451 -0.863070  atis_2956
# 8 -0.852175  0.074185   atis_308
# 9  0.538156  0.052659  atis_3120
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.580617 -0.285214  0.462933  0.179898
# 1                       banking77  1.191896 -0.078953 -0.783731  0.390418
# 2                        clinc150  0.180666  0.168034 -0.355287  0.116083
# 3  clinicalDialogueSummarizations -0.572597 -0.541456  0.600380 -0.257302
# 4                   dementiaAudio  0.894463  1.255697 -1.398516 -0.127783
# 5                    huffPostNews  0.223915  0.527481  0.229759  0.497902
# 6                medicalAbstracts -1.553893 -0.085043  1.194989  0.112091
# 7                          simSUM -0.517747  0.495556  0.824297 -0.894486
# 8     syntheticCareHomeNurseNotes  0.535879 -0.345453 -0.105135 -0.265072
# 9                           yahoo  0.198035 -1.110649 -0.669690  0.248250
#
#    factor_5  factor_6     doc_id
# 0  0.043828  0.942269  atis_1187
# 1  0.213980 -0.043898  atis_1355
# 2 -0.010391  0.483019  atis_1522
# 3  0.247295 -0.374456  atis_2243
# 4 -0.633865 -0.032890  atis_2642
# 5 -0.732938  0.481323  atis_2895
# 6  0.952472 -0.416801  atis_3186
# 7  0.421022 -0.755649  atis_3262
# 8 -0.637420  0.081064  atis_3270
# 9  0.136018 -0.363982  atis_3457
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis  0.049466  0.357122 -0.210199  0.130265
# 1                       banking77  0.097449 -0.645805 -0.618708 -0.879681
# 2                        clinc150  0.242757 -0.101424 -0.504147  0.189552
# 3  clinicalDialogueSummarizations -0.710160 -0.780539  0.659543 -0.687466
# 4                   dementiaAudio  1.215753  1.590077 -1.591707  0.022280
# 5                    huffPostNews  0.653529  0.067190 -0.201379  0.889011
# 6                medicalAbstracts -1.431065  0.160829  1.327898  0.427394
# 7                          simSUM -0.680585 -0.013285  0.851072 -0.900869
# 8     syntheticCareHomeNurseNotes  0.590755  0.018023  0.132052  0.231350
# 9                           yahoo -0.027899 -0.652189  0.155576  0.578165
#
#    factor_5  factor_6     doc_id
# 0  0.054377  0.950043  atis_1012
# 1  0.633865 -0.712915  atis_1557
# 2  0.143206  0.552443  atis_1740
# 3  0.527032 -0.985314   atis_180
# 4 -0.839289  0.294918   atis_192
# 5 -0.444241  0.361820   atis_268
# 6  0.756739 -0.398675  atis_2830
# 7  0.131403 -0.277397  atis_3103
# 8 -1.089195  0.219544   atis_345
# 9  0.126103 -0.004467   atis_567
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.368840  0.019380  0.143907  0.549678
# 1                       banking77  0.610283 -0.119116 -0.847799 -0.097791
# 2                        clinc150  0.083259  0.347933 -0.222623  0.123568
# 3  clinicalDialogueSummarizations -0.516583 -0.203722  0.128194 -0.042169
# 4                   dementiaAudio  0.898263  1.549133 -1.605600  0.040308
# 5                    huffPostNews  0.761731 -0.391066 -0.382452  0.316205
# 6                medicalAbstracts -1.466018 -0.611940  1.280314 -0.265296
# 7                          simSUM -0.527133 -0.148588  1.179214 -0.836442
# 8     syntheticCareHomeNurseNotes  0.450850 -0.014134  0.415536 -0.167223
# 9                           yahoo  0.074189 -0.427879 -0.088693  0.379162
#
#    factor_5  factor_6     doc_id
# 0 -0.300476  1.175261   atis_107
# 1  0.475878 -0.051519  atis_1465
# 2 -0.273844  0.350130  atis_1985
# 3  0.133049 -0.336283  atis_2518
# 4 -0.555665  0.092957  atis_2539
# 5 -0.203072  0.112361   atis_272
# 6  0.962207 -0.644961  atis_2753
# 7  0.257239 -0.424839  atis_2828
# 8 -0.919273  0.255575  atis_3000
# 9  0.423956 -0.528682   atis_470
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.271181 -0.027222  0.326155  0.296838
# 1                       banking77  0.845689 -0.153810 -0.674138  0.088478
# 2                        clinc150  0.263382 -0.092643  0.050868  0.073995
# 3  clinicalDialogueSummarizations -0.718409 -0.681878 -0.044440 -0.772301
# 4                   dementiaAudio  0.800368  1.293111 -1.579401 -0.548973
# 5                    huffPostNews  0.569845  0.545276  0.224647  0.818017
# 6                medicalAbstracts -1.302290 -0.130052  1.263610  0.231419
# 7                          simSUM -0.914110  0.088028  0.902802 -0.576527
# 8     syntheticCareHomeNurseNotes  0.459932  0.233067 -0.002283  0.262923
# 9                           yahoo  0.266773 -1.073876 -0.467820  0.126133
#
#    factor_5  factor_6     doc_id
# 0  0.091194  0.906143  atis_1332
# 1  0.246171  0.353557  atis_1517
# 2 -0.028091  0.585973  atis_1613
# 3  0.181079 -0.405695  atis_1698
# 4 -0.334520 -0.249456  atis_1939
# 5 -0.572490  0.794588  atis_2836
# 6  1.227007 -0.710845  atis_3400
# 7  0.437275 -0.661282   atis_422
# 8 -0.725656 -0.048292   atis_749
# 9 -0.521969 -0.564691   atis_818
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.422994  0.223913  0.451939  0.105408
# 1                       banking77  0.813886 -0.323421 -0.435818  0.027386
# 2                        clinc150  0.421289  0.221064 -0.504273  0.121137
# 3  clinicalDialogueSummarizations -0.144882 -1.130129 -0.109294 -0.980682
# 4                   dementiaAudio  1.056043  1.409210 -1.291475  0.003640
# 5                    huffPostNews  0.206559  0.340477 -0.114534  1.363271
# 6                medicalAbstracts -1.745500 -0.059679  1.402130 -0.191814
# 7                          simSUM -0.813196  0.179735  0.934952 -0.665015
# 8     syntheticCareHomeNurseNotes  0.402159  0.032689 -0.235814 -0.638304
# 9                           yahoo  0.226636 -0.893860 -0.097813  0.854974
#
#    factor_5  factor_6     doc_id
# 0  0.181204  1.187869  atis_1088
# 1  0.318525  0.180188  atis_1091
# 2  0.159106  0.545476  atis_1371
# 3 -0.694071 -0.455455  atis_1816
# 4 -0.552263 -0.403193  atis_1979
# 5 -0.064495  0.867965  atis_2023
# 6  1.371003 -0.827869  atis_2322
# 7  0.739722 -0.938314  atis_2385
# 8 -1.356832 -0.217798  atis_2622
# 9 -0.101898  0.061131  atis_3261
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.185708 -0.068587  0.050583  0.104180
# 1                       banking77  0.789691 -0.328330 -0.586576 -0.370823
# 2                        clinc150  0.474742  0.159017 -0.321380 -0.002668
# 3  clinicalDialogueSummarizations -0.748370 -0.974510  0.583396 -0.786279
# 4                   dementiaAudio  0.997166  1.519079 -1.777890 -0.233096
# 5                    huffPostNews  0.448066 -0.216066  0.139381  1.005468
# 6                medicalAbstracts -1.540302 -0.048505  1.027440 -0.017746
# 7                          simSUM -1.000291  0.300240  0.895314 -0.916274
# 8     syntheticCareHomeNurseNotes  0.576661 -0.071716 -0.002039  0.180806
# 9                           yahoo  0.188347 -0.270620 -0.008230  1.036431
#
#    factor_5  factor_6     doc_id
# 0 -0.280635  0.907850  atis_1017
# 1  0.376525  0.239340  atis_1511
# 2 -0.088891  0.430939  atis_1784
# 3 -0.019522 -0.675583  atis_2156
# 4 -0.530257 -0.654528   atis_222
# 5 -0.252298  0.600143  atis_2317
# 6  0.977230 -0.565760  atis_2829
# 7  0.666756 -0.847974  atis_2985
# 8 -0.918535  0.460348  atis_3318
# 9  0.069626  0.105225  atis_3366
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.377637 -0.049396 -0.174013  0.096160
# 1                       banking77  0.753862  0.220201 -0.606497  0.019765
# 2                        clinc150  0.099644 -0.043820 -0.578583 -0.266576
# 3  clinicalDialogueSummarizations -0.532551 -0.722981  0.251275 -0.012748
# 4                   dementiaAudio  1.093131  1.119127 -1.465217 -0.282685
# 5                    huffPostNews  0.328981 -0.201863  0.254976  0.695376
# 6                medicalAbstracts -1.392525 -0.055956  1.254366  0.009280
# 7                          simSUM -0.527135  0.195378  0.799145 -0.954160
# 8     syntheticCareHomeNurseNotes  0.483888  0.043024  0.373000 -0.194179
# 9                           yahoo  0.070342 -0.503714 -0.108451  0.889767
#
#    factor_5  factor_6     doc_id
# 0 -0.210941  0.973651   atis_127
# 1  0.069098  0.266370  atis_1529
# 2  0.230834  0.288364  atis_2412
# 3 -0.197873 -0.254669  atis_2922
# 4 -0.642953 -0.013306  atis_3030
# 5 -0.039355  0.057733   atis_321
# 6  1.132356 -0.745673  atis_3336
# 7  0.113047 -0.568153   atis_437
# 8 -0.664994  0.132917   atis_493
# 9  0.210779 -0.137235    atis_75
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.022364 -0.131292  0.116104  0.088752
# 1                       banking77  0.470788 -0.174838 -0.475720 -0.518318
# 2                        clinc150  0.478668  0.402718 -0.341015  0.286945
# 3  clinicalDialogueSummarizations -0.985256 -0.416323  0.691863 -0.344896
# 4                   dementiaAudio  1.107966  1.078690 -1.626310  0.095960
# 5                    huffPostNews  0.525353 -0.018134 -0.043633  0.675399
# 6                medicalAbstracts -1.566278 -0.178470  1.203185  0.094466
# 7                          simSUM -0.647193  0.048927  0.672722 -0.424973
# 8     syntheticCareHomeNurseNotes  0.174663 -0.353048  0.040099 -0.288247
# 9                           yahoo  0.463654 -0.258229 -0.237295  0.334913
#
#    factor_5  factor_6     doc_id
# 0 -0.010828  0.816516  atis_1018
# 1  0.533349 -0.224890  atis_1391
# 2 -0.029614  0.588136  atis_2169
# 3  0.658788 -0.853728  atis_2450
# 4 -1.183774  0.489564  atis_2846
# 5 -0.192583  0.453920  atis_2939
# 6  0.633773 -0.342106  atis_3277
# 7  0.286460 -0.676268   atis_475
# 8 -0.631153  0.083711   atis_864
# 9 -0.064416 -0.334856   atis_978
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.289168  0.106106  0.042926 -0.035365
# 1                       banking77  0.731915 -0.008425 -0.644451  0.255615
# 2                        clinc150  0.475166  0.032383 -0.748620 -0.102397
# 3  clinicalDialogueSummarizations -0.694362 -0.042332  0.571469 -0.048469
# 4                   dementiaAudio  0.942660  1.624888 -1.248609  0.113283
# 5                    huffPostNews  0.241422  0.021500 -0.181520  0.669555
# 6                medicalAbstracts -1.546709 -0.357112  1.369162 -0.055363
# 7                          simSUM -0.540744 -0.364882  0.868305 -1.112340
# 8     syntheticCareHomeNurseNotes  0.265120 -0.244237  0.410258 -0.416705
# 9                           yahoo  0.414699 -0.767889 -0.438920  0.732187
#
#    factor_5  factor_6     doc_id
# 0 -0.009489  1.030901  atis_1255
# 1  0.221173  0.101200  atis_1590
# 2  0.092044  0.346710  atis_2003
# 3  0.158622 -0.235253  atis_2452
# 4 -0.793108  0.241823  atis_2469
# 5 -0.354167  0.101488  atis_2474
# 6  0.976646 -0.853983  atis_2843
# 7  0.379847 -0.818031  atis_2870
# 8 -0.395268 -0.209030  atis_3030
# 9 -0.276300  0.294176  atis_3135
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.208018  0.031468  0.086483  0.180013
# 1                       banking77  0.416911 -0.625029 -0.666079 -0.586957
# 2                        clinc150  0.454133  0.456135 -0.213401  0.053458
# 3  clinicalDialogueSummarizations -0.565694 -0.339827  0.669661 -0.321104
# 4                   dementiaAudio  1.264853  0.806600 -1.713165 -0.080664
# 5                    huffPostNews  0.176397 -0.261987 -0.032699  0.774271
# 6                medicalAbstracts -1.367080 -0.057435  1.107311  0.004942
# 7                          simSUM -0.811999  0.397529  0.921458 -0.439722
# 8     syntheticCareHomeNurseNotes  0.693880 -0.317791  0.070934 -0.466151
# 9                           yahoo -0.053383 -0.089663 -0.230504  0.881913
#
#    factor_5  factor_6     doc_id
# 0  0.164887  0.821808   atis_109
# 1  0.629012 -0.287551  atis_1270
# 2 -0.121459  0.503792  atis_1872
# 3 -0.087605 -0.256797   atis_223
# 4 -0.754438 -0.422175  atis_2504
# 5 -0.479636  0.644075  atis_2698
# 6  0.705352 -0.442354   atis_295
# 7  0.533952 -0.316728  atis_3121
# 8 -1.095788 -0.221680  atis_3177
# 9  0.505724 -0.022390    atis_47
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.017727  0.041679 -0.115563 -0.164662
# 1                       banking77  0.676570 -0.050998 -0.721310  0.100991
# 2                        clinc150  0.356677  0.288183 -0.164295  0.130594
# 3  clinicalDialogueSummarizations -0.386758 -0.386789  0.222173 -0.773364
# 4                   dementiaAudio  1.301833  1.787091 -1.286769  0.325368
# 5                    huffPostNews -0.039982 -0.053214  0.211475  0.750861
# 6                medicalAbstracts -1.385723 -0.085736  1.182265 -0.026092
# 7                          simSUM -0.821150  0.061275  0.931908 -0.986760
# 8     syntheticCareHomeNurseNotes  0.342545 -0.461432  0.123452 -0.092358
# 9                           yahoo -0.026286 -1.140060 -0.383336  0.735422
#
#    factor_5  factor_6     doc_id
# 0  0.195275  0.745177  atis_1101
# 1  0.581529 -0.099046  atis_1456
# 2 -0.386489  0.742301  atis_1659
# 3  0.099991 -0.514485  atis_2042
# 4 -0.881289  0.812990  atis_2085
# 5 -0.445550  0.219469  atis_2198
# 6  0.687321 -0.684700  atis_2713
# 7  0.505118 -0.781844  atis_3115
# 8 -0.580166 -0.118254  atis_3384
# 9  0.224260 -0.321608   atis_493
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.176728  0.257979  0.032956  0.162297
# 1                       banking77  0.852824  0.036657 -0.869719  0.217780
# 2                        clinc150  0.477300  0.174360 -0.441313  0.080957
# 3  clinicalDialogueSummarizations -0.691948 -1.012736  0.591039 -1.197560
# 4                   dementiaAudio  1.096905  1.163634 -1.601289 -0.174645
# 5                    huffPostNews -0.099383 -0.227540  0.273048  1.000283
# 6                medicalAbstracts -1.567559 -0.232106  1.113631 -0.111938
# 7                          simSUM -0.656551 -0.039647  0.739418 -0.949024
# 8     syntheticCareHomeNurseNotes  0.335612 -0.089473  0.386986  0.197765
# 9                           yahoo  0.429527 -0.031126 -0.224757  0.774086
#
#    factor_5  factor_6     doc_id
# 0  0.214944  0.842799  atis_1064
# 1  0.444970  0.156637  atis_1188
# 2  0.212994  0.580861  atis_1558
# 3 -0.448717 -0.509627  atis_1602
# 4 -0.404443 -0.023230  atis_1853
# 5 -0.316517  0.278184  atis_2344
# 6  0.783984 -0.585371  atis_2718
# 7 -0.010453 -0.431769  atis_3217
# 8 -0.538197 -0.042926   atis_572
# 9  0.061436 -0.265559   atis_979
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.197049 -0.007465 -0.223596  0.196096
# 1                       banking77  0.432448 -0.075278 -0.564766 -0.305199
# 2                        clinc150  0.429225 -0.186657 -0.441466  0.057957
# 3  clinicalDialogueSummarizations -0.214704 -1.100757  0.286803 -1.056064
# 4                   dementiaAudio  1.108757  1.575781 -1.596434  0.024080
# 5                    huffPostNews -0.034672  0.107246  0.398576  0.927208
# 6                medicalAbstracts -1.337278 -0.242288  1.248288 -0.054233
# 7                          simSUM -0.736670  0.101208  0.668010 -0.831731
# 8     syntheticCareHomeNurseNotes  0.418412  0.153657  0.453308  0.235661
# 9                           yahoo  0.131533 -0.325447 -0.228723  0.806225
#
#    factor_5  factor_6     doc_id
# 0  0.083781  0.652574  atis_1463
# 1  0.377188 -0.165689  atis_1660
# 2  0.127964  0.464369  atis_1861
# 3 -0.689794 -0.364776  atis_2268
# 4 -0.610609  0.143749  atis_2414
# 5 -0.306074  0.776961  atis_2440
# 6  1.127126 -0.811639  atis_3199
# 7  0.172753 -0.536076  atis_3324
# 8 -0.427450  0.131630   atis_355
# 9  0.145115 -0.291104   atis_949
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis  0.026807  0.127259  0.078302  0.046587
# 1                       banking77  0.345913 -0.454062 -0.623799 -0.619572
# 2                        clinc150  0.272673  0.372343 -0.435676  0.194500
# 3  clinicalDialogueSummarizations -0.525895 -0.313409  0.543416 -0.327553
# 4                   dementiaAudio  0.927772  1.266890 -1.723921  0.081355
# 5                    huffPostNews  0.321984  0.640960 -0.164387  1.167384
# 6                medicalAbstracts -1.380375 -0.161663  0.907186  0.051504
# 7                          simSUM -0.294592  0.225940  0.646590 -0.443715
# 8     syntheticCareHomeNurseNotes  0.439933 -0.308981  0.266760  0.054260
# 9                           yahoo -0.134220 -1.395278  0.505531 -0.204750
#
#    factor_5  factor_6     doc_id
# 0  0.264114  0.634630  atis_1243
# 1  0.546033 -0.247428  atis_1286
# 2  0.449070  0.534973  atis_1384
# 3  0.258358 -0.303028  atis_1726
# 4 -0.821973 -0.317572  atis_2856
# 5 -0.567719  0.552497  atis_3110
# 6  0.496151 -0.591983  atis_3254
# 7  0.454405 -0.661558  atis_3270
# 8 -1.496276  0.556620   atis_455
# 9  0.417836 -0.157150   atis_908
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.373433 -0.116524  0.309996 -0.073694
# 1                       banking77  0.707106 -0.321475 -0.857633 -0.343748
# 2                        clinc150  0.313020 -0.131006 -0.413958  0.044642
# 3  clinicalDialogueSummarizations -0.626360 -0.457329  0.425139 -0.343854
# 4                   dementiaAudio  1.201422  1.533754 -1.558378  0.528787
# 5                    huffPostNews  0.043644 -0.179653  0.223421  0.964621
# 6                medicalAbstracts -1.310267 -0.071544  1.236627 -0.223394
# 7                          simSUM -0.842441  0.063618  0.952285 -0.856488
# 8     syntheticCareHomeNurseNotes  0.259187 -0.203106 -0.166091 -0.581146
# 9                           yahoo  0.628123 -0.116734 -0.151408  0.884275
#
#    factor_5  factor_6     doc_id
# 0 -0.004639  0.712593  atis_1006
# 1  0.400168  0.022707  atis_1396
# 2 -0.111214  0.260462  atis_1759
# 3 -0.250963 -0.300361  atis_1998
# 4 -0.331227  0.654921  atis_2342
# 5 -0.843738  0.526157  atis_2686
# 6  0.894159 -0.826217  atis_2799
# 7  0.896200 -0.842436  atis_2836
# 8 -0.734578 -0.344311   atis_588
# 9  0.085833  0.136484   atis_600
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.123677 -0.033969 -0.092564  0.132803
# 1                       banking77  0.778567 -0.432411 -0.885796 -0.005564
# 2                        clinc150  0.538692  0.325162 -0.443263  0.076957
# 3  clinicalDialogueSummarizations -0.706763 -0.445396  0.610373 -0.759100
# 4                   dementiaAudio  0.750257  1.341764 -1.133863 -0.308400
# 5                    huffPostNews  0.616277  0.126421 -0.074066  0.924809
# 6                medicalAbstracts -1.204509 -0.279513  0.949361 -0.109820
# 7                          simSUM -0.956842 -0.068160  1.151514 -1.014147
# 8     syntheticCareHomeNurseNotes  0.074570 -0.313496  0.206256  0.000623
# 9                           yahoo  0.233427 -0.220403 -0.287952  1.061839
#
#    factor_5  factor_6     doc_id
# 0 -0.052449  0.876187  atis_1487
# 1  0.366677  0.091551   atis_166
# 2 -0.483737  0.473312  atis_2668
# 3  0.321008 -0.672108  atis_2711
# 4 -0.492896 -0.182876  atis_2741
# 5 -0.239047  0.504603  atis_2841
# 6  0.941989 -0.700050  atis_3218
# 7  0.847831 -0.924984   atis_661
# 8 -1.202130  0.136504   atis_764
# 9 -0.007246  0.397862   atis_928
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.048185  0.233080  0.001126  0.100202
# 1                       banking77  0.604157 -0.395476 -0.770643 -0.278309
# 2                        clinc150  0.115380  0.296768 -0.279611  0.035666
# 3  clinicalDialogueSummarizations -0.690052 -0.351211  0.503439  0.100222
# 4                   dementiaAudio  1.288670  1.339438 -1.477576  0.580959
# 5                    huffPostNews  0.297100  0.099539  0.121711  0.316353
# 6                medicalAbstracts -1.512245 -0.803922  1.158891 -0.126348
# 7                          simSUM -0.444642  0.204591  0.734764 -0.956698
# 8     syntheticCareHomeNurseNotes  0.155079 -0.013343  0.311664 -0.532794
# 9                           yahoo  0.234738 -0.609464 -0.303764  0.760745
#
#    factor_5  factor_6     doc_id
# 0 -0.026023  0.833068   atis_130
# 1  0.474735 -0.165497  atis_1544
# 2  0.063686  0.475269  atis_2332
# 3  0.203536 -0.384050  atis_2392
# 4 -0.464573  0.179299  atis_2672
# 5 -0.374930  0.111217  atis_2724
# 6  0.887617 -0.503626  atis_2980
# 7 -0.054615 -0.655969  atis_3072
# 8 -0.501728 -0.117861   atis_408
# 9 -0.207707  0.228149   atis_925
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.067765  0.325672 -0.085140  0.105873
# 1                       banking77  0.865593  0.069046 -0.851289  0.136753
# 2                        clinc150  0.364990  0.013609 -0.708071 -0.057530
# 3  clinicalDialogueSummarizations -0.589846 -0.385667  0.521570 -0.598645
# 4                   dementiaAudio  1.114370  1.629940 -1.450046  0.286821
# 5                    huffPostNews -0.175355 -0.461056  0.178198  0.478075
# 6                medicalAbstracts -1.241018 -0.257560  1.144308  0.049989
# 7                          simSUM -0.578338  0.211215  0.890899 -1.065032
# 8     syntheticCareHomeNurseNotes  0.363075 -0.126367  0.483723 -0.164568
# 9                           yahoo -0.055706 -1.018832 -0.124152  0.828265
#
#    factor_5  factor_6     doc_id
# 0  0.139976  0.826932  atis_1431
# 1  0.183051  0.003921  atis_1488
# 2 -0.149285  0.435563  atis_1543
# 3 -0.118029 -0.340919  atis_1619
# 4 -0.638673  0.115845  atis_2639
# 5 -0.257484  0.256214   atis_266
# 6  0.623433 -0.583007  atis_2775
# 7  0.486283 -0.913188  atis_3250
# 8 -0.541918  0.001841   atis_392
# 9  0.272647  0.196799   atis_635
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.227957  0.085122 -0.180251  0.100212
# 1                       banking77  0.444361 -0.132557 -0.777002 -0.266821
# 2                        clinc150  0.410349  0.107199 -0.675177 -0.036633
# 3  clinicalDialogueSummarizations -0.714867 -0.161330  0.799338 -0.234152
# 4                   dementiaAudio  1.193659  1.412254 -1.713650 -0.000505
# 5                    huffPostNews -0.000578 -0.319734  0.429784  0.779786
# 6                medicalAbstracts -1.018760 -0.362337  1.159145  0.220213
# 7                          simSUM -0.672327 -0.221015  0.973745 -1.104800
# 8     syntheticCareHomeNurseNotes  0.348319 -0.342993  0.013997 -0.272800
# 9                           yahoo  0.237801 -0.064610 -0.029928  0.815500
#
#    factor_5  factor_6     doc_id
# 0 -0.021609  0.877123  atis_1558
# 1  0.309753 -0.227457   atis_161
# 2 -0.263099  0.429960  atis_1719
# 3  0.661706 -0.835585  atis_1836
# 4 -0.951990 -0.162853  atis_1957
# 5  0.011264  0.108670  atis_1980
# 6  0.483368 -0.354243  atis_2654
# 7  0.382485 -0.562339  atis_2867
# 8 -1.002835  0.477874  atis_3340
# 9  0.390957  0.248850   atis_621
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.304244 -0.094710 -0.193851  0.203012
# 1                       banking77  0.718375 -0.406218 -0.945737 -0.253286
# 2                        clinc150  0.449615  0.497122 -0.375850  0.110036
# 3  clinicalDialogueSummarizations -0.845540 -0.127545  0.871413 -0.709568
# 4                   dementiaAudio  0.990853  0.973261 -1.466259  0.201997
# 5                    huffPostNews  0.256387 -0.227989 -0.001303  0.829260
# 6                medicalAbstracts -1.439139 -0.416594  1.039604 -0.230232
# 7                          simSUM -0.453974  0.097463  0.713322 -1.084210
# 8     syntheticCareHomeNurseNotes  0.541881  0.254603  0.209639  0.221724
# 9                           yahoo  0.085786 -0.549394  0.149023  0.711268
#
#    factor_5  factor_6     doc_id
# 0 -0.122278  0.850433  atis_1189
# 1  0.466914 -0.089236  atis_1529
# 2  0.020193  0.554808  atis_2081
# 3  0.469304 -0.679294  atis_2416
# 4 -0.718253  0.022215  atis_2671
# 5  0.000870  0.388315  atis_3022
# 6  1.120722 -0.927879  atis_3061
# 7 -0.022007 -0.710016  atis_3102
# 8 -1.444615  0.833481   atis_411
# 9  0.229149 -0.242827   atis_815
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.460446 -0.043530  0.298834  0.199321
# 1                       banking77  0.742985  0.055253 -0.545481  0.221806
# 2                        clinc150  0.145215  0.414112 -0.053972  0.142041
# 3  clinicalDialogueSummarizations -0.739525 -0.824884  0.414186 -0.832468
# 4                   dementiaAudio  1.280547  1.227626 -1.547152 -0.088995
# 5                    huffPostNews  0.447127 -0.006314 -0.142401  0.669368
# 6                medicalAbstracts -1.073092 -0.047189  1.233064  0.246414
# 7                          simSUM -0.624902  0.109165  0.878534 -0.723291
# 8     syntheticCareHomeNurseNotes -0.013739 -0.162136 -0.123647 -0.243313
# 9                           yahoo  0.295830 -0.722102 -0.411964  0.409116
#
#    factor_5  factor_6     doc_id
# 0 -0.031153  1.073960  atis_1179
# 1  0.509450  0.145770  atis_2480
# 2  0.198717  0.667705  atis_2683
# 3 -0.203086 -0.620367   atis_282
# 4 -0.774248  0.139408  atis_3032
# 5 -0.277882  0.236964   atis_450
# 6  0.948364 -0.488408   atis_812
# 7  0.290041 -0.665590   atis_885
# 8 -0.542568 -0.170730   atis_891
# 9 -0.117635 -0.318712   atis_916
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis  0.053853  0.138760  0.147515  0.015182
# 1                       banking77  0.772193 -0.273338 -0.719900 -0.167166
# 2                        clinc150  0.383414  0.015196 -0.429670  0.173755
# 3  clinicalDialogueSummarizations -0.897586 -1.187842  0.569803 -1.040262
# 4                   dementiaAudio  1.156749  1.404117 -1.597800  0.384194
# 5                    huffPostNews  0.436730  0.320593  0.241707  1.056624
# 6                medicalAbstracts -1.303971 -0.207934  1.306996  0.148457
# 7                          simSUM -0.751907  0.001663  0.853696 -0.637952
# 8     syntheticCareHomeNurseNotes  0.338664  0.041370 -0.147457 -0.150548
# 9                           yahoo -0.188138 -0.252587 -0.224890  0.217716
#
#    factor_5  factor_6     doc_id
# 0 -0.039235  0.885989  atis_1572
# 1 -0.058955  0.147336  atis_1635
# 2  0.158054  0.567742  atis_2398
# 3  0.294790 -1.008321  atis_2876
# 4 -0.945245  0.968772  atis_3017
# 5 -0.562006  0.510583  atis_3020
# 6  0.932814 -0.540571  atis_3038
# 7  0.263181 -0.684650   atis_308
# 8 -0.546654 -0.346304  atis_3182
# 9  0.503257 -0.500575    atis_69
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.159161 -0.052408  0.040181  0.012622
# 1                       banking77  0.742762 -0.461939 -1.298274 -0.485439
# 2                        clinc150  0.109597  0.340031 -0.066587  0.132057
# 3  clinicalDialogueSummarizations -0.546577 -0.309662  0.589284 -0.477033
# 4                   dementiaAudio  0.929539  1.070804 -1.574269 -0.263686
# 5                    huffPostNews  0.352033  0.199354  0.129866  1.414871
# 6                medicalAbstracts -1.376076 -0.001616  1.033441  0.187275
# 7                          simSUM -0.516081  0.138131  0.901516 -1.008360
# 8     syntheticCareHomeNurseNotes  0.466715  0.089603  0.351851 -0.101635
# 9                           yahoo -0.002752 -1.012298 -0.107008  0.589329
#
#    factor_5  factor_6     doc_id
# 0  0.072988  0.874934   atis_133
# 1  0.336752 -0.105319  atis_1386
# 2 -0.100516  0.458891  atis_1614
# 3  0.193439 -0.259281  atis_1670
# 4 -0.704151 -0.450227  atis_1824
# 5 -0.383592  0.681133  atis_2178
# 6  0.570627 -0.555358  atis_2591
# 7  0.244453 -0.792259  atis_2752
# 8 -0.497627  0.060864  atis_2762
# 9  0.267626  0.086622  atis_2989
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.165789 -0.009111  0.299654  0.000078
# 1                       banking77  0.353220 -0.167982 -0.795949 -0.213337
# 2                        clinc150  0.646953  0.344849 -0.559740 -0.027539
# 3  clinicalDialogueSummarizations -0.668307 -0.493613  0.538286 -0.101340
# 4                   dementiaAudio  0.873216  1.409812 -1.434346  0.056427
# 5                    huffPostNews  0.541111  0.356322  0.074629  1.105909
# 6                medicalAbstracts -1.364437 -0.614117  0.990034  0.242686
# 7                          simSUM -0.780144  0.138578  0.881805 -0.960014
# 8     syntheticCareHomeNurseNotes  0.627498  0.123129  0.406357 -0.431153
# 9                           yahoo -0.063323 -1.087866 -0.400731  0.328282
#
#    factor_5  factor_6     doc_id
# 0  0.324785  0.768212  atis_1738
# 1  0.596487 -0.345776  atis_2019
# 2 -0.055491  0.308779  atis_2428
# 3  0.257395 -0.318893  atis_2509
# 4 -0.659724  0.262855  atis_2984
# 5 -0.653387  0.762666    atis_40
# 6  0.478085 -0.630314     atis_5
# 7  0.616502 -0.641226   atis_501
# 8 -1.109703  0.009313   atis_654
# 9  0.205051 -0.175618   atis_812
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.122946 -0.127538  0.229262  0.031122
# 1                       banking77  0.429060 -0.162902 -0.525744 -0.344386
# 2                        clinc150  0.149772  0.382274 -0.690500 -0.241349
# 3  clinicalDialogueSummarizations -0.399970 -0.987053  0.417373 -0.840893
# 4                   dementiaAudio  1.197078  1.592108 -1.245812  0.233689
# 5                    huffPostNews  0.631249  0.212504 -0.220151  0.942114
# 6                medicalAbstracts -1.496433 -0.475332  0.849682 -0.127087
# 7                          simSUM -0.826751  0.140012  1.320374 -0.859940
# 8     syntheticCareHomeNurseNotes  0.543793 -0.090953 -0.062024  0.325905
# 9                           yahoo -0.104852 -0.483121 -0.072460  0.880825
#
#    factor_5  factor_6     doc_id
# 0  0.206193  0.608920  atis_1153
# 1  0.029871  0.154230  atis_1288
# 2  0.095431 -0.058585  atis_1574
# 3  0.369215 -0.690401  atis_1688
# 4 -0.770015  0.456503  atis_1994
# 5 -0.184388  0.277088  atis_2205
# 6  0.349690 -0.408061  atis_2261
# 7  0.469426 -0.477651  atis_2981
# 8 -1.189559  0.539417   atis_375
# 9  0.624136 -0.401460   atis_600
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis  0.078818  0.162818 -0.009081 -0.182740
# 1                       banking77  0.691803 -0.358785 -0.653053 -0.295686
# 2                        clinc150  0.476763 -0.175997 -0.385140 -0.041298
# 3  clinicalDialogueSummarizations -0.829429 -0.435291  0.291576 -0.234767
# 4                   dementiaAudio  0.634706  1.122319 -1.541296 -0.262095
# 5                    huffPostNews  0.304297  0.412391  0.532149  1.434542
# 6                medicalAbstracts -1.011623 -0.427504  0.804443  0.313998
# 7                          simSUM -0.867601  0.517989  1.068467 -1.039568
# 8     syntheticCareHomeNurseNotes  0.558552 -0.063979  0.215074  0.186400
# 9                           yahoo -0.036286 -0.753961 -0.323140  0.121213
#
#    factor_5  factor_6     doc_id
# 0  0.295861  0.869730   atis_122
# 1  0.721242 -0.246468  atis_1246
# 2 -0.039785  0.590293   atis_180
# 3  0.082195 -0.244262  atis_1948
# 4 -0.511629 -0.131738  atis_2095
# 5 -0.528212  0.801127  atis_2811
# 6  0.876581 -0.704704   atis_297
# 7  0.695799 -0.913252  atis_3108
# 8 -1.205510  0.211251   atis_629
# 9 -0.386542 -0.231977   atis_979
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.068861  0.031241  0.263171  0.103016
# 1                       banking77  0.577641 -0.029350 -0.742091 -0.213078
# 2                        clinc150  0.648926  0.262012 -0.240152  0.228911
# 3  clinicalDialogueSummarizations -0.795438 -0.683078  0.405765 -1.064147
# 4                   dementiaAudio  1.086370  0.998767 -1.286639  0.073920
# 5                    huffPostNews  0.345316  0.146938  0.104742  1.026030
# 6                medicalAbstracts -1.147475 -0.300209  0.768955  0.399284
# 7                          simSUM -0.960470  0.067079  0.912302 -0.777046
# 8     syntheticCareHomeNurseNotes  0.362102 -0.107164  0.033430 -0.125573
# 9                           yahoo -0.048112 -0.386235 -0.219484  0.348684
#
#    factor_5  factor_6     doc_id
# 0  0.000979  1.006045  atis_1017
# 1  0.425616 -0.317469  atis_1474
# 2  0.109588  0.749206  atis_1524
# 3 -0.066604 -0.784743  atis_1732
# 4 -0.627342  0.540627  atis_1854
# 5 -0.551111  0.583199  atis_2166
# 6  0.723917 -0.502990  atis_2867
# 7  0.731937 -0.818388   atis_557
# 8 -1.253170  0.255990   atis_679
# 9  0.506189 -0.711477   atis_883
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.124000  0.249290  0.161851  0.180630
# 1                       banking77  0.486571 -0.316315 -0.787380 -0.378460
# 2                        clinc150  0.223283  0.518773 -0.604057  0.323281
# 3  clinicalDialogueSummarizations -0.589620 -0.771506  0.614735 -0.530636
# 4                   dementiaAudio  1.076838  1.378180 -1.231831  0.427121
# 5                    huffPostNews -0.129315  0.162155  0.150033  0.903040
# 6                medicalAbstracts -1.265695 -0.435220  1.297219  0.003078
# 7                          simSUM -0.180486  0.154191  0.896195 -0.492047
# 8     syntheticCareHomeNurseNotes  0.487565 -0.315216 -0.128972 -0.522692
# 9                           yahoo  0.014858 -0.624332 -0.367794  0.086684
#
#    factor_5  factor_6     doc_id
# 0  0.027622  0.967676  atis_1682
# 1  0.441183 -0.289474  atis_2065
# 2 -0.200597  0.455183  atis_2093
# 3 -0.134372 -0.336425  atis_2295
# 4 -1.110594  1.000675  atis_2308
# 5  0.324953  0.304926  atis_2864
# 6  0.875481 -0.661368  atis_3292
# 7  0.166800 -0.582366   atis_343
# 8 -0.945315 -0.196156   atis_399
# 9  0.554840 -0.662670   atis_822
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.248369  0.047194 -0.076951  0.182276
# 1                       banking77  0.491102 -0.507753 -0.309060 -0.256776
# 2                        clinc150  0.317785 -0.180321 -0.612906 -0.025061
# 3  clinicalDialogueSummarizations -0.790629 -0.317147  0.629171 -0.577418
# 4                   dementiaAudio  1.137440  1.212026 -1.445239 -0.447927
# 5                    huffPostNews  0.184133  0.184198 -0.278484  1.322690
# 6                medicalAbstracts -1.398439 -0.318097  1.152287 -0.015683
# 7                          simSUM -0.903112 -0.251878  0.901658 -1.039923
# 8     syntheticCareHomeNurseNotes  0.564034  0.004479 -0.168250  0.042137
# 9                           yahoo  0.646056  0.127299  0.207775  0.815684
#
#    factor_5  factor_6     doc_id
# 0  0.117740  1.208211   atis_117
# 1  0.351322 -0.140321  atis_1586
# 2 -0.124224  0.349232  atis_1759
# 3  1.098528 -0.831796  atis_1852
# 4 -0.854156 -0.221539  atis_2406
# 5 -0.244481  0.780060  atis_2493
# 6  0.389188 -0.420098  atis_2513
# ...
# 0                            atis -0.245086  0.134132  0.205981  0.213893
# 1                       banking77  1.004845  0.028637 -0.720697 -0.086570
# 2                        clinc150  0.528864 -0.037950 -0.150853  0.224704
# 3  clinicalDialogueSummarizations -0.765085 -0.852129  0.478341 -0.911480
# 4                   dementiaAudio  0.792631  0.901044 -1.612842  0.033075
# 5                    huffPostNews -0.148075 -0.416986  0.155834  0.618308
# 6                medicalAbstracts -1.554498  0.005424  1.050133  0.081819
# 7                          simSUM -0.518129  0.353178  0.813935 -0.518224
# 8     syntheticCareHomeNurseNotes  0.868147  0.376320 -0.238922  0.388182
# 9                           yahoo  0.036386 -0.491670  0.019090 -0.043707
#
#    factor_5  factor_6     doc_id
# 0  0.041823  0.751651  atis_1634
# 1  0.312087  0.001632  atis_1809
# 2  0.039209  0.757370  atis_2270
# 3 -0.261903 -0.046655  atis_2649
# 4 -0.713703  0.203035  atis_2758
# 5 -0.370778  0.256961  atis_2842
# 6  0.810530 -0.515194  atis_3267
# 7  0.441095 -0.615565   atis_552
# 8 -0.687327 -0.003113    atis_81
# 9  0.388966 -0.790121   atis_838
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.311200  0.053867  0.259107  0.272539
# 1                       banking77  0.576868 -0.163657 -0.873717 -0.165536
# 2                        clinc150  0.502091  0.151335 -0.486817 -0.066877
# 3  clinicalDialogueSummarizations -0.767013 -0.474271  0.720146 -0.864873
# 4                   dementiaAudio  0.981004  1.147961 -1.574448 -0.204428
# 5                    huffPostNews  0.445856 -0.039476 -0.051665  1.062915
# 6                medicalAbstracts -1.526367 -0.130403  1.086117 -0.014848
# 7                          simSUM -0.817407  0.055254  0.946312 -0.680937
# 8     syntheticCareHomeNurseNotes  0.635596  0.012480  0.247467 -0.044449
# 9                           yahoo  0.280571 -0.613089 -0.272500  0.706493
#
#    factor_5  factor_6     doc_id
# 0 -0.306539  1.155908  atis_2271
# 1  0.612904 -0.111771  atis_2282
# 2 -0.193745  0.481263  atis_2399
# 3  0.515807 -0.664977  atis_2816
# 4 -0.718937 -0.208621  atis_2900
# 5 -0.367514  0.903877  atis_2942
# 6  0.913830 -0.631504  atis_3072
# 7  0.954013 -0.848620   atis_333
# 8 -1.011461 -0.007966   atis_466
# 9 -0.398358 -0.067591   atis_657
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.440054 -0.125051  0.437610  0.186934
# 1                       banking77  0.702006 -0.278625 -0.721487 -0.206864
# 2                        clinc150  0.668466  0.516791 -0.313240  0.297662
# 3  clinicalDialogueSummarizations -0.909843 -0.474138  0.692507 -0.478502
# 4                   dementiaAudio  1.059697  1.495538 -1.771271 -0.151002
# 5                    huffPostNews  0.035749  0.048698 -0.076700  0.949512
# 6                medicalAbstracts -1.397410 -0.459742  1.081412 -0.211196
# 7                          simSUM -0.577784  0.094931  0.689378 -1.117832
# 8     syntheticCareHomeNurseNotes  0.426276 -0.361139  0.460141  0.015567
# 9                           yahoo  0.432898 -0.457263 -0.478352  0.715719
#
#    factor_5  factor_6     doc_id
# 0 -0.099203  1.039656     atis_0
# 1  0.438992 -0.313779  atis_1214
# 2  0.015098  0.492029  atis_1391
# 3  0.688640 -0.447968    atis_14
# 4 -0.975272 -0.062633  atis_1488
# 5 -0.571227  0.311924  atis_2673
# 6  1.209755 -0.727403  atis_3178
# 7  0.397710 -0.736123   atis_499
# 8 -1.110950  0.321106   atis_551
# 9  0.006457  0.123191   atis_830
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.264021  0.326408 -0.010049  0.020386
# 1                       banking77  0.222313 -0.115666 -0.638511 -0.268588
# 2                        clinc150  0.488826  0.097817 -0.394140  0.014273
# 3  clinicalDialogueSummarizations -0.692409 -0.622801  0.676722 -0.263415
# 4                   dementiaAudio  1.264415  1.119493 -1.658652  0.247497
# 5                    huffPostNews  0.420011  0.256962 -0.166722  0.384332
# 6                medicalAbstracts -1.232081 -0.238320  1.305149  0.368535
# 7                          simSUM -0.601704 -0.158500  0.905117 -1.120775
# 8     syntheticCareHomeNurseNotes  0.356162  0.060223 -0.077435  0.151617
# 9                           yahoo  0.038487 -0.725617  0.058521  0.466137
#
#    factor_5  factor_6     doc_id
# 0  0.196692  0.652632  atis_1586
# 1  0.318542 -0.260937  atis_1587
# 2 -0.006903  0.566234  atis_1646
# 3  0.641261 -0.611459  atis_1855
# 4 -0.638911  0.539309  atis_1864
# 5 -0.588131  0.300344  atis_2261
# 6  1.052063 -0.477584  atis_2297
# 7  0.046687 -0.614324  atis_2738
# 8 -1.020883  0.315435   atis_441
# 9 -0.000417 -0.409650   atis_739
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.241782 -0.225520  0.145222  0.120776
# 1                       banking77  0.645271 -0.088219 -0.724693  0.082356
# 2                        clinc150  0.452829  0.140150 -0.518512 -0.089874
# 3  clinicalDialogueSummarizations -0.491638 -0.705252  0.644827 -0.217316
# 4                   dementiaAudio  1.247554  1.511274 -1.511588  0.612463
# 5                    huffPostNews  0.460115  0.498716  0.129160  0.990703
# 6                medicalAbstracts -1.492315 -0.524298  0.946292 -0.125759
# 7                          simSUM -0.603138  0.311453  0.934218 -0.772510
# 8     syntheticCareHomeNurseNotes  0.194713 -0.316681 -0.089910 -0.721328
# 9                           yahoo -0.171609 -0.601621  0.044983  0.120488
#
#    factor_5  factor_6     doc_id
# 0  0.196602  0.681945   atis_100
# 1  0.456998 -0.088849  atis_1028
# 2 -0.064143  0.370684   atis_112
# 3 -0.383406 -0.244465  atis_1372
# 4 -0.607265  0.294510  atis_1911
# 5 -0.523348  0.440560  atis_2311
# 6  0.745330 -0.548318   atis_358
# 7  0.550297 -0.675874   atis_431
# 8 -0.876609 -0.033170   atis_449
# 9  0.505543 -0.197023   atis_783
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.127835  0.073999 -0.146163  0.406004
# 1                       banking77  0.292144 -0.521496 -0.434671 -0.394912
# 2                        clinc150  0.532452  0.131507 -0.486914  0.197262
# 3  clinicalDialogueSummarizations -0.632550 -1.194345  0.545680 -0.960678
# 4                   dementiaAudio  0.967618  1.494176 -1.412345  0.118082
# 5                    huffPostNews  0.626919  0.203853 -0.252507  0.955398
# 6                medicalAbstracts -1.359239 -0.051535  1.302555 -0.032918
# 7                          simSUM -0.952770  0.058681  0.970916 -0.821228
# 8     syntheticCareHomeNurseNotes  0.476683  0.272133 -0.039798  0.117364
# 9                           yahoo  0.176578 -0.466974 -0.046753  0.415626
#
#    factor_5  factor_6     doc_id
# 0  0.085250  0.785745  atis_1225
# 1  0.630157 -0.391415  atis_2043
# 2 -0.209523  0.632343   atis_230
# 3 -0.163727 -0.156374  atis_2561
# 4 -0.554608 -0.112683  atis_2901
# 5 -0.555569  0.720607  atis_3209
# 6  1.205373 -0.722603  atis_3307
# 7  0.576632 -0.754584  atis_3348
# 8 -1.121815  0.194662    atis_42
# 9  0.107830 -0.195698   atis_594
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.264758 -0.010400 -0.004817  0.139209
# 1                       banking77  0.598532 -0.066282 -0.756184  0.040489
# 2                        clinc150  0.654841  0.054757 -0.692822  0.306604
# 3  clinicalDialogueSummarizations -0.446846  0.066544  0.667565 -0.569618
# 4                   dementiaAudio  0.939597  1.751597 -1.244939 -0.083522
# 5                    huffPostNews  0.265766 -0.638656  0.224530  0.659066
# 6                medicalAbstracts -1.476432 -0.086836  1.384591 -0.084210
# 7                          simSUM -0.417662  0.182893  0.843598 -1.127379
# 8     syntheticCareHomeNurseNotes  0.262737 -0.335273 -0.342931  0.073812
# 9                           yahoo -0.115774 -0.918343 -0.078589  0.645550
#
#    factor_5  factor_6     doc_id
# 0 -0.017893  1.096870  atis_1016
# 1  0.353944  0.185009  atis_1746
# 2 -0.123248  1.209515  atis_2131
# 3  0.653579 -0.681856   atis_308
# 4 -0.542135 -0.258905  atis_3098
# 5 -0.443717 -0.052442  atis_3440
# 6  1.234073 -0.662030  atis_3474
# 7 -0.054900 -0.479339    atis_47
# 8 -1.154691  0.006021   atis_713
# 9  0.094989 -0.362844   atis_812
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.141686 -0.087739 -0.166512  0.302684
# 1                       banking77  0.300842 -0.122456 -0.529006 -0.210130
# 2                        clinc150  0.399180  0.328959 -0.189957  0.453168
# 3  clinicalDialogueSummarizations -1.012039 -0.577708  0.627906 -0.928275
# 4                   dementiaAudio  0.951374  1.068185 -1.391082 -0.115661
# 5                    huffPostNews  0.605845  0.598663  0.113711  1.023480
# 6                medicalAbstracts -1.221056 -0.386425  1.103791  0.233347
# 7                          simSUM -0.756953 -0.017100  0.815404 -1.016174
# 8     syntheticCareHomeNurseNotes  0.755106 -0.050444 -0.334950  0.043256
# 9                           yahoo  0.119386 -0.753935 -0.049305  0.214306
#
#    factor_5  factor_6     doc_id
# 0  0.053836  0.682913    atis_11
# 1  0.725996 -0.348264   atis_131
# 2 -0.451384  0.836911  atis_1378
# 3  0.522418 -1.192929  atis_1727
# 4 -0.609051  0.028345  atis_1917
# 5 -0.444237  0.854106  atis_2075
# 6  0.616596 -0.396961  atis_2111
# 7  0.060640 -0.464305   atis_248
# 8 -0.581317  0.198276  atis_2900
# 9  0.106505 -0.198094  atis_3245
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.149382  0.353903 -0.116904  0.149698
# 1                       banking77  0.734889 -0.287970 -0.850508 -0.261196
# 2                        clinc150  0.622167  0.445446 -0.727860  0.277734
# 3  clinicalDialogueSummarizations -0.694083 -0.484040  0.642987 -0.264181
# 4                   dementiaAudio  0.782454  1.126218 -1.430435  0.031421
# 5                    huffPostNews  0.467078 -0.121300  0.005892  0.891202
# 6                medicalAbstracts -1.449579 -0.105599  1.244748  0.042081
# 7                          simSUM -0.860975 -0.101859  0.862604 -0.885710
# 8     syntheticCareHomeNurseNotes  0.472213 -0.164819  0.025812 -0.419891
# 9                           yahoo  0.075218 -0.659981  0.343664  0.438841
#
#    factor_5  factor_6     doc_id
# 0  0.206923  0.622576   atis_112
# 1  0.766635 -0.287806  atis_1197
# 2 -0.185833  0.483597  atis_1687
# 3  0.369135 -0.382904  atis_1789
# 4 -0.527368  0.434902  atis_1834
# 5 -0.965647  0.732740  atis_1972
# 6  0.628652 -0.532499  atis_2215
# 7  0.013973 -0.488607  atis_2524
# 8 -0.640479 -0.361478  atis_2651
# 9  0.334010 -0.220521   atis_668
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.390529  0.229456  0.068221  0.179176
# 1                       banking77  0.218378 -0.346432 -0.316097 -0.287147
# 2                        clinc150  0.328909  0.136573 -0.463722  0.213523
# 3  clinicalDialogueSummarizations -0.236043 -0.559740  0.332905 -0.537347
# 4                   dementiaAudio  1.242551  1.430867 -1.516843  0.101835
# 5                    huffPostNews -0.069455 -0.223413  0.544147  0.023131
# 6                medicalAbstracts -1.445149 -0.062973  1.301656 -0.004456
# 7                          simSUM -0.513007  0.121686  0.841300 -0.610791
# 8     syntheticCareHomeNurseNotes  0.465284 -0.360802 -0.152309 -0.087451
# 9                           yahoo  0.399060 -0.365221 -0.639259  1.009527
#
#    factor_5  factor_6     doc_id
# 0 -0.110598  0.950483  atis_1035
# 1  0.250560 -0.335548  atis_1101
# 2 -0.211645  0.819767  atis_1572
# 3 -0.224642 -0.229531  atis_1762
# 4 -0.396845 -0.131393  atis_1826
# 5 -0.112893  0.493947  atis_2647
# 6  0.734205 -0.512727   atis_401
# 7  0.478063 -0.738557   atis_533
# 8 -0.737818 -0.336129   atis_709
# 9  0.331612  0.019688   atis_950
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.087275 -0.043400  0.094005  0.070034
# 1                       banking77  0.727687 -0.010116 -0.573333  0.045523
# 2                        clinc150  0.364022  0.184338 -0.415756  0.227827
# 3  clinicalDialogueSummarizations -0.760246 -0.197153  0.537221 -0.546061
# 4                   dementiaAudio  1.273064  1.351114 -1.767752  0.044641
# 5                    huffPostNews  0.129877  0.119883  0.274658  0.835296
# 6                medicalAbstracts -1.541203 -0.208479  1.240295 -0.133961
# 7                          simSUM -0.577872 -0.095370  0.660673 -0.920883
# 8     syntheticCareHomeNurseNotes  0.641826 -0.459418 -0.228675 -0.221398
# 9                           yahoo -0.169879 -0.641400  0.178663  0.598982
#
#    factor_5  factor_6     doc_id
# 0  0.408783  0.951101  atis_1077
# 1  0.579527  0.058157  atis_1104
# 2  0.153303  0.653383  atis_1193
# 3 -0.028283 -0.146144  atis_1659
# 4 -0.780560 -0.112726  atis_1830
# 5 -0.550085  0.809130  atis_1967
# 6  0.726268 -0.684911  atis_1996
# 7  0.159190 -0.764736  atis_2513
# 8 -1.035815 -0.074616   atis_587
# 9  0.367674 -0.688638   atis_604
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.169092 -0.095689 -0.138131  0.219598
# 1                       banking77  0.568357 -0.250315 -0.633501 -0.104374
# 2                        clinc150  0.712578  0.438444 -0.645758  0.367222
# 3  clinicalDialogueSummarizations -0.307254 -0.335720  0.685189 -0.192255
# 4                   dementiaAudio  0.969539  0.850398 -1.399795 -0.226969
# 5                    huffPostNews -0.094245  0.050793  0.128642  0.456945
# 6                medicalAbstracts -1.390130 -0.261485  1.317615  0.250855
# 7                          simSUM -1.023413  0.365289  0.703208 -0.704072
# 8     syntheticCareHomeNurseNotes  0.195147 -0.053165  0.367777 -0.295799
# 9                           yahoo  0.538514 -0.708550 -0.385246  0.228851
#
#    factor_5  factor_6     doc_id
# 0 -0.065410  0.766768  atis_1270
# 1  0.440575  0.026021  atis_1721
# 2 -0.228353  0.653707  atis_2256
# 3 -0.355008 -0.353714  atis_2267
# 4 -0.978129 -0.307056  atis_2434
# 5 -0.490184  0.360396  atis_2469
# 6  0.962683 -0.520402  atis_2683
# 7  0.538144 -0.756106  atis_2862
# 8 -0.206727  0.202389  atis_3236
# 9  0.382409 -0.072003  atis_3411
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.208899 -0.370548  0.118952 -0.029261
# 1                       banking77  0.506078 -0.700092 -0.491944 -0.440303
# 2                        clinc150  0.406895  0.135156 -0.508765 -0.028184
# 3  clinicalDialogueSummarizations -0.384670 -0.619720  0.492756 -0.260822
# 4                   dementiaAudio  1.004740  0.802671 -1.586032 -0.068848
# 5                    huffPostNews  0.120763  0.583954  0.116131  1.344918
# 6                medicalAbstracts -1.362150 -0.044626  1.252928  0.072685
# 7                          simSUM -0.571628  0.308095  0.541340 -0.865186
# 8     syntheticCareHomeNurseNotes  0.811126  0.631854  0.350380 -0.164354
# 9                           yahoo -0.322256 -0.726745 -0.285747  0.439355
#
#    factor_5  factor_6     doc_id
# 0  0.048913  0.941759   atis_106
# 1  0.655924 -0.398315   atis_124
# 2 -0.230407  0.365614  atis_1704
# 3  0.243664 -0.324087  atis_1960
# 4 -0.569135  0.314668  atis_2031
# 5 -0.126588  0.359978  atis_2396
# 6  0.840407 -0.493035  atis_2685
# 7 -0.333168 -0.473986   atis_323
# 8 -0.961802  0.263521  atis_3278
# 9  0.432192 -0.556115   atis_443

# %%
# Get all CSV files.
all_files = glob.glob("./outputsTrain/*/mean_model_zero_shot_classification.csv")  # change this to your folder path

# Loop through files.
all_dfs = []

for f in all_files:
    df = pd.read_csv(f)
    # Extract categories from doc_id
    doc_ids = df['doc_id']
    df['category'] = df['doc_id'].apply(lambda x: x.split('_')[0])
    
    # Aggregate numeric factor columns by category
    factor_cols = [f"factor_{i}" for i in range(1, 7)]
    df_agg = df.groupby('category')[factor_cols].mean().reset_index()
    df_agg['doc_id'] = doc_ids
    print(df_agg)
    all_dfs.append(df_agg)

# Concatenate all aggregated DataFrames
dfs = pd.concat(all_dfs, ignore_index=True)

dim_red_results = all_dim_red_methods(dfs)
plot_results(dim_red_results)
# Use UMAP as chosen method.
dfs = put_embeddings_in_df(dfs, umap.UMAP)
draw_dim_red_plot(dfs)
# Out:
# /home/isabel/anaconda3/envs/realData/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# /home/isabel/anaconda3/envs/realData/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(

# %%
# Get all CSV files.
all_files = glob.glob("./outputsTrain/*/mda_dim_scores.csv")  # change this to your folder path

# Loop through files.
all_dfs = []

for f in all_files:
    df = pd.read_csv(f)
    # Extract categories from doc_id
    doc_ids = df['doc_id']
    df['category'] = df['doc_id'].apply(lambda x: x.split('_')[0])
    
    # Aggregate numeric factor columns by category
    factor_cols = [f"factor_{i}" for i in range(1, 7)]
    df_agg = df.groupby('category')[factor_cols].mean().reset_index()
    df_agg['doc_id'] = doc_ids
    print(df_agg)
    all_dfs.append(df_agg)

# Concatenate all aggregated DataFrames
dfs = pd.concat(all_dfs, ignore_index=True)

dim_red_results = all_dim_red_methods(dfs)
plot_results(dim_red_results)
# Use UMAP as chosen method.
dfs = put_embeddings_in_df(dfs, umap.UMAP)
draw_dim_red_plot(dfs)
# Out:
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.670573 -0.599659  0.414005 -0.296522
# 1                       banking77  1.088952  0.040388 -0.774786  0.965327
# 2                        clinc150  0.137088 -0.512090 -0.385258  0.426517
# 3  clinicalDialogueSummarizations -0.247006  0.546923 -0.035581 -0.539193
# 4                   dementiaAudio  1.364835 -0.289053 -0.231418 -0.400903
# 5                    huffPostNews  0.117585 -0.130985 -0.332246  0.081881
# 6                medicalAbstracts -0.629761 -0.438488  0.953657 -0.236547
# 7                          simSUM -1.018689  0.321578  0.253672 -0.679934
# 8     syntheticCareHomeNurseNotes -0.529095  1.630855  0.273385  0.094890
# 9                           yahoo  0.386662 -0.569469 -0.135429  0.584484
#
#    factor_5  factor_6     doc_id
# 0 -0.461816 -0.024145  atis_1448
# 1 -0.337183  0.180077  atis_1577
# 2 -0.159137 -0.337850  atis_1593
# 3  0.206466 -0.161713  atis_2129
# 4 -0.301231 -0.337850  atis_2325
# 5  0.191365  0.336930  atis_2450
# 6  0.711749  0.443960  atis_2451
# 7 -0.155784 -0.337850  atis_3431
# 8  0.231468  0.166319   atis_872
# 9  0.074104  0.072121   atis_988
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.602478 -0.532554  0.128086 -0.607640
# 1                       banking77  0.898209  0.172868 -0.866345  0.918746
# 2                        clinc150  0.312468 -0.397980  0.020747  0.242475
# 3  clinicalDialogueSummarizations -0.438938 -0.221664  0.605265 -0.588782
# 4                   dementiaAudio  1.472851 -0.304983 -0.307970 -0.154224
# 5                    huffPostNews  0.167850  0.017541 -0.383002  0.475742
# 6                medicalAbstracts -0.527427 -0.314134  0.509608 -0.436361
# 7                          simSUM -0.861451  0.635068  0.283775 -0.659778
# 8     syntheticCareHomeNurseNotes -0.934081  1.583177  0.631992  0.449193
# 9                           yahoo  0.512998 -0.637339 -0.622156  0.360628
#
#    factor_5  factor_6     doc_id
# 0 -0.421444 -0.448844  atis_1474
# 1  0.193650 -0.160769  atis_1558
# 2 -0.421444 -0.448844  atis_1691
# 3 -0.195161  0.126890  atis_2064
# 4 -0.253878  0.114362  atis_2501
# 5 -0.018500  0.026687  atis_3395
# 6  1.163229  0.673018   atis_455
# 7 -0.198787 -0.369016    atis_53
# 8 -0.125097 -0.160769   atis_773
# 9  0.277431  0.647286    atis_79
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -1.029453 -0.436223  0.021759 -0.616708
# 1                       banking77  1.211143 -0.287607 -0.827744  1.113497
# 2                        clinc150  0.189948 -0.729179  0.254409  0.380573
# 3  clinicalDialogueSummarizations -0.222527  0.583838  0.239820 -0.206153
# 4                   dementiaAudio  1.247631 -0.361848 -0.474671 -0.170906
# 5                    huffPostNews  0.145193 -0.136352 -0.285861 -0.066262
# 6                medicalAbstracts -0.441230 -0.130418  0.157777 -0.020379
# 7                          simSUM -0.847438  0.681808  0.132242 -0.728002
# 8     syntheticCareHomeNurseNotes -0.690060  1.075175  0.784745  0.056274
# 9                           yahoo  0.436792 -0.259194 -0.002475  0.258067
#
#    factor_5  factor_6     doc_id
# 0 -0.402590 -0.477381  atis_1145
# 1 -0.232764  0.856730  atis_1216
# 2 -0.402590 -0.477381  atis_1807
# 3  0.367525  0.163477  atis_2418
# 4 -0.181771 -0.051947  atis_2507
# 5 -0.402590  0.084147  atis_2721
# 6  0.006703 -0.043456  atis_2932
# 7 -0.343375 -0.427644  atis_3186
# 8  0.405887  0.053738  atis_3231
# 9  1.185566  0.319718   atis_430
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.657952 -0.713519  0.378040 -0.101578
# 1                       banking77  1.301824  0.318109 -1.073117  0.417579
# 2                        clinc150  0.272589 -0.215653 -0.156571  0.017137
# 3  clinicalDialogueSummarizations  0.026533  0.222896  0.375945 -0.369199
# 4                   dementiaAudio  1.061373 -0.271255 -0.161669 -0.425491
# 5                    huffPostNews -0.022058  0.030854 -0.438579  0.518331
# 6                medicalAbstracts -0.542806 -0.667111  0.338949  0.002041
# 7                          simSUM -0.932931  0.581326  0.258911 -0.763878
# 8     syntheticCareHomeNurseNotes -0.871549  0.909756  0.423659 -0.118716
# 9                           yahoo  0.364977 -0.195404  0.054433  0.823773
#
#    factor_5  factor_6     doc_id
# 0 -0.491851 -0.379801  atis_1102
# 1 -0.491851 -0.379801  atis_1425
# 2 -0.491851  0.741953  atis_1670
# 3  0.282208  0.352787  atis_3009
# 4 -0.096977 -0.055616  atis_3089
# 5 -0.120133  0.256587  atis_3139
# 6  0.468146  0.116975  atis_3467
# 7  0.140617 -0.379801    atis_42
# 8  0.770778 -0.198845   atis_773
# 9  0.030913 -0.074437   atis_986
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.631315 -0.483148  0.134895 -0.222070
# 1                       banking77  0.777706  0.510612 -0.653951  0.352658
# 2                        clinc150  0.463860 -0.567042 -0.347854  0.322188
# 3  clinicalDialogueSummarizations -0.643471  0.038446  0.157764 -0.352290
# 4                   dementiaAudio  1.223102 -0.227992  0.191462 -0.454307
# 5                    huffPostNews  0.204065  0.360936 -0.479429  0.998419
# 6                medicalAbstracts -0.778736 -0.520662  0.493746 -0.076858
# 7                          simSUM -0.854284  0.034116  0.305845 -0.754667
# 8     syntheticCareHomeNurseNotes -0.665091  1.339279  0.768802 -0.071777
# 9                           yahoo  0.904164 -0.484546 -0.571279  0.258703
#
#    factor_5  factor_6     doc_id
# 0 -0.508081 -0.419430  atis_1607
# 1 -0.396152  0.799098  atis_1670
# 2  0.133392 -0.419430  atis_1684
# 3  0.212559 -0.055252  atis_1996
# 4 -0.298651  0.503325  atis_2075
# 5  0.057602  0.396170  atis_2194
# 6  0.779896  0.162761  atis_2613
# 7  0.016161 -0.419430  atis_3179
# 8 -0.020702 -0.419430  atis_3236
# 9  0.023976 -0.128382   atis_431
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.620625 -0.490108 -0.066354 -0.532361
# 1                       banking77  1.243411 -0.111663 -0.474417  1.114068
# 2                        clinc150 -0.031367 -0.641589 -0.601214 -0.125611
# 3  clinicalDialogueSummarizations -0.537919  0.232721  0.149895 -0.143262
# 4                   dementiaAudio  1.062679 -0.298397 -0.105182 -0.053121
# 5                    huffPostNews  0.263679 -0.080731  0.191646  0.244908
# 6                medicalAbstracts -0.727685 -0.341568  0.620685 -0.420136
# 7                          simSUM -0.816881  0.960434  0.175860 -0.683781
# 8     syntheticCareHomeNurseNotes -0.739044  1.185480  0.427755 -0.193497
# 9                           yahoo  0.903750 -0.414579 -0.318673  0.792790
#
#    factor_5  factor_6     doc_id
# 0 -0.473921 -0.385492  atis_1119
# 1  0.339383 -0.385492  atis_1989
# 2 -0.473921 -0.385492  atis_1996
# 3 -0.178933  0.129018  atis_2258
# 4 -0.226755  1.019554  atis_2818
# 5  0.267504  0.248894  atis_2902
# 6  1.022748  0.723455  atis_3171
# 7 -0.024125 -0.385492  atis_3231
# 8 -0.066593 -0.385492  atis_3250
# 9 -0.185387 -0.193462  atis_3365
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.722322 -0.590161 -0.136932 -0.482786
# 1                       banking77  0.705753  0.189224 -0.737658  0.263916
# 2                        clinc150  0.240003 -0.214752 -0.218427  0.433211
# 3  clinicalDialogueSummarizations -0.419424  0.188547  0.369656 -0.366209
# 4                   dementiaAudio  1.424131 -0.579933 -0.309818  0.127036
# 5                    huffPostNews  0.158022  0.550500 -0.749844  0.953436
# 6                medicalAbstracts -0.639544 -0.536263  0.489685 -0.520691
# 7                          simSUM -1.021905  0.348468  0.447038 -0.730638
# 8     syntheticCareHomeNurseNotes -0.759735  1.482182  1.001411  0.034454
# 9                           yahoo  1.035022 -0.837812 -0.155110  0.288271
#
#    factor_5  factor_6     doc_id
# 0 -0.447851 -0.362279  atis_1102
# 1 -0.447851  0.454812  atis_1410
# 2  0.309803  0.146524  atis_1785
# 3 -0.293287 -0.047936  atis_2132
# 4 -0.149280  0.489623  atis_2282
# 5 -0.286785  0.043942  atis_2424
# 6  0.908754 -0.055276  atis_2436
# 7 -0.084927 -0.362279   atis_422
# 8  0.675055 -0.362279   atis_796
# 9 -0.183630  0.055146   atis_894
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.834453 -0.487617 -0.233769 -0.591853
# 1                       banking77  0.822744  0.025378 -0.441852  0.992344
# 2                        clinc150  0.319737 -0.774325 -0.524005  0.113998
# 3  clinicalDialogueSummarizations -0.419274  0.417489  0.168897 -0.657814
# 4                   dementiaAudio  1.477369 -0.302578 -0.160812 -0.116893
# 5                    huffPostNews  0.235133 -0.071930  0.811176  0.212037
# 6                medicalAbstracts -0.620567 -0.341244  0.243583 -0.243419
# 7                          simSUM -0.947916  0.541727  0.433932 -0.807813
# 8     syntheticCareHomeNurseNotes -0.941264  0.844168  0.454289  0.116082
# 9                           yahoo  0.908492  0.148932 -0.751438  0.983332
#
#    factor_5  factor_6     doc_id
# 0 -0.425710 -0.374219  atis_1139
# 1 -0.287104  0.094425  atis_1197
# 2 -0.099986 -0.089483  atis_1880
# 3 -0.281207 -0.315639  atis_2140
# 4 -0.405969  0.101397  atis_2673
# 5  0.056041  0.689227  atis_2994
# 6  1.467605  0.590496  atis_3317
# 7 -0.074458 -0.327413   atis_392
# 8 -0.073704 -0.374219    atis_80
# 9  0.124492  0.005429   atis_864
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.577525 -0.624692  0.132257  0.003615
# 1                       banking77  1.077142 -0.781794 -1.199753  0.016731
# 2                        clinc150  0.316935 -0.458585  0.025503  0.600414
# 3  clinicalDialogueSummarizations -0.151371  0.122749  0.242552 -0.371172
# 4                   dementiaAudio  0.973699 -0.231825  0.235585  0.094477
# 5                    huffPostNews -0.155046  0.564654 -0.372884  0.338421
# 6                medicalAbstracts -0.746905 -0.019584  0.477256 -0.467924
# 7                          simSUM -0.970689  0.708680  0.102920 -0.631844
# 8     syntheticCareHomeNurseNotes -0.618391  1.152120  0.629508 -0.099835
# 9                           yahoo  0.852150 -0.431723 -0.272946  0.517117
#
#    factor_5  factor_6     doc_id
# 0 -0.417102 -0.241751  atis_1083
# 1 -0.193697  0.981714  atis_1217
# 2 -0.417102 -0.241751  atis_1328
# 3 -0.089175  0.199076  atis_1522
# 4 -0.171503 -0.166630   atis_209
# 5  0.633842 -0.241751  atis_2233
# 6  1.403371  0.176843   atis_284
# 7 -0.306996 -0.241751  atis_3479
# 8 -0.236250  0.017750   atis_384
# 9 -0.205388 -0.241751   atis_456
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.517388 -0.612735  0.042225 -0.502559
# 1                       banking77  1.091088  0.311661 -1.218156  0.153489
# 2                        clinc150 -0.224479 -0.515838 -0.043786  0.619559
# 3  clinicalDialogueSummarizations -0.407471  0.157596  0.302779 -0.519337
# 4                   dementiaAudio  0.962230 -0.425919 -0.143422 -0.432104
# 5                    huffPostNews  0.233351  0.291719  0.118951 -0.305417
# 6                medicalAbstracts -0.673385 -0.431077  0.410174  0.180495
# 7                          simSUM -0.980107  0.456770  0.210044 -0.709751
# 8     syntheticCareHomeNurseNotes -0.779952  1.216834  0.389758  0.217929
# 9                           yahoo  1.296115 -0.449010 -0.068566  1.297695
#
#    factor_5  factor_6     doc_id
# 0 -0.390539 -0.334695  atis_1109
# 1  0.218941  0.514188   atis_113
# 2 -0.017778 -0.334695  atis_1153
# 3 -0.126398 -0.334695  atis_1944
# 4 -0.172872 -0.227574  atis_2092
# 5  0.391934  0.397987  atis_2432
# 6  0.654215  0.191198  atis_2624
# 7 -0.172879 -0.334695  atis_2956
# 8 -0.390539 -0.334695   atis_308
# 9  0.005915  0.797677  atis_3120
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.855796 -0.514299  0.109564 -0.437734
# 1                       banking77  0.739959 -0.442545 -0.287338  0.636088
# 2                        clinc150  0.302381 -0.043589 -0.486502  0.975220
# 3  clinicalDialogueSummarizations -0.270448  0.266020 -0.088246 -0.422481
# 4                   dementiaAudio  1.309074 -0.366342 -0.099709 -0.384342
# 5                    huffPostNews  0.140794 -0.015724 -0.241840 -0.287067
# 6                medicalAbstracts -0.648653 -0.535561  0.011931 -0.160939
# 7                          simSUM -0.858920  0.571328  0.289970 -0.637029
# 8     syntheticCareHomeNurseNotes -0.741706  0.969275  1.089811 -0.138804
# 9                           yahoo  0.883316  0.111437 -0.297641  0.857088
#
#    factor_5  factor_6     doc_id
# 0 -0.473243 -0.306345  atis_1187
# 1 -0.206459 -0.068022  atis_1355
# 2 -0.185937  0.155405  atis_1522
# 3  0.080472  0.424415  atis_2243
# 4 -0.150348 -0.037342  atis_2642
# 5  0.332521 -0.306345  atis_2895
# 6  1.155533  0.440833  atis_3186
# 7 -0.282080 -0.306345  atis_3262
# 8 -0.136848 -0.306345  atis_3270
# 9 -0.133610  0.310091  atis_3457
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.544249 -0.743898  0.090386 -0.116412
# 1                       banking77  1.257782 -0.263701 -1.017412 -0.090695
# 2                        clinc150  0.442129 -0.410286 -0.104656  1.580786
# 3  clinicalDialogueSummarizations -0.654724  0.749647  0.197562 -0.670775
# 4                   dementiaAudio  1.230160 -0.245321 -0.570008 -0.268460
# 5                    huffPostNews  0.055101 -0.080273 -0.031360  0.284428
# 6                medicalAbstracts -0.577069 -0.496820  0.843294 -0.096775
# 7                          simSUM -0.865834  0.556539  0.144538 -0.742339
# 8     syntheticCareHomeNurseNotes -0.608703  1.352533  0.846943  0.037822
# 9                           yahoo  0.265406 -0.418420 -0.399287  0.082421
#
#    factor_5  factor_6     doc_id
# 0 -0.486968 -0.407355  atis_1012
# 1  0.165618 -0.112217  atis_1557
# 2  0.418749 -0.407355  atis_1740
# 3 -0.347550 -0.064408   atis_180
# 4 -0.179413 -0.161331   atis_192
# 5  0.232633  0.701718   atis_268
# 6  0.372524  0.471731  atis_2830
# 7 -0.009184 -0.407355  atis_3103
# 8 -0.165193 -0.112217   atis_345
# 9 -0.001217  0.498792   atis_567
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.687739 -0.730108 -0.289585 -0.718717
# 1                       banking77  0.807377  0.026277 -0.113526 -0.326295
# 2                        clinc150  0.001096 -0.428871  0.024183  0.312009
# 3  clinicalDialogueSummarizations -0.513448  0.392214  0.405165  0.123864
# 4                   dementiaAudio  1.512458 -0.226451  0.037294  0.279280
# 5                    huffPostNews  0.200310 -0.235925 -0.519178  0.123425
# 6                medicalAbstracts -0.665890 -0.382257  0.849878 -0.185544
# 7                          simSUM -0.982041  0.657263  0.163231 -0.718717
# 8     syntheticCareHomeNurseNotes -0.600062  1.739880  0.020547 -0.248883
# 9                           yahoo  0.927939 -0.812021 -0.578008  1.359578
#
#    factor_5  factor_6     doc_id
# 0 -0.500116 -0.364003   atis_107
# 1 -0.000007  0.120548  atis_1465
# 2 -0.500116  0.169105  atis_1985
# 3  0.379519  0.221570  atis_2518
# 4 -0.214806  0.477623  atis_2539
# 5  0.214153 -0.055652   atis_272
# 6  0.890338  0.397193  atis_2753
# 7  0.106112 -0.364003  atis_2828
# 8 -0.273376 -0.364003  atis_3000
# 9 -0.101701 -0.238378   atis_470
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.641130 -0.519768  0.272285 -0.114358
# 1                       banking77  0.709022 -0.361618 -0.339449  0.675052
# 2                        clinc150 -0.292355 -0.549446  0.043618  0.225711
# 3  clinicalDialogueSummarizations -0.450716  0.133962  0.728286 -0.319112
# 4                   dementiaAudio  1.295914 -0.130449 -0.298382 -0.085419
# 5                    huffPostNews  0.504012 -0.183954 -1.117092  0.117974
# 6                medicalAbstracts -0.566719  0.070230  0.334970 -0.443156
# 7                          simSUM -0.780498  0.629698  0.320970 -0.625346
# 8     syntheticCareHomeNurseNotes -0.819885  1.194741  0.814467 -0.093685
# 9                           yahoo  1.042355 -0.283395 -0.759673  0.662340
#
#    factor_5  factor_6     doc_id
# 0 -0.058350 -0.349856  atis_1332
# 1 -0.134558  0.945433  atis_1517
# 2 -0.085032 -0.349856  atis_1613
# 3  0.678382 -0.349856  atis_1698
# 4 -0.120011  0.201790  atis_1939
# 5  0.578931 -0.349856  atis_2836
# 6  0.152839  0.466220  atis_3400
# 7 -0.390071 -0.349856   atis_422
# 8 -0.450326 -0.349856   atis_749
# 9 -0.171805  0.485692   atis_818
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.548927 -0.538397 -0.231694 -0.160433
# 1                       banking77  1.312132 -0.135161 -0.377602  1.070871
# 2                        clinc150  0.460892 -0.482532 -0.486120  0.213382
# 3  clinicalDialogueSummarizations -0.843348 -0.258602  0.658011 -0.713087
# 4                   dementiaAudio  1.145285 -0.237494 -0.527560 -0.178463
# 5                    huffPostNews -0.111398  0.063720  0.261253  0.208070
# 6                medicalAbstracts -0.490345 -0.205118  0.605414 -0.473587
# 7                          simSUM -0.718804  0.409591  0.132546 -0.631415
# 8     syntheticCareHomeNurseNotes -0.808632  1.611465  0.452340  0.079110
# 9                           yahoo  0.603144 -0.227471 -0.486590  0.585553
#
#    factor_5  factor_6     doc_id
# 0 -0.445570 -0.360634  atis_1088
# 1 -0.445570  0.661722  atis_1091
# 2 -0.445570 -0.360634  atis_1371
# 3  0.093361 -0.288607  atis_1816
# 4 -0.091137 -0.202799  atis_1979
# 5 -0.445570  0.927404  atis_2023
# 6  0.733699 -0.039627  atis_2322
# 7  0.079633 -0.314196  atis_2385
# 8  0.695673 -0.108541  atis_2622
# 9  0.271052  0.085910  atis_3261
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.699388 -0.840194  0.205410 -0.579272
# 1                       banking77  0.941539 -0.276602 -0.167868  0.629229
# 2                        clinc150  0.272042 -0.539717 -0.382316  0.543043
# 3  clinicalDialogueSummarizations  0.032511  0.819724 -0.085798 -0.544796
# 4                   dementiaAudio  1.290068 -0.198779 -0.098131 -0.033537
# 5                    huffPostNews -0.164285  0.138408 -0.494407  0.234485
# 6                medicalAbstracts -0.486767 -0.579353  0.318111 -0.190933
# 7                          simSUM -0.801000  0.774703  0.248753 -0.574137
# 8     syntheticCareHomeNurseNotes -0.924955  0.997666  0.461589 -0.267573
# 9                           yahoo  0.540234 -0.295856 -0.005342  0.783491
#
#    factor_5  factor_6     doc_id
# 0 -0.451796 -0.328608  atis_1017
# 1 -0.258310 -0.328608  atis_1511
# 2 -0.451796  0.033503  atis_1784
# 3 -0.089569  0.431482  atis_2156
# 4 -0.168225  0.245075   atis_222
# 5  0.796796 -0.328608  atis_2317
# 6  0.132934  1.082878  atis_2829
# 7 -0.262141 -0.328608  atis_2985
# 8 -0.047233 -0.328608  atis_3318
# 9  0.799341 -0.149899  atis_3366
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.602685 -0.515344  0.170267 -0.335878
# 1                       banking77  0.840812 -0.074734 -0.459654  0.663124
# 2                        clinc150  0.225978 -0.418854  0.075402  0.693504
# 3  clinicalDialogueSummarizations -0.466376  0.028867  0.333826 -0.422993
# 4                   dementiaAudio  1.130603 -0.140337 -0.610013 -0.136336
# 5                    huffPostNews  0.160436  0.126946 -0.271251  0.148496
# 6                medicalAbstracts -0.560941 -0.462242  0.319833 -0.350979
# 7                          simSUM -0.979493  0.419235 -0.136660 -0.711768
# 8     syntheticCareHomeNurseNotes -0.835918  1.649582  1.044751 -0.381917
# 9                           yahoo  1.087584 -0.613118 -0.466500  0.834747
#
#    factor_5  factor_6     doc_id
# 0 -0.502851 -0.361858   atis_127
# 1 -0.502851 -0.191867  atis_1529
# 2 -0.502851 -0.361858  atis_2412
# 3 -0.275175 -0.361858  atis_2922
# 4 -0.129326  0.303186  atis_3030
# 5 -0.186673  1.110316   atis_321
# 6  1.054749  0.174532  atis_3336
# 7  0.652934 -0.301653   atis_437
# 8 -0.280784  0.103497   atis_493
# 9  0.672827 -0.112436    atis_75
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.564469 -0.613276  0.148048 -0.145806
# 1                       banking77  0.978998  0.311765 -1.137197  0.758138
# 2                        clinc150  0.179593 -0.480784  0.077824  0.578650
# 3  clinicalDialogueSummarizations  0.020608  1.005503  0.219232 -0.348925
# 4                   dementiaAudio  1.245827 -0.204576 -0.230285 -0.432301
# 5                    huffPostNews  0.469979 -0.372038 -0.129107  0.048525
# 6                medicalAbstracts -0.590461 -0.514465 -0.042786 -0.212338
# 7                          simSUM -0.999565  0.369208  0.324498 -0.657173
# 8     syntheticCareHomeNurseNotes -0.971144  1.002747  0.847480 -0.212459
# 9                           yahoo  0.230634 -0.504084 -0.077707  0.623689
#
#    factor_5  factor_6     doc_id
# 0 -0.361072 -0.376365  atis_1018
# 1 -0.117123 -0.376365  atis_1391
# 2 -0.361072 -0.376365  atis_2169
# 3  0.137556  0.598050  atis_2450
# 4 -0.216751  0.626789  atis_2846
# 5  0.378437 -0.376365  atis_2939
# 6  0.624631  0.671558  atis_3277
# 7 -0.314563 -0.376365   atis_475
# 8 -0.361072 -0.376365   atis_864
# 9  0.591032  0.361795   atis_978
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.872089 -0.686056  0.315266 -0.460885
# 1                       banking77  0.490640  0.115314 -1.128350  0.323179
# 2                        clinc150  0.403507 -0.229244 -0.035909  1.092409
# 3  clinicalDialogueSummarizations -0.177090  0.361231  0.570398 -0.509941
# 4                   dementiaAudio  1.309984 -0.166879  0.018597 -0.257154
# 5                    huffPostNews -0.164386 -0.229613 -0.603790  0.314621
# 6                medicalAbstracts -0.511577 -0.679723  0.360710 -0.409303
# 7                          simSUM -0.882597  0.607619  0.192965 -0.751240
# 8     syntheticCareHomeNurseNotes -0.417477  1.067414  0.534500  0.102406
# 9                           yahoo  0.821085 -0.160063 -0.224387  0.555908
#
#    factor_5  factor_6     doc_id
# 0 -0.434437 -0.248886  atis_1255
# 1  0.495768  0.682994  atis_1590
# 2 -0.434437  0.374962  atis_2003
# 3 -0.195198  0.052734  atis_2452
# 4 -0.099264 -0.153723  atis_2469
# 5  0.447232 -0.135087  atis_2474
# 6  0.431628  0.176894  atis_2843
# 7 -0.434437 -0.340419  atis_2870
# 8  0.273958 -0.109535  atis_3030
# 9 -0.050814 -0.299933  atis_3135
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.596749 -0.601847  0.199350 -0.295371
# 1                       banking77  0.785343 -0.412246 -0.614755  0.128741
# 2                        clinc150  0.006898 -0.431254  0.005149  0.997633
# 3  clinicalDialogueSummarizations -0.308724  1.020437  0.382234 -0.429616
# 4                   dementiaAudio  1.487020 -0.146147 -0.261476  0.014352
# 5                    huffPostNews  0.022372 -0.120986 -0.521689  0.684762
# 6                medicalAbstracts -0.743690 -0.365658  0.268540 -0.313533
# 7                          simSUM -0.913281  0.530826  0.196158 -0.569856
# 8     syntheticCareHomeNurseNotes -0.742092  1.289816  0.926975 -0.392421
# 9                           yahoo  1.002903 -0.762940 -0.580488  0.175308
#
#    factor_5  factor_6     doc_id
# 0 -0.469638 -0.399911   atis_109
# 1  0.755626  0.640293  atis_1270
# 2 -0.469638 -0.399911  atis_1872
# 3 -0.245339 -0.088226   atis_223
# 4 -0.215362 -0.178515  atis_2504
# 5 -0.160830  0.821114  atis_2698
# 6  0.700384  0.165896   atis_295
# 7 -0.304387 -0.399911  atis_3121
# 8 -0.469638 -0.198038  atis_3177
# 9  0.878823  0.037209    atis_47
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.733533 -0.600010 -0.574583 -0.281656
# 1                       banking77  1.157823 -0.353448 -0.621958  0.390920
# 2                        clinc150  0.187046  0.073205 -0.228858  0.763581
# 3  clinicalDialogueSummarizations -0.169633  0.084660 -0.112506 -0.399609
# 4                   dementiaAudio  0.942911 -0.153319 -0.119271 -0.115126
# 5                    huffPostNews  0.045519  0.021638 -0.017528  0.144714
# 6                medicalAbstracts -0.547637 -0.391956  0.589423 -0.160286
# 7                          simSUM -0.817346  0.550356  0.428954 -0.668592
# 8     syntheticCareHomeNurseNotes -0.840986  1.622386  0.677863 -0.315514
# 9                           yahoo  0.775836 -0.853511 -0.021536  0.641568
#
#    factor_5  factor_6     doc_id
# 0 -0.472732 -0.355959  atis_1101
# 1 -0.198616 -0.184184  atis_1456
# 2  0.226267  0.093298  atis_1659
# 3  0.881717  0.298339  atis_2042
# 4 -0.405553  0.085604  atis_2085
# 5 -0.024473 -0.202266  atis_2198
# 6  0.422579  0.556488  atis_2713
# 7 -0.472732 -0.355959  atis_3115
# 8 -0.027411 -0.355959  atis_3384
# 9  0.070954  0.420598   atis_493
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.698531 -0.674019 -0.276427 -0.222243
# 1                       banking77  0.722835  0.123008 -0.598543  0.577160
# 2                        clinc150  0.303661 -0.671705 -0.701530  0.826483
# 3  clinicalDialogueSummarizations -0.225158  0.553260  0.104979 -0.534676
# 4                   dementiaAudio  1.232094 -0.328734  0.080374 -0.382633
# 5                    huffPostNews -0.135915  0.434499 -0.047725  0.462151
# 6                medicalAbstracts -0.632309 -0.228625  0.704693 -0.421609
# 7                          simSUM -0.961096  0.255337  0.216668 -0.747390
# 8     syntheticCareHomeNurseNotes -0.726106  0.787866  0.773751  0.136116
# 9                           yahoo  1.120524 -0.250888 -0.256240  0.306641
#
#    factor_5  factor_6     doc_id
# 0 -0.416770 -0.365466  atis_1064
# 1  0.148639  0.816033  atis_1188
# 2  0.085028 -0.365466  atis_1558
# 3  0.242481 -0.263137  atis_1602
# 4 -0.277207 -0.242327  atis_1853
# 5 -0.164041  0.956642  atis_2344
# 6  0.252769  0.387675  atis_2718
# 7 -0.335897 -0.365466  atis_3217
# 8  0.384031 -0.365466   atis_572
# 9  0.080968 -0.193023   atis_979
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.367400 -0.549288  0.018307 -0.208226
# 1                       banking77  1.139274 -0.543572 -1.018276  0.104507
# 2                        clinc150  0.094487 -0.427606  0.292257  0.908458
# 3  clinicalDialogueSummarizations -0.725771  0.252621 -0.016377 -0.686869
# 4                   dementiaAudio  1.390203 -0.218067 -0.328715  0.471357
# 5                    huffPostNews -0.261765 -0.166472  0.006445 -0.139751
# 6                medicalAbstracts -0.541546 -0.388628  0.507196 -0.108877
# 7                          simSUM -0.781779  0.348263  0.073088 -0.677609
# 8     syntheticCareHomeNurseNotes -0.613519  1.753641  0.533090 -0.134573
# 9                           yahoo  0.667818 -0.060893 -0.067015  0.471584
#
#    factor_5  factor_6     doc_id
# 0 -0.405318 -0.350978  atis_1463
# 1 -0.405318  0.517636  atis_1660
# 2  0.319446 -0.092075  atis_1861
# 3  0.001231 -0.040130  atis_2268
# 4 -0.126226  0.039213  atis_2414
# 5  0.285949 -0.143855  atis_2440
# 6  0.143668 -0.057267  atis_3199
# 7 -0.148198 -0.350978  atis_3324
# 8  0.077327 -0.170871   atis_355
# 9  0.257438  0.649305   atis_949
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.442867 -0.727708  0.172113 -0.201254
# 1                       banking77  1.042422  0.040943 -0.580747  0.338982
# 2                        clinc150  0.340117 -0.528569 -0.667159  0.170993
# 3  clinicalDialogueSummarizations -0.091733  0.510949  0.201405 -0.403764
# 4                   dementiaAudio  1.200944 -0.213541  0.017363  0.233687
# 5                    huffPostNews -0.170453 -0.185989 -0.179942 -0.470008
# 6                medicalAbstracts -0.670419 -0.272673  0.475469 -0.141575
# 7                          simSUM -0.781984  0.626672  0.266681 -0.611175
# 8     syntheticCareHomeNurseNotes -0.560269  1.242024  0.572443  0.188574
# 9                           yahoo  0.134243 -0.492109 -0.277628  0.895539
#
#    factor_5  factor_6     doc_id
# 0 -0.425061 -0.297597  atis_1243
# 1 -0.425061  1.161582  atis_1286
# 2 -0.111810  0.104217  atis_1384
# 3 -0.241173  0.135189  atis_1726
# 4 -0.202680 -0.297597  atis_2856
# 5 -0.079368 -0.297597  atis_3110
# 6  0.834869  0.166944  atis_3254
# 7 -0.009143 -0.297597  atis_3270
# 8 -0.284638 -0.297597   atis_455
# 9  0.944064 -0.079948   atis_908
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.531214 -0.655572  0.710507 -0.037659
# 1                       banking77  0.625889 -0.240890 -0.484578  0.205918
# 2                        clinc150  0.662294 -0.626022 -0.390804  0.176363
# 3  clinicalDialogueSummarizations -0.412595  0.272955  0.062287 -0.119628
# 4                   dementiaAudio  1.009065 -0.145751 -0.238628 -0.010293
# 5                    huffPostNews -0.402111  0.247043 -0.424092 -0.214582
# 6                medicalAbstracts -0.584659 -0.293952  0.014607 -0.018302
# 7                          simSUM -0.860813  0.255220  0.286774 -0.719053
# 8     syntheticCareHomeNurseNotes -0.629616  1.645230  0.666025 -0.113724
# 9                           yahoo  1.123761 -0.458262 -0.202098  0.850961
#
#    factor_5  factor_6     doc_id
# 0 -0.396769 -0.346095  atis_1006
# 1 -0.396769  0.601099  atis_1396
# 2  0.054393  0.146627  atis_1759
# 3  0.215902  0.319570  atis_1998
# 4 -0.285371 -0.334410  atis_2342
# 5 -0.011005 -0.346095  atis_2686
# 6  1.067988  0.483549  atis_2799
# 7  0.072620 -0.305598  atis_2836
# 8 -0.199601 -0.025435   atis_588
# 9 -0.121388 -0.193211   atis_600
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.566576 -0.491968 -0.110189 -0.433300
# 1                       banking77  0.804508 -0.244484 -0.824031  0.113572
# 2                        clinc150  0.140623 -0.052479 -0.213004  1.308310
# 3  clinicalDialogueSummarizations -0.144400  0.445361  0.887290 -0.392870
# 4                   dementiaAudio  1.291523 -0.313518 -0.181289 -0.251731
# 5                    huffPostNews -0.121941 -0.445028 -0.590289 -0.204666
# 6                medicalAbstracts -0.594858 -0.323003  0.752540 -0.068811
# 7                          simSUM -1.000519  0.412971  0.323424 -0.679696
# 8     syntheticCareHomeNurseNotes -0.671629  1.586278  0.303946 -0.042791
# 9                           yahoo  0.863271 -0.574130 -0.348398  0.651983
#
#    factor_5  factor_6     doc_id
# 0 -0.431704 -0.384386  atis_1487
# 1  0.008246 -0.384386   atis_166
# 2  0.348125 -0.384386  atis_2668
# 3  0.082158  0.137929  atis_2711
# 4 -0.284884  0.552611  atis_2741
# 5 -0.200986  0.470696  atis_2841
# 6  0.758621  0.636917  atis_3218
# 7 -0.110605 -0.384386   atis_661
# 8 -0.008017 -0.158030   atis_764
# 9 -0.160953 -0.102581   atis_928
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.569002 -0.413078  0.523491 -0.234787
# 1                       banking77  0.858882 -0.116661 -0.987384  1.017681
# 2                        clinc150  0.281453 -0.354301  0.021650  0.317135
# 3  clinicalDialogueSummarizations -0.568366  0.464657 -0.065418 -0.645939
# 4                   dementiaAudio  1.676417 -0.315274 -0.213407 -0.282424
# 5                    huffPostNews -0.281003  0.497601 -0.325979  0.488477
# 6                medicalAbstracts -0.653941 -0.149114  0.554648 -0.363751
# 7                          simSUM -0.867723  0.554438  0.428648 -0.689577
# 8     syntheticCareHomeNurseNotes -0.541146  0.582820  0.545815 -0.341823
# 9                           yahoo  0.664428 -0.751086 -0.482064  0.735008
#
#    factor_5  factor_6     doc_id
# 0 -0.405455 -0.407929   atis_130
# 1 -0.158148 -0.407929  atis_1544
# 2 -0.026595  0.255670  atis_2332
# 3 -0.150582 -0.176951  atis_2392
# 4 -0.332501  0.889686  atis_2672
# 5  0.194261 -0.407929  atis_2724
# 6  0.557555  0.684237  atis_2980
# 7 -0.257073 -0.305055  atis_3072
# 8 -0.292879  0.209314   atis_408
# 9  0.871418 -0.333112   atis_925
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.639517 -0.352069 -0.065237 -0.120177
# 1                       banking77  1.384673  0.239727 -0.151885  0.088880
# 2                        clinc150  0.031729 -0.496612 -0.429452  1.270961
# 3  clinicalDialogueSummarizations -0.313845  0.500912 -0.090036 -0.531244
# 4                   dementiaAudio  1.182330 -0.235024 -0.750518 -0.063190
# 5                    huffPostNews -0.431457 -0.470080  0.354001 -0.450644
# 6                medicalAbstracts -0.494637 -0.192367  0.300081 -0.260855
# 7                          simSUM -1.008031  0.429860  0.503667 -0.693719
# 8     syntheticCareHomeNurseNotes -0.502962  1.382218  0.155080  0.230097
# 9                           yahoo  0.791717 -0.806565  0.174298  0.529892
#
#    factor_5  factor_6     doc_id
# 0 -0.479247 -0.046386  atis_1431
# 1 -0.151354  0.096604  atis_1488
# 2 -0.479247 -0.360696  atis_1543
# 3  0.298918 -0.158764  atis_1619
# 4 -0.330756 -0.254627  atis_2639
# 5 -0.043499  0.483594   atis_266
# 6  0.923866  0.298481  atis_2775
# 7 -0.381050 -0.360696  atis_3250
# 8 -0.250157  0.079918   atis_392
# 9  0.892527  0.222571   atis_635
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.735525 -0.468563  0.038033 -0.507405
# 1                       banking77  1.223330 -0.005552 -0.748284  1.144767
# 2                        clinc150  0.140259 -0.485830 -0.079021  1.175816
# 3  clinicalDialogueSummarizations -0.412234  0.120101  0.027913 -0.551574
# 4                   dementiaAudio  0.867342 -0.300192  0.289399 -0.316815
# 5                    huffPostNews -0.009578  0.612590 -0.397498 -0.238398
# 6                medicalAbstracts -0.568157 -0.510646  0.545395 -0.153697
# 7                          simSUM -0.773116  0.416493  0.230788 -0.687744
# 8     syntheticCareHomeNurseNotes -0.737889  1.058303  0.195513 -0.295988
# 9                           yahoo  1.005568 -0.436705 -0.102237  0.431037
#
#    factor_5  factor_6     doc_id
# 0  0.032293 -0.323691  atis_1558
# 1 -0.250523 -0.020284   atis_161
# 2 -0.371730 -0.323691  atis_1719
# 3 -0.316469  0.778759  atis_1836
# 4 -0.224373 -0.310189  atis_1957
# 5  0.095002  0.003078  atis_1980
# 6  1.173099  0.718160  atis_2654
# 7 -0.297823 -0.323691  atis_2867
# 8 -0.157959 -0.323691  atis_3340
# 9  0.318483  0.125239   atis_621
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.819650 -0.458769 -0.059796 -0.616153
# 1                       banking77  1.264874 -0.313168 -0.256841  0.676998
# 2                        clinc150  0.187591 -0.130738 -0.705854  0.609951
# 3  clinicalDialogueSummarizations -0.161839  0.241862  0.298390 -0.442082
# 4                   dementiaAudio  1.215673 -0.302255  0.166473 -0.166262
# 5                    huffPostNews  0.033553 -0.488024 -0.403996  0.460930
# 6                medicalAbstracts -0.624735 -0.246196  0.125816 -0.393358
# 7                          simSUM -0.773969  0.522630 -0.123596 -0.689581
# 8     syntheticCareHomeNurseNotes -0.830553  1.724543  1.159515  0.040573
# 9                           yahoo  0.509055 -0.549885 -0.200110  0.518982
#
#    factor_5  factor_6     doc_id
# 0 -0.422492 -0.465497  atis_1189
# 1 -0.422492  1.187788  atis_1529
# 2  0.111942 -0.230656  atis_2081
# 3  0.165639  0.263378  atis_2416
# 4 -0.156332 -0.165466  atis_2671
# 5 -0.228550  0.052610  atis_3022
# 6  0.269675  0.642868  atis_3061
# 7 -0.263626 -0.465497  atis_3102
# 8  0.105584 -0.465497   atis_411
# 9  0.840651 -0.354031   atis_815
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.669618 -0.574149  0.266983 -0.294449
# 1                       banking77  1.397295 -0.427975 -1.019665  0.803619
# 2                        clinc150 -0.295562 -0.408688  0.080423 -0.082128
# 3  clinicalDialogueSummarizations -0.268245  0.485282  0.078707 -0.415106
# 4                   dementiaAudio  1.256039 -0.416119 -0.258249 -0.100306
# 5                    huffPostNews -0.021494  0.218931 -0.283955  0.630360
# 6                medicalAbstracts -0.581722 -0.218963  0.464174 -0.355263
# 7                          simSUM -0.758616  0.490568  0.135858 -0.631953
# 8     syntheticCareHomeNurseNotes -0.745586  1.048542  1.133590 -0.117099
# 9                           yahoo  0.687508 -0.197428 -0.597866  0.562324
#
#    factor_5  factor_6     doc_id
# 0 -0.401175 -0.171963  atis_1179
# 1 -0.401175  0.595431  atis_2480
# 2 -0.032752 -0.367046  atis_2683
# 3  0.119905  0.292198   atis_282
# 4  0.098943 -0.147925  atis_3032
# 5 -0.232314 -0.186413   atis_450
# 6  0.633175  0.523751   atis_812
# 7  0.365485 -0.367046   atis_885
# 8 -0.401175 -0.154999   atis_891
# 9  0.251083 -0.015987   atis_916
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.702549 -0.728542 -0.008382 -0.694883
# 1                       banking77  1.004240  0.466974 -0.420557  0.154557
# 2                        clinc150  0.066766 -0.607518 -0.055952  0.324165
# 3  clinicalDialogueSummarizations -0.452983  0.665663  0.032595 -0.526662
# 4                   dementiaAudio  1.290887 -0.171457  0.281628 -0.199847
# 5                    huffPostNews  0.313171  0.088651 -0.876865  0.917559
# 6                medicalAbstracts -0.476238 -0.483661  0.439927 -0.334998
# 7                          simSUM -0.849580  0.219528  0.086483 -0.620074
# 8     syntheticCareHomeNurseNotes -0.896442  1.212586  0.779482  0.426856
# 9                           yahoo  0.702728 -0.662224 -0.258358  0.553328
#
#    factor_5  factor_6     doc_id
# 0 -0.433539 -0.307602  atis_1572
# 1  0.000820  0.380210  atis_1635
# 2 -0.433539  0.069585  atis_2398
# 3  0.476702  0.650809  atis_2876
# 4 -0.246973  0.176491  atis_3017
# 5 -0.365454 -0.207968  atis_3020
# 6  1.134677 -0.071086  atis_3038
# 7 -0.116963 -0.307602   atis_308
# 8  0.417809 -0.307602  atis_3182
# 9 -0.433539 -0.075234    atis_69
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.788023 -0.621917  0.420532 -0.146580
# 1                       banking77  1.170619 -0.458042 -0.716310  0.502709
# 2                        clinc150 -0.001830 -0.146000 -1.009879 -0.254420
# 3  clinicalDialogueSummarizations -0.438505  0.106748 -0.036423 -0.424728
# 4                   dementiaAudio  1.014486 -0.223554 -0.117831 -0.258926
# 5                    huffPostNews  0.550304 -0.102097  0.004533  0.333606
# 6                medicalAbstracts -0.500678 -0.461113  0.369593  0.272483
# 7                          simSUM -0.923550  0.599244  0.115541 -0.717040
# 8     syntheticCareHomeNurseNotes -0.648733  1.874859  0.839194  0.102543
# 9                           yahoo  0.565911 -0.568127  0.131050  0.590353
#
#    factor_5  factor_6     doc_id
# 0 -0.389034 -0.336988   atis_133
# 1 -0.119042 -0.045180  atis_1386
# 2 -0.119042 -0.093815  atis_1614
# 3  0.769802  0.046480  atis_1670
# 4 -0.333170 -0.044330  atis_1824
# 5 -0.287546  0.604379  atis_2178
# 6  0.087666 -0.011438  atis_2591
# 7  0.214888 -0.336988  atis_2752
# 8 -0.389034 -0.336988  atis_2762
# 9  0.564510  0.554866  atis_2989
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.541927 -0.671763  0.031923  0.263671
# 1                       banking77  1.063158 -0.086733 -0.395239  0.286335
# 2                        clinc150  0.243624 -0.240400 -0.325955  0.475442
# 3  clinicalDialogueSummarizations -0.446839 -0.002572 -0.137960 -0.084027
# 4                   dementiaAudio  1.118021 -0.160104  0.083225 -0.409829
# 5                    huffPostNews  0.458769  0.181185 -0.547629  0.077808
# 6                medicalAbstracts -0.834882 -0.484128  0.815069 -0.462284
# 7                          simSUM -0.924395  0.728252  0.192390 -0.645612
# 8     syntheticCareHomeNurseNotes -0.718179  1.188862  0.834404 -0.243337
# 9                           yahoo  0.582650 -0.452599 -0.550228  0.741834
#
#    factor_5  factor_6     doc_id
# 0 -0.385676 -0.130186  atis_1738
# 1  0.166836  0.691740  atis_2019
# 2 -0.385676  0.112522  atis_2428
# 3 -0.125093 -0.116895  atis_2509
# 4 -0.026013 -0.139770  atis_2984
# 5 -0.158112  0.147367    atis_40
# 6  0.887496  0.175920     atis_5
# 7 -0.385676 -0.250510   atis_501
# 8 -0.015414 -0.311900   atis_654
# 9  0.427329 -0.178287   atis_812
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.540149 -0.652094  0.680614 -0.191650
# 1                       banking77  1.066223  0.397767 -1.188604 -0.209701
# 2                        clinc150  0.022909 -0.797310 -0.102906  0.706520
# 3  clinicalDialogueSummarizations -0.514277  0.076264  0.146559 -0.394613
# 4                   dementiaAudio  0.985475 -0.212213 -0.063362 -0.165207
# 5                    huffPostNews  0.815732  0.034430 -0.444071  0.248937
# 6                medicalAbstracts -0.571319 -0.418422  0.345873  0.171482
# 7                          simSUM -0.793005  0.625853  0.299149 -0.539376
# 8     syntheticCareHomeNurseNotes -0.777140  1.377927  0.703387  0.077577
# 9                           yahoo  0.305551 -0.432203 -0.376638  0.296031
#
#    factor_5  factor_6     doc_id
# 0 -0.427584 -0.365635  atis_1153
# 1  0.412689 -0.365635  atis_1288
# 2 -0.128474 -0.365635  atis_1574
# 3 -0.309007 -0.138798  atis_1688
# 4 -0.114686  0.439364  atis_1994
# 5 -0.305955  0.649632  atis_2205
# 6  0.359190  0.933891  atis_2261
# 7  0.088813 -0.365635  atis_2981
# 8 -0.228177 -0.365635   atis_375
# 9  0.653192 -0.055915   atis_600
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.522255 -0.832386 -0.170894  0.217554
# 1                       banking77  1.442456 -0.092412 -0.947532  0.076778
# 2                        clinc150  0.023709 -0.427056  0.067869  0.179984
# 3  clinicalDialogueSummarizations -0.279518 -0.053142  0.425279 -0.428136
# 4                   dementiaAudio  1.099522 -0.127432  0.235548 -0.286915
# 5                    huffPostNews -0.377278  0.244105 -0.353600  0.162408
# 6                medicalAbstracts -0.538932 -0.378455  0.778181 -0.088538
# 7                          simSUM -0.923355  0.630776  0.173006 -0.695808
# 8     syntheticCareHomeNurseNotes -0.942958  1.205978  0.488352  0.042393
# 9                           yahoo  1.018609 -0.169976 -0.696208  0.820280
#
#    factor_5  factor_6     doc_id
# 0 -0.518284 -0.420149   atis_122
# 1  0.756000  0.237020  atis_1246
# 2  0.162610 -0.420149   atis_180
# 3  0.236041 -0.368968  atis_1948
# 4  0.179222 -0.125086  atis_2095
# 5 -0.294944  0.416694  atis_2811
# 6  0.368529  0.252632   atis_297
# 7 -0.344918 -0.307650  atis_3108
# 8 -0.369649 -0.249546   atis_629
# 9 -0.174607  0.985201   atis_979
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.708994 -0.819958  0.054586 -0.266223
# 1                       banking77  0.835285  0.060165 -0.768570  1.134642
# 2                        clinc150 -0.001715 -0.437413 -0.026370  0.730343
# 3  clinicalDialogueSummarizations -0.146689  0.967745  0.579311 -0.690755
# 4                   dementiaAudio  1.009335 -0.533636  0.203861 -0.276620
# 5                    huffPostNews  0.179816  0.060010 -0.320535  0.065192
# 6                medicalAbstracts -0.469100 -0.771915  0.189673 -0.026912
# 7                          simSUM -0.937345  0.399236  0.285902 -0.757703
# 8     syntheticCareHomeNurseNotes -0.914930  1.071865  0.751074 -0.316732
# 9                           yahoo  1.154337  0.003902 -0.948934  0.404768
#
#    factor_5  factor_6     doc_id
# 0 -0.476401 -0.361622  atis_1017
# 1 -0.221750  0.686684  atis_1474
# 2 -0.031632 -0.361622  atis_1524
# 3 -0.342225  0.546744  atis_1732
# 4 -0.339079 -0.084380  atis_1854
# 5  0.423480  0.271681  atis_2166
# 6  0.686345  0.098617  atis_2867
# 7  0.012998 -0.302197   atis_557
# 8  0.397339 -0.361622   atis_679
# 9 -0.109074 -0.132281   atis_883
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.718762 -0.367540 -0.165924 -0.365370
# 1                       banking77  1.183691 -0.271568 -1.014307  0.379327
# 2                        clinc150  0.211451 -0.127217  0.075104  0.674770
# 3  clinicalDialogueSummarizations -0.573238  0.451157  0.307884 -0.416456
# 4                   dementiaAudio  0.960770 -0.308351 -0.199764 -0.254395
# 5                    huffPostNews -0.126176  0.177489  0.293650  0.420128
# 6                medicalAbstracts -0.381324 -0.494864  0.224171 -0.283611
# 7                          simSUM -0.971971  0.164073  0.342890 -0.801650
# 8     syntheticCareHomeNurseNotes -0.660509  1.303757  0.496940 -0.143899
# 9                           yahoo  1.076068 -0.526936 -0.360643  0.791157
#
#    factor_5  factor_6     doc_id
# 0 -0.404426 -0.312595  atis_1682
# 1 -0.404426 -0.312595  atis_2065
# 2 -0.404426 -0.312595  atis_2093
# 3 -0.213942 -0.277513  atis_2295
# 4 -0.178382 -0.274895  atis_2308
# 5 -0.220001  0.357157  atis_2864
# 6  0.937714  0.235539  atis_3292
# 7 -0.243705 -0.255188   atis_343
# 8  0.184113 -0.118293   atis_399
# 9  0.947481  1.270977   atis_822
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.599777 -0.535745  0.257972 -0.390643
# 1                       banking77  1.132755 -0.179037 -0.725977  0.363809
# 2                        clinc150  0.075449 -0.732236 -0.494784  0.610665
# 3  clinicalDialogueSummarizations -0.186596  0.107377 -0.031704 -0.248684
# 4                   dementiaAudio  1.074705 -0.446306  0.046448 -0.240407
# 5                    huffPostNews  0.187043  0.341840 -0.018519  0.124222
# 6                medicalAbstracts -0.650113 -0.280325  0.746292 -0.113741
# 7                          simSUM -0.790471  0.465644  0.241054 -0.669607
# 8     syntheticCareHomeNurseNotes -0.735775  1.723483  0.681064 -0.243727
# 9                           yahoo  0.492780 -0.464695 -0.701847  0.808113
#
#    factor_5  factor_6     doc_id
# 0 -0.489648 -0.403368   atis_117
# 1 -0.042053  0.246386  atis_1586
# 2 -0.279127 -0.069390  atis_1759
# 3  0.237290  0.163138  atis_1852
# 4 -0.084260 -0.005460  atis_2406
# 5 -0.332853 -0.101748  atis_2493
# 6  0.981417  0.445177  atis_2513
# ...
# 5                    huffPostNews  0.106678  0.043137 -0.595417  0.296225
# 6                medicalAbstracts -0.625036 -0.453731  0.388071 -0.512153
# 7                          simSUM -0.815371  0.485334  0.184347 -0.672039
# 8     syntheticCareHomeNurseNotes -0.635298  1.746420  0.331936  0.248948
# 9                           yahoo  0.801605  0.027293 -0.042883  0.536380
#
#    factor_5  factor_6     doc_id
# 0 -0.050724 -0.335814  atis_1634
# 1  0.225973  0.226223  atis_1809
# 2 -0.265988 -0.335814  atis_2270
# 3  0.517095 -0.148792  atis_2649
# 4 -0.208136 -0.056176  atis_2758
# 5 -0.143236 -0.335814  atis_2842
# 6  0.019216  0.557078  atis_3267
# 7 -0.234618 -0.335814   atis_552
# 8  0.340747  0.069399    atis_81
# 9 -0.200330  0.695522   atis_838
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.658258 -0.712045  0.101567 -0.588297
# 1                       banking77  0.894317  0.097383 -0.781136  0.089835
# 2                        clinc150  0.271684 -0.462332 -0.159133  0.694847
# 3  clinicalDialogueSummarizations -0.209373  0.739086  0.254930 -0.308624
# 4                   dementiaAudio  1.250329 -0.238242  0.305718  0.086554
# 5                    huffPostNews  0.090102 -0.604378 -0.538548  0.167790
# 6                medicalAbstracts -0.519892 -0.451230  0.271445 -0.201382
# 7                          simSUM -0.968203  0.616792  0.125213 -0.547053
# 8     syntheticCareHomeNurseNotes -0.827353  1.387467  0.663679 -0.182557
# 9                           yahoo  0.676648 -0.372500 -0.243734  0.788888
#
#    factor_5  factor_6     doc_id
# 0 -0.068008 -0.368402  atis_2271
# 1 -0.471841 -0.090345  atis_2282
# 2 -0.054126 -0.152135  atis_2399
# 3 -0.173854 -0.112643  atis_2816
# 4 -0.193574  0.205493  atis_2900
# 5  0.450432 -0.224224  atis_2942
# 6  0.767846  0.800069  atis_3072
# 7 -0.313398 -0.368402   atis_333
# 8 -0.230564 -0.368402   atis_466
# 9  0.287088  0.678991   atis_657
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.734819 -0.373933  0.115563 -0.244556
# 1                       banking77  0.643227  0.010446 -0.495731  0.881557
# 2                        clinc150  0.277876 -0.451318 -0.662942  0.483779
# 3  clinicalDialogueSummarizations -0.344341  0.690184  0.533538 -0.740207
# 4                   dementiaAudio  1.119939 -0.427970 -0.191798 -0.293651
# 5                    huffPostNews  0.820834 -0.459280 -0.687892  0.234180
# 6                medicalAbstracts -0.749495 -0.061994  0.804648 -0.378562
# 7                          simSUM -0.975021  1.036717  0.278212 -0.813903
# 8     syntheticCareHomeNurseNotes -0.893758  0.856516  0.344516  0.066189
# 9                           yahoo  0.835558 -0.819370 -0.038115  0.805173
#
#    factor_5  factor_6     doc_id
# 0 -0.353513 -0.356424     atis_0
# 1  0.641434  0.147369  atis_1214
# 2 -0.353513  0.004165  atis_1391
# 3 -0.197132  0.131868    atis_14
# 4 -0.174681  0.321142  atis_1488
# 5  0.127582  0.366961  atis_2673
# 6  0.753897  0.454188  atis_3178
# 7 -0.353513 -0.356424   atis_499
# 8  0.199971 -0.356424   atis_551
# 9 -0.290533 -0.356424   atis_830
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.635472 -0.428337  0.213635 -0.496927
# 1                       banking77  1.130950  0.256194 -0.700345  0.154230
# 2                        clinc150  0.719677 -0.562958 -0.776025  1.129892
# 3  clinicalDialogueSummarizations -0.587262  0.082168  0.009233 -0.395330
# 4                   dementiaAudio  1.174341 -0.291164  0.157617 -0.417383
# 5                    huffPostNews  0.052204  0.007547  0.021983  0.306792
# 6                medicalAbstracts -0.611890 -0.260885  0.390465 -0.276775
# 7                          simSUM -1.011030  0.234657  0.359713 -0.605381
# 8     syntheticCareHomeNurseNotes -0.808846  1.643712  0.593958 -0.248079
# 9                           yahoo  0.577328 -0.680934 -0.270233  0.848961
#
#    factor_5  factor_6     doc_id
# 0 -0.468618 -0.386229  atis_1586
# 1  0.257295 -0.232337  atis_1587
# 2 -0.468618 -0.059792  atis_1646
# 3 -0.190448  0.281979  atis_1855
# 4  0.050891 -0.048692  atis_1864
# 5 -0.292618  0.549035  atis_2261
# 6  1.310349  0.741889  atis_2297
# 7 -0.215193 -0.386229  atis_2738
# 8 -0.468618 -0.073394   atis_441
# 9  0.485578 -0.386229   atis_739
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.617395 -0.684928 -0.016022 -0.470918
# 1                       banking77  1.698732 -0.580573 -0.722370  0.898358
# 2                        clinc150  0.117477 -0.491578 -0.494409  0.520819
# 3  clinicalDialogueSummarizations  0.063105  0.541035 -0.141537 -0.558986
# 4                   dementiaAudio  0.827671 -0.363375  0.359059 -0.141450
# 5                    huffPostNews -0.578051  0.768297  0.024500 -0.037707
# 6                medicalAbstracts -0.627971 -0.597114  0.368594 -0.118832
# 7                          simSUM -0.785306  0.570935  0.255597 -0.593445
# 8     syntheticCareHomeNurseNotes -0.678869  1.139780  0.667464 -0.067228
# 9                           yahoo  0.580605 -0.302478 -0.300876  0.569389
#
#    factor_5  factor_6     doc_id
# 0 -0.424524 -0.187675   atis_100
# 1 -0.424524  0.057697  atis_1028
# 2 -0.062906  0.619822   atis_112
# 3  0.124222  0.111600  atis_1372
# 4 -0.043284 -0.011946  atis_1911
# 5  0.290412 -0.074082  atis_2311
# 6  0.663261  0.361480   atis_358
# 7 -0.358818 -0.334529   atis_431
# 8  0.261052 -0.395296   atis_449
# 9 -0.024892 -0.147070   atis_783
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.579480 -0.452235  0.433613 -0.199053
# 1                       banking77  1.346796  0.084002 -0.582323  0.536666
# 2                        clinc150  0.110678 -0.501814 -0.385374  0.161979
# 3  clinicalDialogueSummarizations -0.592235  0.157191  0.669128 -0.547390
# 4                   dementiaAudio  1.315605 -0.399140  0.131760  0.161238
# 5                    huffPostNews  0.108628  0.783074 -0.472266  0.636586
# 6                medicalAbstracts -0.714479 -0.372579  0.513206 -0.358402
# 7                          simSUM -0.873792  0.501646  0.209355 -0.580267
# 8     syntheticCareHomeNurseNotes -0.460286  0.851972  0.050475 -0.048758
# 9                           yahoo  0.338565 -0.652117 -0.567573  0.237401
#
#    factor_5  factor_6     doc_id
# 0 -0.399885 -0.366183  atis_1225
# 1 -0.234707  0.687266  atis_2043
# 2 -0.399885 -0.366183   atis_230
# 3  0.324695  0.410115  atis_2561
# 4 -0.123195  0.467425  atis_2901
# 5 -0.257232 -0.290308  atis_3209
# 6  0.557012  0.072174  atis_3307
# 7 -0.399885 -0.322963  atis_3348
# 8 -0.007589  0.074841    atis_42
# 9  0.940670 -0.366183   atis_594
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.589585 -0.530775  0.139637 -0.267372
# 1                       banking77  1.224584 -0.272355 -0.150685  0.901769
# 2                        clinc150  0.140484 -0.409220  0.289685  0.491468
# 3  clinicalDialogueSummarizations -0.304915  0.638129  0.073345 -0.680636
# 4                   dementiaAudio  1.243336 -0.350724  0.018273  0.005744
# 5                    huffPostNews  0.190570 -0.042467 -0.059485 -0.050891
# 6                medicalAbstracts -0.779146 -0.227931  0.529344 -0.290867
# 7                          simSUM -0.916892  0.556507 -0.107087 -0.807483
# 8     syntheticCareHomeNurseNotes -0.989133  1.192015  0.050368  0.110517
# 9                           yahoo  0.780696 -0.553180 -0.783396  0.587751
#
#    factor_5  factor_6     doc_id
# 0 -0.395739 -0.299958  atis_1016
# 1  0.077238  0.773047  atis_1746
# 2 -0.130980 -0.431221  atis_2131
# 3  0.190734  0.254868   atis_308
# 4 -0.319975  0.100069  atis_3098
# 5  0.064486  0.390652  atis_3440
# 6  1.243759  0.111201  atis_3474
# 7 -0.395739 -0.431221    atis_47
# 8 -0.172784 -0.157757   atis_713
# 9 -0.160999 -0.309681   atis_812
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.846477 -0.595597  0.211469 -0.354575
# 1                       banking77  0.940326 -0.446760 -0.767586  0.857032
# 2                        clinc150  0.313353 -0.148265  0.009366  0.581577
# 3  clinicalDialogueSummarizations -0.077808  1.063957 -0.197429 -0.409543
# 4                   dementiaAudio  1.650541 -0.218462 -0.359249 -0.344186
# 5                    huffPostNews  0.106998 -0.331183 -0.147384  0.041764
# 6                medicalAbstracts -0.713681 -0.551388  0.342144 -0.302188
# 7                          simSUM -0.934535  0.502898  0.263284 -0.686902
# 8     syntheticCareHomeNurseNotes -0.870516  1.378065  0.520177  0.308031
# 9                           yahoo  0.431799 -0.653265  0.125208  0.308990
#
#    factor_5  factor_6     doc_id
# 0 -0.417804 -0.360553    atis_11
# 1  0.335371  0.140639   atis_131
# 2 -0.417804  0.376570  atis_1378
# 3  0.308619 -0.318135  atis_1727
# 4 -0.113077  0.017717  atis_1917
# 5  0.391643 -0.204181  atis_2075
# 6 -0.017942  0.866152  atis_2111
# 7 -0.317383 -0.360553   atis_248
# 8 -0.266392 -0.268569  atis_2900
# 9  0.514769  0.110912  atis_3245
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.509013 -0.656045 -0.296891 -0.463961
# 1                       banking77  0.864416 -0.028692 -0.599566  0.604351
# 2                        clinc150  0.189380 -0.317635 -0.490641  0.706906
# 3  clinicalDialogueSummarizations -0.753979  0.006616  0.467574 -0.618875
# 4                   dementiaAudio  1.550660 -0.006112  0.234791 -0.193637
# 5                    huffPostNews  0.270082 -0.292116 -0.332808  0.088100
# 6                medicalAbstracts -0.530238 -0.174708  0.184036 -0.099909
# 7                          simSUM -0.873121  0.487751  0.215675 -0.664503
# 8     syntheticCareHomeNurseNotes -0.482856  1.589861  0.109076  0.033374
# 9                           yahoo  0.274669 -0.608921  0.508754  0.608153
#
#    factor_5  factor_6     doc_id
# 0 -0.436123 -0.399372   atis_112
# 1 -0.016381  0.638606  atis_1197
# 2 -0.104635 -0.399372  atis_1687
# 3 -0.257723 -0.326866  atis_1789
# 4 -0.303849 -0.095742  atis_1834
# 5  0.145374  0.492849  atis_1972
# 6  1.037942  0.132220  atis_2215
# 7 -0.251109 -0.399372  atis_2524
# 8  0.166942 -0.399372  atis_2651
# 9  0.019563  0.756421   atis_668
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.390731 -0.466770 -0.222480 -0.173077
# 1                       banking77  0.925591 -0.291940 -0.515801  0.154300
# 2                        clinc150 -0.130858 -0.348923 -0.229264  0.134251
# 3  clinicalDialogueSummarizations -0.458036  0.375346  0.097926 -0.072098
# 4                   dementiaAudio  1.291871 -0.193540  0.083835 -0.074960
# 5                    huffPostNews -0.283472  0.294194 -0.314140  0.032063
# 6                medicalAbstracts -0.471111 -0.597959  0.136219  0.086377
# 7                          simSUM -0.661887  0.308416  0.333432 -0.685676
# 8     syntheticCareHomeNurseNotes -0.716078  1.519266  0.783788 -0.013838
# 9                           yahoo  0.894711 -0.598090 -0.153517  0.612657
#
#    factor_5  factor_6     doc_id
# 0 -0.437125 -0.349450  atis_1035
# 1 -0.034389  0.325790  atis_1101
# 2  0.078133 -0.349450  atis_1572
# 3 -0.351342 -0.349450  atis_1762
# 4 -0.236380 -0.091699  atis_1826
# 5 -0.141710  0.281154  atis_2647
# 6  0.728088  0.847740   atis_401
# 7  0.183586 -0.349450   atis_533
# 8 -0.250141 -0.110770   atis_709
# 9  0.461280  0.145586   atis_950
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.904221 -0.653321 -0.274745 -0.573906
# 1                       banking77  0.992577  0.323375 -0.439636  0.982828
# 2                        clinc150  0.114437 -0.259219  0.052408  0.895694
# 3  clinicalDialogueSummarizations -0.222119  0.537124 -0.273645 -0.472191
# 4                   dementiaAudio  1.159700 -0.215702 -0.205501 -0.251506
# 5                    huffPostNews  0.272753  0.119470 -0.151892  0.417253
# 6                medicalAbstracts -0.626653 -0.409726  0.892565 -0.371910
# 7                          simSUM -0.782045  0.216039  0.032906 -0.689133
# 8     syntheticCareHomeNurseNotes -0.851111  1.070241  0.467273  0.063194
# 9                           yahoo  0.846681 -0.728280 -0.099733 -0.000324
#
#    factor_5  factor_6     doc_id
# 0 -0.468152 -0.334041  atis_1077
# 1  0.332429 -0.334041  atis_1104
# 2  0.216895 -0.050666  atis_1193
# 3 -0.005537 -0.083829  atis_1659
# 4 -0.227286  0.187462  atis_1830
# 5  0.275236  0.995266  atis_1967
# 6  0.686790  0.440187  atis_1996
# 7 -0.422377 -0.334041  atis_2513
# 8 -0.332657 -0.334041   atis_587
# 9 -0.055341 -0.152254   atis_604
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.387234 -0.540613  0.343096 -0.241326
# 1                       banking77  1.301140 -0.416097 -0.075501  0.656937
# 2                        clinc150  0.449958 -0.550716  0.137679  0.753181
# 3  clinicalDialogueSummarizations -0.383454  0.757396 -0.537773 -0.417404
# 4                   dementiaAudio  1.202850 -0.209152 -0.255237  0.016964
# 5                    huffPostNews -0.172972 -0.177679  0.191108 -0.081145
# 6                medicalAbstracts -0.766743 -0.390993  0.288259 -0.356306
# 7                          simSUM -0.921755  0.494631  0.391660 -0.742609
# 8     syntheticCareHomeNurseNotes -0.756441  1.442054  0.211590 -0.231023
# 9                           yahoo  0.434651 -0.408831 -0.694881  0.642731
#
#    factor_5  factor_6     doc_id
# 0 -0.392900 -0.346916  atis_1270
# 1 -0.392900  0.029699  atis_1721
# 2 -0.392900  0.493640  atis_2256
# 3 -0.127747  0.572095  atis_2267
# 4 -0.366045  0.445518  atis_2434
# 5  0.777693 -0.198553  atis_2469
# 6  0.959126  0.045266  atis_2683
# 7  0.060002 -0.346916  atis_2862
# 8  0.135710 -0.346916  atis_3236
# 9 -0.260038 -0.346916  atis_3411
#                          category  factor_1  factor_2  factor_3  factor_4  \
# 0                            atis -0.545890 -0.575093  0.097265 -0.028463
# 1                       banking77  0.950368 -0.297922 -0.803677  0.448187
# 2                        clinc150 -0.150380 -0.330582 -0.222578  0.790784
# 3  clinicalDialogueSummarizations  0.051200  0.370017 -0.406562 -0.203510
# 4                   dementiaAudio  1.032294 -0.324111 -0.353187 -0.084966
# 5                    huffPostNews  0.187221 -0.053139  0.204767  0.171350
# 6                medicalAbstracts -0.569713 -0.456904  0.866230 -0.291120
# 7                          simSUM -0.903731  0.567026  0.288561 -0.714876
# 8     syntheticCareHomeNurseNotes -0.829411  1.601815  0.674851 -0.137812
# 9                           yahoo  0.778043 -0.501107 -0.345671  0.050426
#
#    factor_5  factor_6     doc_id
# 0  0.080284 -0.350809   atis_106
# 1 -0.209433  0.587434   atis_124
# 2 -0.229520 -0.076992  atis_1704
# 3 -0.014363 -0.037591  atis_1960
# 4 -0.004402 -0.192420  atis_2031
# 5  0.317384  0.192614  atis_2396
# 6  0.721332  0.662315  atis_2685
# 7 -0.482882 -0.350809   atis_323
# 8 -0.060872 -0.350809  atis_3278
# 9 -0.117528 -0.082933   atis_443
# /home/isabel/anaconda3/envs/realData/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# /home/isabel/anaconda3/envs/realData/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
