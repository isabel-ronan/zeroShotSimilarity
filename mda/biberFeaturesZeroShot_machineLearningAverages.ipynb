# %%
import random
import torch
import os
import umap
import glob
import json
import numpy as np
import pandas as pd
import polars as pl

from sklearn.model_selection import (
    StratifiedKFold, cross_validate, GridSearchCV
)
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, FunctionTransformer
from sklearn.impute import SimpleImputer
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score, balanced_accuracy_score, make_scorer, confusion_matrix
)
from sklearn.linear_model import LogisticRegression, RidgeClassifier, SGDClassifier
from sklearn.svm import SVC, LinearSVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier, GradientBoostingClassifier, HistGradientBoostingClassifier, AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB

from scipy import sparse

import warnings
warnings.simplefilter("ignore", UserWarning)

# %%
N_SPLITS_CV = 5
N_JOBS = 1  # prioritizing no leakage
INPUT_DIR = '.'
OUTPUT_DIR = './machineLearningOutputs'

os.makedirs(OUTPUT_DIR, exist_ok=True)

# %%
# Set random states.
def set_random_states(random_state):
    # Set various random seeds.
    np.random.seed(random_state)
    pl.set_random_seed(random_state)
    pd.core.common.random_state(random_state)
    random.seed(random_state)
    torch.manual_seed(random_state)
    torch.cuda.manual_seed_all(random_state)
    os.environ["PYTHONHASHSEED"] = str(random_state)
    os.environ["TOKENIZERS_PARALLELISM"] = "false"
    try:
        torch.use_deterministic_algorithms(True)
    except Exception:
        pass
    return random_state

RANDOM_STATE = set_random_states(1618)

# %%
# get models - broad coverage across linear, margin, instance-based, and nonlinear tree ensembles
def build_models(random_state):
    models = {
        # high numbers of iterations (max_iter) avoids convergence warnings in high-dimensional spaces
        "LogisticRegression": LogisticRegression(max_iter=20000, class_weight="balanced", random_state=random_state), # strong baseline
        "RidgeClassifier": RidgeClassifier(class_weight="balanced", random_state=random_state), # strong baseline
        "LinearSVC": LinearSVC(max_iter=20000, class_weight="balanced", random_state=random_state), # strong baseline
        "SVC-RBF": SVC(probability=False, random_state=random_state, class_weight="balanced"), # probability set to false saves on compute
        "SGD-Hinge": SGDClassifier(loss="hinge", max_iter=20000, random_state=random_state, class_weight="balanced"), # hinge loss is good for binary classification problems - fast on large data
        "KNN": KNeighborsClassifier(), # deterministic - sensitive to scaling (good to test with and without standard scaler)
        "DecisionTree": DecisionTreeClassifier(random_state=random_state, class_weight="balanced"), # don't need scaling and captures nonlinear splits
        "RandomForest": RandomForestClassifier(random_state=random_state, class_weight="balanced"), # don't need scaling and captures nonlinear splits
        "ExtraTrees": ExtraTreesClassifier(random_state=random_state, class_weight="balanced"), # don't need scaling and captures nonlinear splits
        "GradientBoosting": GradientBoostingClassifier(random_state=random_state), # don't need scaling and captures nonlinear splits
        "HistGB": HistGradientBoostingClassifier(random_state=random_state), # don't need scaling and captures nonlinear splits
        "AdaBoost": AdaBoostClassifier(random_state=random_state), # don't need scaling and captures nonlinear splits
        "GaussianNaiveBayes": GaussianNB(), # deterministic - interpretable
    }
    return models

# get parameter grid to test
def small_param_grid(name): # high-leverage parameter sweeps (runtime will be effected if we test everything)
    grids = {
        # lowered c values due to convergence issues
        "LogisticRegression": {"clf__C": [0.1, 0.5, 1.0]},
        "LinearSVC":          {"clf__C": [0.1, 0.5, 1.0]},
        "SVC-RBF":            {"clf__C": [0.1, 0.5, 1.0], "clf__gamma": ["scale", "auto"]},
        "KNN":                {"clf__n_neighbors": [3, 5, 11]},
        "RandomForest":       {"clf__n_estimators": [300, 600], "clf__max_depth": [None, 10, 20]},
        "ExtraTrees":         {"clf__n_estimators": [300, 600], "clf__max_depth": [None, 10, 20]},
        "HistGB":             {"clf__max_depth": [None, 6, 10]},
    }
    return grids.get(name, None)

# make pipeline with and without scaling
def preprocessor(scale):
    # median ensures it is robust to outliers
    steps = [("imputer", SimpleImputer(strategy="median"))]
    if scale:
        # scales data to benefit models such as SVM and KNN
        steps.append(("scaler", StandardScaler(with_mean=True)))
    else:
        steps.append(("scaler", FunctionTransformer(lambda X: X, feature_names_out="one-to-one")))
    return Pipeline(steps)


def build_scorers():
    return {
        "accuracy": "accuracy", # normal accuracy
        "balanced_accuracy": make_scorer(balanced_accuracy_score), # balanced accuracy
        "precision": make_scorer(precision_score, average="macro", zero_division=0),
        "recall": make_scorer(recall_score, average="macro", zero_division=0),
        "f1": make_scorer(f1_score, average="macro", zero_division=0)
    }

# %%
def evaluate_one(X_train, y_train, X_test, y_test, variant,
                 random_state=RANDOM_STATE, n_splits=N_SPLITS_CV, n_jobs=N_JOBS):

    inner_cv = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=random_state)
    outer_cv = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=random_state)
    scorers = build_scorers()
    results = []

    for name, clf in build_models(random_state).items():
        # scaling decision
        X_tr, X_te = X_train, X_test

        # Convert sparse to dense for models that need dense arrays
        if sparse.issparse(X_tr):
            if name in ["HistGB", "GradientBoosting", "GaussianNaiveBayes"]:
                X_tr = X_tr.toarray()
                X_te = X_te.toarray()

        # Scaling decision
        if variant == "scaled":
            scaler = StandardScaler(with_mean=False if sparse.issparse(X_tr) else True)
        else:
            scaler = FunctionTransformer(lambda X: X, feature_names_out="one-to-one")

        pipe = Pipeline([
            ("scale", scaler),
            ("clf", clf)
        ])

        grid = small_param_grid(name)
        model_for_cv = GridSearchCV(pipe, grid, scoring=scorers, cv=inner_cv,
                                    n_jobs=n_jobs, refit="f1") if grid else pipe

        cv_out = cross_validate(model_for_cv, X_tr, y_train, cv=outer_cv,
                                scoring=scorers, return_train_score=False,
                                n_jobs=n_jobs, return_estimator=True)

        # Fit on full training
        model_for_cv.fit(X_tr, y_train)
        y_pred = model_for_cv.predict(X_te)

        # best estimator info
        if isinstance(model_for_cv, GridSearchCV):
            chosen = model_for_cv.best_estimator_
            tuned = model_for_cv.best_params_
        else:
            chosen = model_for_cv
            tuned = {}

        clf_params = chosen.named_steps["clf"].get_params()
        tuned_json = json.dumps(tuned, default=str)
        clf_json = json.dumps(clf_params, default=str)

        y_score = None
        if hasattr(model_for_cv, "predict_proba"):
            y_score = model_for_cv.predict_proba(X_te)[:, 1]
        elif hasattr(model_for_cv, "decision_function"):
            y_score = model_for_cv.decision_function(X_te)

        row = {
            "variant": variant,
            "model": name,
            "tuned_parameters": tuned_json,
            "clf_parameters": clf_json,
            **{f"cv_{k.replace('test_','')}_mean": float(np.mean(v))
               for k,v in cv_out.items() if k.startswith("test_")},
            **{f"cv_{k.replace('test_','')}_std": float(np.std(v))
               for k,v in cv_out.items() if k.startswith("test_")},
            "holdout_accuracy": accuracy_score(y_test, y_pred),
            "holdout_bal_acc": balanced_accuracy_score(y_test, y_pred),
            "holdout_precision": precision_score(y_test, y_pred, average="macro", zero_division=0),
            "holdout_recall": recall_score(y_test, y_pred, average="macro", zero_division=0),
            "holdout_f1": f1_score(y_test, y_pred, average="macro", zero_division=0),
        }

        results.append(row)
        print(row)
    return pd.DataFrame(results)

# %%
def make_input_data(file_paths="./outputsTrain/*/mean_model_zero_shot_classification.csv"):
    # Get all CSV files.
    all_files = glob.glob(file_paths)  # change this to your folder path

    # Loop through files.
    all_dfs = []

    for f in all_files:
        df = pd.read_csv(f)
        df['category'] = df['doc_id'].apply(lambda x: x.split('_')[0])
        
        # Aggregate numeric factor columns by category
        factor_cols = [f"factor_{i}" for i in range(1, 7)]
        df_agg = df.groupby('category')[factor_cols].mean().reset_index()
        all_dfs.append(df_agg)

    # Concatenate all aggregated DataFrames
    dfs = pd.concat(all_dfs, ignore_index=True)

    dfs['category_codes'] = dfs['category'].astype('category').cat.codes
    # Return x and y arrays.
    return dfs[[f"factor_{i}" for i in range(1, 7)]].values, dfs['category_codes'].values

# %%
# Assess zero-shot performance. 
X_train, y_train = make_input_data(file_paths="./outputsTrain/*/mean_model_zero_shot_classification.csv")
X_test, y_test = make_input_data(file_paths="./outputsTest/*/mean_model_zero_shot_classification.csv")

all_results = []
for variant in ("raw", "scaled"):
    df_res = evaluate_one(X_train, y_train, X_test, y_test, variant)
    all_results.append(df_res)

# Concatenate all results and save.
final_results = pd.concat(all_results, ignore_index=True)
final_results.to_csv(f"./{OUTPUT_DIR}/zeroShotResults.csv", index=False)

for metric in ['holdout_accuracy', 'holdout_bal_acc', 'holdout_precision', 'holdout_recall', 'holdout_f1']:
    print(f"Highest: {final_results.sort_values(by=metric, ascending=False)[metric].tolist()[0]}")
    print(pl.from_pandas(final_results.sort_values(by=metric, ascending=False).head()))
# Out:
# {'variant': 'raw', 'model': 'LogisticRegression', 'tuned_parameters': '{"clf__C": 1.0}', 'clf_parameters': '{"C": 1.0, "class_weight": "balanced", "dual": false, "fit_intercept": true, "intercept_scaling": 1, "l1_ratio": 0.0, "max_iter": 20000, "n_jobs": null, "penalty": "deprecated", "random_state": 1618, "solver": "lbfgs", "tol": 0.0001, "verbose": 0, "warm_start": false}', 'cv_accuracy_mean': 0.9550000000000001, 'cv_balanced_accuracy_mean': 0.9550000000000001, 'cv_precision_mean': 0.956725481261085, 'cv_recall_mean': 0.9550000000000001, 'cv_f1_mean': 0.9546824092074413, 'cv_accuracy_std': 0.009486832980505146, 'cv_balanced_accuracy_std': 0.009486832980505112, 'cv_precision_std': 0.008491852392948196, 'cv_recall_std': 0.009486832980505112, 'cv_f1_std': 0.00932902848086184, 'holdout_accuracy': 0.954, 'holdout_bal_acc': 0.9540000000000001, 'holdout_precision': 0.9538740189447286, 'holdout_recall': 0.9540000000000001, 'holdout_f1': 0.9536877312927625}
# {'variant': 'raw', 'model': 'RidgeClassifier', 'tuned_parameters': '{}', 'clf_parameters': '{"alpha": 1.0, "class_weight": "balanced", "copy_X": true, "fit_intercept": true, "max_iter": null, "positive": false, "random_state": 1618, "solver": "auto", "tol": 0.0001}', 'cv_accuracy_mean': 0.817, 'cv_balanced_accuracy_mean': 0.817, 'cv_precision_mean': 0.7618975596272088, 'cv_recall_mean': 0.817, 'cv_f1_mean': 0.7744593428308622, 'cv_accuracy_std': 0.02063976744055026, 'cv_balanced_accuracy_std': 0.020639767440550284, 'cv_precision_std': 0.01658254570356081, 'cv_recall_std': 0.020639767440550284, 'cv_f1_std': 0.023068702074074195, 'holdout_accuracy': 0.824, 'holdout_bal_acc': 0.8240000000000001, 'holdout_precision': 0.7649877049728911, 'holdout_recall': 0.8240000000000001, 'holdout_f1': 0.7811084727219572}
# {'variant': 'raw', 'model': 'LinearSVC', 'tuned_parameters': '{"clf__C": 1.0}', 'clf_parameters': '{"C": 1.0, "class_weight": "balanced", "dual": "auto", "fit_intercept": true, "intercept_scaling": 1, "loss": "squared_hinge", "max_iter": 20000, "multi_class": "ovr", "penalty": "l2", "random_state": 1618, "tol": 0.0001, "verbose": 0}', 'cv_accuracy_mean': 0.93, 'cv_balanced_accuracy_mean': 0.9299999999999999, 'cv_precision_mean': 0.9338147318909534, 'cv_recall_mean': 0.9299999999999999, 'cv_f1_mean': 0.9288248532758331, 'cv_accuracy_std': 0.015165750888103078, 'cv_balanced_accuracy_std': 0.01516575088810305, 'cv_precision_std': 0.014540808318410205, 'cv_recall_std': 0.01516575088810305, 'cv_f1_std': 0.01566610929406641, 'holdout_accuracy': 0.934, 'holdout_bal_acc': 0.9339999999999999, 'holdout_precision': 0.9353285738118273, 'holdout_recall': 0.9339999999999999, 'holdout_f1': 0.932624740333894}
# {'variant': 'raw', 'model': 'SVC-RBF', 'tuned_parameters': '{"clf__C": 1.0, "clf__gamma": "scale"}', 'clf_parameters': '{"C": 1.0, "break_ties": false, "cache_size": 200, "class_weight": "balanced", "coef0": 0.0, "decision_function_shape": "ovr", "degree": 3, "gamma": "scale", "kernel": "rbf", "max_iter": -1, "probability": false, "random_state": 1618, "shrinking": true, "tol": 0.001, "verbose": false}', 'cv_accuracy_mean': 0.96, 'cv_balanced_accuracy_mean': 0.96, 'cv_precision_mean': 0.960795458673033, 'cv_recall_mean': 0.96, 'cv_f1_mean': 0.9596147652281038, 'cv_accuracy_std': 0.01140175425099139, 'cv_balanced_accuracy_std': 0.01140175425099139, 'cv_precision_std': 0.011268505774303774, 'cv_recall_std': 0.01140175425099139, 'cv_f1_std': 0.011833953477637313, 'holdout_accuracy': 0.966, 'holdout_bal_acc': 0.966, 'holdout_precision': 0.9660917012695469, 'holdout_recall': 0.966, 'holdout_f1': 0.9659267277849661}
# {'variant': 'raw', 'model': 'SGD-Hinge', 'tuned_parameters': '{}', 'clf_parameters': '{"alpha": 0.0001, "average": false, "class_weight": "balanced", "early_stopping": false, "epsilon": 0.1, "eta0": 0.01, "fit_intercept": true, "l1_ratio": 0.15, "learning_rate": "optimal", "loss": "hinge", "max_iter": 20000, "n_iter_no_change": 5, "n_jobs": null, "penalty": "l2", "power_t": 0.5, "random_state": 1618, "shuffle": true, "tol": 0.001, "validation_fraction": 0.1, "verbose": 0, "warm_start": false}', 'cv_accuracy_mean': 0.9100000000000001, 'cv_balanced_accuracy_mean': 0.9100000000000001, 'cv_precision_mean': 0.9207512615036844, 'cv_recall_mean': 0.9100000000000001, 'cv_f1_mean': 0.9086598129458074, 'cv_accuracy_std': 0.02073644135332774, 'cv_balanced_accuracy_std': 0.02073644135332773, 'cv_precision_std': 0.01101340631138271, 'cv_recall_std': 0.02073644135332773, 'cv_f1_std': 0.02101937083852963, 'holdout_accuracy': 0.914, 'holdout_bal_acc': 0.914, 'holdout_precision': 0.9180354304137051, 'holdout_recall': 0.914, 'holdout_f1': 0.912198850641128}
# {'variant': 'raw', 'model': 'KNN', 'tuned_parameters': '{"clf__n_neighbors": 11}', 'clf_parameters': '{"algorithm": "auto", "leaf_size": 30, "metric": "minkowski", "metric_params": null, "n_jobs": null, "n_neighbors": 11, "p": 2, "weights": "uniform"}', 'cv_accuracy_mean': 0.959, 'cv_balanced_accuracy_mean': 0.959, 'cv_precision_mean': 0.9604555823022641, 'cv_recall_mean': 0.959, 'cv_f1_mean': 0.9584935594948731, 'cv_accuracy_std': 0.012806248474865669, 'cv_balanced_accuracy_std': 0.012806248474865708, 'cv_precision_std': 0.012880094389786354, 'cv_recall_std': 0.012806248474865708, 'cv_f1_std': 0.01354342714048645, 'holdout_accuracy': 0.952, 'holdout_bal_acc': 0.952, 'holdout_precision': 0.9519754353303078, 'holdout_recall': 0.952, 'holdout_f1': 0.9516622416622379}
# {'variant': 'raw', 'model': 'DecisionTree', 'tuned_parameters': '{}', 'clf_parameters': '{"ccp_alpha": 0.0, "class_weight": "balanced", "criterion": "gini", "max_depth": null, "max_features": null, "max_leaf_nodes": null, "min_impurity_decrease": 0.0, "min_samples_leaf": 1, "min_samples_split": 2, "min_weight_fraction_leaf": 0.0, "monotonic_cst": null, "random_state": 1618, "splitter": "best"}', 'cv_accuracy_mean': 0.874, 'cv_balanced_accuracy_mean': 0.8739999999999999, 'cv_precision_mean': 0.8815002953376423, 'cv_recall_mean': 0.8739999999999999, 'cv_f1_mean': 0.874069136618705, 'cv_accuracy_std': 0.014628738838327807, 'cv_balanced_accuracy_std': 0.014628738838327835, 'cv_precision_std': 0.015765395162453504, 'cv_recall_std': 0.014628738838327835, 'cv_f1_std': 0.015243338893193428, 'holdout_accuracy': 0.882, 'holdout_bal_acc': 0.882, 'holdout_precision': 0.8834234733569539, 'holdout_recall': 0.882, 'holdout_f1': 0.8820496077023561}
# {'variant': 'raw', 'model': 'RandomForest', 'tuned_parameters': '{"clf__max_depth": null, "clf__n_estimators": 300}', 'clf_parameters': '{"bootstrap": true, "ccp_alpha": 0.0, "class_weight": "balanced", "criterion": "gini", "max_depth": null, "max_features": "sqrt", "max_leaf_nodes": null, "max_samples": null, "min_impurity_decrease": 0.0, "min_samples_leaf": 1, "min_samples_split": 2, "min_weight_fraction_leaf": 0.0, "monotonic_cst": null, "n_estimators": 300, "n_jobs": null, "oob_score": false, "random_state": 1618, "verbose": 0, "warm_start": false}', 'cv_accuracy_mean': 0.9410000000000001, 'cv_balanced_accuracy_mean': 0.9410000000000001, 'cv_precision_mean': 0.9436674294431731, 'cv_recall_mean': 0.9410000000000001, 'cv_f1_mean': 0.94067720388573, 'cv_accuracy_std': 0.010677078252031272, 'cv_balanced_accuracy_std': 0.010677078252031298, 'cv_precision_std': 0.01037710595142105, 'cv_recall_std': 0.010677078252031298, 'cv_f1_std': 0.010638240725508041, 'holdout_accuracy': 0.942, 'holdout_bal_acc': 0.942, 'holdout_precision': 0.9423156215919585, 'holdout_recall': 0.942, 'holdout_f1': 0.9418994423572282}
# {'variant': 'raw', 'model': 'ExtraTrees', 'tuned_parameters': '{"clf__max_depth": 20, "clf__n_estimators": 300}', 'clf_parameters': '{"bootstrap": false, "ccp_alpha": 0.0, "class_weight": "balanced", "criterion": "gini", "max_depth": 20, "max_features": "sqrt", "max_leaf_nodes": null, "max_samples": null, "min_impurity_decrease": 0.0, "min_samples_leaf": 1, "min_samples_split": 2, "min_weight_fraction_leaf": 0.0, "monotonic_cst": null, "n_estimators": 300, "n_jobs": null, "oob_score": false, "random_state": 1618, "verbose": 0, "warm_start": false}', 'cv_accuracy_mean': 0.959, 'cv_balanced_accuracy_mean': 0.959, 'cv_precision_mean': 0.9601881408065619, 'cv_recall_mean': 0.959, 'cv_f1_mean': 0.9586849421611939, 'cv_accuracy_std': 0.008000000000000007, 'cv_balanced_accuracy_std': 0.00799999999999999, 'cv_precision_std': 0.00789781210651479, 'cv_recall_std': 0.00799999999999999, 'cv_f1_std': 0.00816779286200482, 'holdout_accuracy': 0.952, 'holdout_bal_acc': 0.9520000000000002, 'holdout_precision': 0.951925013058054, 'holdout_recall': 0.9520000000000002, 'holdout_f1': 0.951730671072301}
# {'variant': 'raw', 'model': 'GradientBoosting', 'tuned_parameters': '{}', 'clf_parameters': '{"ccp_alpha": 0.0, "criterion": "friedman_mse", "init": null, "learning_rate": 0.1, "loss": "log_loss", "max_depth": 3, "max_features": null, "max_leaf_nodes": null, "min_impurity_decrease": 0.0, "min_samples_leaf": 1, "min_samples_split": 2, "min_weight_fraction_leaf": 0.0, "n_estimators": 100, "n_iter_no_change": null, "random_state": 1618, "subsample": 1.0, "tol": 0.0001, "validation_fraction": 0.1, "verbose": 0, "warm_start": false}', 'cv_accuracy_mean': 0.924, 'cv_balanced_accuracy_mean': 0.9239999999999998, 'cv_precision_mean': 0.9266358597804283, 'cv_recall_mean': 0.9239999999999998, 'cv_f1_mean': 0.9234634015536782, 'cv_accuracy_std': 0.010677078252031288, 'cv_balanced_accuracy_std': 0.010677078252031416, 'cv_precision_std': 0.01022090884575977, 'cv_recall_std': 0.010677078252031416, 'cv_f1_std': 0.010861273799329621, 'holdout_accuracy': 0.929, 'holdout_bal_acc': 0.9289999999999999, 'holdout_precision': 0.9299176047557036, 'holdout_recall': 0.9289999999999999, 'holdout_f1': 0.9289737744221276}
# {'variant': 'raw', 'model': 'HistGB', 'tuned_parameters': '{"clf__max_depth": 10}', 'clf_parameters': '{"categorical_features": "from_dtype", "class_weight": null, "early_stopping": "auto", "interaction_cst": null, "l2_regularization": 0.0, "learning_rate": 0.1, "loss": "log_loss", "max_bins": 255, "max_depth": 10, "max_features": 1.0, "max_iter": 100, "max_leaf_nodes": 31, "min_samples_leaf": 20, "monotonic_cst": null, "n_iter_no_change": 10, "random_state": 1618, "scoring": "loss", "tol": 1e-07, "validation_fraction": 0.1, "verbose": 0, "warm_start": false}', 'cv_accuracy_mean': 0.933, 'cv_balanced_accuracy_mean': 0.933, 'cv_precision_mean': 0.9364356627832466, 'cv_recall_mean': 0.933, 'cv_f1_mean': 0.932870956572333, 'cv_accuracy_std': 0.01568438714135809, 'cv_balanced_accuracy_std': 0.01568438714135809, 'cv_precision_std': 0.014880391323668758, 'cv_recall_std': 0.01568438714135809, 'cv_f1_std': 0.016178755708632177, 'holdout_accuracy': 0.942, 'holdout_bal_acc': 0.942, 'holdout_precision': 0.9425105661979154, 'holdout_recall': 0.942, 'holdout_f1': 0.9419217717034861}
# {'variant': 'raw', 'model': 'AdaBoost', 'tuned_parameters': '{}', 'clf_parameters': '{"estimator": null, "learning_rate": 1.0, "n_estimators": 50, "random_state": 1618}', 'cv_accuracy_mean': 0.476, 'cv_balanced_accuracy_mean': 0.476, 'cv_precision_mean': 0.4437647875694034, 'cv_recall_mean': 0.476, 'cv_f1_mean': 0.39749761613554124, 'cv_accuracy_std': 0.042355637169094754, 'cv_balanced_accuracy_std': 0.04235563716909478, 'cv_precision_std': 0.11713182590604793, 'cv_recall_std': 0.04235563716909478, 'cv_f1_std': 0.049317570538026864, 'holdout_accuracy': 0.495, 'holdout_bal_acc': 0.49499999999999994, 'holdout_precision': 0.6419149875693734, 'holdout_recall': 0.49499999999999994, 'holdout_f1': 0.419925477850806}
# {'variant': 'raw', 'model': 'GaussianNaiveBayes', 'tuned_parameters': '{}', 'clf_parameters': '{"priors": null, "var_smoothing": 1e-09}', 'cv_accuracy_mean': 0.95, 'cv_balanced_accuracy_mean': 0.95, 'cv_precision_mean': 0.9520054994884717, 'cv_recall_mean': 0.95, 'cv_f1_mean': 0.9500786111196895, 'cv_accuracy_std': 0.009486832980505112, 'cv_balanced_accuracy_std': 0.009486832980505112, 'cv_precision_std': 0.008864025364830674, 'cv_recall_std': 0.009486832980505112, 'cv_f1_std': 0.008928348290204304, 'holdout_accuracy': 0.937, 'holdout_bal_acc': 0.9369999999999999, 'holdout_precision': 0.9374621243521526, 'holdout_recall': 0.9369999999999999, 'holdout_f1': 0.9370910189030328}
# {'variant': 'scaled', 'model': 'LogisticRegression', 'tuned_parameters': '{"clf__C": 1.0}', 'clf_parameters': '{"C": 1.0, "class_weight": "balanced", "dual": false, "fit_intercept": true, "intercept_scaling": 1, "l1_ratio": 0.0, "max_iter": 20000, "n_jobs": null, "penalty": "deprecated", "random_state": 1618, "solver": "lbfgs", "tol": 0.0001, "verbose": 0, "warm_start": false}', 'cv_accuracy_mean': 0.953, 'cv_balanced_accuracy_mean': 0.953, 'cv_precision_mean': 0.9550857990516086, 'cv_recall_mean': 0.953, 'cv_f1_mean': 0.9528521287889589, 'cv_accuracy_std': 0.009273618495495711, 'cv_balanced_accuracy_std': 0.009273618495495689, 'cv_precision_std': 0.00843788378974701, 'cv_recall_std': 0.009273618495495689, 'cv_f1_std': 0.00925482659552133, 'holdout_accuracy': 0.953, 'holdout_bal_acc': 0.9530000000000001, 'holdout_precision': 0.9528874518796023, 'holdout_recall': 0.9530000000000001, 'holdout_f1': 0.9527956768575983}
# {'variant': 'scaled', 'model': 'RidgeClassifier', 'tuned_parameters': '{}', 'clf_parameters': '{"alpha": 1.0, "class_weight": "balanced", "copy_X": true, "fit_intercept": true, "max_iter": null, "positive": false, "random_state": 1618, "solver": "auto", "tol": 0.0001}', 'cv_accuracy_mean': 0.817, 'cv_balanced_accuracy_mean': 0.817, 'cv_precision_mean': 0.7618975596272088, 'cv_recall_mean': 0.817, 'cv_f1_mean': 0.7744593428308622, 'cv_accuracy_std': 0.02063976744055026, 'cv_balanced_accuracy_std': 0.020639767440550284, 'cv_precision_std': 0.01658254570356081, 'cv_recall_std': 0.020639767440550284, 'cv_f1_std': 0.023068702074074195, 'holdout_accuracy': 0.824, 'holdout_bal_acc': 0.8240000000000001, 'holdout_precision': 0.7649877049728911, 'holdout_recall': 0.8240000000000001, 'holdout_f1': 0.7811084727219572}
# {'variant': 'scaled', 'model': 'LinearSVC', 'tuned_parameters': '{"clf__C": 1.0}', 'clf_parameters': '{"C": 1.0, "class_weight": "balanced", "dual": "auto", "fit_intercept": true, "intercept_scaling": 1, "loss": "squared_hinge", "max_iter": 20000, "multi_class": "ovr", "penalty": "l2", "random_state": 1618, "tol": 0.0001, "verbose": 0}', 'cv_accuracy_mean': 0.933, 'cv_balanced_accuracy_mean': 0.933, 'cv_precision_mean': 0.936487531313753, 'cv_recall_mean': 0.933, 'cv_f1_mean': 0.9321883079269113, 'cv_accuracy_std': 0.015999999999999976, 'cv_balanced_accuracy_std': 0.01600000000000001, 'cv_precision_std': 0.01566884372674566, 'cv_recall_std': 0.01600000000000001, 'cv_f1_std': 0.01628198323591533, 'holdout_accuracy': 0.936, 'holdout_bal_acc': 0.9359999999999999, 'holdout_precision': 0.9367850521344507, 'holdout_recall': 0.9359999999999999, 'holdout_f1': 0.9348904926611532}
# {'variant': 'scaled', 'model': 'SVC-RBF', 'tuned_parameters': '{"clf__C": 1.0, "clf__gamma": "scale"}', 'clf_parameters': '{"C": 1.0, "break_ties": false, "cache_size": 200, "class_weight": "balanced", "coef0": 0.0, "decision_function_shape": "ovr", "degree": 3, "gamma": "scale", "kernel": "rbf", "max_iter": -1, "probability": false, "random_state": 1618, "shrinking": true, "tol": 0.001, "verbose": false}', 'cv_accuracy_mean': 0.959, 'cv_balanced_accuracy_mean': 0.959, 'cv_precision_mean': 0.9600162378938123, 'cv_recall_mean': 0.959, 'cv_f1_mean': 0.9585980210791387, 'cv_accuracy_std': 0.009695359714832668, 'cv_balanced_accuracy_std': 0.009695359714832638, 'cv_precision_std': 0.009882408594606273, 'cv_recall_std': 0.009695359714832638, 'cv_f1_std': 0.010177559697559778, 'holdout_accuracy': 0.964, 'holdout_bal_acc': 0.9640000000000001, 'holdout_precision': 0.9642960007222552, 'holdout_recall': 0.9640000000000001, 'holdout_f1': 0.9640214214544607}
# {'variant': 'scaled', 'model': 'SGD-Hinge', 'tuned_parameters': '{}', 'clf_parameters': '{"alpha": 0.0001, "average": false, "class_weight": "balanced", "early_stopping": false, "epsilon": 0.1, "eta0": 0.01, "fit_intercept": true, "l1_ratio": 0.15, "learning_rate": "optimal", "loss": "hinge", "max_iter": 20000, "n_iter_no_change": 5, "n_jobs": null, "penalty": "l2", "power_t": 0.5, "random_state": 1618, "shuffle": true, "tol": 0.001, "validation_fraction": 0.1, "verbose": 0, "warm_start": false}', 'cv_accuracy_mean': 0.9259999999999999, 'cv_balanced_accuracy_mean': 0.9259999999999999, 'cv_precision_mean': 0.9309072251464903, 'cv_recall_mean': 0.9259999999999999, 'cv_f1_mean': 0.9259949323114085, 'cv_accuracy_std': 0.013564659966250519, 'cv_balanced_accuracy_std': 0.013564659966250548, 'cv_precision_std': 0.011945353857100337, 'cv_recall_std': 0.013564659966250548, 'cv_f1_std': 0.014037603031506318, 'holdout_accuracy': 0.92, 'holdout_bal_acc': 0.9199999999999999, 'holdout_precision': 0.9235566486610702, 'holdout_recall': 0.9199999999999999, 'holdout_f1': 0.9198115857754756}
# {'variant': 'scaled', 'model': 'KNN', 'tuned_parameters': '{"clf__n_neighbors": 11}', 'clf_parameters': '{"algorithm": "auto", "leaf_size": 30, "metric": "minkowski", "metric_params": null, "n_jobs": null, "n_neighbors": 11, "p": 2, "weights": "uniform"}', 'cv_accuracy_mean': 0.9549999999999998, 'cv_balanced_accuracy_mean': 0.9549999999999998, 'cv_precision_mean': 0.9566137559662934, 'cv_recall_mean': 0.9549999999999998, 'cv_f1_mean': 0.9544273182415843, 'cv_accuracy_std': 0.008366600265340762, 'cv_balanced_accuracy_std': 0.00836660026534083, 'cv_precision_std': 0.007507923411245481, 'cv_recall_std': 0.00836660026534083, 'cv_f1_std': 0.009136195958850783, 'holdout_accuracy': 0.952, 'holdout_bal_acc': 0.952, 'holdout_precision': 0.9522294544047634, 'holdout_recall': 0.952, 'holdout_f1': 0.9517492902510171}
# {'variant': 'scaled', 'model': 'DecisionTree', 'tuned_parameters': '{}', 'clf_parameters': '{"ccp_alpha": 0.0, "class_weight": "balanced", "criterion": "gini", "max_depth": null, "max_features": null, "max_leaf_nodes": null, "min_impurity_decrease": 0.0, "min_samples_leaf": 1, "min_samples_split": 2, "min_weight_fraction_leaf": 0.0, "monotonic_cst": null, "random_state": 1618, "splitter": "best"}', 'cv_accuracy_mean': 0.874, 'cv_balanced_accuracy_mean': 0.8739999999999999, 'cv_precision_mean': 0.8815002953376423, 'cv_recall_mean': 0.8739999999999999, 'cv_f1_mean': 0.874069136618705, 'cv_accuracy_std': 0.014628738838327807, 'cv_balanced_accuracy_std': 0.014628738838327835, 'cv_precision_std': 0.015765395162453504, 'cv_recall_std': 0.014628738838327835, 'cv_f1_std': 0.015243338893193428, 'holdout_accuracy': 0.882, 'holdout_bal_acc': 0.882, 'holdout_precision': 0.8834234733569539, 'holdout_recall': 0.882, 'holdout_f1': 0.8820496077023561}
# {'variant': 'scaled', 'model': 'RandomForest', 'tuned_parameters': '{"clf__max_depth": null, "clf__n_estimators": 300}', 'clf_parameters': '{"bootstrap": true, "ccp_alpha": 0.0, "class_weight": "balanced", "criterion": "gini", "max_depth": null, "max_features": "sqrt", "max_leaf_nodes": null, "max_samples": null, "min_impurity_decrease": 0.0, "min_samples_leaf": 1, "min_samples_split": 2, "min_weight_fraction_leaf": 0.0, "monotonic_cst": null, "n_estimators": 300, "n_jobs": null, "oob_score": false, "random_state": 1618, "verbose": 0, "warm_start": false}', 'cv_accuracy_mean': 0.9410000000000001, 'cv_balanced_accuracy_mean': 0.9410000000000001, 'cv_precision_mean': 0.9436674294431731, 'cv_recall_mean': 0.9410000000000001, 'cv_f1_mean': 0.94067720388573, 'cv_accuracy_std': 0.010677078252031272, 'cv_balanced_accuracy_std': 0.010677078252031298, 'cv_precision_std': 0.01037710595142105, 'cv_recall_std': 0.010677078252031298, 'cv_f1_std': 0.010638240725508041, 'holdout_accuracy': 0.942, 'holdout_bal_acc': 0.942, 'holdout_precision': 0.9423156215919585, 'holdout_recall': 0.942, 'holdout_f1': 0.9418994423572282}
# {'variant': 'scaled', 'model': 'ExtraTrees', 'tuned_parameters': '{"clf__max_depth": 20, "clf__n_estimators": 300}', 'clf_parameters': '{"bootstrap": false, "ccp_alpha": 0.0, "class_weight": "balanced", "criterion": "gini", "max_depth": 20, "max_features": "sqrt", "max_leaf_nodes": null, "max_samples": null, "min_impurity_decrease": 0.0, "min_samples_leaf": 1, "min_samples_split": 2, "min_weight_fraction_leaf": 0.0, "monotonic_cst": null, "n_estimators": 300, "n_jobs": null, "oob_score": false, "random_state": 1618, "verbose": 0, "warm_start": false}', 'cv_accuracy_mean': 0.959, 'cv_balanced_accuracy_mean': 0.959, 'cv_precision_mean': 0.9601881408065619, 'cv_recall_mean': 0.959, 'cv_f1_mean': 0.9586849421611939, 'cv_accuracy_std': 0.008000000000000007, 'cv_balanced_accuracy_std': 0.00799999999999999, 'cv_precision_std': 0.00789781210651479, 'cv_recall_std': 0.00799999999999999, 'cv_f1_std': 0.00816779286200482, 'holdout_accuracy': 0.952, 'holdout_bal_acc': 0.9520000000000002, 'holdout_precision': 0.951925013058054, 'holdout_recall': 0.9520000000000002, 'holdout_f1': 0.951730671072301}
# {'variant': 'scaled', 'model': 'GradientBoosting', 'tuned_parameters': '{}', 'clf_parameters': '{"ccp_alpha": 0.0, "criterion": "friedman_mse", "init": null, "learning_rate": 0.1, "loss": "log_loss", "max_depth": 3, "max_features": null, "max_leaf_nodes": null, "min_impurity_decrease": 0.0, "min_samples_leaf": 1, "min_samples_split": 2, "min_weight_fraction_leaf": 0.0, "n_estimators": 100, "n_iter_no_change": null, "random_state": 1618, "subsample": 1.0, "tol": 0.0001, "validation_fraction": 0.1, "verbose": 0, "warm_start": false}', 'cv_accuracy_mean': 0.924, 'cv_balanced_accuracy_mean': 0.9239999999999998, 'cv_precision_mean': 0.9266358597804283, 'cv_recall_mean': 0.9239999999999998, 'cv_f1_mean': 0.9234634015536782, 'cv_accuracy_std': 0.010677078252031288, 'cv_balanced_accuracy_std': 0.010677078252031416, 'cv_precision_std': 0.01022090884575977, 'cv_recall_std': 0.010677078252031416, 'cv_f1_std': 0.010861273799329621, 'holdout_accuracy': 0.929, 'holdout_bal_acc': 0.9289999999999999, 'holdout_precision': 0.9299176047557036, 'holdout_recall': 0.9289999999999999, 'holdout_f1': 0.9289737744221276}
# {'variant': 'scaled', 'model': 'HistGB', 'tuned_parameters': '{"clf__max_depth": 10}', 'clf_parameters': '{"categorical_features": "from_dtype", "class_weight": null, "early_stopping": "auto", "interaction_cst": null, "l2_regularization": 0.0, "learning_rate": 0.1, "loss": "log_loss", "max_bins": 255, "max_depth": 10, "max_features": 1.0, "max_iter": 100, "max_leaf_nodes": 31, "min_samples_leaf": 20, "monotonic_cst": null, "n_iter_no_change": 10, "random_state": 1618, "scoring": "loss", "tol": 1e-07, "validation_fraction": 0.1, "verbose": 0, "warm_start": false}', 'cv_accuracy_mean': 0.933, 'cv_balanced_accuracy_mean': 0.933, 'cv_precision_mean': 0.9364356627832466, 'cv_recall_mean': 0.933, 'cv_f1_mean': 0.932870956572333, 'cv_accuracy_std': 0.01568438714135809, 'cv_balanced_accuracy_std': 0.01568438714135809, 'cv_precision_std': 0.014880391323668758, 'cv_recall_std': 0.01568438714135809, 'cv_f1_std': 0.016178755708632177, 'holdout_accuracy': 0.942, 'holdout_bal_acc': 0.942, 'holdout_precision': 0.9425105661979154, 'holdout_recall': 0.942, 'holdout_f1': 0.9419217717034861}
# {'variant': 'scaled', 'model': 'AdaBoost', 'tuned_parameters': '{}', 'clf_parameters': '{"estimator": null, "learning_rate": 1.0, "n_estimators": 50, "random_state": 1618}', 'cv_accuracy_mean': 0.476, 'cv_balanced_accuracy_mean': 0.476, 'cv_precision_mean': 0.4437647875694034, 'cv_recall_mean': 0.476, 'cv_f1_mean': 0.39749761613554124, 'cv_accuracy_std': 0.042355637169094754, 'cv_balanced_accuracy_std': 0.04235563716909478, 'cv_precision_std': 0.11713182590604793, 'cv_recall_std': 0.04235563716909478, 'cv_f1_std': 0.049317570538026864, 'holdout_accuracy': 0.495, 'holdout_bal_acc': 0.49499999999999994, 'holdout_precision': 0.6419149875693734, 'holdout_recall': 0.49499999999999994, 'holdout_f1': 0.419925477850806}
# {'variant': 'scaled', 'model': 'GaussianNaiveBayes', 'tuned_parameters': '{}', 'clf_parameters': '{"priors": null, "var_smoothing": 1e-09}', 'cv_accuracy_mean': 0.95, 'cv_balanced_accuracy_mean': 0.95, 'cv_precision_mean': 0.9520054994884717, 'cv_recall_mean': 0.95, 'cv_f1_mean': 0.9500786111196895, 'cv_accuracy_std': 0.009486832980505112, 'cv_balanced_accuracy_std': 0.009486832980505112, 'cv_precision_std': 0.008864025364830674, 'cv_recall_std': 0.009486832980505112, 'cv_f1_std': 0.008928348290204304, 'holdout_accuracy': 0.937, 'holdout_bal_acc': 0.9369999999999999, 'holdout_precision': 0.9374621243521526, 'holdout_recall': 0.9369999999999999, 'holdout_f1': 0.9370910189030328}
# Highest: 0.966
# shape: (5, 19)
# ┌─────────┬────────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ variant ┆ model      ┆ tuned_par ┆ clf_param ┆ … ┆ holdout_b ┆ holdout_p ┆ holdout_r ┆ holdout_f │
# │ ---     ┆ ---        ┆ ameters   ┆ eters     ┆   ┆ al_acc    ┆ recision  ┆ ecall     ┆ 1         │
# │ str     ┆ str        ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │         ┆            ┆ str       ┆ str       ┆   ┆ f64       ┆ f64       ┆ f64       ┆ f64       │
# ╞═════════╪════════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ raw     ┆ SVC-RBF    ┆ {"clf__C" ┆ {"C":     ┆ … ┆ 0.966     ┆ 0.966092  ┆ 0.966     ┆ 0.965927  │
# │         ┆            ┆ : 1.0,    ┆ 1.0, "bre ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ "clf__gam ┆ ak_ties": ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ ma": …    ┆ false…    ┆   ┆           ┆           ┆           ┆           │
# │ scaled  ┆ SVC-RBF    ┆ {"clf__C" ┆ {"C":     ┆ … ┆ 0.964     ┆ 0.964296  ┆ 0.964     ┆ 0.964021  │
# │         ┆            ┆ : 1.0,    ┆ 1.0, "bre ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ "clf__gam ┆ ak_ties": ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ ma": …    ┆ false…    ┆   ┆           ┆           ┆           ┆           │
# │ raw     ┆ LogisticRe ┆ {"clf__C" ┆ {"C":     ┆ … ┆ 0.954     ┆ 0.953874  ┆ 0.954     ┆ 0.953688  │
# │         ┆ gression   ┆ : 1.0}    ┆ 1.0, "cla ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ ss_weight ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ ": "ba…   ┆   ┆           ┆           ┆           ┆           │
# │ scaled  ┆ LogisticRe ┆ {"clf__C" ┆ {"C":     ┆ … ┆ 0.953     ┆ 0.952887  ┆ 0.953     ┆ 0.952796  │
# │         ┆ gression   ┆ : 1.0}    ┆ 1.0, "cla ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ ss_weight ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ ": "ba…   ┆   ┆           ┆           ┆           ┆           │
# │ raw     ┆ ExtraTrees ┆ {"clf__ma ┆ {"bootstr ┆ … ┆ 0.952     ┆ 0.951925  ┆ 0.952     ┆ 0.951731  │
# │         ┆            ┆ x_depth": ┆ ap":      ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ 20,       ┆ false,    ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ "clf__n…  ┆ "ccp_alph ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ …         ┆   ┆           ┆           ┆           ┆           │
# └─────────┴────────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘
# Highest: 0.966
# shape: (5, 19)
# ┌─────────┬────────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ variant ┆ model      ┆ tuned_par ┆ clf_param ┆ … ┆ holdout_b ┆ holdout_p ┆ holdout_r ┆ holdout_f │
# │ ---     ┆ ---        ┆ ameters   ┆ eters     ┆   ┆ al_acc    ┆ recision  ┆ ecall     ┆ 1         │
# │ str     ┆ str        ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │         ┆            ┆ str       ┆ str       ┆   ┆ f64       ┆ f64       ┆ f64       ┆ f64       │
# ╞═════════╪════════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ raw     ┆ SVC-RBF    ┆ {"clf__C" ┆ {"C":     ┆ … ┆ 0.966     ┆ 0.966092  ┆ 0.966     ┆ 0.965927  │
# │         ┆            ┆ : 1.0,    ┆ 1.0, "bre ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ "clf__gam ┆ ak_ties": ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ ma": …    ┆ false…    ┆   ┆           ┆           ┆           ┆           │
# │ scaled  ┆ SVC-RBF    ┆ {"clf__C" ┆ {"C":     ┆ … ┆ 0.964     ┆ 0.964296  ┆ 0.964     ┆ 0.964021  │
# │         ┆            ┆ : 1.0,    ┆ 1.0, "bre ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ "clf__gam ┆ ak_ties": ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ ma": …    ┆ false…    ┆   ┆           ┆           ┆           ┆           │
# │ raw     ┆ LogisticRe ┆ {"clf__C" ┆ {"C":     ┆ … ┆ 0.954     ┆ 0.953874  ┆ 0.954     ┆ 0.953688  │
# │         ┆ gression   ┆ : 1.0}    ┆ 1.0, "cla ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ ss_weight ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ ": "ba…   ┆   ┆           ┆           ┆           ┆           │
# │ scaled  ┆ LogisticRe ┆ {"clf__C" ┆ {"C":     ┆ … ┆ 0.953     ┆ 0.952887  ┆ 0.953     ┆ 0.952796  │
# │         ┆ gression   ┆ : 1.0}    ┆ 1.0, "cla ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ ss_weight ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ ": "ba…   ┆   ┆           ┆           ┆           ┆           │
# │ raw     ┆ ExtraTrees ┆ {"clf__ma ┆ {"bootstr ┆ … ┆ 0.952     ┆ 0.951925  ┆ 0.952     ┆ 0.951731  │
# │         ┆            ┆ x_depth": ┆ ap":      ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ 20,       ┆ false,    ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ "clf__n…  ┆ "ccp_alph ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ …         ┆   ┆           ┆           ┆           ┆           │
# └─────────┴────────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘
# Highest: 0.9660917012695469
# shape: (5, 19)
# ┌─────────┬────────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ variant ┆ model      ┆ tuned_par ┆ clf_param ┆ … ┆ holdout_b ┆ holdout_p ┆ holdout_r ┆ holdout_f │
# │ ---     ┆ ---        ┆ ameters   ┆ eters     ┆   ┆ al_acc    ┆ recision  ┆ ecall     ┆ 1         │
# │ str     ┆ str        ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │         ┆            ┆ str       ┆ str       ┆   ┆ f64       ┆ f64       ┆ f64       ┆ f64       │
# ╞═════════╪════════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ raw     ┆ SVC-RBF    ┆ {"clf__C" ┆ {"C":     ┆ … ┆ 0.966     ┆ 0.966092  ┆ 0.966     ┆ 0.965927  │
# │         ┆            ┆ : 1.0,    ┆ 1.0, "bre ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ "clf__gam ┆ ak_ties": ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ ma": …    ┆ false…    ┆   ┆           ┆           ┆           ┆           │
# │ scaled  ┆ SVC-RBF    ┆ {"clf__C" ┆ {"C":     ┆ … ┆ 0.964     ┆ 0.964296  ┆ 0.964     ┆ 0.964021  │
# │         ┆            ┆ : 1.0,    ┆ 1.0, "bre ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ "clf__gam ┆ ak_ties": ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ ma": …    ┆ false…    ┆   ┆           ┆           ┆           ┆           │
# │ raw     ┆ LogisticRe ┆ {"clf__C" ┆ {"C":     ┆ … ┆ 0.954     ┆ 0.953874  ┆ 0.954     ┆ 0.953688  │
# │         ┆ gression   ┆ : 1.0}    ┆ 1.0, "cla ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ ss_weight ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ ": "ba…   ┆   ┆           ┆           ┆           ┆           │
# │ scaled  ┆ LogisticRe ┆ {"clf__C" ┆ {"C":     ┆ … ┆ 0.953     ┆ 0.952887  ┆ 0.953     ┆ 0.952796  │
# │         ┆ gression   ┆ : 1.0}    ┆ 1.0, "cla ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ ss_weight ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ ": "ba…   ┆   ┆           ┆           ┆           ┆           │
# │ scaled  ┆ KNN        ┆ {"clf__n_ ┆ {"algorit ┆ … ┆ 0.952     ┆ 0.952229  ┆ 0.952     ┆ 0.951749  │
# │         ┆            ┆ neighbors ┆ hm":      ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ ": 11}    ┆ "auto",   ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ "leaf_si… ┆   ┆           ┆           ┆           ┆           │
# └─────────┴────────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘
# Highest: 0.966
# shape: (5, 19)
# ┌─────────┬────────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ variant ┆ model      ┆ tuned_par ┆ clf_param ┆ … ┆ holdout_b ┆ holdout_p ┆ holdout_r ┆ holdout_f │
# │ ---     ┆ ---        ┆ ameters   ┆ eters     ┆   ┆ al_acc    ┆ recision  ┆ ecall     ┆ 1         │
# │ str     ┆ str        ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │         ┆            ┆ str       ┆ str       ┆   ┆ f64       ┆ f64       ┆ f64       ┆ f64       │
# ╞═════════╪════════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ raw     ┆ SVC-RBF    ┆ {"clf__C" ┆ {"C":     ┆ … ┆ 0.966     ┆ 0.966092  ┆ 0.966     ┆ 0.965927  │
# │         ┆            ┆ : 1.0,    ┆ 1.0, "bre ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ "clf__gam ┆ ak_ties": ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ ma": …    ┆ false…    ┆   ┆           ┆           ┆           ┆           │
# │ scaled  ┆ SVC-RBF    ┆ {"clf__C" ┆ {"C":     ┆ … ┆ 0.964     ┆ 0.964296  ┆ 0.964     ┆ 0.964021  │
# │         ┆            ┆ : 1.0,    ┆ 1.0, "bre ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ "clf__gam ┆ ak_ties": ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ ma": …    ┆ false…    ┆   ┆           ┆           ┆           ┆           │
# │ raw     ┆ LogisticRe ┆ {"clf__C" ┆ {"C":     ┆ … ┆ 0.954     ┆ 0.953874  ┆ 0.954     ┆ 0.953688  │
# │         ┆ gression   ┆ : 1.0}    ┆ 1.0, "cla ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ ss_weight ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ ": "ba…   ┆   ┆           ┆           ┆           ┆           │
# │ scaled  ┆ LogisticRe ┆ {"clf__C" ┆ {"C":     ┆ … ┆ 0.953     ┆ 0.952887  ┆ 0.953     ┆ 0.952796  │
# │         ┆ gression   ┆ : 1.0}    ┆ 1.0, "cla ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ ss_weight ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ ": "ba…   ┆   ┆           ┆           ┆           ┆           │
# │ raw     ┆ ExtraTrees ┆ {"clf__ma ┆ {"bootstr ┆ … ┆ 0.952     ┆ 0.951925  ┆ 0.952     ┆ 0.951731  │
# │         ┆            ┆ x_depth": ┆ ap":      ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ 20,       ┆ false,    ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ "clf__n…  ┆ "ccp_alph ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ …         ┆   ┆           ┆           ┆           ┆           │
# └─────────┴────────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘
# Highest: 0.9659267277849661
# shape: (5, 19)
# ┌─────────┬────────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ variant ┆ model      ┆ tuned_par ┆ clf_param ┆ … ┆ holdout_b ┆ holdout_p ┆ holdout_r ┆ holdout_f │
# │ ---     ┆ ---        ┆ ameters   ┆ eters     ┆   ┆ al_acc    ┆ recision  ┆ ecall     ┆ 1         │
# │ str     ┆ str        ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │         ┆            ┆ str       ┆ str       ┆   ┆ f64       ┆ f64       ┆ f64       ┆ f64       │
# ╞═════════╪════════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ raw     ┆ SVC-RBF    ┆ {"clf__C" ┆ {"C":     ┆ … ┆ 0.966     ┆ 0.966092  ┆ 0.966     ┆ 0.965927  │
# │         ┆            ┆ : 1.0,    ┆ 1.0, "bre ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ "clf__gam ┆ ak_ties": ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ ma": …    ┆ false…    ┆   ┆           ┆           ┆           ┆           │
# │ scaled  ┆ SVC-RBF    ┆ {"clf__C" ┆ {"C":     ┆ … ┆ 0.964     ┆ 0.964296  ┆ 0.964     ┆ 0.964021  │
# │         ┆            ┆ : 1.0,    ┆ 1.0, "bre ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ "clf__gam ┆ ak_ties": ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ ma": …    ┆ false…    ┆   ┆           ┆           ┆           ┆           │
# │ raw     ┆ LogisticRe ┆ {"clf__C" ┆ {"C":     ┆ … ┆ 0.954     ┆ 0.953874  ┆ 0.954     ┆ 0.953688  │
# │         ┆ gression   ┆ : 1.0}    ┆ 1.0, "cla ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ ss_weight ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ ": "ba…   ┆   ┆           ┆           ┆           ┆           │
# │ scaled  ┆ LogisticRe ┆ {"clf__C" ┆ {"C":     ┆ … ┆ 0.953     ┆ 0.952887  ┆ 0.953     ┆ 0.952796  │
# │         ┆ gression   ┆ : 1.0}    ┆ 1.0, "cla ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ ss_weight ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ ": "ba…   ┆   ┆           ┆           ┆           ┆           │
# │ scaled  ┆ KNN        ┆ {"clf__n_ ┆ {"algorit ┆ … ┆ 0.952     ┆ 0.952229  ┆ 0.952     ┆ 0.951749  │
# │         ┆            ┆ neighbors ┆ hm":      ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ ": 11}    ┆ "auto",   ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ "leaf_si… ┆   ┆           ┆           ┆           ┆           │
# └─────────┴────────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
# Assess MDA performance. 
X_train, y_train = make_input_data(file_paths="./outputsTrain/*/mda_dim_scores.csv")
X_test, y_test = make_input_data(file_paths="./outputsTest/*/mda_dim_scores.csv")

all_results = []
for variant in ("raw", "scaled"):
    df_res = evaluate_one(X_train, y_train, X_test, y_test, variant)
    all_results.append(df_res)

# Concatenate all results and save.
final_results = pd.concat(all_results, ignore_index=True)
final_results.to_csv(f"./{OUTPUT_DIR}/mdaResults.csv", index=False)

for metric in ['holdout_accuracy', 'holdout_bal_acc', 'holdout_precision', 'holdout_recall', 'holdout_f1']:
    print(f"Highest: {final_results.sort_values(by=metric, ascending=False)[metric].tolist()[0]}")
    print(pl.from_pandas(final_results.sort_values(by=metric, ascending=False).head()))
# Out:
# {'variant': 'raw', 'model': 'LogisticRegression', 'tuned_parameters': '{"clf__C": 1.0}', 'clf_parameters': '{"C": 1.0, "class_weight": "balanced", "dual": false, "fit_intercept": true, "intercept_scaling": 1, "l1_ratio": 0.0, "max_iter": 20000, "n_jobs": null, "penalty": "deprecated", "random_state": 1618, "solver": "lbfgs", "tol": 0.0001, "verbose": 0, "warm_start": false}', 'cv_accuracy_mean': 0.865, 'cv_balanced_accuracy_mean': 0.865, 'cv_precision_mean': 0.865936245937996, 'cv_recall_mean': 0.865, 'cv_f1_mean': 0.8628513686907274, 'cv_accuracy_std': 0.01843908891458579, 'cv_balanced_accuracy_std': 0.018439088914585792, 'cv_precision_std': 0.01710523855743119, 'cv_recall_std': 0.018439088914585792, 'cv_f1_std': 0.01848649153128783, 'holdout_accuracy': 0.858, 'holdout_bal_acc': 0.858, 'holdout_precision': 0.854931213338426, 'holdout_recall': 0.858, 'holdout_f1': 0.8548698059340524}
# {'variant': 'raw', 'model': 'RidgeClassifier', 'tuned_parameters': '{}', 'clf_parameters': '{"alpha": 1.0, "class_weight": "balanced", "copy_X": true, "fit_intercept": true, "max_iter": null, "positive": false, "random_state": 1618, "solver": "auto", "tol": 0.0001}', 'cv_accuracy_mean': 0.68, 'cv_balanced_accuracy_mean': 0.6799999999999999, 'cv_precision_mean': 0.7032491251323336, 'cv_recall_mean': 0.6799999999999999, 'cv_f1_mean': 0.6203788064781512, 'cv_accuracy_std': 0.015811388300841868, 'cv_balanced_accuracy_std': 0.015811388300841903, 'cv_precision_std': 0.051460581518143825, 'cv_recall_std': 0.015811388300841903, 'cv_f1_std': 0.015077166062435194, 'holdout_accuracy': 0.692, 'holdout_bal_acc': 0.692, 'holdout_precision': 0.7136689800133513, 'holdout_recall': 0.692, 'holdout_f1': 0.641090409562662}
# {'variant': 'raw', 'model': 'LinearSVC', 'tuned_parameters': '{"clf__C": 1.0}', 'clf_parameters': '{"C": 1.0, "class_weight": "balanced", "dual": "auto", "fit_intercept": true, "intercept_scaling": 1, "loss": "squared_hinge", "max_iter": 20000, "multi_class": "ovr", "penalty": "l2", "random_state": 1618, "tol": 0.0001, "verbose": 0}', 'cv_accuracy_mean': 0.835, 'cv_balanced_accuracy_mean': 0.835, 'cv_precision_mean': 0.8341053361207823, 'cv_recall_mean': 0.835, 'cv_f1_mean': 0.8297020270003383, 'cv_accuracy_std': 0.020248456731316606, 'cv_balanced_accuracy_std': 0.02024845673131661, 'cv_precision_std': 0.021052523248349667, 'cv_recall_std': 0.02024845673131661, 'cv_f1_std': 0.021283648765044988, 'holdout_accuracy': 0.837, 'holdout_bal_acc': 0.8370000000000001, 'holdout_precision': 0.8324151218667348, 'holdout_recall': 0.8370000000000001, 'holdout_f1': 0.8328442489302944}
# {'variant': 'raw', 'model': 'SVC-RBF', 'tuned_parameters': '{"clf__C": 1.0, "clf__gamma": "scale"}', 'clf_parameters': '{"C": 1.0, "break_ties": false, "cache_size": 200, "class_weight": "balanced", "coef0": 0.0, "decision_function_shape": "ovr", "degree": 3, "gamma": "scale", "kernel": "rbf", "max_iter": -1, "probability": false, "random_state": 1618, "shrinking": true, "tol": 0.001, "verbose": false}', 'cv_accuracy_mean': 0.8780000000000001, 'cv_balanced_accuracy_mean': 0.8779999999999999, 'cv_precision_mean': 0.8801588550543995, 'cv_recall_mean': 0.8779999999999999, 'cv_f1_mean': 0.8766390460103313, 'cv_accuracy_std': 0.017776388834631195, 'cv_balanced_accuracy_std': 0.01777638883463113, 'cv_precision_std': 0.014980555064498092, 'cv_recall_std': 0.01777638883463113, 'cv_f1_std': 0.017331519387777918, 'holdout_accuracy': 0.879, 'holdout_bal_acc': 0.8789999999999999, 'holdout_precision': 0.877240240507682, 'holdout_recall': 0.8789999999999999, 'holdout_f1': 0.8776641754954164}
# {'variant': 'raw', 'model': 'SGD-Hinge', 'tuned_parameters': '{}', 'clf_parameters': '{"alpha": 0.0001, "average": false, "class_weight": "balanced", "early_stopping": false, "epsilon": 0.1, "eta0": 0.01, "fit_intercept": true, "l1_ratio": 0.15, "learning_rate": "optimal", "loss": "hinge", "max_iter": 20000, "n_iter_no_change": 5, "n_jobs": null, "penalty": "l2", "power_t": 0.5, "random_state": 1618, "shuffle": true, "tol": 0.001, "validation_fraction": 0.1, "verbose": 0, "warm_start": false}', 'cv_accuracy_mean': 0.818, 'cv_balanced_accuracy_mean': 0.818, 'cv_precision_mean': 0.8260223568462767, 'cv_recall_mean': 0.818, 'cv_f1_mean': 0.8115198927391475, 'cv_accuracy_std': 0.029086079144497956, 'cv_balanced_accuracy_std': 0.029086079144497946, 'cv_precision_std': 0.022204578360290342, 'cv_recall_std': 0.029086079144497946, 'cv_f1_std': 0.03442162190328222, 'holdout_accuracy': 0.823, 'holdout_bal_acc': 0.8230000000000001, 'holdout_precision': 0.8387901678977425, 'holdout_recall': 0.8230000000000001, 'holdout_f1': 0.8207258254662835}
# {'variant': 'raw', 'model': 'KNN', 'tuned_parameters': '{"clf__n_neighbors": 11}', 'clf_parameters': '{"algorithm": "auto", "leaf_size": 30, "metric": "minkowski", "metric_params": null, "n_jobs": null, "n_neighbors": 11, "p": 2, "weights": "uniform"}', 'cv_accuracy_mean': 0.867, 'cv_balanced_accuracy_mean': 0.867, 'cv_precision_mean': 0.8681430101658261, 'cv_recall_mean': 0.867, 'cv_f1_mean': 0.8647839405289728, 'cv_accuracy_std': 0.014696938456699083, 'cv_balanced_accuracy_std': 0.014696938456699062, 'cv_precision_std': 0.012907929123901705, 'cv_recall_std': 0.014696938456699062, 'cv_f1_std': 0.01466694438053284, 'holdout_accuracy': 0.853, 'holdout_bal_acc': 0.853, 'holdout_precision': 0.8490655995236394, 'holdout_recall': 0.853, 'holdout_f1': 0.8486348087840868}
# {'variant': 'raw', 'model': 'DecisionTree', 'tuned_parameters': '{}', 'clf_parameters': '{"ccp_alpha": 0.0, "class_weight": "balanced", "criterion": "gini", "max_depth": null, "max_features": null, "max_leaf_nodes": null, "min_impurity_decrease": 0.0, "min_samples_leaf": 1, "min_samples_split": 2, "min_weight_fraction_leaf": 0.0, "monotonic_cst": null, "random_state": 1618, "splitter": "best"}', 'cv_accuracy_mean': 0.792, 'cv_balanced_accuracy_mean': 0.792, 'cv_precision_mean': 0.7969062462152732, 'cv_recall_mean': 0.792, 'cv_f1_mean': 0.7897530256192985, 'cv_accuracy_std': 0.019646882704388493, 'cv_balanced_accuracy_std': 0.019646882704388458, 'cv_precision_std': 0.02125915305898754, 'cv_recall_std': 0.019646882704388458, 'cv_f1_std': 0.019015076382105357, 'holdout_accuracy': 0.789, 'holdout_bal_acc': 0.7890000000000001, 'holdout_precision': 0.7866551521114629, 'holdout_recall': 0.7890000000000001, 'holdout_f1': 0.7868087416084224}
# {'variant': 'raw', 'model': 'RandomForest', 'tuned_parameters': '{"clf__max_depth": null, "clf__n_estimators": 600}', 'clf_parameters': '{"bootstrap": true, "ccp_alpha": 0.0, "class_weight": "balanced", "criterion": "gini", "max_depth": null, "max_features": "sqrt", "max_leaf_nodes": null, "max_samples": null, "min_impurity_decrease": 0.0, "min_samples_leaf": 1, "min_samples_split": 2, "min_weight_fraction_leaf": 0.0, "monotonic_cst": null, "n_estimators": 600, "n_jobs": null, "oob_score": false, "random_state": 1618, "verbose": 0, "warm_start": false}', 'cv_accuracy_mean': 0.882, 'cv_balanced_accuracy_mean': 0.8819999999999999, 'cv_precision_mean': 0.8850241646487105, 'cv_recall_mean': 0.8819999999999999, 'cv_f1_mean': 0.8804035106892275, 'cv_accuracy_std': 0.016309506430300106, 'cv_balanced_accuracy_std': 0.016309506430300037, 'cv_precision_std': 0.015617748035829417, 'cv_recall_std': 0.016309506430300037, 'cv_f1_std': 0.016196338695937326, 'holdout_accuracy': 0.869, 'holdout_bal_acc': 0.869, 'holdout_precision': 0.8674739056707212, 'holdout_recall': 0.869, 'holdout_f1': 0.8679016765059355}
# {'variant': 'raw', 'model': 'ExtraTrees', 'tuned_parameters': '{"clf__max_depth": 10, "clf__n_estimators": 600}', 'clf_parameters': '{"bootstrap": false, "ccp_alpha": 0.0, "class_weight": "balanced", "criterion": "gini", "max_depth": 10, "max_features": "sqrt", "max_leaf_nodes": null, "max_samples": null, "min_impurity_decrease": 0.0, "min_samples_leaf": 1, "min_samples_split": 2, "min_weight_fraction_leaf": 0.0, "monotonic_cst": null, "n_estimators": 600, "n_jobs": null, "oob_score": false, "random_state": 1618, "verbose": 0, "warm_start": false}', 'cv_accuracy_mean': 0.8870000000000001, 'cv_balanced_accuracy_mean': 0.8870000000000001, 'cv_precision_mean': 0.8877164803720532, 'cv_recall_mean': 0.8870000000000001, 'cv_f1_mean': 0.8850268172578828, 'cv_accuracy_std': 0.02227105745132011, 'cv_balanced_accuracy_std': 0.022271057451320048, 'cv_precision_std': 0.02266918799741052, 'cv_recall_std': 0.022271057451320048, 'cv_f1_std': 0.02317086979439385, 'holdout_accuracy': 0.873, 'holdout_bal_acc': 0.8729999999999999, 'holdout_precision': 0.8697293744657303, 'holdout_recall': 0.8729999999999999, 'holdout_f1': 0.8700888812704756}
# {'variant': 'raw', 'model': 'GradientBoosting', 'tuned_parameters': '{}', 'clf_parameters': '{"ccp_alpha": 0.0, "criterion": "friedman_mse", "init": null, "learning_rate": 0.1, "loss": "log_loss", "max_depth": 3, "max_features": null, "max_leaf_nodes": null, "min_impurity_decrease": 0.0, "min_samples_leaf": 1, "min_samples_split": 2, "min_weight_fraction_leaf": 0.0, "n_estimators": 100, "n_iter_no_change": null, "random_state": 1618, "subsample": 1.0, "tol": 0.0001, "validation_fraction": 0.1, "verbose": 0, "warm_start": false}', 'cv_accuracy_mean': 0.8630000000000001, 'cv_balanced_accuracy_mean': 0.8629999999999999, 'cv_precision_mean': 0.8709018951218237, 'cv_recall_mean': 0.8629999999999999, 'cv_f1_mean': 0.8631850967524416, 'cv_accuracy_std': 0.02063976744055031, 'cv_balanced_accuracy_std': 0.020639767440550304, 'cv_precision_std': 0.015364289972162846, 'cv_recall_std': 0.020639767440550304, 'cv_f1_std': 0.020256563336947194, 'holdout_accuracy': 0.861, 'holdout_bal_acc': 0.861, 'holdout_precision': 0.8630670711566607, 'holdout_recall': 0.861, 'holdout_f1': 0.8617843650285237}
# {'variant': 'raw', 'model': 'HistGB', 'tuned_parameters': '{"clf__max_depth": 6}', 'clf_parameters': '{"categorical_features": "from_dtype", "class_weight": null, "early_stopping": "auto", "interaction_cst": null, "l2_regularization": 0.0, "learning_rate": 0.1, "loss": "log_loss", "max_bins": 255, "max_depth": 6, "max_features": 1.0, "max_iter": 100, "max_leaf_nodes": 31, "min_samples_leaf": 20, "monotonic_cst": null, "n_iter_no_change": 10, "random_state": 1618, "scoring": "loss", "tol": 1e-07, "validation_fraction": 0.1, "verbose": 0, "warm_start": false}', 'cv_accuracy_mean': 0.8619999999999999, 'cv_balanced_accuracy_mean': 0.8619999999999999, 'cv_precision_mean': 0.8664173477009323, 'cv_recall_mean': 0.8619999999999999, 'cv_f1_mean': 0.8616980422978857, 'cv_accuracy_std': 0.013266499161421611, 'cv_balanced_accuracy_std': 0.013266499161421624, 'cv_precision_std': 0.011870317108967864, 'cv_recall_std': 0.013266499161421624, 'cv_f1_std': 0.012750115464931058, 'holdout_accuracy': 0.86, 'holdout_bal_acc': 0.86, 'holdout_precision': 0.8621050005571561, 'holdout_recall': 0.86, 'holdout_f1': 0.8608856949266623}
# {'variant': 'raw', 'model': 'AdaBoost', 'tuned_parameters': '{}', 'clf_parameters': '{"estimator": null, "learning_rate": 1.0, "n_estimators": 50, "random_state": 1618}', 'cv_accuracy_mean': 0.319, 'cv_balanced_accuracy_mean': 0.31900000000000006, 'cv_precision_mean': 0.1964311490103417, 'cv_recall_mean': 0.31900000000000006, 'cv_f1_mean': 0.2140251556982621, 'cv_accuracy_std': 0.08290958931269651, 'cv_balanced_accuracy_std': 0.08290958931269651, 'cv_precision_std': 0.1000754590347687, 'cv_recall_std': 0.08290958931269651, 'cv_f1_std': 0.09875649854250362, 'holdout_accuracy': 0.313, 'holdout_bal_acc': 0.313, 'holdout_precision': 0.19588993145362393, 'holdout_recall': 0.313, 'holdout_f1': 0.20396888306583688}
# {'variant': 'raw', 'model': 'GaussianNaiveBayes', 'tuned_parameters': '{}', 'clf_parameters': '{"priors": null, "var_smoothing": 1e-09}', 'cv_accuracy_mean': 0.8789999999999999, 'cv_balanced_accuracy_mean': 0.8790000000000001, 'cv_precision_mean': 0.8814818160407067, 'cv_recall_mean': 0.8790000000000001, 'cv_f1_mean': 0.8783987010795927, 'cv_accuracy_std': 0.02177154105707726, 'cv_balanced_accuracy_std': 0.02177154105707721, 'cv_precision_std': 0.02334029208108819, 'cv_recall_std': 0.02177154105707721, 'cv_f1_std': 0.02248444671310901, 'holdout_accuracy': 0.859, 'holdout_bal_acc': 0.859, 'holdout_precision': 0.8606094903417967, 'holdout_recall': 0.859, 'holdout_f1': 0.8582760334594468}
# {'variant': 'scaled', 'model': 'LogisticRegression', 'tuned_parameters': '{"clf__C": 1.0}', 'clf_parameters': '{"C": 1.0, "class_weight": "balanced", "dual": false, "fit_intercept": true, "intercept_scaling": 1, "l1_ratio": 0.0, "max_iter": 20000, "n_jobs": null, "penalty": "deprecated", "random_state": 1618, "solver": "lbfgs", "tol": 0.0001, "verbose": 0, "warm_start": false}', 'cv_accuracy_mean': 0.866, 'cv_balanced_accuracy_mean': 0.866, 'cv_precision_mean': 0.8682819069878835, 'cv_recall_mean': 0.866, 'cv_f1_mean': 0.8642931029607027, 'cv_accuracy_std': 0.01319090595827293, 'cv_balanced_accuracy_std': 0.013190905958272953, 'cv_precision_std': 0.01300537776905156, 'cv_recall_std': 0.013190905958272953, 'cv_f1_std': 0.01329771578115925, 'holdout_accuracy': 0.855, 'holdout_bal_acc': 0.8550000000000001, 'holdout_precision': 0.8531677352534317, 'holdout_recall': 0.8550000000000001, 'holdout_f1': 0.8525792271779448}
# {'variant': 'scaled', 'model': 'RidgeClassifier', 'tuned_parameters': '{}', 'clf_parameters': '{"alpha": 1.0, "class_weight": "balanced", "copy_X": true, "fit_intercept": true, "max_iter": null, "positive": false, "random_state": 1618, "solver": "auto", "tol": 0.0001}', 'cv_accuracy_mean': 0.681, 'cv_balanced_accuracy_mean': 0.6809999999999998, 'cv_precision_mean': 0.7047390241222325, 'cv_recall_mean': 0.6809999999999998, 'cv_f1_mean': 0.6218513482499775, 'cv_accuracy_std': 0.015297058540778327, 'cv_balanced_accuracy_std': 0.015297058540778365, 'cv_precision_std': 0.05176529375271322, 'cv_recall_std': 0.015297058540778365, 'cv_f1_std': 0.014774120471817665, 'holdout_accuracy': 0.691, 'holdout_bal_acc': 0.6910000000000001, 'holdout_precision': 0.7128737599010033, 'holdout_recall': 0.6910000000000001, 'holdout_f1': 0.6400230051292898}
# {'variant': 'scaled', 'model': 'LinearSVC', 'tuned_parameters': '{"clf__C": 1.0}', 'clf_parameters': '{"C": 1.0, "class_weight": "balanced", "dual": "auto", "fit_intercept": true, "intercept_scaling": 1, "loss": "squared_hinge", "max_iter": 20000, "multi_class": "ovr", "penalty": "l2", "random_state": 1618, "tol": 0.0001, "verbose": 0}', 'cv_accuracy_mean': 0.836, 'cv_balanced_accuracy_mean': 0.836, 'cv_precision_mean': 0.8349526888958845, 'cv_recall_mean': 0.836, 'cv_f1_mean': 0.8307970363823584, 'cv_accuracy_std': 0.019849433241279225, 'cv_balanced_accuracy_std': 0.01984943324127924, 'cv_precision_std': 0.02060217372587812, 'cv_recall_std': 0.01984943324127924, 'cv_f1_std': 0.020786456931430573, 'holdout_accuracy': 0.836, 'holdout_bal_acc': 0.836, 'holdout_precision': 0.8312954409298143, 'holdout_recall': 0.836, 'holdout_f1': 0.8319157919056168}
# {'variant': 'scaled', 'model': 'SVC-RBF', 'tuned_parameters': '{"clf__C": 0.5, "clf__gamma": "scale"}', 'clf_parameters': '{"C": 0.5, "break_ties": false, "cache_size": 200, "class_weight": "balanced", "coef0": 0.0, "decision_function_shape": "ovr", "degree": 3, "gamma": "scale", "kernel": "rbf", "max_iter": -1, "probability": false, "random_state": 1618, "shrinking": true, "tol": 0.001, "verbose": false}', 'cv_accuracy_mean': 0.867, 'cv_balanced_accuracy_mean': 0.8670000000000002, 'cv_precision_mean': 0.8676614274584391, 'cv_recall_mean': 0.8670000000000002, 'cv_f1_mean': 0.8652436719643337, 'cv_accuracy_std': 0.024207436873820428, 'cv_balanced_accuracy_std': 0.024207436873820404, 'cv_precision_std': 0.022093954678693083, 'cv_recall_std': 0.024207436873820404, 'cv_f1_std': 0.023800933458707603, 'holdout_accuracy': 0.868, 'holdout_bal_acc': 0.868, 'holdout_precision': 0.8645346900176584, 'holdout_recall': 0.868, 'holdout_f1': 0.8656326079328656}
# {'variant': 'scaled', 'model': 'SGD-Hinge', 'tuned_parameters': '{}', 'clf_parameters': '{"alpha": 0.0001, "average": false, "class_weight": "balanced", "early_stopping": false, "epsilon": 0.1, "eta0": 0.01, "fit_intercept": true, "l1_ratio": 0.15, "learning_rate": "optimal", "loss": "hinge", "max_iter": 20000, "n_iter_no_change": 5, "n_jobs": null, "penalty": "l2", "power_t": 0.5, "random_state": 1618, "shuffle": true, "tol": 0.001, "validation_fraction": 0.1, "verbose": 0, "warm_start": false}', 'cv_accuracy_mean': 0.7969999999999999, 'cv_balanced_accuracy_mean': 0.7969999999999999, 'cv_precision_mean': 0.8148343823008435, 'cv_recall_mean': 0.7969999999999999, 'cv_f1_mean': 0.7889678980391378, 'cv_accuracy_std': 0.03655133376499413, 'cv_balanced_accuracy_std': 0.036551333764994115, 'cv_precision_std': 0.026497265927782464, 'cv_recall_std': 0.036551333764994115, 'cv_f1_std': 0.041632532808001166, 'holdout_accuracy': 0.808, 'holdout_bal_acc': 0.808, 'holdout_precision': 0.8435122380962795, 'holdout_recall': 0.808, 'holdout_f1': 0.8096661812413382}
# {'variant': 'scaled', 'model': 'KNN', 'tuned_parameters': '{"clf__n_neighbors": 11}', 'clf_parameters': '{"algorithm": "auto", "leaf_size": 30, "metric": "minkowski", "metric_params": null, "n_jobs": null, "n_neighbors": 11, "p": 2, "weights": "uniform"}', 'cv_accuracy_mean': 0.836, 'cv_balanced_accuracy_mean': 0.8360000000000001, 'cv_precision_mean': 0.8365882899200978, 'cv_recall_mean': 0.8360000000000001, 'cv_f1_mean': 0.832376728786272, 'cv_accuracy_std': 0.01496662954709574, 'cv_balanced_accuracy_std': 0.01496662954709574, 'cv_precision_std': 0.013896596608635424, 'cv_recall_std': 0.01496662954709574, 'cv_f1_std': 0.014148377699073443, 'holdout_accuracy': 0.845, 'holdout_bal_acc': 0.845, 'holdout_precision': 0.8405957452774239, 'holdout_recall': 0.845, 'holdout_f1': 0.8404582931028001}
# {'variant': 'scaled', 'model': 'DecisionTree', 'tuned_parameters': '{}', 'clf_parameters': '{"ccp_alpha": 0.0, "class_weight": "balanced", "criterion": "gini", "max_depth": null, "max_features": null, "max_leaf_nodes": null, "min_impurity_decrease": 0.0, "min_samples_leaf": 1, "min_samples_split": 2, "min_weight_fraction_leaf": 0.0, "monotonic_cst": null, "random_state": 1618, "splitter": "best"}', 'cv_accuracy_mean': 0.792, 'cv_balanced_accuracy_mean': 0.792, 'cv_precision_mean': 0.7969062462152732, 'cv_recall_mean': 0.792, 'cv_f1_mean': 0.7897530256192985, 'cv_accuracy_std': 0.019646882704388493, 'cv_balanced_accuracy_std': 0.019646882704388458, 'cv_precision_std': 0.02125915305898754, 'cv_recall_std': 0.019646882704388458, 'cv_f1_std': 0.019015076382105357, 'holdout_accuracy': 0.789, 'holdout_bal_acc': 0.7890000000000001, 'holdout_precision': 0.7866551521114629, 'holdout_recall': 0.7890000000000001, 'holdout_f1': 0.7868087416084224}
# {'variant': 'scaled', 'model': 'RandomForest', 'tuned_parameters': '{"clf__max_depth": null, "clf__n_estimators": 600}', 'clf_parameters': '{"bootstrap": true, "ccp_alpha": 0.0, "class_weight": "balanced", "criterion": "gini", "max_depth": null, "max_features": "sqrt", "max_leaf_nodes": null, "max_samples": null, "min_impurity_decrease": 0.0, "min_samples_leaf": 1, "min_samples_split": 2, "min_weight_fraction_leaf": 0.0, "monotonic_cst": null, "n_estimators": 600, "n_jobs": null, "oob_score": false, "random_state": 1618, "verbose": 0, "warm_start": false}', 'cv_accuracy_mean': 0.882, 'cv_balanced_accuracy_mean': 0.8819999999999999, 'cv_precision_mean': 0.8850241646487105, 'cv_recall_mean': 0.8819999999999999, 'cv_f1_mean': 0.8804035106892275, 'cv_accuracy_std': 0.016309506430300106, 'cv_balanced_accuracy_std': 0.016309506430300037, 'cv_precision_std': 0.015617748035829417, 'cv_recall_std': 0.016309506430300037, 'cv_f1_std': 0.016196338695937326, 'holdout_accuracy': 0.869, 'holdout_bal_acc': 0.869, 'holdout_precision': 0.8674739056707212, 'holdout_recall': 0.869, 'holdout_f1': 0.8679016765059355}
# {'variant': 'scaled', 'model': 'ExtraTrees', 'tuned_parameters': '{"clf__max_depth": 10, "clf__n_estimators": 600}', 'clf_parameters': '{"bootstrap": false, "ccp_alpha": 0.0, "class_weight": "balanced", "criterion": "gini", "max_depth": 10, "max_features": "sqrt", "max_leaf_nodes": null, "max_samples": null, "min_impurity_decrease": 0.0, "min_samples_leaf": 1, "min_samples_split": 2, "min_weight_fraction_leaf": 0.0, "monotonic_cst": null, "n_estimators": 600, "n_jobs": null, "oob_score": false, "random_state": 1618, "verbose": 0, "warm_start": false}', 'cv_accuracy_mean': 0.8870000000000001, 'cv_balanced_accuracy_mean': 0.8870000000000001, 'cv_precision_mean': 0.8877164803720532, 'cv_recall_mean': 0.8870000000000001, 'cv_f1_mean': 0.8850268172578828, 'cv_accuracy_std': 0.02227105745132011, 'cv_balanced_accuracy_std': 0.022271057451320048, 'cv_precision_std': 0.02266918799741052, 'cv_recall_std': 0.022271057451320048, 'cv_f1_std': 0.02317086979439385, 'holdout_accuracy': 0.873, 'holdout_bal_acc': 0.8729999999999999, 'holdout_precision': 0.8697293744657303, 'holdout_recall': 0.8729999999999999, 'holdout_f1': 0.8700888812704756}
# {'variant': 'scaled', 'model': 'GradientBoosting', 'tuned_parameters': '{}', 'clf_parameters': '{"ccp_alpha": 0.0, "criterion": "friedman_mse", "init": null, "learning_rate": 0.1, "loss": "log_loss", "max_depth": 3, "max_features": null, "max_leaf_nodes": null, "min_impurity_decrease": 0.0, "min_samples_leaf": 1, "min_samples_split": 2, "min_weight_fraction_leaf": 0.0, "n_estimators": 100, "n_iter_no_change": null, "random_state": 1618, "subsample": 1.0, "tol": 0.0001, "validation_fraction": 0.1, "verbose": 0, "warm_start": false}', 'cv_accuracy_mean': 0.8630000000000001, 'cv_balanced_accuracy_mean': 0.8629999999999999, 'cv_precision_mean': 0.8709018951218237, 'cv_recall_mean': 0.8629999999999999, 'cv_f1_mean': 0.8631850967524416, 'cv_accuracy_std': 0.02063976744055031, 'cv_balanced_accuracy_std': 0.020639767440550304, 'cv_precision_std': 0.015364289972162846, 'cv_recall_std': 0.020639767440550304, 'cv_f1_std': 0.020256563336947194, 'holdout_accuracy': 0.861, 'holdout_bal_acc': 0.861, 'holdout_precision': 0.8630670711566607, 'holdout_recall': 0.861, 'holdout_f1': 0.8617843650285237}
# {'variant': 'scaled', 'model': 'HistGB', 'tuned_parameters': '{"clf__max_depth": 6}', 'clf_parameters': '{"categorical_features": "from_dtype", "class_weight": null, "early_stopping": "auto", "interaction_cst": null, "l2_regularization": 0.0, "learning_rate": 0.1, "loss": "log_loss", "max_bins": 255, "max_depth": 6, "max_features": 1.0, "max_iter": 100, "max_leaf_nodes": 31, "min_samples_leaf": 20, "monotonic_cst": null, "n_iter_no_change": 10, "random_state": 1618, "scoring": "loss", "tol": 1e-07, "validation_fraction": 0.1, "verbose": 0, "warm_start": false}', 'cv_accuracy_mean': 0.8619999999999999, 'cv_balanced_accuracy_mean': 0.8619999999999999, 'cv_precision_mean': 0.8664173477009323, 'cv_recall_mean': 0.8619999999999999, 'cv_f1_mean': 0.8616980422978857, 'cv_accuracy_std': 0.013266499161421611, 'cv_balanced_accuracy_std': 0.013266499161421624, 'cv_precision_std': 0.011870317108967864, 'cv_recall_std': 0.013266499161421624, 'cv_f1_std': 0.012750115464931058, 'holdout_accuracy': 0.86, 'holdout_bal_acc': 0.86, 'holdout_precision': 0.8621050005571561, 'holdout_recall': 0.86, 'holdout_f1': 0.8608856949266623}
# {'variant': 'scaled', 'model': 'AdaBoost', 'tuned_parameters': '{}', 'clf_parameters': '{"estimator": null, "learning_rate": 1.0, "n_estimators": 50, "random_state": 1618}', 'cv_accuracy_mean': 0.319, 'cv_balanced_accuracy_mean': 0.31900000000000006, 'cv_precision_mean': 0.1964311490103417, 'cv_recall_mean': 0.31900000000000006, 'cv_f1_mean': 0.2140251556982621, 'cv_accuracy_std': 0.08290958931269651, 'cv_balanced_accuracy_std': 0.08290958931269651, 'cv_precision_std': 0.1000754590347687, 'cv_recall_std': 0.08290958931269651, 'cv_f1_std': 0.09875649854250362, 'holdout_accuracy': 0.313, 'holdout_bal_acc': 0.313, 'holdout_precision': 0.19588993145362393, 'holdout_recall': 0.313, 'holdout_f1': 0.20396888306583688}
# {'variant': 'scaled', 'model': 'GaussianNaiveBayes', 'tuned_parameters': '{}', 'clf_parameters': '{"priors": null, "var_smoothing": 1e-09}', 'cv_accuracy_mean': 0.8789999999999999, 'cv_balanced_accuracy_mean': 0.8790000000000001, 'cv_precision_mean': 0.8814818160407067, 'cv_recall_mean': 0.8790000000000001, 'cv_f1_mean': 0.8783987010795927, 'cv_accuracy_std': 0.02177154105707726, 'cv_balanced_accuracy_std': 0.02177154105707721, 'cv_precision_std': 0.02334029208108819, 'cv_recall_std': 0.02177154105707721, 'cv_f1_std': 0.02248444671310901, 'holdout_accuracy': 0.859, 'holdout_bal_acc': 0.859, 'holdout_precision': 0.8606094903417967, 'holdout_recall': 0.859, 'holdout_f1': 0.8582760334594468}
# Highest: 0.879
# shape: (5, 19)
# ┌─────────┬────────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ variant ┆ model      ┆ tuned_par ┆ clf_param ┆ … ┆ holdout_b ┆ holdout_p ┆ holdout_r ┆ holdout_f │
# │ ---     ┆ ---        ┆ ameters   ┆ eters     ┆   ┆ al_acc    ┆ recision  ┆ ecall     ┆ 1         │
# │ str     ┆ str        ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │         ┆            ┆ str       ┆ str       ┆   ┆ f64       ┆ f64       ┆ f64       ┆ f64       │
# ╞═════════╪════════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ raw     ┆ SVC-RBF    ┆ {"clf__C" ┆ {"C":     ┆ … ┆ 0.879     ┆ 0.87724   ┆ 0.879     ┆ 0.877664  │
# │         ┆            ┆ : 1.0,    ┆ 1.0, "bre ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ "clf__gam ┆ ak_ties": ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ ma": …    ┆ false…    ┆   ┆           ┆           ┆           ┆           │
# │ raw     ┆ ExtraTrees ┆ {"clf__ma ┆ {"bootstr ┆ … ┆ 0.873     ┆ 0.869729  ┆ 0.873     ┆ 0.870089  │
# │         ┆            ┆ x_depth": ┆ ap":      ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ 10,       ┆ false,    ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ "clf__n…  ┆ "ccp_alph ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ …         ┆   ┆           ┆           ┆           ┆           │
# │ scaled  ┆ ExtraTrees ┆ {"clf__ma ┆ {"bootstr ┆ … ┆ 0.873     ┆ 0.869729  ┆ 0.873     ┆ 0.870089  │
# │         ┆            ┆ x_depth": ┆ ap":      ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ 10,       ┆ false,    ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ "clf__n…  ┆ "ccp_alph ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ …         ┆   ┆           ┆           ┆           ┆           │
# │ raw     ┆ RandomFore ┆ {"clf__ma ┆ {"bootstr ┆ … ┆ 0.869     ┆ 0.867474  ┆ 0.869     ┆ 0.867902  │
# │         ┆ st         ┆ x_depth": ┆ ap":      ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ null,     ┆ true, "cc ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ "clf_…    ┆ p_alpha…  ┆   ┆           ┆           ┆           ┆           │
# │ scaled  ┆ RandomFore ┆ {"clf__ma ┆ {"bootstr ┆ … ┆ 0.869     ┆ 0.867474  ┆ 0.869     ┆ 0.867902  │
# │         ┆ st         ┆ x_depth": ┆ ap":      ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ null,     ┆ true, "cc ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ "clf_…    ┆ p_alpha…  ┆   ┆           ┆           ┆           ┆           │
# └─────────┴────────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘
# Highest: 0.8789999999999999
# shape: (5, 19)
# ┌─────────┬────────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ variant ┆ model      ┆ tuned_par ┆ clf_param ┆ … ┆ holdout_b ┆ holdout_p ┆ holdout_r ┆ holdout_f │
# │ ---     ┆ ---        ┆ ameters   ┆ eters     ┆   ┆ al_acc    ┆ recision  ┆ ecall     ┆ 1         │
# │ str     ┆ str        ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │         ┆            ┆ str       ┆ str       ┆   ┆ f64       ┆ f64       ┆ f64       ┆ f64       │
# ╞═════════╪════════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ raw     ┆ SVC-RBF    ┆ {"clf__C" ┆ {"C":     ┆ … ┆ 0.879     ┆ 0.87724   ┆ 0.879     ┆ 0.877664  │
# │         ┆            ┆ : 1.0,    ┆ 1.0, "bre ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ "clf__gam ┆ ak_ties": ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ ma": …    ┆ false…    ┆   ┆           ┆           ┆           ┆           │
# │ raw     ┆ ExtraTrees ┆ {"clf__ma ┆ {"bootstr ┆ … ┆ 0.873     ┆ 0.869729  ┆ 0.873     ┆ 0.870089  │
# │         ┆            ┆ x_depth": ┆ ap":      ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ 10,       ┆ false,    ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ "clf__n…  ┆ "ccp_alph ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ …         ┆   ┆           ┆           ┆           ┆           │
# │ scaled  ┆ ExtraTrees ┆ {"clf__ma ┆ {"bootstr ┆ … ┆ 0.873     ┆ 0.869729  ┆ 0.873     ┆ 0.870089  │
# │         ┆            ┆ x_depth": ┆ ap":      ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ 10,       ┆ false,    ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ "clf__n…  ┆ "ccp_alph ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ …         ┆   ┆           ┆           ┆           ┆           │
# │ raw     ┆ RandomFore ┆ {"clf__ma ┆ {"bootstr ┆ … ┆ 0.869     ┆ 0.867474  ┆ 0.869     ┆ 0.867902  │
# │         ┆ st         ┆ x_depth": ┆ ap":      ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ null,     ┆ true, "cc ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ "clf_…    ┆ p_alpha…  ┆   ┆           ┆           ┆           ┆           │
# │ scaled  ┆ RandomFore ┆ {"clf__ma ┆ {"bootstr ┆ … ┆ 0.869     ┆ 0.867474  ┆ 0.869     ┆ 0.867902  │
# │         ┆ st         ┆ x_depth": ┆ ap":      ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ null,     ┆ true, "cc ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ "clf_…    ┆ p_alpha…  ┆   ┆           ┆           ┆           ┆           │
# └─────────┴────────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘
# Highest: 0.877240240507682
# shape: (5, 19)
# ┌─────────┬────────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ variant ┆ model      ┆ tuned_par ┆ clf_param ┆ … ┆ holdout_b ┆ holdout_p ┆ holdout_r ┆ holdout_f │
# │ ---     ┆ ---        ┆ ameters   ┆ eters     ┆   ┆ al_acc    ┆ recision  ┆ ecall     ┆ 1         │
# │ str     ┆ str        ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │         ┆            ┆ str       ┆ str       ┆   ┆ f64       ┆ f64       ┆ f64       ┆ f64       │
# ╞═════════╪════════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ raw     ┆ SVC-RBF    ┆ {"clf__C" ┆ {"C":     ┆ … ┆ 0.879     ┆ 0.87724   ┆ 0.879     ┆ 0.877664  │
# │         ┆            ┆ : 1.0,    ┆ 1.0, "bre ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ "clf__gam ┆ ak_ties": ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ ma": …    ┆ false…    ┆   ┆           ┆           ┆           ┆           │
# │ raw     ┆ ExtraTrees ┆ {"clf__ma ┆ {"bootstr ┆ … ┆ 0.873     ┆ 0.869729  ┆ 0.873     ┆ 0.870089  │
# │         ┆            ┆ x_depth": ┆ ap":      ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ 10,       ┆ false,    ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ "clf__n…  ┆ "ccp_alph ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ …         ┆   ┆           ┆           ┆           ┆           │
# │ scaled  ┆ ExtraTrees ┆ {"clf__ma ┆ {"bootstr ┆ … ┆ 0.873     ┆ 0.869729  ┆ 0.873     ┆ 0.870089  │
# │         ┆            ┆ x_depth": ┆ ap":      ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ 10,       ┆ false,    ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ "clf__n…  ┆ "ccp_alph ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ …         ┆   ┆           ┆           ┆           ┆           │
# │ raw     ┆ RandomFore ┆ {"clf__ma ┆ {"bootstr ┆ … ┆ 0.869     ┆ 0.867474  ┆ 0.869     ┆ 0.867902  │
# │         ┆ st         ┆ x_depth": ┆ ap":      ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ null,     ┆ true, "cc ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ "clf_…    ┆ p_alpha…  ┆   ┆           ┆           ┆           ┆           │
# │ scaled  ┆ RandomFore ┆ {"clf__ma ┆ {"bootstr ┆ … ┆ 0.869     ┆ 0.867474  ┆ 0.869     ┆ 0.867902  │
# │         ┆ st         ┆ x_depth": ┆ ap":      ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ null,     ┆ true, "cc ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ "clf_…    ┆ p_alpha…  ┆   ┆           ┆           ┆           ┆           │
# └─────────┴────────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘
# Highest: 0.8789999999999999
# shape: (5, 19)
# ┌─────────┬────────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ variant ┆ model      ┆ tuned_par ┆ clf_param ┆ … ┆ holdout_b ┆ holdout_p ┆ holdout_r ┆ holdout_f │
# │ ---     ┆ ---        ┆ ameters   ┆ eters     ┆   ┆ al_acc    ┆ recision  ┆ ecall     ┆ 1         │
# │ str     ┆ str        ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │         ┆            ┆ str       ┆ str       ┆   ┆ f64       ┆ f64       ┆ f64       ┆ f64       │
# ╞═════════╪════════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ raw     ┆ SVC-RBF    ┆ {"clf__C" ┆ {"C":     ┆ … ┆ 0.879     ┆ 0.87724   ┆ 0.879     ┆ 0.877664  │
# │         ┆            ┆ : 1.0,    ┆ 1.0, "bre ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ "clf__gam ┆ ak_ties": ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ ma": …    ┆ false…    ┆   ┆           ┆           ┆           ┆           │
# │ raw     ┆ ExtraTrees ┆ {"clf__ma ┆ {"bootstr ┆ … ┆ 0.873     ┆ 0.869729  ┆ 0.873     ┆ 0.870089  │
# │         ┆            ┆ x_depth": ┆ ap":      ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ 10,       ┆ false,    ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ "clf__n…  ┆ "ccp_alph ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ …         ┆   ┆           ┆           ┆           ┆           │
# │ scaled  ┆ ExtraTrees ┆ {"clf__ma ┆ {"bootstr ┆ … ┆ 0.873     ┆ 0.869729  ┆ 0.873     ┆ 0.870089  │
# │         ┆            ┆ x_depth": ┆ ap":      ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ 10,       ┆ false,    ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ "clf__n…  ┆ "ccp_alph ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ …         ┆   ┆           ┆           ┆           ┆           │
# │ raw     ┆ RandomFore ┆ {"clf__ma ┆ {"bootstr ┆ … ┆ 0.869     ┆ 0.867474  ┆ 0.869     ┆ 0.867902  │
# │         ┆ st         ┆ x_depth": ┆ ap":      ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ null,     ┆ true, "cc ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ "clf_…    ┆ p_alpha…  ┆   ┆           ┆           ┆           ┆           │
# │ scaled  ┆ RandomFore ┆ {"clf__ma ┆ {"bootstr ┆ … ┆ 0.869     ┆ 0.867474  ┆ 0.869     ┆ 0.867902  │
# │         ┆ st         ┆ x_depth": ┆ ap":      ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ null,     ┆ true, "cc ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ "clf_…    ┆ p_alpha…  ┆   ┆           ┆           ┆           ┆           │
# └─────────┴────────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘
# Highest: 0.8776641754954164
# shape: (5, 19)
# ┌─────────┬────────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ variant ┆ model      ┆ tuned_par ┆ clf_param ┆ … ┆ holdout_b ┆ holdout_p ┆ holdout_r ┆ holdout_f │
# │ ---     ┆ ---        ┆ ameters   ┆ eters     ┆   ┆ al_acc    ┆ recision  ┆ ecall     ┆ 1         │
# │ str     ┆ str        ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │         ┆            ┆ str       ┆ str       ┆   ┆ f64       ┆ f64       ┆ f64       ┆ f64       │
# ╞═════════╪════════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ raw     ┆ SVC-RBF    ┆ {"clf__C" ┆ {"C":     ┆ … ┆ 0.879     ┆ 0.87724   ┆ 0.879     ┆ 0.877664  │
# │         ┆            ┆ : 1.0,    ┆ 1.0, "bre ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ "clf__gam ┆ ak_ties": ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ ma": …    ┆ false…    ┆   ┆           ┆           ┆           ┆           │
# │ raw     ┆ ExtraTrees ┆ {"clf__ma ┆ {"bootstr ┆ … ┆ 0.873     ┆ 0.869729  ┆ 0.873     ┆ 0.870089  │
# │         ┆            ┆ x_depth": ┆ ap":      ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ 10,       ┆ false,    ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ "clf__n…  ┆ "ccp_alph ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ …         ┆   ┆           ┆           ┆           ┆           │
# │ scaled  ┆ ExtraTrees ┆ {"clf__ma ┆ {"bootstr ┆ … ┆ 0.873     ┆ 0.869729  ┆ 0.873     ┆ 0.870089  │
# │         ┆            ┆ x_depth": ┆ ap":      ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ 10,       ┆ false,    ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ "clf__n…  ┆ "ccp_alph ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ …         ┆   ┆           ┆           ┆           ┆           │
# │ raw     ┆ RandomFore ┆ {"clf__ma ┆ {"bootstr ┆ … ┆ 0.869     ┆ 0.867474  ┆ 0.869     ┆ 0.867902  │
# │         ┆ st         ┆ x_depth": ┆ ap":      ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ null,     ┆ true, "cc ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ "clf_…    ┆ p_alpha…  ┆   ┆           ┆           ┆           ┆           │
# │ scaled  ┆ RandomFore ┆ {"clf__ma ┆ {"bootstr ┆ … ┆ 0.869     ┆ 0.867474  ┆ 0.869     ┆ 0.867902  │
# │         ┆ st         ┆ x_depth": ┆ ap":      ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ null,     ┆ true, "cc ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ "clf_…    ┆ p_alpha…  ┆   ┆           ┆           ┆           ┆           │
# └─────────┴────────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘
