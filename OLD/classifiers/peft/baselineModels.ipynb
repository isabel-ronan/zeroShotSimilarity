# %% [markdown]
# # Train Machine Learning Models
#
# ## Overview
# - Test a range of different models.
# - Test a range of different hyperparameters.
# - Test a range of different inputs.

# %%
# Import libraries.
import os
import random
import json
import pandas as pd
import numpy as np
from glob import glob

from sklearn.model_selection import (
    StratifiedKFold, cross_validate, GridSearchCV
)

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, FunctionTransformer
from sklearn.impute import SimpleImputer
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    roc_auc_score, balanced_accuracy_score, make_scorer, confusion_matrix
)

from sklearn.linear_model import LogisticRegression, RidgeClassifier, SGDClassifier
from sklearn.svm import SVC, LinearSVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier, GradientBoostingClassifier, HistGradientBoostingClassifier, AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB

import pandas as pd
import numpy as np
import random
import torch
import re
import nltk
from nltk.corpus import stopwords

import shap
from itertools import product


from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, classification_report


from sklearn.feature_extraction.text import TfidfVectorizer
from sentence_transformers import SentenceTransformer

import numpy as np
import pandas as pd
import os
import random
from sklearn.decomposition import PCA, FastICA, FactorAnalysis
from sklearn.random_projection import GaussianRandomProjection
from sklearn.manifold import TSNE, trustworthiness
from sklearn.metrics import silhouette_score, pairwise_distances
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.datasets import make_blobs
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import NearestNeighbors
import umap
import matplotlib.pyplot as plt
import seaborn as sns

from scipy import sparse

# %%
# Set random states.
def set_random_states(random_state):
    # Set various random seeds.
    np.random.seed(random_state)
    random.seed(random_state)
    torch.manual_seed(random_state)
    torch.cuda.manual_seed_all(random_state)
    os.environ["PYTHONHASHSEED"] = str(random_state)
    os.environ["TOKENIZERS_PARALLELISM"] = "false"
    try:
        torch.use_deterministic_algorithms(True)
    except Exception:
        pass
    return random_state

RANDOM_STATE = set_random_states(1618)

N_SPLITS_CV = 5
N_JOBS = 1  # prioritizing no leakage

# %%
# Make stop words.
nltk.download('stopwords')
stop_words = list(stopwords.words('english'))
stop_words.extend(['mrs', 'ms', 'mr', 'am', 'pm'])
# Map dataset labels to 1s or 0s.
label_map = {
    "met": 0,
    "unmet": 1
}
# Load the dataset
dataset = pd.read_csv("./dataSyntheticAll.csv")
dataset["label"] = dataset["needs"].map(label_map)

# Make function to remove punctuation, make lowercase, remove names, remove stopwords, punctuation, lemmatize, remove documents with less than 5 tokens.
def preprocessing(notes, min_words=1):
    cleaned_notes = []

    for note in notes:
        # lowercase + extract words only
        tokens = re.findall(r"\b[a-zA-Z]+\b", note.lower())
        
        # filter stopwords
        tokens = [t for t in tokens if t not in stop_words]
        
        if len(tokens) >= min_words:
            cleaned_notes.append(" ".join(tokens))

    return cleaned_notes

dataset['report'] = preprocessing(dataset['report'].values.tolist())

# Split the dataset. (80/10/10)
train_df, test_df = train_test_split(
    dataset,
    test_size=0.2,
    random_state=RANDOM_STATE,
    stratify=dataset["label"]
)
y_train = train_df['label'].values
y_test = test_df['label'].values

# Check distributions.
def check_distribution(dataframe, name):
    counts = dataframe["label"].value_counts(normalize=True)
    print(f"{name} distribution:")
    print(counts)

check_distribution(train_df, "Train")
check_distribution(test_df, "Test")
# Out:
# [nltk_data] Downloading package stopwords to /home/isabel/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Train distribution:
# label
# 0    0.502162
# 1    0.497838
# Name: proportion, dtype: float64
# Test distribution:
# label
# 0    0.502161
# 1    0.497839
# Name: proportion, dtype: float64

# %%
embedding_model = SentenceTransformer('all-MiniLM-L6-v2')  # fast and strong
train_embeddings = embedding_model.encode(train_df['report'].tolist(), show_progress_bar=True)
test_embeddings  = embedding_model.encode(test_df['report'].tolist(), show_progress_bar=True)

# tfidf and reduction parameters
tfidf_params = {
    "max_features": [10000, 20000],
    "ngram_range": [(1,1), (1,2)],
    "min_df": [2,5]
}

reduction_methods = {
    "pca": PCA,
    "ica": FastICA,
    "rp": GaussianRandomProjection,
    "fa": FactorAnalysis,
    "umap": umap.UMAP
}

inputs_dict = {'embeddings': train_embeddings}
test_dict = {'embeddings': test_embeddings}

# tf-idf representations
for max_feat, n_gram, min_df in product(tfidf_params['max_features'],
                                       tfidf_params['ngram_range'],
                                       tfidf_params['min_df']):
    key = f"tfidf_{max_feat}_{max(list(n_gram))}_{min_df}"
    vectorizer = TfidfVectorizer(max_features=max_feat, ngram_range=n_gram, min_df=min_df)
    X_train_tfidf = vectorizer.fit_transform(train_df['report'].tolist())
    X_test_tfidf  = vectorizer.transform(test_df['report'].tolist())
    inputs_dict[key] = X_train_tfidf
    test_dict[key] = X_test_tfidf

# embeddings and dimensionality reduction
for name, method in reduction_methods.items():
    for n_components in [10,50,100,200]:
        key = f"{name}_{n_components}"
        if name == "umap":
            reducer = method(n_components=n_components, random_state=RANDOM_STATE, n_neighbors=10)
        else:
            reducer = method(n_components=n_components, random_state=RANDOM_STATE)
        X_train_red = reducer.fit_transform(train_embeddings)
        X_test_red  = reducer.transform(test_embeddings)
        inputs_dict[key] = X_train_red
        test_dict[key] = X_test_red
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Batches:   0%|          | 0/145 [00:00<?, ?it/s]
# Batches:   0%|          | 0/37 [00:00<?, ?it/s]
# /home/isabel/anaconda3/envs/realData/lib/python3.12/site-packages/sklearn/decomposition/_fastica.py:132: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/isabel/anaconda3/envs/realData/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# /home/isabel/anaconda3/envs/realData/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# /home/isabel/anaconda3/envs/realData/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# /home/isabel/anaconda3/envs/realData/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(

# %%
# get models - broad coverage across linear, margin, instance-based, and nonlinear tree ensembles
def build_models(random_state):
    models = {
        # high numbers of iterations (max_iter) avoids convergence warnings in high-dimensional spaces
        "LogisticRegression": LogisticRegression(max_iter=20000, class_weight="balanced", random_state=random_state), # strong baseline
        "RidgeClassifier": RidgeClassifier(class_weight="balanced", random_state=random_state), # strong baseline
        "LinearSVC": LinearSVC(max_iter=20000, class_weight="balanced", random_state=random_state), # strong baseline
        "SVC-RBF": SVC(probability=False, random_state=random_state, class_weight="balanced"), # probability set to false saves on compute
        "SGD-Hinge": SGDClassifier(loss="hinge", max_iter=20000, random_state=random_state, class_weight="balanced"), # hinge loss is good for binary classification problems - fast on large data
        "KNN": KNeighborsClassifier(), # deterministic - sensitive to scaling (good to test with and without standard scaler)
        "DecisionTree": DecisionTreeClassifier(random_state=random_state, class_weight="balanced"), # don't need scaling and captures nonlinear splits
        "RandomForest": RandomForestClassifier(random_state=random_state, class_weight="balanced"), # don't need scaling and captures nonlinear splits
        "ExtraTrees": ExtraTreesClassifier(random_state=random_state, class_weight="balanced"), # don't need scaling and captures nonlinear splits
        "GradientBoosting": GradientBoostingClassifier(random_state=random_state), # don't need scaling and captures nonlinear splits
        "HistGB": HistGradientBoostingClassifier(random_state=random_state), # don't need scaling and captures nonlinear splits
        "AdaBoost": AdaBoostClassifier(random_state=random_state), # don't need scaling and captures nonlinear splits
        "GaussianNaiveBayes": GaussianNB(), # deterministic - interpretable
    }
    return models

# get parameter grid to test
def small_param_grid(name): # high-leverage parameter sweeps (runtime will be effected if we test everything)
    grids = {
        # lowered c values due to convergence issues
        "LogisticRegression": {"clf__C": [0.1, 0.5, 1.0]},
        "LinearSVC":          {"clf__C": [0.1, 0.5, 1.0]},
        "SVC-RBF":            {"clf__C": [0.1, 0.5, 1.0], "clf__gamma": ["scale", "auto"]},
        "KNN":                {"clf__n_neighbors": [3, 5, 11]},
        "RandomForest":       {"clf__n_estimators": [300, 600], "clf__max_depth": [None, 10, 20]},
        "ExtraTrees":         {"clf__n_estimators": [300, 600], "clf__max_depth": [None, 10, 20]},
        "HistGB":             {"clf__max_depth": [None, 6, 10]},
    }
    return grids.get(name, None)

# make pipeline with and without scaling
def preprocessor(scale):
    # median ensures it is robust to outliers
    steps = [("imputer", SimpleImputer(strategy="median"))]
    if scale:
        # scales data to benefit models such as SVM and KNN
        steps.append(("scaler", StandardScaler(with_mean=True)))
    else:
        steps.append(("scaler", FunctionTransformer(lambda X: X, feature_names_out="one-to-one")))
    return Pipeline(steps)


def gmean_binary_score(y_true, y_pred):
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()
    tpr = tp / (tp + fn) if (tp + fn) else 0.0   # sensitivity
    tnr = tn / (tn + fp) if (tn + fp) else 0.0   # specificity
    return np.sqrt(tpr * tnr)

gmean_scorer = make_scorer(gmean_binary_score)

def build_scorers():
    return {
        "accuracy": "accuracy", # normal accuracy
        "balanced_accuracy": make_scorer(balanced_accuracy_score), # balanced accuracy
        "precision": make_scorer(precision_score, average="binary", zero_division=0),
        "recall": make_scorer(recall_score, average="binary", zero_division=0),
        "f1": make_scorer(f1_score, average="binary", zero_division=0),
        "roc_auc": "roc_auc",
        "gmean": gmean_scorer
    }

# %%
def evaluate_one(X_train, y_train, X_test, y_test, feature_name, variant,
                 random_state=RANDOM_STATE, n_splits=N_SPLITS_CV, n_jobs=N_JOBS):

    inner_cv = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=random_state)
    outer_cv = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=random_state)
    scorers = build_scorers()
    results = []

    for name, clf in build_models(random_state).items():
        # scaling decision
        X_tr, X_te = X_train, X_test

        # Convert sparse to dense for models that need dense arrays
        if sparse.issparse(X_tr):
            if name in ["HistGB", "GradientBoosting", "GaussianNaiveBayes"]:
                X_tr = X_tr.toarray()
                X_te = X_te.toarray()

        # Scaling decision
        if variant == "scaled":
            scaler = StandardScaler(with_mean=False if sparse.issparse(X_tr) else True)
        else:
            scaler = FunctionTransformer(lambda X: X, feature_names_out="one-to-one")

        pipe = Pipeline([
            ("scale", scaler),
            ("clf", clf)
        ])

        grid = small_param_grid(name)
        model_for_cv = GridSearchCV(pipe, grid, scoring=scorers, cv=inner_cv,
                                    n_jobs=n_jobs, refit="gmean") if grid else pipe

        cv_out = cross_validate(model_for_cv, X_tr, y_train, cv=outer_cv,
                                scoring=scorers, return_train_score=False,
                                n_jobs=n_jobs, return_estimator=True)

        # Fit on full training
        model_for_cv.fit(X_tr, y_train)
        y_pred = model_for_cv.predict(X_te)

        # best estimator info
        if isinstance(model_for_cv, GridSearchCV):
            chosen = model_for_cv.best_estimator_
            tuned = model_for_cv.best_params_
        else:
            chosen = model_for_cv
            tuned = {}

        clf_params = chosen.named_steps["clf"].get_params()
        tuned_json = json.dumps(tuned, default=str)
        clf_json = json.dumps(clf_params, default=str)

        y_score = None
        if hasattr(model_for_cv, "predict_proba"):
            y_score = model_for_cv.predict_proba(X_te)[:, 1]
        elif hasattr(model_for_cv, "decision_function"):
            y_score = model_for_cv.decision_function(X_te)

        row = {
            "feature_set": feature_name,
            "variant": variant,
            "model": name,
            "tuned_parameters": tuned_json,
            "clf_parameters": clf_json,
            **{f"cv_{k.replace('test_','')}_mean": float(np.mean(v))
               for k,v in cv_out.items() if k.startswith("test_")},
            **{f"cv_{k.replace('test_','')}_std": float(np.std(v))
               for k,v in cv_out.items() if k.startswith("test_")},
            "holdout_accuracy": accuracy_score(y_test, y_pred),
            "holdout_bal_acc": balanced_accuracy_score(y_test, y_pred),
            "holdout_precision": precision_score(y_test, y_pred, zero_division=0),
            "holdout_recall": recall_score(y_test, y_pred, zero_division=0),
            "holdout_f1": f1_score(y_test, y_pred, zero_division=0),
            "holdout_roc_auc": roc_auc_score(y_test, y_score) if y_score is not None else np.nan,
            "holdout_gmean": gmean_binary_score(y_test, y_pred)
        }

        results.append(row)
        print(row)
    return pd.DataFrame(results)

# %%
all_results = []
for feature_name, X_train in inputs_dict.items():
    X_test = test_dict[feature_name]

    for variant in ("raw", "scaled"):
        df_res = evaluate_one(X_train, y_train, X_test, y_test, feature_name, variant)
        all_results.append(df_res)

# Concatenate all results and save.
final_results = pd.concat(all_results, ignore_index=True)
final_results.to_csv("baseline_model_results.csv", index=False)
# Out:
# {'feature_set': 'embeddings', 'variant': 'raw', 'model': 'LogisticRegression', 'tuned_parameters': '{"clf__C": 1.0}', 'clf_parameters': '{"C": 1.0, "class_weight": "balanced", "dual": false, "fit_intercept": true, "intercept_scaling": 1, "l1_ratio": 0.0, "max_iter": 20000, "n_jobs": null, "penalty": "deprecated", "random_state": 1618, "solver": "lbfgs", "tol": 0.0001, "verbose": 0, "warm_start": false}', 'cv_accuracy_mean': 0.8843502422508902, 'cv_balanced_accuracy_mean': 0.884454534418467, 'cv_precision_mean': 0.8668893310311064, 'cv_recall_mean': 0.9070866735829484, 'cv_f1_mean': 0.88648661428689, 'cv_roc_auc_mean': 0.9501831986532798, 'cv_gmean_mean': 0.8841344402582546, 'cv_accuracy_std': 0.009487095159951484, 'cv_balanced_accuracy_std': 0.009490637504293645, 'cv_precision_std': 0.010975020614202906, 'cv_recall_std': 0.011618466269500902, 'cv_f1_std': 0.009260099180156073, 'cv_roc_auc_std': 0.0031152116620973406, 'cv_gmean_std': 0.009485911558573298, 'holdout_accuracy': 0.878133102852204, 'holdout_bal_acc': 0.878291439567795, 'holdout_precision': 0.851373182552504, 'holdout_recall': 0.9149305555555556, 'holdout_f1': 0.8820083682008368, 'holdout_roc_auc': 0.9485710699942629, 'holdout_gmean': np.float64(0.8775268816382237)}
# {'feature_set': 'embeddings', 'variant': 'raw', 'model': 'RidgeClassifier', 'tuned_parameters': '{}', 'clf_parameters': '{"alpha": 1.0, "class_weight": "balanced", "copy_X": true, "fit_intercept": true, "max_iter": null, "positive": false, "random_state": 1618, "solver": "auto", "tol": 0.0001}', 'cv_accuracy_mean': 0.8951601190823653, 'cv_balanced_accuracy_mean': 0.8952823903369147, 'cv_precision_mean': 0.8752233129101835, 'cv_recall_mean': 0.9209883995095727, 'cv_f1_mean': 0.8973847768315478, 'cv_roc_auc_mean': 0.9578671215438395, 'cv_gmean_mean': 0.8948188409788, 'cv_accuracy_std': 0.00779128267101859, 'cv_balanced_accuracy_std': 0.007795358404964659, 'cv_precision_std': 0.011785124143887766, 'cv_recall_std': 0.01531299525365756, 'cv_f1_std': 0.007727516663979554, 'cv_roc_auc_std': 0.0022732147449283247, 'cv_gmean_std': 0.007822092764813186, 'holdout_accuracy': 0.8720829732065687, 'holdout_bal_acc': 0.8722972246127367, 'holdout_precision': 0.8375394321766562, 'holdout_recall': 0.921875, 'holdout_f1': 0.8776859504132232, 'holdout_roc_auc': 0.9575773331420923, 'holdout_gmean': np.float64(0.8708871868702245)}
# {'feature_set': 'embeddings', 'variant': 'raw', 'model': 'LinearSVC', 'tuned_parameters': '{"clf__C": 1.0}', 'clf_parameters': '{"C": 1.0, "class_weight": "balanced", "dual": "auto", "fit_intercept": true, "intercept_scaling": 1, "loss": "squared_hinge", "max_iter": 20000, "multi_class": "ovr", "penalty": "l2", "random_state": 1618, "tol": 0.0001, "verbose": 0}', 'cv_accuracy_mean': 0.894727686649933, 'cv_balanced_accuracy_mean': 0.8948093206825318, 'cv_precision_mean': 0.8805713458408775, 'cv_recall_mean': 0.91230217862869, 'cv_f1_mean': 0.8960858339835935, 'cv_roc_auc_mean': 0.9588866312068234, 'cv_gmean_mean': 0.8945933971612213, 'cv_accuracy_std': 0.0066465319780348656, 'cv_balanced_accuracy_std': 0.006691805346531393, 'cv_precision_std': 0.0032666602428644636, 'cv_recall_std': 0.015311445982930558, 'cv_f1_std': 0.007361534676332734, 'cv_roc_auc_std': 0.0019201015803863382, 'cv_gmean_std': 0.006546966531410224, 'holdout_accuracy': 0.8789974070872947, 'holdout_bal_acc': 0.8791296136928667, 'holdout_precision': 0.8562091503267973, 'holdout_recall': 0.9097222222222222, 'holdout_f1': 0.8821548821548821, 'holdout_roc_auc': 0.9592745983935744, 'holdout_gmean': np.float64(0.8785971602362135)}
# {'feature_set': 'embeddings', 'variant': 'raw', 'model': 'SVC-RBF', 'tuned_parameters': '{"clf__C": 1.0, "clf__gamma": "scale"}', 'clf_parameters': '{"C": 1.0, "break_ties": false, "cache_size": 200, "class_weight": "balanced", "coef0": 0.0, "decision_function_shape": "ovr", "degree": 3, "gamma": "scale", "kernel": "rbf", "max_iter": -1, "probability": false, "random_state": 1618, "shrinking": true, "tol": 0.001, "verbose": false}', 'cv_accuracy_mean': 0.8977530792131224, 'cv_balanced_accuracy_mean': 0.8978602384571481, 'cv_precision_mean': 0.8794329795526912, 'cv_recall_mean': 0.9209865132509666, 'cv_f1_mean': 0.8996452529271546, 'cv_roc_auc_mean': 0.9629633746033708, 'cv_gmean_mean': 0.8975063602858896, 'cv_accuracy_std': 0.007705962674955641, 'cv_balanced_accuracy_std': 0.0077330502685378465, 'cv_precision_std': 0.007902490951981055, 'cv_recall_std': 0.015133083087056477, 'cv_f1_std': 0.008007464510466201, 'cv_roc_auc_std': 0.0030522704410738282, 'cv_gmean_std': 0.0076416128358704595, 'holdout_accuracy': 0.8910976663785652, 'holdout_bal_acc': 0.8912823914706445, 'holdout_precision': 0.8594249201277955, 'holdout_recall': 0.9340277777777778, 'holdout_f1': 0.8951747088186356, 'holdout_roc_auc': 0.9619161168483457, 'holdout_gmean': np.float64(0.8902567794154027)}
# {'feature_set': 'embeddings', 'variant': 'raw', 'model': 'SGD-Hinge', 'tuned_parameters': '{}', 'clf_parameters': '{"alpha": 0.0001, "average": false, "class_weight": "balanced", "early_stopping": false, "epsilon": 0.1, "eta0": 0.01, "fit_intercept": true, "l1_ratio": 0.15, "learning_rate": "optimal", "loss": "hinge", "max_iter": 20000, "n_iter_no_change": 5, "n_jobs": null, "penalty": "l2", "power_t": 0.5, "random_state": 1618, "shuffle": true, "tol": 0.001, "validation_fraction": 0.1, "verbose": 0, "warm_start": false}', 'cv_accuracy_mean': 0.8891053645438095, 'cv_balanced_accuracy_mean': 0.8891758510745328, 'cv_precision_mean': 0.8774462183298037, 'cv_recall_mean': 0.9049089880222578, 'cv_f1_mean': 0.8904684369824691, 'cv_roc_auc_mean': 0.9574482217291747, 'cv_gmean_mean': 0.8886919194890156, 'cv_accuracy_std': 0.00635719101603578, 'cv_balanced_accuracy_std': 0.006238367896260594, 'cv_precision_std': 0.022837857165304756, 'cv_recall_std': 0.019688769227463522, 'cv_f1_std': 0.0042755513370556835, 'cv_roc_auc_std': 0.0016573830364662655, 'cv_gmean_std': 0.006880725313345417, 'holdout_accuracy': 0.8582541054451167, 'holdout_bal_acc': 0.8587146203863072, 'holdout_precision': 0.7942857142857143, 'holdout_recall': 0.9652777777777778, 'holdout_f1': 0.8714733542319749, 'holdout_roc_auc': 0.9566181392235609, 'holdout_gmean': np.float64(0.8520769288931371)}
# {'feature_set': 'embeddings', 'variant': 'raw', 'model': 'KNN', 'tuned_parameters': '{"clf__n_neighbors": 11}', 'clf_parameters': '{"algorithm": "auto", "leaf_size": 30, "metric": "minkowski", "metric_params": null, "n_jobs": null, "n_neighbors": 11, "p": 2, "weights": "uniform"}', 'cv_accuracy_mean': 0.8484651217091823, 'cv_balanced_accuracy_mean': 0.8488128627415353, 'cv_precision_mean': 0.8009761712866499, 'cv_recall_mean': 0.9261963595208904, 'cv_f1_mean': 0.8588740925991978, 'cv_roc_auc_mean': 0.9189617062663826, 'cv_gmean_mean': 0.8451165592244637, 'cv_accuracy_std': 0.002855313456288484, 'cv_balanced_accuracy_std': 0.0027319124673968933, 'cv_precision_std': 0.010929508946196766, 'cv_recall_std': 0.013801124486551276, 'cv_f1_std': 0.0011459449387688997, 'cv_roc_auc_std': 0.010313475598777943, 'cv_gmean_std': 0.00418532337044705, 'holdout_accuracy': 0.8383751080380294, 'holdout_bal_acc': 0.8388016351118761, 'holdout_precision': 0.7814761215629522, 'holdout_recall': 0.9375, 'holdout_f1': 0.8524072612470402, 'holdout_roc_auc': 0.9225787076878944, 'holdout_gmean': np.float64(0.8329746789877635)}
# {'feature_set': 'embeddings', 'variant': 'raw', 'model': 'DecisionTree', 'tuned_parameters': '{}', 'clf_parameters': '{"ccp_alpha": 0.0, "class_weight": "balanced", "criterion": "gini", "max_depth": null, "max_features": null, "max_leaf_nodes": null, "min_impurity_decrease": 0.0, "min_samples_leaf": 1, "min_samples_split": 2, "min_weight_fraction_leaf": 0.0, "monotonic_cst": null, "random_state": 1618, "splitter": "best"}', 'cv_accuracy_mean': 0.72567742688693, 'cv_balanced_accuracy_mean': 0.7257104531056143, 'cv_precision_mean': 0.7211710879920471, 'cv_recall_mean': 0.7329661416580213, 'cv_f1_mean': 0.726776742645648, 'cv_roc_auc_mean': 0.7257104531056143, 'cv_gmean_mean': 0.7254360123750727, 'cv_accuracy_std': 0.012330894721232891, 'cv_balanced_accuracy_std': 0.012306492646158226, 'cv_precision_std': 0.01652910437126365, 'cv_recall_std': 0.019230329104791458, 'cv_f1_std': 0.011952911573731378, 'cv_roc_auc_std': 0.012306492646158256, 'cv_gmean_std': 0.012376694815262417, 'holdout_accuracy': 0.7433016421780466, 'holdout_bal_acc': 0.7433454054312487, 'holdout_precision': 0.7368421052631579, 'holdout_recall': 0.7534722222222222, 'holdout_f1': 0.7450643776824034, 'holdout_roc_auc': 0.7433454054312488, 'holdout_gmean': np.float64(0.7432764219033385)}
# {'feature_set': 'embeddings', 'variant': 'raw', 'model': 'RandomForest', 'tuned_parameters': '{"clf__max_depth": 20, "clf__n_estimators": 300}', 'clf_parameters': '{"bootstrap": true, "ccp_alpha": 0.0, "class_weight": "balanced", "criterion": "gini", "max_depth": 20, "max_features": "sqrt", "max_leaf_nodes": null, "max_samples": null, "min_impurity_decrease": 0.0, "min_samples_leaf": 1, "min_samples_split": 2, "min_weight_fraction_leaf": 0.0, "monotonic_cst": null, "n_estimators": 300, "n_jobs": null, "oob_score": false, "random_state": 1618, "verbose": 0, "warm_start": false}', 'cv_accuracy_mean': 0.864462086276341, 'cv_balanced_accuracy_mean': 0.8646164699733262, 'cv_precision_mean': 0.8406011552602168, 'cv_recall_mean': 0.8984051683485805, 'cv_f1_mean': 0.8684257766485661, 'cv_roc_auc_mean': 0.9389594491817139, 'cv_gmean_mean': 0.8638660915552061, 'cv_accuracy_std': 0.010423058900496232, 'cv_balanced_accuracy_std': 0.010413542765390664, 'cv_precision_std': 0.013881712508201314, 'cv_recall_std': 0.014409905431969077, 'cv_f1_std': 0.00992769922462019, 'cv_roc_auc_std': 0.005587701587264152, 'cv_gmean_std': 0.01054667809756791, 'holdout_accuracy': 0.8634399308556612, 'holdout_bal_acc': 0.8636614912029068, 'holdout_precision': 0.8286163522012578, 'holdout_recall': 0.9149305555555556, 'holdout_f1': 0.8696369636963697, 'holdout_roc_auc': 0.9339261809141327, 'holdout_gmean': np.float64(0.8621384195285771)}
# {'feature_set': 'embeddings', 'variant': 'raw', 'model': 'ExtraTrees', 'tuned_parameters': '{"clf__max_depth": 20, "clf__n_estimators": 600}', 'clf_parameters': '{"bootstrap": false, "ccp_alpha": 0.0, "class_weight": "balanced", "criterion": "gini", "max_depth": 20, "max_features": "sqrt", "max_leaf_nodes": null, "max_samples": null, "min_impurity_decrease": 0.0, "min_samples_leaf": 1, "min_samples_split": 2, "min_weight_fraction_leaf": 0.0, "monotonic_cst": null, "n_estimators": 600, "n_jobs": null, "oob_score": false, "random_state": 1618, "verbose": 0, "warm_start": false}', 'cv_accuracy_mean': 0.8648935847294379, 'cv_balanced_accuracy_mean': 0.865078331312267, 'cv_precision_mean': 0.8360738327120275, 'cv_recall_mean': 0.9066490615863435, 'cv_f1_mean': 0.8698609290391422, 'cv_roc_auc_mean': 0.9433145914797132, 'cv_gmean_mean': 0.8640218849484764, 'cv_accuracy_std': 0.007467217781458482, 'cv_balanced_accuracy_std': 0.007440021887166263, 'cv_precision_std': 0.012367225310908574, 'cv_recall_std': 0.0060582709318255795, 'cv_f1_std': 0.006287247869581022, 'cv_roc_auc_std': 0.004708595670596303, 'cv_gmean_std': 0.0077932749309655245, 'holdout_accuracy': 0.8651685393258427, 'holdout_bal_acc': 0.8654200133868809, 'holdout_precision': 0.8260869565217391, 'holdout_recall': 0.9236111111111112, 'holdout_f1': 0.8721311475409836, 'holdout_roc_auc': 0.9344939280933257, 'holdout_gmean': np.float64(0.8634614037212075)}
# {'feature_set': 'embeddings', 'variant': 'raw', 'model': 'GradientBoosting', 'tuned_parameters': '{}', 'clf_parameters': '{"ccp_alpha": 0.0, "criterion": "friedman_mse", "init": null, "learning_rate": 0.1, "loss": "log_loss", "max_depth": 3, "max_features": null, "max_leaf_nodes": null, "min_impurity_decrease": 0.0, "min_samples_leaf": 1, "min_samples_split": 2, "min_weight_fraction_leaf": 0.0, "n_estimators": 100, "n_iter_no_change": null, "random_state": 1618, "subsample": 1.0, "tol": 0.0001, "validation_fraction": 0.1, "verbose": 0, "warm_start": false}', 'cv_accuracy_mean': 0.8674874788395307, 'cv_balanced_accuracy_mean': 0.8676005344976382, 'cv_precision_mean': 0.8496615863882022, 'cv_recall_mean': 0.8918872017353581, 'cv_f1_mean': 0.8701407458826997, 'cv_roc_auc_mean': 0.9402318981856773, 'cv_gmean_mean': 0.8671720011152166, 'cv_accuracy_std': 0.004684645066558912, 'cv_balanced_accuracy_std': 0.004677816266739495, 'cv_precision_std': 0.009866321317197332, 'cv_recall_std': 0.01293718953795869, 'cv_f1_std': 0.004736047145781195, 'cv_roc_auc_std': 0.005575133531660918, 'cv_gmean_std': 0.004675406854559745, 'holdout_accuracy': 0.8686257562662058, 'holdout_bal_acc': 0.8688175320328935, 'holdout_precision': 0.8375796178343949, 'holdout_recall': 0.9131944444444444, 'holdout_f1': 0.8737541528239202, 'holdout_roc_auc': 0.9357997466054695, 'holdout_gmean': np.float64(0.8676834639501582)}
# {'feature_set': 'embeddings', 'variant': 'raw', 'model': 'HistGB', 'tuned_parameters': '{"clf__max_depth": 6}', 'clf_parameters': '{"categorical_features": "from_dtype", "class_weight": null, "early_stopping": "auto", "interaction_cst": null, "l2_regularization": 0.0, "learning_rate": 0.1, "loss": "log_loss", "max_bins": 255, "max_depth": 6, "max_features": 1.0, "max_iter": 100, "max_leaf_nodes": 31, "min_samples_leaf": 20, "monotonic_cst": null, "n_iter_no_change": 10, "random_state": 1618, "scoring": "loss", "tol": 1e-07, "validation_fraction": 0.1, "verbose": 0, "warm_start": false}', 'cv_accuracy_mean': 0.8780802054754538, 'cv_balanced_accuracy_mean': 0.8781881235052476, 'cv_precision_mean': 0.8605624525174467, 'cv_recall_mean': 0.9014429878336319, 'cv_f1_mean': 0.8804136799598672, 'cv_roc_auc_mean': 0.9476574108509388, 'cv_gmean_mean': 0.8778005760046479, 'cv_accuracy_std': 0.010492672721998383, 'cv_balanced_accuracy_std': 0.010483913891970956, 'cv_precision_std': 0.014203084361695761, 'cv_recall_std': 0.014374053292065694, 'cv_f1_std': 0.010125680895189147, 'cv_roc_auc_std': 0.0048262177859433476, 'cv_gmean_std': 0.010528060847566977, 'holdout_accuracy': 0.8738115816767502, 'holdout_bal_acc': 0.8739661025052592, 'holdout_precision': 0.8478964401294499, 'holdout_recall': 0.9097222222222222, 'holdout_f1': 0.8777219430485762, 'holdout_roc_auc': 0.9456157965194109, 'holdout_gmean': np.float64(0.8732343604273822)}
# {'feature_set': 'embeddings', 'variant': 'raw', 'model': 'AdaBoost', 'tuned_parameters': '{}', 'clf_parameters': '{"estimator": null, "learning_rate": 1.0, "n_estimators": 50, "random_state": 1618}', 'cv_accuracy_mean': 0.8374420640943319, 'cv_balanced_accuracy_mean': 0.8374937626089342, 'cv_precision_mean': 0.8285897624811245, 'cv_recall_mean': 0.8493266056776385, 'cv_f1_mean': 0.83874894447981, 'cv_roc_auc_mean': 0.9094546337145613, 'cv_gmean_mean': 0.8373500248763792, 'cv_accuracy_std': 0.0069220429406059766, 'cv_balanced_accuracy_std': 0.006925896207398888, 'cv_precision_std': 0.009229077824727329, 'cv_recall_std': 0.012338805500783492, 'cv_f1_std': 0.0070702845324825195, 'cv_roc_auc_std': 0.003936103671245364, 'cv_gmean_std': 0.006941232699475408, 'holdout_accuracy': 0.8331892826274849, 'holdout_bal_acc': 0.8333168985465672, 'holdout_precision': 0.8134206219312602, 'holdout_recall': 0.8628472222222222, 'holdout_f1': 0.8374052232518955, 'holdout_roc_auc': 0.9064502055842417, 'holdout_gmean': np.float64(0.8327934998466792)}
# {'feature_set': 'embeddings', 'variant': 'raw', 'model': 'GaussianNaiveBayes', 'tuned_parameters': '{}', 'clf_parameters': '{"priors": null, "var_smoothing": 1e-09}', 'cv_accuracy_mean': 0.827930185044656, 'cv_balanced_accuracy_mean': 0.8282268099908482, 'cv_precision_mean': 0.7885441283282064, 'cv_recall_mean': 0.8949278506083186, 'cv_f1_mean': 0.8381833074402874, 'cv_roc_auc_mean': 0.8926628384604143, 'cv_gmean_mean': 0.8253447836045946, 'cv_accuracy_std': 0.009537131337257575, 'cv_balanced_accuracy_std': 0.009483037770820981, 'cv_precision_std': 0.014915869632025422, 'cv_recall_std': 0.014642994578741415, 'cv_f1_std': 0.007914981926097917, 'cv_roc_auc_std': 0.005582567298824935, 'cv_gmean_std': 0.010446802012165272, 'holdout_accuracy': 0.8210890233362144, 'holdout_bal_acc': 0.8214778757888698, 'holdout_precision': 0.7709251101321586, 'holdout_recall': 0.9114583333333334, 'holdout_f1': 0.8353221957040573, 'holdout_roc_auc': 0.8918426682922165, 'holdout_gmean': np.float64(0.8165350070086907)}
# {'feature_set': 'embeddings', 'variant': 'scaled', 'model': 'LogisticRegression', 'tuned_parameters': '{"clf__C": 0.1}', 'clf_parameters': '{"C": 0.1, "class_weight": "balanced", "dual": false, "fit_intercept": true, "intercept_scaling": 1, "l1_ratio": 0.0, "max_iter": 20000, "n_jobs": null, "penalty": "deprecated", "random_state": 1618, "solver": "lbfgs", "tol": 0.0001, "verbose": 0, "warm_start": false}', 'cv_accuracy_mean': 0.8895387309555776, 'cv_balanced_accuracy_mean': 0.8896008486729974, 'cv_precision_mean': 0.8794325315930129, 'cv_recall_mean': 0.9018805998302367, 'cv_f1_mean': 0.8904330276205478, 'cv_roc_auc_mean': 0.9585130719574787, 'cv_gmean_mean': 0.8894635984957022, 'cv_accuracy_std': 0.004673921655783934, 'cv_balanced_accuracy_std': 0.004705649212000803, 'cv_precision_std': 0.006471223575478606, 'cv_recall_std': 0.012812513253132022, 'cv_f1_std': 0.005192807373587978, 'cv_roc_auc_std': 0.0014328238260911833, 'cv_gmean_std': 0.004609135914790632, 'holdout_accuracy': 0.8764044943820225, 'holdout_bal_acc': 0.8765553284566838, 'holdout_precision': 0.8508914100486223, 'holdout_recall': 0.9114583333333334, 'holdout_f1': 0.8801341156747695, 'holdout_roc_auc': 0.9591102505259131, 'holdout_gmean': np.float64(0.8758601624097225)}
# {'feature_set': 'embeddings', 'variant': 'scaled', 'model': 'RidgeClassifier', 'tuned_parameters': '{}', 'clf_parameters': '{"alpha": 1.0, "class_weight": "balanced", "copy_X": true, "fit_intercept": true, "max_iter": null, "positive": false, "random_state": 1618, "solver": "auto", "tol": 0.0001}', 'cv_accuracy_mean': 0.8893227482341954, 'cv_balanced_accuracy_mean': 0.8894250330401239, 'cv_precision_mean': 0.8728624075081572, 'cv_recall_mean': 0.9105649344525133, 'cv_f1_mean': 0.891195125120281, 'cv_roc_auc_mean': 0.9584061358341891, 'cv_gmean_mean': 0.8890925408772402, 'cv_accuracy_std': 0.006831496770135835, 'cv_balanced_accuracy_std': 0.006827940938324475, 'cv_precision_std': 0.01113207369257782, 'cv_recall_std': 0.01353816258122155, 'cv_f1_std': 0.00671440105586294, 'cv_roc_auc_std': 0.0012877405611449273, 'cv_gmean_std': 0.006865432684891629, 'holdout_accuracy': 0.878133102852204, 'holdout_bal_acc': 0.8783437320711418, 'holdout_precision': 0.8436018957345972, 'holdout_recall': 0.9270833333333334, 'holdout_f1': 0.8833746898263027, 'holdout_roc_auc': 0.9595046854082998, 'holdout_gmean': np.float64(0.8769904007099873)}
# {'feature_set': 'embeddings', 'variant': 'scaled', 'model': 'LinearSVC', 'tuned_parameters': '{"clf__C": 0.1}', 'clf_parameters': '{"C": 0.1, "class_weight": "balanced", "dual": "auto", "fit_intercept": true, "intercept_scaling": 1, "loss": "squared_hinge", "max_iter": 20000, "multi_class": "ovr", "penalty": "l2", "random_state": 1618, "tol": 0.0001, "verbose": 0}', 'cv_accuracy_mean': 0.8856482400326893, 'cv_balanced_accuracy_mean': 0.8857000131153372, 'cv_precision_mean': 0.8775532289408752, 'cv_recall_mean': 0.8953701782514383, 'cv_f1_mean': 0.8862609019558925, 'cv_roc_auc_mean': 0.9542783195729824, 'cv_gmean_mean': 0.8855754000405494, 'cv_accuracy_std': 0.005486805868120666, 'cv_balanced_accuracy_std': 0.005529683735643356, 'cv_precision_std': 0.006332005061581503, 'cv_recall_std': 0.015637496358277728, 'cv_f1_std': 0.006311113934119589, 'cv_roc_auc_std': 0.0011285661124450946, 'cv_gmean_std': 0.00542271475707766, 'holdout_accuracy': 0.8755401901469317, 'holdout_bal_acc': 0.8756798025435074, 'holdout_precision': 0.8517915309446255, 'holdout_recall': 0.9079861111111112, 'holdout_f1': 0.8789915966386554, 'holdout_roc_auc': 0.9557246844520941, 'holdout_gmean': np.float64(0.8750836640055458)}
# {'feature_set': 'embeddings', 'variant': 'scaled', 'model': 'SVC-RBF', 'tuned_parameters': '{"clf__C": 1.0, "clf__gamma": "scale"}', 'clf_parameters': '{"C": 1.0, "break_ties": false, "cache_size": 200, "class_weight": "balanced", "coef0": 0.0, "decision_function_shape": "ovr", "degree": 3, "gamma": "scale", "kernel": "rbf", "max_iter": -1, "probability": false, "random_state": 1618, "shrinking": true, "tol": 0.001, "verbose": false}', 'cv_accuracy_mean': 0.8975377969762419, 'cv_balanced_accuracy_mean': 0.8976545064882716, 'cv_precision_mean': 0.8775647805487845, 'cv_recall_mean': 0.9231547675186269, 'cv_f1_mean': 0.8996931786835372, 'cv_roc_auc_mean': 0.9634034948798081, 'cv_gmean_mean': 0.8972307465946112, 'cv_accuracy_std': 0.009182745827899543, 'cv_balanced_accuracy_std': 0.00918159170284303, 'cv_precision_std': 0.01129441506274299, 'cv_recall_std': 0.014181098186895344, 'cv_f1_std': 0.00910385477178731, 'cv_roc_auc_std': 0.0031456135899577877, 'cv_gmean_std': 0.009224940796004952, 'holdout_accuracy': 0.8893690579083837, 'holdout_bal_acc': 0.8895612210747753, 'holdout_precision': 0.856687898089172, 'holdout_recall': 0.9340277777777778, 'holdout_f1': 0.893687707641196, 'holdout_roc_auc': 0.9632189472174411, 'holdout_gmean': np.float64(0.8884491495718952)}
# {'feature_set': 'embeddings', 'variant': 'scaled', 'model': 'SGD-Hinge', 'tuned_parameters': '{}', 'clf_parameters': '{"alpha": 0.0001, "average": false, "class_weight": "balanced", "early_stopping": false, "epsilon": 0.1, "eta0": 0.01, "fit_intercept": true, "l1_ratio": 0.15, "learning_rate": "optimal", "loss": "hinge", "max_iter": 20000, "n_iter_no_change": 5, "n_jobs": null, "penalty": "l2", "power_t": 0.5, "random_state": 1618, "shuffle": true, "tol": 0.001, "validation_fraction": 0.1, "verbose": 0, "warm_start": false}', 'cv_accuracy_mean': 0.8711617535462028, 'cv_balanced_accuracy_mean': 0.8711606263903245, 'cv_precision_mean': 0.8729033441640304, 'cv_recall_mean': 0.868009054041309, 'cv_f1_mean': 0.8702773463424487, 'cv_roc_auc_mean': 0.9435683310118783, 'cv_gmean_mean': 0.8710439878678023, 'cv_accuracy_std': 0.0036209751890953833, 'cv_balanced_accuracy_std': 0.0035717237715257957, 'cv_precision_std': 0.013358299927935517, 'cv_recall_std': 0.011563187963174563, 'cv_f1_std': 0.0026405249750484647, 'cv_roc_auc_std': 0.004401149234200024, 'cv_gmean_std': 0.0036094466578910035, 'holdout_accuracy': 0.8556611927398444, 'holdout_bal_acc': 0.8557444061962134, 'holdout_precision': 0.8414023372287145, 'holdout_recall': 0.875, 'holdout_f1': 0.857872340425532, 'holdout_roc_auc': 0.9366782606616944, 'holdout_gmean': np.float64(0.8555277382080452)}
# {'feature_set': 'embeddings', 'variant': 'scaled', 'model': 'KNN', 'tuned_parameters': '{"clf__n_neighbors": 11}', 'clf_parameters': '{"algorithm": "auto", "leaf_size": 30, "metric": "minkowski", "metric_params": null, "n_jobs": null, "n_neighbors": 11, "p": 2, "weights": "uniform"}', 'cv_accuracy_mean': 0.8471675909170509, 'cv_balanced_accuracy_mean': 0.8475272270449338, 'cv_precision_mean': 0.7975190023681236, 'cv_recall_mean': 0.9292294633594265, 'cv_f1_mean': 0.8582595925496092, 'cv_roc_auc_mean': 0.9288192575044084, 'cv_gmean_mean': 0.8434885255304445, 'cv_accuracy_std': 0.005425660305686698, 'cv_balanced_accuracy_std': 0.0053361588623286734, 'cv_precision_std': 0.01038808828555625, 'cv_recall_std': 0.008017563006884932, 'cv_f1_std': 0.0038423134049044615, 'cv_roc_auc_std': 0.0037263197554363975, 'cv_gmean_std': 0.006406022904006382, 'holdout_accuracy': 0.8340535868625756, 'holdout_bal_acc': 0.8345061794798241, 'holdout_precision': 0.7750716332378224, 'holdout_recall': 0.9392361111111112, 'holdout_f1': 0.8492935635792779, 'holdout_roc_auc': 0.92276247848537, 'holdout_gmean': np.float64(0.8279083312846406)}
# {'feature_set': 'embeddings', 'variant': 'scaled', 'model': 'DecisionTree', 'tuned_parameters': '{}', 'clf_parameters': '{"ccp_alpha": 0.0, "class_weight": "balanced", "criterion": "gini", "max_depth": null, "max_features": null, "max_leaf_nodes": null, "min_impurity_decrease": 0.0, "min_samples_leaf": 1, "min_samples_split": 2, "min_weight_fraction_leaf": 0.0, "monotonic_cst": null, "random_state": 1618, "splitter": "best"}', 'cv_accuracy_mean': 0.7248116280427296, 'cv_balanced_accuracy_mean': 0.7248193504797529, 'cv_precision_mean': 0.7232742318370432, 'cv_recall_mean': 0.7251475997359238, 'cv_f1_mean': 0.7240514774505276, 'cv_roc_auc_mean': 0.7248193504797529, 'cv_gmean_mean': 0.7246723948026471, 'cv_accuracy_std': 0.011795181073483934, 'cv_balanced_accuracy_std': 0.011763194688539216, 'cv_precision_std': 0.015959729059891944, 'cv_recall_std': 0.014630237614520118, 'cv_f1_std': 0.010953545233644186, 'cv_roc_auc_std': 0.011763194688539175, 'cv_gmean_std': 0.01176839708269099, 'holdout_accuracy': 0.7320656871218669, 'holdout_bal_acc': 0.7321577978580991, 'holdout_precision': 0.7209302325581395, 'holdout_recall': 0.7534722222222222, 'holdout_f1': 0.7368421052631579, 'holdout_roc_auc': 0.7321577978580991, 'holdout_gmean': np.float64(0.7318474815686989)}
# {'feature_set': 'embeddings', 'variant': 'scaled', 'model': 'RandomForest', 'tuned_parameters': '{"clf__max_depth": null, "clf__n_estimators": 300}', 'clf_parameters': '{"bootstrap": true, "ccp_alpha": 0.0, "class_weight": "balanced", "criterion": "gini", "max_depth": null, "max_features": "sqrt", "max_leaf_nodes": null, "max_samples": null, "min_impurity_decrease": 0.0, "min_samples_leaf": 1, "min_samples_split": 2, "min_weight_fraction_leaf": 0.0, "monotonic_cst": null, "n_estimators": 300, "n_jobs": null, "oob_score": false, "random_state": 1618, "verbose": 0, "warm_start": false}', 'cv_accuracy_mean': 0.86921837604343, 'cv_balanced_accuracy_mean': 0.8693854682500609, 'cv_precision_mean': 0.8429342989814188, 'cv_recall_mean': 0.906220880882769, 'cv_f1_mean': 0.8733720527623436, 'cv_roc_auc_mean': 0.940888714221715, 'cv_gmean_mean': 0.8685616576605257, 'cv_accuracy_std': 0.009800757729959475, 'cv_balanced_accuracy_std': 0.00982653228368929, 'cv_precision_std': 0.009118137466127923, 'cv_recall_std': 0.015367726770458525, 'cv_f1_std': 0.009917837159027727, 'cv_roc_auc_std': 0.005603861731588589, 'cv_gmean_std': 0.009691962432649847, 'holdout_accuracy': 0.8582541054451167, 'holdout_bal_acc': 0.8584755689424364, 'holdout_precision': 0.8238993710691824, 'holdout_recall': 0.9097222222222222, 'holdout_f1': 0.8646864686468647, 'holdout_roc_auc': 0.9344446237330273, 'holdout_gmean': np.float64(0.8569446207303372)}
# {'feature_set': 'embeddings', 'variant': 'scaled', 'model': 'ExtraTrees', 'tuned_parameters': '{"clf__max_depth": 20, "clf__n_estimators": 300}', 'clf_parameters': '{"bootstrap": false, "ccp_alpha": 0.0, "class_weight": "balanced", "criterion": "gini", "max_depth": 20, "max_features": "sqrt", "max_leaf_nodes": null, "max_samples": null, "min_impurity_decrease": 0.0, "min_samples_leaf": 1, "min_samples_split": 2, "min_weight_fraction_leaf": 0.0, "monotonic_cst": null, "n_estimators": 300, "n_jobs": null, "oob_score": false, "random_state": 1618, "verbose": 0, "warm_start": false}', 'cv_accuracy_mean': 0.8681361274881793, 'cv_balanced_accuracy_mean': 0.8683377700101037, 'cv_precision_mean': 0.8369451602228427, 'cv_recall_mean': 0.913166085070263, 'cv_f1_mean': 0.8733324305879959, 'cv_roc_auc_mean': 0.9437898463213289, 'cv_gmean_mean': 0.867131179804052, 'cv_accuracy_std': 0.00918005006022171, 'cv_balanced_accuracy_std': 0.009186447379539659, 'cv_precision_std': 0.010389179321547952, 'cv_recall_std': 0.012961568101189546, 'cv_f1_std': 0.008903224905814647, 'cv_roc_auc_std': 0.004821191822340401, 'cv_gmean_std': 0.009210820325823007, 'holdout_accuracy': 0.8643042350907519, 'holdout_bal_acc': 0.8645444874737043, 'holdout_precision': 0.8268330733229329, 'holdout_recall': 0.9201388888888888, 'holdout_f1': 0.8709942481511914, 'holdout_roc_auc': 0.9375926324345, 'holdout_gmean': np.float64(0.8627551410176919)}
# {'feature_set': 'embeddings', 'variant': 'scaled', 'model': 'GradientBoosting', 'tuned_parameters': '{}', 'clf_parameters': '{"ccp_alpha": 0.0, "criterion": "friedman_mse", "init": null, "learning_rate": 0.1, "loss": "log_loss", "max_depth": 3, "max_features": null, "max_leaf_nodes": null, "min_impurity_decrease": 0.0, "min_samples_leaf": 1, "min_samples_split": 2, "min_weight_fraction_leaf": 0.0, "n_estimators": 100, "n_iter_no_change": null, "random_state": 1618, "subsample": 1.0, "tol": 0.0001, "validation_fraction": 0.1, "verbose": 0, "warm_start": false}', 'cv_accuracy_mean': 0.8696503414861947, 'cv_balanced_accuracy_mean': 0.8697744515189051, 'cv_precision_mean': 0.8498326104492717, 'cv_recall_mean': 0.896667924172404, 'cv_f1_mean': 0.8725557345707472, 'cv_roc_auc_mean': 0.9412665084783198, 'cv_gmean_mean': 0.8693123592964511, 'cv_accuracy_std': 0.007436337591004616, 'cv_balanced_accuracy_std': 0.007467752679623887, 'cv_precision_std': 0.006489370059633005, 'cv_recall_std': 0.014621894688247731, 'cv_f1_std': 0.007918295586498439, 'cv_roc_auc_std': 0.006450057230665839, 'cv_gmean_std': 0.007306261121894411, 'holdout_accuracy': 0.867761452031115, 'holdout_bal_acc': 0.867934535762096, 'holdout_precision': 0.8394863563402889, 'holdout_recall': 0.9079861111111112, 'holdout_f1': 0.872393661384487, 'holdout_roc_auc': 0.9379810910307899, 'holdout_gmean': np.float64(0.8670099363217398)}
# {'feature_set': 'embeddings', 'variant': 'scaled', 'model': 'HistGB', 'tuned_parameters': '{"clf__max_depth": 6}', 'clf_parameters': '{"categorical_features": "from_dtype", "class_weight": null, "early_stopping": "auto", "interaction_cst": null, "l2_regularization": 0.0, "learning_rate": 0.1, "loss": "log_loss", "max_bins": 255, "max_depth": 6, "max_features": 1.0, "max_iter": 100, "max_leaf_nodes": 31, "min_samples_leaf": 20, "monotonic_cst": null, "n_iter_no_change": 10, "random_state": 1618, "scoring": "loss", "tol": 1e-07, "validation_fraction": 0.1, "verbose": 0, "warm_start": false}', 'cv_accuracy_mean': 0.8793775027727511, 'cv_balanced_accuracy_mean': 0.8794948088722416, 'cv_precision_mean': 0.8606632655255766, 'cv_recall_mean': 0.9044864660945015, 'cv_f1_mean': 0.8818772653940407, 'cv_roc_auc_mean': 0.9473105197803451, 'cv_gmean_mean': 0.8790322889214472, 'cv_accuracy_std': 0.009537009596051709, 'cv_balanced_accuracy_std': 0.009532994144796789, 'cv_precision_std': 0.014082869185262166, 'cv_recall_std': 0.015751620796402653, 'cv_f1_std': 0.009275057879503945, 'cv_roc_auc_std': 0.004738496930305155, 'cv_gmean_std': 0.009584042417214556, 'holdout_accuracy': 0.8738115816767502, 'holdout_bal_acc': 0.8739661025052592, 'holdout_precision': 0.8478964401294499, 'holdout_recall': 0.9097222222222222, 'holdout_f1': 0.8777219430485762, 'holdout_roc_auc': 0.9456157965194109, 'holdout_gmean': np.float64(0.8732343604273822)}
# {'feature_set': 'embeddings', 'variant': 'scaled', 'model': 'AdaBoost', 'tuned_parameters': '{}', 'clf_parameters': '{"estimator": null, "learning_rate": 1.0, "n_estimators": 50, "random_state": 1618}', 'cv_accuracy_mean': 0.8322531083999767, 'cv_balanced_accuracy_mean': 0.8322596467143238, 'cv_precision_mean': 0.8314708214412733, 'cv_recall_mean': 0.8319683108554183, 'cv_f1_mean': 0.8316126893809604, 'cv_roc_auc_mean': 0.9105234141203837, 'cv_gmean_mean': 0.8321870496615619, 'cv_accuracy_std': 0.007580957777044203, 'cv_balanced_accuracy_std': 0.007570880479280331, 'cv_precision_std': 0.012781535609486722, 'cv_recall_std': 0.01088612422480386, 'cv_f1_std': 0.007075382314706439, 'cv_roc_auc_std': 0.003810925496290788, 'cv_gmean_std': 0.007498295966265932, 'holdout_accuracy': 0.8254105445116681, 'holdout_bal_acc': 0.8256239242685026, 'holdout_precision': 0.7949526813880127, 'holdout_recall': 0.875, 'holdout_f1': 0.8330578512396695, 'holdout_roc_auc': 0.9040148689998087, 'holdout_gmean': np.float64(0.824146144485236)}
# {'feature_set': 'embeddings', 'variant': 'scaled', 'model': 'GaussianNaiveBayes', 'tuned_parameters': '{}', 'clf_parameters': '{"priors": null, "var_smoothing": 1e-09}', 'cv_accuracy_mean': 0.8300918802171502, 'cv_balanced_accuracy_mean': 0.8303955722789365, 'cv_precision_mean': 0.7895925648784148, 'cv_recall_mean': 0.8988371215693671, 'cv_f1_mean': 0.8404999366906276, 'cv_roc_auc_mean': 0.8917653518073376, 'cv_gmean_mean': 0.8273875003603719, 'cv_accuracy_std': 0.011142427454634165, 'cv_balanced_accuracy_std': 0.011101192865389091, 'cv_precision_std': 0.0163047988046627, 'cv_recall_std': 0.013703615417600193, 'cv_f1_std': 0.009254043505668007, 'cv_roc_auc_std': 0.004763159051265269, 'cv_gmean_std': 0.012063846296500091, 'holdout_accuracy': 0.8184961106309421, 'holdout_bal_acc': 0.8189260016255498, 'holdout_precision': 0.7644508670520231, 'holdout_recall': 0.9184027777777778, 'holdout_f1': 0.8343848580441641, 'holdout_roc_auc': 0.8884825014343087, 'holdout_gmean': np.float64(0.8128617146506345)}
# {'feature_set': 'tfidf_10000_1_2', 'variant': 'raw', 'model': 'LogisticRegression', 'tuned_parameters': '{"clf__C": 1.0}', 'clf_parameters': '{"C": 1.0, "class_weight": "balanced", "dual": false, "fit_intercept": true, "intercept_scaling": 1, "l1_ratio": 0.0, "max_iter": 20000, "n_jobs": null, "penalty": "deprecated", "random_state": 1618, "solver": "lbfgs", "tol": 0.0001, "verbose": 0, "warm_start": false}', 'cv_accuracy_mean': 0.9223951900064211, 'cv_balanced_accuracy_mean': 0.9224476738958909, 'cv_precision_mean': 0.9123906701720885, 'cv_recall_mean': 0.9340054701499575, 'cv_f1_mean': 0.9229784478441004, 'cv_roc_auc_mean': 0.9750493069363436, 'cv_gmean_mean': 0.9223193548423296, 'cv_accuracy_std': 0.0042910540405774284, 'cv_balanced_accuracy_std': 0.004280820431590257, 'cv_precision_std': 0.010001528262569077, 'cv_recall_std': 0.010285499574575217, 'cv_f1_std': 0.004172711125896106, 'cv_roc_auc_std': 0.0013476011266536684, 'cv_gmean_std': 0.004321230023933543, 'holdout_accuracy': 0.9135695764909249, 'holdout_bal_acc': 0.9137397805507745, 'holdout_precision': 0.882636655948553, 'holdout_recall': 0.953125, 'holdout_f1': 0.9165275459098498, 'holdout_roc_auc': 0.9763936699177663, 'holdout_gmean': np.float64(0.9128905690442387)}
# {'feature_set': 'tfidf_10000_1_2', 'variant': 'raw', 'model': 'RidgeClassifier', 'tuned_parameters': '{}', 'clf_parameters': '{"alpha": 1.0, "class_weight": "balanced", "copy_X": true, "fit_intercept": true, "max_iter": null, "positive": false, "random_state": 1618, "solver": "auto", "tol": 0.0001}', 'cv_accuracy_mean': 0.9269331621037884, 'cv_balanced_accuracy_mean': 0.9269927358324196, 'cv_precision_mean': 0.9160830962591294, 'cv_recall_mean': 0.939650099028577, 'cv_f1_mean': 0.9275882747117958, 'cv_roc_auc_mean': 0.9783794977817228, 'cv_gmean_mean': 0.9268288711918686, 'cv_accuracy_std': 0.004433039326159804, 'cv_balanced_accuracy_std': 0.0043910649464087405, 'cv_precision_std': 0.013479645630841267, 'cv_recall_std': 0.009217258409125292, 'cv_f1_std': 0.0038451891728460315, 'cv_roc_auc_std': 0.0018629342807407532, 'cv_gmean_std': 0.004467117385651538, 'holdout_accuracy': 0.9187554019014693, 'holdout_bal_acc': 0.9189107620960031, 'holdout_precision': 0.889967637540453, 'holdout_recall': 0.9548611111111112, 'holdout_f1': 0.9212730318257957, 'holdout_roc_auc': 0.9783150458978772, 'holdout_gmean': np.float64(0.9182072538929047)}
# {'feature_set': 'tfidf_10000_1_2', 'variant': 'raw', 'model': 'LinearSVC', 'tuned_parameters': '{"clf__C": 0.5}', 'clf_parameters': '{"C": 0.5, "class_weight": "balanced", "dual": "auto", "fit_intercept": true, "intercept_scaling": 1, "loss": "squared_hinge", "max_iter": 20000, "multi_class": "ovr", "penalty": "l2", "random_state": 1618, "tol": 0.0001, "verbose": 0}', 'cv_accuracy_mean': 0.9252055338275641, 'cv_balanced_accuracy_mean': 0.9252606383027085, 'cv_precision_mean': 0.9150094265399897, 'cv_recall_mean': 0.937046119022918, 'cv_f1_mean': 0.9257742815282297, 'cv_roc_auc_mean': 0.9781777580351243, 'cv_gmean_mean': 0.9251117301219036, 'cv_accuracy_std': 0.0012499112589143444, 'cv_balanced_accuracy_std': 0.0012358728525812771, 'cv_precision_std': 0.00975309730523804, 'cv_recall_std': 0.011692487517630176, 'cv_f1_std': 0.0014852357843694447, 'cv_roc_auc_std': 0.001669825674056661, 'cv_gmean_std': 0.0013002798750073941, 'holdout_accuracy': 0.9265341400172861, 'holdout_bal_acc': 0.9266933806655192, 'holdout_precision': 0.8966074313408724, 'holdout_recall': 0.9635416666666666, 'holdout_f1': 0.9288702928870293, 'holdout_roc_auc': 0.978321022183974, 'holdout_gmean': np.float64(0.9259604881354639)}
# {'feature_set': 'tfidf_10000_1_2', 'variant': 'raw', 'model': 'SVC-RBF', 'tuned_parameters': '{"clf__C": 1.0, "clf__gamma": "scale"}', 'clf_parameters': '{"C": 1.0, "break_ties": false, "cache_size": 200, "class_weight": "balanced", "coef0": 0.0, "decision_function_shape": "ovr", "degree": 3, "gamma": "scale", "kernel": "rbf", "max_iter": -1, "probability": false, "random_state": 1618, "shrinking": true, "tol": 0.001, "verbose": false}', 'cv_accuracy_mean': 0.9299604226256495, 'cv_balanced_accuracy_mean': 0.9300104566008228, 'cv_precision_mean': 0.9199480709782855, 'cv_recall_mean': 0.9413816844289352, 'cv_f1_mean': 0.9304946494789139, 'cv_roc_auc_mean': 0.978233965988806, 'cv_gmean_mean': 0.9299127175177639, 'cv_accuracy_std': 0.005452305344040134, 'cv_balanced_accuracy_std': 0.005423622831898707, 'cv_precision_std': 0.010514154420090308, 'cv_recall_std': 0.004936145961945751, 'cv_f1_std': 0.005064278040788578, 'cv_roc_auc_std': 0.001958978830709442, 'cv_gmean_std': 0.005496897101220027, 'holdout_accuracy': 0.9230769230769231, 'holdout_bal_acc': 0.9232510398737808, 'holdout_precision': 0.8908507223113965, 'holdout_recall': 0.9635416666666666, 'holdout_f1': 0.9257714762301918, 'holdout_roc_auc': 0.9797314257028112, 'holdout_gmean': np.float64(0.922371480489642)}
# {'feature_set': 'tfidf_10000_1_2', 'variant': 'raw', 'model': 'SGD-Hinge', 'tuned_parameters': '{}', 'clf_parameters': '{"alpha": 0.0001, "average": false, "class_weight": "balanced", "early_stopping": false, "epsilon": 0.1, "eta0": 0.01, "fit_intercept": true, "l1_ratio": 0.15, "learning_rate": "optimal", "loss": "hinge", "max_iter": 20000, "n_iter_no_change": 5, "n_jobs": null, "penalty": "l2", "power_t": 0.5, "random_state": 1618, "shuffle": true, "tol": 0.001, "validation_fraction": 0.1, "verbose": 0, "warm_start": false}', 'cv_accuracy_mean': 0.9182877823828148, 'cv_balanced_accuracy_mean': 0.9183359435494625, 'cv_precision_mean': 0.9093164030796526, 'cv_recall_mean': 0.9287909082335188, 'cv_f1_mean': 0.9188109634833801, 'cv_roc_auc_mean': 0.9745690738179997, 'cv_gmean_mean': 0.9181904142698052, 'cv_accuracy_std': 0.0054549607407483975, 'cv_balanced_accuracy_std': 0.005435061649617977, 'cv_precision_std': 0.012284776005474365, 'cv_recall_std': 0.012752863727552233, 'cv_f1_std': 0.00538671605609761, 'cv_roc_auc_std': 0.00233856563308093, 'cv_gmean_std': 0.005492028178213658, 'holdout_accuracy': 0.9222126188418324, 'holdout_bal_acc': 0.9223232214572576, 'holdout_precision': 0.900990099009901, 'holdout_recall': 0.9479166666666666, 'holdout_f1': 0.9238578680203046, 'holdout_roc_auc': 0.9758438515968636, 'holdout_gmean': np.float64(0.9219680582328253)}
# {'feature_set': 'tfidf_10000_1_2', 'variant': 'raw', 'model': 'KNN', 'tuned_parameters': '{"clf__n_neighbors": 11}', 'clf_parameters': '{"algorithm": "auto", "leaf_size": 30, "metric": "minkowski", "metric_params": null, "n_jobs": null, "n_neighbors": 11, "p": 2, "weights": "uniform"}', 'cv_accuracy_mean': 0.8971046640593077, 'cv_balanced_accuracy_mean': 0.8972758325546485, 'cv_precision_mean': 0.8683011514016883, 'cv_recall_mean': 0.9353154767518628, 'cv_f1_mean': 0.9004472623494651, 'cv_roc_auc_mean': 0.9580632140458354, 'cv_gmean_mean': 0.8963897472804264, 'cv_accuracy_std': 0.005330163689420166, 'cv_balanced_accuracy_std': 0.005390262856152893, 'cv_precision_std': 0.0057428660635001575, 'cv_recall_std': 0.016564230185142588, 'cv_f1_std': 0.0060140270360607906, 'cv_roc_auc_std': 0.005049196084646498, 'cv_gmean_std': 0.005005347679817591, 'holdout_accuracy': 0.88504753673293, 'holdout_bal_acc': 0.8853031172308281, 'holdout_precision': 0.8434108527131783, 'holdout_recall': 0.9444444444444444, 'holdout_f1': 0.8910728910728911, 'holdout_roc_auc': 0.9617009705488622, 'holdout_gmean': np.float64(0.8833254851944629)}
# {'feature_set': 'tfidf_10000_1_2', 'variant': 'raw', 'model': 'DecisionTree', 'tuned_parameters': '{}', 'clf_parameters': '{"ccp_alpha": 0.0, "class_weight": "balanced", "criterion": "gini", "max_depth": null, "max_features": null, "max_leaf_nodes": null, "min_impurity_decrease": 0.0, "min_samples_leaf": 1, "min_samples_split": 2, "min_weight_fraction_leaf": 0.0, "monotonic_cst": null, "random_state": 1618, "splitter": "best"}', 'cv_accuracy_mean': 0.8501929834802404, 'cv_balanced_accuracy_mean': 0.850190736623851, 'cv_precision_mean': 0.8495723530511198, 'cv_recall_mean': 0.8497585588984249, 'cv_f1_mean': 0.8495339426153438, 'cv_roc_auc_mean': 0.850190736623851, 'cv_gmean_mean': 0.8500990388851729, 'cv_accuracy_std': 0.007349727921707245, 'cv_balanced_accuracy_std': 0.007363372267153137, 'cv_precision_std': 0.010418299098892617, 'cv_recall_std': 0.015539233891008402, 'cv_f1_std': 0.00800923779051277, 'cv_roc_auc_std': 0.007363372267153165, 'cv_gmean_std': 0.007400014141749469, 'holdout_accuracy': 0.8418323249783924, 'holdout_bal_acc': 0.8417957544463568, 'holdout_precision': 0.8465608465608465, 'holdout_recall': 0.8333333333333334, 'holdout_f1': 0.8398950131233596, 'holdout_roc_auc': 0.8417957544463568, 'holdout_gmean': np.float64(0.8417532177739607)}
# {'feature_set': 'tfidf_10000_1_2', 'variant': 'raw', 'model': 'RandomForest', 'tuned_parameters': '{"clf__max_depth": null, "clf__n_estimators": 300}', 'clf_parameters': '{"bootstrap": true, "ccp_alpha": 0.0, "class_weight": "balanced", "criterion": "gini", "max_depth": null, "max_features": "sqrt", "max_leaf_nodes": null, "max_samples": null, "min_impurity_decrease": 0.0, "min_samples_leaf": 1, "min_samples_split": 2, "min_weight_fraction_leaf": 0.0, "monotonic_cst": null, "n_estimators": 300, "n_jobs": null, "oob_score": false, "random_state": 1618, "verbose": 0, "warm_start": false}', 'cv_accuracy_mean': 0.9118010624014945, 'cv_balanced_accuracy_mean': 0.9119073230510907, 'cv_precision_mean': 0.8926824067978234, 'cv_recall_mean': 0.935742714326134, 'cv_f1_mean': 0.9135692285200501, 'cv_roc_auc_mean': 0.9734422404814665, 'cv_gmean_mean': 0.9115057568071305, 'cv_accuracy_std': 0.008351934495833477, 'cv_balanced_accuracy_std': 0.008319896953280191, 'cv_precision_std': 0.015727332630552503, 'cv_recall_std': 0.010379026611974703, 'cv_f1_std': 0.007595224141668539, 'cv_roc_auc_std': 0.0025318796799948824, 'cv_gmean_std': 0.00850845433525312, 'holdout_accuracy': 0.909248055315471, 'holdout_bal_acc': 0.9094443249187225, 'holdout_precision': 0.8744038155802861, 'holdout_recall': 0.9548611111111112, 'holdout_f1': 0.9128630705394191, 'holdout_roc_auc': 0.9707983720596671, 'holdout_gmean': np.float64(0.9083095813976784)}
# {'feature_set': 'tfidf_10000_1_2', 'variant': 'raw', 'model': 'ExtraTrees', 'tuned_parameters': '{"clf__max_depth": null, "clf__n_estimators": 300}', 'clf_parameters': '{"bootstrap": false, "ccp_alpha": 0.0, "class_weight": "balanced", "criterion": "gini", "max_depth": null, "max_features": "sqrt", "max_leaf_nodes": null, "max_samples": null, "min_impurity_decrease": 0.0, "min_samples_leaf": 1, "min_samples_split": 2, "min_weight_fraction_leaf": 0.0, "monotonic_cst": null, "n_estimators": 300, "n_jobs": null, "oob_score": false, "random_state": 1618, "verbose": 0, "warm_start": false}', 'cv_accuracy_mean': 0.9193679294845601, 'cv_balanced_accuracy_mean': 0.9194547388593156, 'cv_precision_mean': 0.903430165006905, 'cv_recall_mean': 0.9387861925870036, 'cv_f1_mean': 0.9206173987484177, 'cv_roc_auc_mean': 0.9768235471166523, 'cv_gmean_mean': 0.9191569287757646, 'cv_accuracy_std': 0.007792138983304547, 'cv_balanced_accuracy_std': 0.007780210334994396, 'cv_precision_std': 0.0150939244862276, 'cv_recall_std': 0.012336126236269885, 'cv_f1_std': 0.007250801683654929, 'cv_roc_auc_std': 0.002481072242383735, 'cv_gmean_std': 0.007879716471636182, 'holdout_accuracy': 0.9127052722558341, 'holdout_bal_acc': 0.912864254637598, 'holdout_precision': 0.8836833602584814, 'holdout_recall': 0.9496527777777778, 'holdout_f1': 0.9154811715481171, 'holdout_roc_auc': 0.9715767833237714, 'holdout_gmean': np.float64(0.9121226627818333)}
# {'feature_set': 'tfidf_10000_1_2', 'variant': 'raw', 'model': 'GradientBoosting', 'tuned_parameters': '{}', 'clf_parameters': '{"ccp_alpha": 0.0, "criterion": "friedman_mse", "init": null, "learning_rate": 0.1, "loss": "log_loss", "max_depth": 3, "max_features": null, "max_leaf_nodes": null, "min_impurity_decrease": 0.0, "min_samples_leaf": 1, "min_samples_split": 2, "min_weight_fraction_leaf": 0.0, "n_estimators": 100, "n_iter_no_change": null, "random_state": 1618, "subsample": 1.0, "tol": 0.0001, "validation_fraction": 0.1, "verbose": 0, "warm_start": false}', 'cv_accuracy_mean': 0.880242134142782, 'cv_balanced_accuracy_mean': 0.8803615808952288, 'cv_precision_mean': 0.8598994036231409, 'cv_recall_mean': 0.9075214561916438, 'cv_f1_mean': 0.8829627662337269, 'cv_roc_auc_mean': 0.9517234875582291, 'cv_gmean_mean': 0.879867718573041, 'cv_accuracy_std': 0.008685913595102233, 'cv_balanced_accuracy_std': 0.008699108506144663, 'cv_precision_std': 0.01134945793579845, 'cv_recall_std': 0.014510008005672537, 'cv_f1_std': 0.008524903872240756, 'cv_roc_auc_std': 0.004479155468433056, 'cv_gmean_std': 0.00869429415188299, 'holdout_accuracy': 0.874675885911841, 'holdout_bal_acc': 0.8749013912794034, 'holdout_precision': 0.8383045525902669, 'holdout_recall': 0.9270833333333334, 'holdout_f1': 0.8804616652926628, 'holdout_roc_auc': 0.947187559762861, 'holdout_gmean': np.float64(0.8733438551831209)}
# {'feature_set': 'tfidf_10000_1_2', 'variant': 'raw', 'model': 'HistGB', 'tuned_parameters': '{"clf__max_depth": null}', 'clf_parameters': '{"categorical_features": "from_dtype", "class_weight": null, "early_stopping": "auto", "interaction_cst": null, "l2_regularization": 0.0, "learning_rate": 0.1, "loss": "log_loss", "max_bins": 255, "max_depth": null, "max_features": 1.0, "max_iter": 100, "max_leaf_nodes": 31, "min_samples_leaf": 20, "monotonic_cst": null, "n_iter_no_change": 10, "random_state": 1618, "scoring": "loss", "tol": 1e-07, "validation_fraction": 0.1, "verbose": 0, "warm_start": false}', 'cv_accuracy_mean': 0.9120191465763821, 'cv_balanced_accuracy_mean': 0.9120620646222968, 'cv_precision_mean': 0.9035217204634589, 'cv_recall_mean': 0.9218438177874188, 'cv_f1_mean': 0.9125106019662084, 'cv_roc_auc_mean': 0.971962767007092, 'cv_gmean_mean': 0.9119606738259923, 'cv_accuracy_std': 0.0026962088383345965, 'cv_balanced_accuracy_std': 0.0027078630486312757, 'cv_precision_std': 0.007052736397887901, 'cv_recall_std': 0.010877742161985877, 'cv_f1_std': 0.003146211924776856, 'cv_roc_auc_std': 0.0022316379742382503, 'cv_gmean_std': 0.0026619300378786423, 'holdout_accuracy': 0.9083837510803803, 'holdout_bal_acc': 0.9085165065021993, 'holdout_precision': 0.8839869281045751, 'holdout_recall': 0.9392361111111112, 'holdout_f1': 0.9107744107744108, 'holdout_roc_auc': 0.9704890992541595, 'holdout_gmean': np.float64(0.9079969980565095)}
# ...
# {'feature_set': 'umap_200', 'variant': 'scaled', 'model': 'RidgeClassifier', 'tuned_parameters': '{}', 'clf_parameters': '{"alpha": 1.0, "class_weight": "balanced", "copy_X": true, "fit_intercept": true, "max_iter": null, "positive": false, "random_state": 1618, "solver": "auto", "tol": 0.0001}', 'cv_accuracy_mean': 0.8011210086976825, 'cv_balanced_accuracy_mean': 0.8013883432033196, 'cv_precision_mean': 0.7677799718826375, 'cv_recall_mean': 0.8610534754314816, 'cv_f1_mean': 0.8116559710221969, 'cv_roc_auc_mean': 0.8726912322650515, 'cv_gmean_mean': 0.7990814243791121, 'cv_accuracy_std': 0.011012481948234327, 'cv_balanced_accuracy_std': 0.011002837155728126, 'cv_precision_std': 0.01036778968630911, 'cv_recall_std': 0.01771506007887822, 'cv_f1_std': 0.01112092059956228, 'cv_roc_auc_std': 0.010449777663089242, 'cv_gmean_std': 0.01091265688297362, 'holdout_accuracy': 0.7813310285220397, 'holdout_bal_acc': 0.7816294941671448, 'holdout_precision': 0.745814307458143, 'holdout_recall': 0.8506944444444444, 'holdout_f1': 0.7948094079480941, 'holdout_roc_auc': 0.8531327691719257, 'holdout_gmean': np.float64(0.7785722180987328)}
# {'feature_set': 'umap_200', 'variant': 'scaled', 'model': 'LinearSVC', 'tuned_parameters': '{"clf__C": 1.0}', 'clf_parameters': '{"C": 1.0, "class_weight": "balanced", "dual": "auto", "fit_intercept": true, "intercept_scaling": 1, "loss": "squared_hinge", "max_iter": 20000, "multi_class": "ovr", "penalty": "l2", "random_state": 1618, "tol": 0.0001, "verbose": 0}', 'cv_accuracy_mean': 0.8067423968244702, 'cv_balanced_accuracy_mean': 0.8069647445712451, 'cv_precision_mean': 0.7774720096625459, 'cv_recall_mean': 0.8571423182118268, 'cv_f1_mean': 0.8153180313432129, 'cv_roc_auc_mean': 0.8780305524761935, 'cv_gmean_mean': 0.8053633245800593, 'cv_accuracy_std': 0.010119035161790722, 'cv_balanced_accuracy_std': 0.010117115718337427, 'cv_precision_std': 0.00852142469692535, 'cv_recall_std': 0.015623222744513788, 'cv_f1_std': 0.01042459749677047, 'cv_roc_auc_std': 0.009831384468424197, 'cv_gmean_std': 0.009932307160143006, 'holdout_accuracy': 0.7873811581676751, 'holdout_bal_acc': 0.7876162387645821, 'holdout_precision': 0.7578125, 'holdout_recall': 0.8420138888888888, 'holdout_f1': 0.7976973684210527, 'holdout_roc_auc': 0.8586548575253394, 'holdout_gmean': np.float64(0.785735474079299)}
# {'feature_set': 'umap_200', 'variant': 'scaled', 'model': 'SVC-RBF', 'tuned_parameters': '{"clf__C": 1.0, "clf__gamma": "scale"}', 'clf_parameters': '{"C": 1.0, "break_ties": false, "cache_size": 200, "class_weight": "balanced", "coef0": 0.0, "decision_function_shape": "ovr", "degree": 3, "gamma": "scale", "kernel": "rbf", "max_iter": -1, "probability": false, "random_state": 1618, "shrinking": true, "tol": 0.001, "verbose": false}', 'cv_accuracy_mean': 0.8127955168991885, 'cv_balanced_accuracy_mean': 0.8131366574340009, 'cv_precision_mean': 0.7699061832363545, 'cv_recall_mean': 0.8901433556540601, 'cv_f1_mean': 0.825608632814502, 'cv_roc_auc_mean': 0.8846746675818903, 'cv_gmean_mean': 0.8094183144264904, 'cv_accuracy_std': 0.016504869746809384, 'cv_balanced_accuracy_std': 0.016470986268101805, 'cv_precision_std': 0.015643457755307028, 'cv_recall_std': 0.018436205735998475, 'cv_f1_std': 0.01541496297151034, 'cv_roc_auc_std': 0.00887164834248273, 'cv_gmean_std': 0.016686046551085344, 'holdout_accuracy': 0.7830596369922213, 'holdout_bal_acc': 0.7835075420730542, 'holdout_precision': 0.733142037302726, 'holdout_recall': 0.8871527777777778, 'holdout_f1': 0.802827965435978, 'holdout_roc_auc': 0.8601788104800153, 'holdout_gmean': np.float64(0.7766220017492879)}
# {'feature_set': 'umap_200', 'variant': 'scaled', 'model': 'SGD-Hinge', 'tuned_parameters': '{}', 'clf_parameters': '{"alpha": 0.0001, "average": false, "class_weight": "balanced", "early_stopping": false, "epsilon": 0.1, "eta0": 0.01, "fit_intercept": true, "l1_ratio": 0.15, "learning_rate": "optimal", "loss": "hinge", "max_iter": 20000, "n_iter_no_change": 5, "n_jobs": null, "penalty": "l2", "power_t": 0.5, "random_state": 1618, "shuffle": true, "tol": 0.001, "validation_fraction": 0.1, "verbose": 0, "warm_start": false}', 'cv_accuracy_mean': 0.742105189422684, 'cv_balanced_accuracy_mean': 0.7422524948690024, 'cv_precision_mean': 0.7276994159913432, 'cv_recall_mean': 0.7755125907761954, 'cv_f1_mean': 0.7501986211909124, 'cv_roc_auc_mean': 0.8047037636804018, 'cv_gmean_mean': 0.7408014324807962, 'cv_accuracy_std': 0.03465709080790676, 'cv_balanced_accuracy_std': 0.034567106658944725, 'cv_precision_std': 0.043942713589502025, 'cv_recall_std': 0.021806008238897858, 'cv_f1_std': 0.028101469419192664, 'cv_roc_auc_std': 0.04412644140911336, 'cv_gmean_std': 0.035753260716881674, 'holdout_accuracy': 0.7147796024200519, 'holdout_bal_acc': 0.7149386235417863, 'holdout_precision': 0.6983870967741935, 'holdout_recall': 0.7517361111111112, 'holdout_f1': 0.7240802675585284, 'holdout_roc_auc': 0.7681440045897877, 'holdout_gmean': np.float64(0.7139910225909072)}
# {'feature_set': 'umap_200', 'variant': 'scaled', 'model': 'KNN', 'tuned_parameters': '{"clf__n_neighbors": 5}', 'clf_parameters': '{"algorithm": "auto", "leaf_size": 30, "metric": "minkowski", "metric_params": null, "n_jobs": null, "n_neighbors": 5, "p": 2, "weights": "uniform"}', 'cv_accuracy_mean': 0.8138779989492733, 'cv_balanced_accuracy_mean': 0.8140475222818232, 'cv_precision_mean': 0.7908351302420984, 'cv_recall_mean': 0.8515099500141471, 'cv_f1_mean': 0.8198159871360648, 'cv_roc_auc_mean': 0.880241880494222, 'cv_gmean_mean': 0.8129906224944043, 'cv_accuracy_std': 0.011949755039645339, 'cv_balanced_accuracy_std': 0.01198835571913077, 'cv_precision_std': 0.009782718171774729, 'cv_recall_std': 0.027032002849732138, 'cv_f1_std': 0.013618753405408841, 'cv_roc_auc_std': 0.011768163456116339, 'cv_gmean_std': 0.011498698049642398, 'holdout_accuracy': 0.808124459809853, 'holdout_bal_acc': 0.8084047499521897, 'holdout_precision': 0.7714723926380368, 'holdout_recall': 0.8732638888888888, 'holdout_f1': 0.8192182410423453, 'holdout_roc_auc': 0.8660012072097916, 'holdout_gmean': np.float64(0.8057986918838056)}
# {'feature_set': 'umap_200', 'variant': 'scaled', 'model': 'DecisionTree', 'tuned_parameters': '{}', 'clf_parameters': '{"ccp_alpha": 0.0, "class_weight": "balanced", "criterion": "gini", "max_depth": null, "max_features": null, "max_leaf_nodes": null, "min_impurity_decrease": 0.0, "min_samples_leaf": 1, "min_samples_split": 2, "min_weight_fraction_leaf": 0.0, "monotonic_cst": null, "random_state": 1618, "splitter": "best"}', 'cv_accuracy_mean': 0.7797237756114646, 'cv_balanced_accuracy_mean': 0.7797136150891036, 'cv_precision_mean': 0.7797589073073237, 'cv_recall_mean': 0.7768159954729794, 'cv_f1_mean': 0.7782084002322911, 'cv_roc_auc_mean': 0.7797136150891036, 'cv_gmean_mean': 0.7796465611277502, 'cv_accuracy_std': 0.013673524093984602, 'cv_balanced_accuracy_std': 0.013712183978613868, 'cv_precision_std': 0.010294456344575563, 'cv_recall_std': 0.022227302890764102, 'cv_f1_std': 0.015476538036703473, 'cv_roc_auc_std': 0.013712183978613858, 'cv_gmean_std': 0.013704294246102443, 'holdout_accuracy': 0.7467588591184097, 'holdout_bal_acc': 0.7468998015873016, 'holdout_precision': 0.7300813008130081, 'holdout_recall': 0.7795138888888888, 'holdout_f1': 0.7539882451721243, 'holdout_roc_auc': 0.7468998015873016, 'holdout_gmean': np.float64(0.7461873993311834)}
# {'feature_set': 'umap_200', 'variant': 'scaled', 'model': 'RandomForest', 'tuned_parameters': '{"clf__max_depth": 10, "clf__n_estimators": 600}', 'clf_parameters': '{"bootstrap": true, "ccp_alpha": 0.0, "class_weight": "balanced", "criterion": "gini", "max_depth": 10, "max_features": "sqrt", "max_leaf_nodes": null, "max_samples": null, "min_impurity_decrease": 0.0, "min_samples_leaf": 1, "min_samples_split": 2, "min_weight_fraction_leaf": 0.0, "monotonic_cst": null, "n_estimators": 600, "n_jobs": null, "oob_score": false, "random_state": 1618, "verbose": 0, "warm_start": false}', 'cv_accuracy_mean': 0.8316030587823245, 'cv_balanced_accuracy_mean': 0.831814480416359, 'cv_precision_mean': 0.8018322782113089, 'cv_recall_mean': 0.8788606998019428, 'cv_f1_mean': 0.8384536659536728, 'cv_roc_auc_mean': 0.9079314353739092, 'cv_gmean_mean': 0.8303834625462203, 'cv_accuracy_std': 0.018219145303391117, 'cv_balanced_accuracy_std': 0.018242443842171836, 'cv_precision_std': 0.013601810971214164, 'cv_recall_std': 0.028445485147474713, 'cv_f1_std': 0.018827612803264844, 'cv_roc_auc_std': 0.007990691880252756, 'cv_gmean_std': 0.01787488899751193, 'holdout_accuracy': 0.808124459809853, 'holdout_bal_acc': 0.8084869238860203, 'holdout_precision': 0.7626112759643917, 'holdout_recall': 0.8923611111111112, 'holdout_f1': 0.8224, 'holdout_roc_auc': 0.886477457448843, 'holdout_gmean': np.float64(0.8041245095207644)}
# {'feature_set': 'umap_200', 'variant': 'scaled', 'model': 'ExtraTrees', 'tuned_parameters': '{"clf__max_depth": 10, "clf__n_estimators": 300}', 'clf_parameters': '{"bootstrap": false, "ccp_alpha": 0.0, "class_weight": "balanced", "criterion": "gini", "max_depth": 10, "max_features": "sqrt", "max_leaf_nodes": null, "max_samples": null, "min_impurity_decrease": 0.0, "min_samples_leaf": 1, "min_samples_split": 2, "min_weight_fraction_leaf": 0.0, "monotonic_cst": null, "n_estimators": 300, "n_jobs": null, "oob_score": false, "random_state": 1618, "verbose": 0, "warm_start": false}', 'cv_accuracy_mean': 0.8300883777946414, 'cv_balanced_accuracy_mean': 0.8303170354330218, 'cv_precision_mean': 0.7986018879041646, 'cv_recall_mean': 0.8810289540696029, 'cv_f1_mean': 0.8377097895733879, 'cv_roc_auc_mean': 0.9059400440252899, 'cv_gmean_mean': 0.8286953648294573, 'cv_accuracy_std': 0.014995951578252934, 'cv_balanced_accuracy_std': 0.014982139999101527, 'cv_precision_std': 0.014634075019091721, 'cv_recall_std': 0.01895888227395319, 'cv_f1_std': 0.014557680312667546, 'cv_roc_auc_std': 0.007059534143249268, 'cv_gmean_std': 0.015049861191349826, 'holdout_accuracy': 0.8055315471045809, 'holdout_bal_acc': 0.8058902275769746, 'holdout_precision': 0.7607726597325408, 'holdout_recall': 0.8888888888888888, 'holdout_f1': 0.8198558847077662, 'holdout_roc_auc': 0.8820311005928475, 'holdout_gmean': np.float64(0.8016048160562024)}
# {'feature_set': 'umap_200', 'variant': 'scaled', 'model': 'GradientBoosting', 'tuned_parameters': '{}', 'clf_parameters': '{"ccp_alpha": 0.0, "criterion": "friedman_mse", "init": null, "learning_rate": 0.1, "loss": "log_loss", "max_depth": 3, "max_features": null, "max_leaf_nodes": null, "min_impurity_decrease": 0.0, "min_samples_leaf": 1, "min_samples_split": 2, "min_weight_fraction_leaf": 0.0, "n_estimators": 100, "n_iter_no_change": null, "random_state": 1618, "subsample": 1.0, "tol": 0.0001, "validation_fraction": 0.1, "verbose": 0, "warm_start": false}', 'cv_accuracy_mean': 0.8244693246161929, 'cv_balanced_accuracy_mean': 0.8247046807136632, 'cv_precision_mean': 0.7930416582926544, 'cv_recall_mean': 0.8762604923134962, 'cv_f1_mean': 0.8324280810137671, 'cv_roc_auc_mean': 0.9009407729047798, 'cv_gmean_mean': 0.8229636522134088, 'cv_accuracy_std': 0.014299109291481987, 'cv_balanced_accuracy_std': 0.014304658585421565, 'cv_precision_std': 0.013467271935945555, 'cv_recall_std': 0.02294052183922988, 'cv_f1_std': 0.014550190982719537, 'cv_roc_auc_std': 0.006123964059983756, 'cv_gmean_std': 0.014215104389269631, 'holdout_accuracy': 0.7968885047536733, 'holdout_bal_acc': 0.797209672021419, 'holdout_precision': 0.7571644042232277, 'holdout_recall': 0.8715277777777778, 'holdout_f1': 0.8103309120258273, 'holdout_roc_auc': 0.8762161742206923, 'holdout_gmean': np.float64(0.7937380426320041)}
# {'feature_set': 'umap_200', 'variant': 'scaled', 'model': 'HistGB', 'tuned_parameters': '{"clf__max_depth": 6}', 'clf_parameters': '{"categorical_features": "from_dtype", "class_weight": null, "early_stopping": "auto", "interaction_cst": null, "l2_regularization": 0.0, "learning_rate": 0.1, "loss": "log_loss", "max_bins": 255, "max_depth": 6, "max_features": 1.0, "max_iter": 100, "max_leaf_nodes": 31, "min_samples_leaf": 20, "monotonic_cst": null, "n_iter_no_change": 10, "random_state": 1618, "scoring": "loss", "tol": 1e-07, "validation_fraction": 0.1, "verbose": 0, "warm_start": false}', 'cv_accuracy_mean': 0.8290093981670654, 'cv_balanced_accuracy_mean': 0.82916984784845, 'cv_precision_mean': 0.8070002531612591, 'cv_recall_mean': 0.8632358766386872, 'cv_f1_mean': 0.8339664425309344, 'cv_roc_auc_mean': 0.9043125816299045, 'cv_gmean_mean': 0.828304387858253, 'cv_accuracy_std': 0.01389148349363047, 'cv_balanced_accuracy_std': 0.013901266845474835, 'cv_precision_std': 0.014050615091926904, 'cv_recall_std': 0.024477568537864425, 'cv_f1_std': 0.014549003483547722, 'cv_roc_auc_std': 0.007648696034481932, 'cv_gmean_std': 0.013804523117140874, 'holdout_accuracy': 0.8003457216940363, 'holdout_bal_acc': 0.8006893646012623, 'holdout_precision': 0.757847533632287, 'holdout_recall': 0.8802083333333334, 'holdout_f1': 0.8144578313253013, 'holdout_roc_auc': 0.8849848799961754, 'holdout_gmean': np.float64(0.7967309409062515)}
# {'feature_set': 'umap_200', 'variant': 'scaled', 'model': 'AdaBoost', 'tuned_parameters': '{}', 'clf_parameters': '{"estimator": null, "learning_rate": 1.0, "n_estimators": 50, "random_state": 1618}', 'cv_accuracy_mean': 0.784915533243827, 'cv_balanced_accuracy_mean': 0.785092581237196, 'cv_precision_mean': 0.7630498381528181, 'cv_recall_mean': 0.8241488258040178, 'cv_f1_mean': 0.792207846585573, 'cv_roc_auc_mean': 0.8574386568261598, 'cv_gmean_mean': 0.7839292036352103, 'cv_accuracy_std': 0.01520914451435934, 'cv_balanced_accuracy_std': 0.015209924022179326, 'cv_precision_std': 0.014795122110051122, 'cv_recall_std': 0.02551357846110233, 'cv_f1_std': 0.01578993094198209, 'cv_roc_auc_std': 0.00857936133389775, 'cv_gmean_std': 0.015153555010883946, 'holdout_accuracy': 0.7510803802938635, 'holdout_bal_acc': 0.7513745458022567, 'holdout_precision': 0.7195121951219512, 'holdout_recall': 0.8194444444444444, 'holdout_f1': 0.7662337662337663, 'holdout_roc_auc': 0.8249530861541403, 'holdout_gmean': np.float64(0.7482848367957149)}
# {'feature_set': 'umap_200', 'variant': 'scaled', 'model': 'GaussianNaiveBayes', 'tuned_parameters': '{}', 'clf_parameters': '{"priors": null, "var_smoothing": 1e-09}', 'cv_accuracy_mean': 0.6277569318778822, 'cv_balanced_accuracy_mean': 0.6270748448199104, 'cv_precision_mean': 0.6840940292189737, 'cv_recall_mean': 0.46895595586154853, 'cv_f1_mean': 0.5561361351870595, 'cv_roc_auc_mean': 0.7506351570383725, 'cv_gmean_mean': 0.6065345290933702, 'cv_accuracy_std': 0.004944859545783347, 'cv_balanced_accuracy_std': 0.005009187065665886, 'cv_precision_std': 0.003758836025029897, 'cv_recall_std': 0.021338998051795847, 'cv_f1_std': 0.014297515437547521, 'cv_roc_auc_std': 0.006458855030187196, 'cv_gmean_std': 0.009258515627705594, 'holdout_accuracy': 0.6101987899740708, 'holdout_bal_acc': 0.6095154427232741, 'holdout_precision': 0.6582278481012658, 'holdout_recall': 0.4513888888888889, 'holdout_f1': 0.5355303810504635, 'holdout_roc_auc': 0.7257273140179767, 'holdout_gmean': np.float64(0.588646810821744)}

# %%
print(f"Highest Accuracy: {final_results.sort_values(by='holdout_accuracy', ascending=False)['holdout_accuracy'].tolist()[0]}")
final_results.sort_values(by='holdout_accuracy', ascending=False).head()
# Out:
# Highest Accuracy: 0.9317199654278306
#          feature_set variant            model tuned_parameters  \
# 184  tfidf_20000_2_2     raw        LinearSVC  {"clf__C": 0.5}
# 80   tfidf_10000_2_2     raw        LinearSVC  {"clf__C": 1.0}
# 132  tfidf_20000_1_2     raw        LinearSVC  {"clf__C": 0.5}
# 79   tfidf_10000_2_2     raw  RidgeClassifier               {}
# 183  tfidf_20000_2_2     raw  RidgeClassifier               {}
#
#                                         clf_parameters  cv_accuracy_mean  \
# 184  {"C": 0.5, "class_weight": "balanced", "dual":...          0.931906
# 80   {"C": 1.0, "class_weight": "balanced", "dual":...          0.931474
# 132  {"C": 0.5, "class_weight": "balanced", "dual":...          0.925206
# 79   {"alpha": 1.0, "class_weight": "balanced", "co...          0.930825
# 183  {"alpha": 1.0, "class_weight": "balanced", "co...          0.931257
#
#      cv_balanced_accuracy_mean  cv_precision_mean  cv_recall_mean  cv_f1_mean  \
# 184                   0.931947           0.923962        0.940951    0.932259
# 80                    0.931514           0.923543        0.940516    0.931831
# 132                   0.925261           0.915009        0.937046    0.925774
# 79                    0.930872           0.921668        0.941384    0.931296
# 183                   0.931304           0.922073        0.941817    0.931726
#
#      ...  cv_f1_std  cv_roc_auc_std  cv_gmean_std  holdout_accuracy  \
# 184  ...   0.006595        0.001448      0.006853          0.931720
# 80   ...   0.006998        0.001624      0.007271          0.927398
# 132  ...   0.001485        0.001670      0.001300          0.926534
# 79   ...   0.008253        0.001625      0.008587          0.926534
# 183  ...   0.008108        0.001640      0.008437          0.926534
#
#      holdout_bal_acc  holdout_precision  holdout_recall  holdout_f1  \
# 184         0.931849           0.906710        0.961806    0.933446
# 80          0.927524           0.903279        0.956597    0.929174
# 132         0.926693           0.896607        0.963542    0.928870
# 79          0.926678           0.899187        0.960069    0.928631
# 183         0.926678           0.899187        0.960069    0.928631
#
#      holdout_roc_auc  holdout_gmean
# 184         0.979914       0.931368
# 80          0.979558       0.927068
# 132         0.978321       0.925960
# 79          0.979588       0.926077
# 183         0.979519       0.926077
#
# [5 rows x 26 columns]

# %%
print(f"Highest Balanced Accuracy: {final_results.sort_values(by='holdout_bal_acc', ascending=False)['holdout_bal_acc'].tolist()[0]}")
final_results.sort_values(by='holdout_bal_acc', ascending=False).head()
# Out:
# Highest Balanced Accuracy: 0.9318494214955059
#          feature_set variant            model tuned_parameters  \
# 184  tfidf_20000_2_2     raw        LinearSVC  {"clf__C": 0.5}
# 80   tfidf_10000_2_2     raw        LinearSVC  {"clf__C": 1.0}
# 28   tfidf_10000_1_2     raw        LinearSVC  {"clf__C": 0.5}
# 132  tfidf_20000_1_2     raw        LinearSVC  {"clf__C": 0.5}
# 183  tfidf_20000_2_2     raw  RidgeClassifier               {}
#
#                                         clf_parameters  cv_accuracy_mean  \
# 184  {"C": 0.5, "class_weight": "balanced", "dual":...          0.931906
# 80   {"C": 1.0, "class_weight": "balanced", "dual":...          0.931474
# 28   {"C": 0.5, "class_weight": "balanced", "dual":...          0.925206
# 132  {"C": 0.5, "class_weight": "balanced", "dual":...          0.925206
# 183  {"alpha": 1.0, "class_weight": "balanced", "co...          0.931257
#
#      cv_balanced_accuracy_mean  cv_precision_mean  cv_recall_mean  cv_f1_mean  \
# 184                   0.931947           0.923962        0.940951    0.932259
# 80                    0.931514           0.923543        0.940516    0.931831
# 28                    0.925261           0.915009        0.937046    0.925774
# 132                   0.925261           0.915009        0.937046    0.925774
# 183                   0.931304           0.922073        0.941817    0.931726
#
#      ...  cv_f1_std  cv_roc_auc_std  cv_gmean_std  holdout_accuracy  \
# 184  ...   0.006595        0.001448      0.006853          0.931720
# 80   ...   0.006998        0.001624      0.007271          0.927398
# 28   ...   0.001485        0.001670      0.001300          0.926534
# 132  ...   0.001485        0.001670      0.001300          0.926534
# 183  ...   0.008108        0.001640      0.008437          0.926534
#
#      holdout_bal_acc  holdout_precision  holdout_recall  holdout_f1  \
# 184         0.931849           0.906710        0.961806    0.933446
# 80          0.927524           0.903279        0.956597    0.929174
# 28          0.926693           0.896607        0.963542    0.928870
# 132         0.926693           0.896607        0.963542    0.928870
# 183         0.926678           0.899187        0.960069    0.928631
#
#      holdout_roc_auc  holdout_gmean
# 184         0.979914       0.931368
# 80          0.979558       0.927068
# 28          0.978321       0.925960
# 132         0.978321       0.925960
# 183         0.979519       0.926077
#
# [5 rows x 26 columns]

# %%
print(f"Highest Precision: {final_results.sort_values(by='holdout_precision', ascending=False)['holdout_precision'].tolist()[0]}")
final_results.sort_values(by='holdout_precision', ascending=False).head()
# Out:
# Highest Precision: 0.9106239460370995
#          feature_set variant               model tuned_parameters  \
# 91   tfidf_10000_2_2  scaled  LogisticRegression  {"clf__C": 0.1}
# 195  tfidf_20000_2_2  scaled  LogisticRegression  {"clf__C": 0.1}
# 184  tfidf_20000_2_2     raw           LinearSVC  {"clf__C": 0.5}
# 93   tfidf_10000_2_2  scaled           LinearSVC  {"clf__C": 0.1}
# 197  tfidf_20000_2_2  scaled           LinearSVC  {"clf__C": 0.1}
#
#                                         clf_parameters  cv_accuracy_mean  \
# 91   {"C": 0.1, "class_weight": "balanced", "dual":...          0.922827
# 195  {"C": 0.1, "class_weight": "balanced", "dual":...          0.923476
# 184  {"C": 0.5, "class_weight": "balanced", "dual":...          0.931906
# 93   {"C": 0.1, "class_weight": "balanced", "dual":...          0.914180
# 197  {"C": 0.1, "class_weight": "balanced", "dual":...          0.913748
#
#      cv_balanced_accuracy_mean  cv_precision_mean  cv_recall_mean  cv_f1_mean  \
# 91                    0.922867           0.914874        0.931832    0.923219
# 195                   0.923513           0.916050        0.931833    0.923816
# 184                   0.931947           0.923962        0.940951    0.932259
# 93                    0.914215           0.907169        0.922281    0.914551
# 197                   0.913782           0.907057        0.921414    0.914080
#
#      ...  cv_f1_std  cv_roc_auc_std  cv_gmean_std  holdout_accuracy  \
# 91   ...   0.006726        0.002418      0.006946          0.923077
# 195  ...   0.006647        0.002401      0.006873          0.921348
# 184  ...   0.006595        0.001448      0.006853          0.931720
# 93   ...   0.004968        0.002616      0.005428          0.919620
# 197  ...   0.005200        0.002802      0.005590          0.918755
#
#      holdout_bal_acc  holdout_precision  holdout_recall  holdout_f1  \
# 91          0.923139           0.910624        0.937500    0.923867
# 195         0.921418           0.907563        0.937500    0.922289
# 184         0.931849           0.906710        0.961806    0.933446
# 93          0.919689           0.905882        0.935764    0.920581
# 197         0.918821           0.905724        0.934028    0.919658
#
#      holdout_roc_auc  holdout_gmean
# 91          0.973026       0.923027
# 195         0.972901       0.921277
# 184         0.979914       0.931368
# 93          0.963879       0.919549
# 197         0.963613       0.918695
#
# [5 rows x 26 columns]

# %%
print(f"Highest Recall: {final_results.sort_values(by='holdout_recall', ascending=False)['holdout_recall'].tolist()[0]}")
final_results.sort_values(by='holdout_recall', ascending=False).head()
# Out:
# Highest Recall: 0.9913194444444444
#          feature_set variant               model         tuned_parameters  \
# 200  tfidf_20000_2_2  scaled                 KNN  {"clf__n_neighbors": 3}
# 96   tfidf_10000_2_2  scaled                 KNN  {"clf__n_neighbors": 3}
# 116  tfidf_10000_2_5     raw  GaussianNaiveBayes                       {}
# 129  tfidf_10000_2_5  scaled  GaussianNaiveBayes                       {}
# 220  tfidf_20000_2_5     raw  GaussianNaiveBayes                       {}
#
#                                         clf_parameters  cv_accuracy_mean  \
# 200  {"algorithm": "auto", "leaf_size": 30, "metric...          0.641818
# 96   {"algorithm": "auto", "leaf_size": 30, "metric...          0.642898
# 116           {"priors": null, "var_smoothing": 1e-09}          0.899695
# 129           {"priors": null, "var_smoothing": 1e-09}          0.888455
# 220           {"priors": null, "var_smoothing": 1e-09}          0.899695
#
#      cv_balanced_accuracy_mean  cv_precision_mean  cv_recall_mean  cv_f1_mean  \
# 200                   0.643248           0.588046        0.970477    0.731116
# 96                    0.644324           0.588755        0.970477    0.731682
# 116                   0.899914           0.862531        0.950066    0.904154
# 129                   0.888661           0.854264        0.935737    0.893107
# 220                   0.899914           0.862531        0.950066    0.904154
#
#      ...  cv_f1_std  cv_roc_auc_std  cv_gmean_std  holdout_accuracy  \
# 200  ...   0.030943        0.049799      0.102292          0.600691
# 96   ...   0.030610        0.050619      0.100683          0.605013
# 116  ...   0.005364        0.006017      0.006283          0.892826
# 129  ...   0.008223        0.009130      0.009237          0.889369
# 220  ...   0.005364        0.006017      0.006283          0.892826
#
#      holdout_bal_acc  holdout_precision  holdout_recall  holdout_f1  \
# 200         0.602372           0.555447        0.991319    0.711970
# 96          0.606675           0.558162        0.991319    0.714196
# 116         0.893183           0.836310        0.975694    0.900641
# 129         0.889741           0.831361        0.975694    0.897764
# 220         0.893183           0.836310        0.975694    0.900641
#
#      holdout_roc_auc  holdout_gmean
# 200         0.726999       0.459970
# 96          0.730750       0.469152
# 116         0.893141       0.889364
# 129         0.889699       0.885579
# 220         0.893141       0.889364
#
# [5 rows x 26 columns]

# %%
print(f"Highest F1: {final_results.sort_values(by='holdout_f1', ascending=False)['holdout_f1'].tolist()[0]}")
final_results.sort_values(by='holdout_f1', ascending=False).head()
# Out:
# Highest F1: 0.9334456613310868
#          feature_set variant            model tuned_parameters  \
# 184  tfidf_20000_2_2     raw        LinearSVC  {"clf__C": 0.5}
# 80   tfidf_10000_2_2     raw        LinearSVC  {"clf__C": 1.0}
# 28   tfidf_10000_1_2     raw        LinearSVC  {"clf__C": 0.5}
# 132  tfidf_20000_1_2     raw        LinearSVC  {"clf__C": 0.5}
# 183  tfidf_20000_2_2     raw  RidgeClassifier               {}
#
#                                         clf_parameters  cv_accuracy_mean  \
# 184  {"C": 0.5, "class_weight": "balanced", "dual":...          0.931906
# 80   {"C": 1.0, "class_weight": "balanced", "dual":...          0.931474
# 28   {"C": 0.5, "class_weight": "balanced", "dual":...          0.925206
# 132  {"C": 0.5, "class_weight": "balanced", "dual":...          0.925206
# 183  {"alpha": 1.0, "class_weight": "balanced", "co...          0.931257
#
#      cv_balanced_accuracy_mean  cv_precision_mean  cv_recall_mean  cv_f1_mean  \
# 184                   0.931947           0.923962        0.940951    0.932259
# 80                    0.931514           0.923543        0.940516    0.931831
# 28                    0.925261           0.915009        0.937046    0.925774
# 132                   0.925261           0.915009        0.937046    0.925774
# 183                   0.931304           0.922073        0.941817    0.931726
#
#      ...  cv_f1_std  cv_roc_auc_std  cv_gmean_std  holdout_accuracy  \
# 184  ...   0.006595        0.001448      0.006853          0.931720
# 80   ...   0.006998        0.001624      0.007271          0.927398
# 28   ...   0.001485        0.001670      0.001300          0.926534
# 132  ...   0.001485        0.001670      0.001300          0.926534
# 183  ...   0.008108        0.001640      0.008437          0.926534
#
#      holdout_bal_acc  holdout_precision  holdout_recall  holdout_f1  \
# 184         0.931849           0.906710        0.961806    0.933446
# 80          0.927524           0.903279        0.956597    0.929174
# 28          0.926693           0.896607        0.963542    0.928870
# 132         0.926693           0.896607        0.963542    0.928870
# 183         0.926678           0.899187        0.960069    0.928631
#
#      holdout_roc_auc  holdout_gmean
# 184         0.979914       0.931368
# 80          0.979558       0.927068
# 28          0.978321       0.925960
# 132         0.978321       0.925960
# 183         0.979519       0.926077
#
# [5 rows x 26 columns]

# %%
print(f"Highest ROC AUC: {final_results.sort_values(by='holdout_roc_auc', ascending=False)['holdout_roc_auc'].tolist()[0]}")
final_results.sort_values(by='holdout_roc_auc', ascending=False).head()
# Out:
# Highest ROC AUC: 0.9804515681774718
#          feature_set variant      model  \
# 55   tfidf_10000_1_5     raw    SVC-RBF
# 159  tfidf_20000_1_5     raw    SVC-RBF
# 184  tfidf_20000_2_2     raw  LinearSVC
# 29   tfidf_10000_1_2     raw    SVC-RBF
# 133  tfidf_20000_1_2     raw    SVC-RBF
#
#                            tuned_parameters  \
# 55   {"clf__C": 1.0, "clf__gamma": "scale"}
# 159  {"clf__C": 1.0, "clf__gamma": "scale"}
# 184                         {"clf__C": 0.5}
# 29   {"clf__C": 1.0, "clf__gamma": "scale"}
# 133  {"clf__C": 1.0, "clf__gamma": "scale"}
#
#                                         clf_parameters  cv_accuracy_mean  \
# 55   {"C": 1.0, "break_ties": false, "cache_size": ...          0.930393
# 159  {"C": 1.0, "break_ties": false, "cache_size": ...          0.930393
# 184  {"C": 0.5, "class_weight": "balanced", "dual":...          0.931906
# 29   {"C": 1.0, "break_ties": false, "cache_size": ...          0.929960
# 133  {"C": 1.0, "break_ties": false, "cache_size": ...          0.929960
#
#      cv_balanced_accuracy_mean  cv_precision_mean  cv_recall_mean  cv_f1_mean  \
# 55                    0.930449           0.919738        0.942688    0.930986
# 159                   0.930449           0.919738        0.942688    0.930986
# 184                   0.931947           0.923962        0.940951    0.932259
# 29                    0.930010           0.919948        0.941382    0.930495
# 133                   0.930010           0.919948        0.941382    0.930495
#
#      ...  cv_f1_std  cv_roc_auc_std  cv_gmean_std  holdout_accuracy  \
# 55   ...   0.005018        0.002065      0.005528          0.919620
# 159  ...   0.005018        0.002065      0.005528          0.919620
# 184  ...   0.006595        0.001448      0.006853          0.931720
# 29   ...   0.005064        0.001959      0.005497          0.923077
# 133  ...   0.005064        0.001959      0.005497          0.923077
#
#      holdout_bal_acc  holdout_precision  holdout_recall  holdout_f1  \
# 55          0.919794           0.887640        0.960069    0.922435
# 159         0.919794           0.887640        0.960069    0.922435
# 184         0.931849           0.906710        0.961806    0.933446
# 29          0.923251           0.890851        0.963542    0.925771
# 133         0.923251           0.890851        0.963542    0.925771
#
#      holdout_roc_auc  holdout_gmean
# 55          0.980452       0.918912
# 159         0.980452       0.918912
# 184         0.979914       0.931368
# 29          0.979731       0.922371
# 133         0.979731       0.922371
#
# [5 rows x 26 columns]

# %%
print(f"Highest Geometric Mean: {final_results.sort_values(by='holdout_gmean', ascending=False)['holdout_gmean'].tolist()[0]}")
final_results.sort_values(by='holdout_gmean', ascending=False).head()
# Out:
# Highest Geometric Mean: 0.9313677975825047
#          feature_set variant            model tuned_parameters  \
# 184  tfidf_20000_2_2     raw        LinearSVC  {"clf__C": 0.5}
# 80   tfidf_10000_2_2     raw        LinearSVC  {"clf__C": 1.0}
# 82   tfidf_10000_2_2     raw        SGD-Hinge               {}
# 183  tfidf_20000_2_2     raw  RidgeClassifier               {}
# 79   tfidf_10000_2_2     raw  RidgeClassifier               {}
#
#                                         clf_parameters  cv_accuracy_mean  \
# 184  {"C": 0.5, "class_weight": "balanced", "dual":...          0.931906
# 80   {"C": 1.0, "class_weight": "balanced", "dual":...          0.931474
# 82   {"alpha": 0.0001, "average": false, "class_wei...          0.926286
# 183  {"alpha": 1.0, "class_weight": "balanced", "co...          0.931257
# 79   {"alpha": 1.0, "class_weight": "balanced", "co...          0.930825
#
#      cv_balanced_accuracy_mean  cv_precision_mean  cv_recall_mean  cv_f1_mean  \
# 184                   0.931947           0.923962        0.940951    0.932259
# 80                    0.931514           0.923543        0.940516    0.931831
# 82                    0.926310           0.921792        0.931402    0.926370
# 183                   0.931304           0.922073        0.941817    0.931726
# 79                    0.930872           0.921668        0.941384    0.931296
#
#      ...  cv_f1_std  cv_roc_auc_std  cv_gmean_std  holdout_accuracy  \
# 184  ...   0.006595        0.001448      0.006853          0.931720
# 80   ...   0.006998        0.001624      0.007271          0.927398
# 82   ...   0.005977        0.001210      0.006169          0.926534
# 183  ...   0.008108        0.001640      0.008437          0.926534
# 79   ...   0.008253        0.001625      0.008587          0.926534
#
#      holdout_bal_acc  holdout_precision  holdout_recall  holdout_f1  \
# 184         0.931849           0.906710        0.961806    0.933446
# 80          0.927524           0.903279        0.956597    0.929174
# 82          0.926663           0.901800        0.956597    0.928391
# 183         0.926678           0.899187        0.960069    0.928631
# 79          0.926678           0.899187        0.960069    0.928631
#
#      holdout_roc_auc  holdout_gmean
# 184         0.979914       0.931368
# 80          0.979558       0.927068
# 82          0.978907       0.926180
# 183         0.979519       0.926077
# 79          0.979588       0.926077
#
# [5 rows x 26 columns]
