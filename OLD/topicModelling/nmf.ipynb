# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import NMF
import json
import time
import pandas as pd

from nltk.tokenize import word_tokenize
from gensim.models import CoherenceModel
from gensim.corpora import Dictionary
from itertools import combinations

# %%
K_RANGE = list(range(3, 20))
TOP_N = 10
RANDOM_STATE = 1618 # same random state as default for MATAVE topic model

# %%
try:
    with open('../dataProcessed/nurseNotes.json', 'r') as file:
        nurse_notes = json.load(file)
    print("File loaded successfully.")
    
except FileNotFoundError:
    print("Error: The file 'data.json' was not found.")
# Out:
# File loaded successfully.

# %%
# Make utility function to get coherence. - gensim implementation is also used in OCTIS (https://github.com/MIND-Lab/OCTIS/blob/master/octis/evaluation_metrics/coherence_metrics.py)
def get_coherence_score(topics, tokenized_texts, dictionary, coherence_type):
    coherence_model = CoherenceModel(
        topics=topics,
        texts=tokenized_texts,
        dictionary=dictionary,
        coherence=coherence_type # either 'c_npmi' or 'c_v'
    )
    return coherence_model.get_coherence()

# Make utility function to get diversity (always 10 words) - adapted from OCTIS (https://github.com/MIND-Lab/OCTIS/blob/master/octis/evaluation_metrics/diversity_metrics.py)
def get_diversity_score(topics):
    if len(topics) <= 0:
        return 0.0
    unique_words = set()
    for topic in topics:
        unique_words.update(topic[:10])
    return len(unique_words) / (10 * len(topics))

# Redundancy calculation. Higher the better, as closer to 1 means non-overlapping topics (inverted score). Adapted from https://aclanthology.org/2024.acl-long.11/.
def compute_topic_redundancy(topic_word_distributions, top_n=10):
    redundancy_scores = []
    for topic1, topic2 in combinations(topic_word_distributions, 2):
        overlap = len(set(topic1[:top_n]).intersection(set(topic2[:top_n])))
        redundancy = overlap / top_n
        redundancy_scores.append(redundancy)
    average_redundancy = sum(redundancy_scores) / len(redundancy_scores)
    return 1 - average_redundancy

# %%
def nmf_analysis(texts, dataset_name):
    # Prepare components for evaluation.
    tokenized_texts = [word_tokenize(text.lower()) for text in texts]
    dictionary = Dictionary(tokenized_texts)

    # Vectorize texts for NMF.
    vectorizer = TfidfVectorizer(
    max_df=0.95,
    min_df=2,
    stop_words='english'
    )
    tfidf = vectorizer.fit_transform(texts)
    feature_names = vectorizer.get_feature_names_out()

    metric_results = {'Dataset Name': [], 'Algorithm Name': [], 'Coherence': [], 'Diversity': [], 'Redundancy': [], 'Time': [], 'Top Topic Words': []}
    for k in K_RANGE:
        start = time.time()

        nmf_model = NMF(
            n_components=k,
            random_state=RANDOM_STATE
        )
        nmf_model.fit(tfidf)

        nmf_topics = [
            [feature_names[i] for i in topic.argsort()[:-TOP_N - 1:-1]]
            for topic in nmf_model.components_
        ]

        end = time.time()

        metric_results['Algorithm Name'].append(f'NMF (K={k})')
        metric_results['Dataset Name'].append(dataset_name)
        metric_results['Coherence'].append(
            get_coherence_score(nmf_topics, tokenized_texts, dictionary, 'c_v')
        )
        metric_results['Diversity'].append(get_diversity_score(nmf_topics))
        metric_results['Redundancy'].append(compute_topic_redundancy(nmf_topics))
        metric_results['Time'].append(end - start)
        metric_results['Top Topic Words'].append(nmf_topics)

    return metric_results

# %%
all_results = []
all_texts = []
for key in nurse_notes:
    all_results.append(pd.DataFrame(nmf_analysis(nurse_notes[key]['Note'], key)))
    all_texts.extend(nurse_notes[key]['Note'])
combined_df = pd.concat(all_results)
# Out:
# /Users/isabel/anaconda3/envs/realData/lib/python3.12/site-packages/sklearn/decomposition/_nmf.py:1720: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn(
# /Users/isabel/anaconda3/envs/realData/lib/python3.12/site-packages/sklearn/decomposition/_nmf.py:1720: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn(
# /Users/isabel/anaconda3/envs/realData/lib/python3.12/site-packages/sklearn/decomposition/_nmf.py:1720: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn(
# /Users/isabel/anaconda3/envs/realData/lib/python3.12/site-packages/sklearn/decomposition/_nmf.py:1720: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn(
# /Users/isabel/anaconda3/envs/realData/lib/python3.12/site-packages/sklearn/decomposition/_nmf.py:1720: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn(
# /Users/isabel/anaconda3/envs/realData/lib/python3.12/site-packages/sklearn/decomposition/_nmf.py:1720: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn(
# /Users/isabel/anaconda3/envs/realData/lib/python3.12/site-packages/sklearn/decomposition/_nmf.py:1720: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn(
# /Users/isabel/anaconda3/envs/realData/lib/python3.12/site-packages/sklearn/decomposition/_nmf.py:1720: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn(
# /Users/isabel/anaconda3/envs/realData/lib/python3.12/site-packages/sklearn/decomposition/_nmf.py:1720: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn(
# /Users/isabel/anaconda3/envs/realData/lib/python3.12/site-packages/sklearn/decomposition/_nmf.py:1720: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn(
# /Users/isabel/anaconda3/envs/realData/lib/python3.12/site-packages/sklearn/decomposition/_nmf.py:1720: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn(
# /Users/isabel/anaconda3/envs/realData/lib/python3.12/site-packages/sklearn/decomposition/_nmf.py:1720: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn(
# /Users/isabel/anaconda3/envs/realData/lib/python3.12/site-packages/sklearn/decomposition/_nmf.py:1720: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn(
# /Users/isabel/anaconda3/envs/realData/lib/python3.12/site-packages/sklearn/decomposition/_nmf.py:1720: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn(
# /Users/isabel/anaconda3/envs/realData/lib/python3.12/site-packages/sklearn/decomposition/_nmf.py:1720: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn(
# /Users/isabel/anaconda3/envs/realData/lib/python3.12/site-packages/sklearn/decomposition/_nmf.py:1720: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn(
# /Users/isabel/anaconda3/envs/realData/lib/python3.12/site-packages/sklearn/decomposition/_nmf.py:1720: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn(
# /Users/isabel/anaconda3/envs/realData/lib/python3.12/site-packages/sklearn/decomposition/_nmf.py:1720: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn(
# /Users/isabel/anaconda3/envs/realData/lib/python3.12/site-packages/sklearn/decomposition/_nmf.py:1720: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn(
# /Users/isabel/anaconda3/envs/realData/lib/python3.12/site-packages/sklearn/decomposition/_nmf.py:1720: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn(

# %%
def get_top_topics(temp_df):
    metrics = ['Coherence', 'Diversity', 'Redundancy']

    for metric in metrics:
        print(f"-------{metric}-------")
        temp_top_row = temp_df.loc[temp_df[metric].idxmax()]['Top Topic Words']
        print(f"Number of Topics: {len(temp_top_row)}")
        for topic in temp_top_row:
            # print(' '.join(topic))
            print(topic)
        print("\n")

# %%
for patient in list(nurse_notes.keys()):
    print("----------------------------")
    print(patient)
    print("----------------------------")
    get_top_topics(combined_df[combined_df['Dataset Name'] == patient])
# Out:
# ----------------------------
# P1
# ----------------------------
# -------Coherence-------
# Number of Topics: 6
# ['given', 'rollator', 'mobilising', 'complaints', 'voiced', 'nil', 'good', 'form', 'appears', 'care']
# ['ongoing', 'asleep', 'toiletting', 'self', 'checks', 'comfortable', 'peaceful', 'resident', 'changes', 'caring']
# ['checks', 'safety', 'settled', 'sleeping', 'night', 'continued', 'comfortable', 'bed', 'concerns', 'meds']
# ['adl', 'taken', 'mobilizing', 'assisted', 'walker', 'meds', 'relaxed', 'charted', 'staff', 'appears']
# ['restaurant', 'mobile', 'usual', 'needs', 'independent', 'attended', 'form', 'meals', 'charted', 'taken']
# ['morning', 'staff', 'planned', 'care', 'adls', 'breakfast', 'intake', 'reported', 'night', 'room']
#
#
# -------Diversity-------
# Number of Topics: 4
# ['form', 'needs', 'given', 'care', 'good', 'attended', 'charted', 'mobilising', 'rollator', 'nil']
# ['ongoing', 'asleep', 'toiletting', 'self', 'checks', 'comfortable', 'peaceful', 'resident', 'changes', 'caring']
# ['checks', 'safety', 'settled', 'night', 'sleeping', 'continued', 'concerns', 'comfortable', 'bed', 'meds']
# ['adl', 'taken', 'assisted', 'staff', 'mobilizing', 'relaxed', 'meds', 'charted', 'walker', 'content']
#
#
# -------Redundancy-------
# Number of Topics: 5
# ['given', 'rollator', 'mobilising', 'complaints', 'nil', 'good', 'voiced', 'form', 'care', 'appears']
# ['ongoing', 'asleep', 'toiletting', 'self', 'checks', 'comfortable', 'peaceful', 'resident', 'changes', 'caring']
# ['checks', 'safety', 'settled', 'night', 'sleeping', 'continued', 'concerns', 'comfortable', 'bed', 'meds']
# ['adl', 'taken', 'assisted', 'staff', 'mobilizing', 'relaxed', 'meds', 'walker', 'charted', 'content']
# ['restaurant', 'mobile', 'usual', 'independent', 'needs', 'attended', 'form', 'meals', 'charted', 'taken']
#
#
# ----------------------------
# P10
# ----------------------------
# -------Coherence-------
# Number of Topics: 4
# ['compliant', 'adls', 'needed', 'maintained', 'night', 'settled', 'checks', 'safety', 'meds', 'charted']
# ['checks', 'asleep', 'going', 'needs', 'toileting', 'taken', 'safety', 'meds', 'comfortable', 'bed']
# ['care', 'form', 'good', 'attended', 'given', 'appeared', 'morning', 'charted', 'resident', 'activities']
# ['administered', 'appears', 'nil', 'bright', 'concerns', 'alert', 'medications', 'home', 'new', 'skin']
#
#
# -------Diversity-------
# Number of Topics: 3
# ['compliant', 'adls', 'needed', 'maintained', 'night', 'settled', 'checks', 'safety', 'meds', 'charted']
# ['checks', 'asleep', 'going', 'needs', 'toileting', 'taken', 'safety', 'meds', 'comfortable', 'bed']
# ['care', 'nil', 'good', 'form', 'medications', 'skin', 'concerns', 'resident', 'appears', 'given']
#
#
# -------Redundancy-------
# Number of Topics: 4
# ['compliant', 'adls', 'needed', 'maintained', 'night', 'settled', 'checks', 'safety', 'meds', 'charted']
# ['checks', 'asleep', 'going', 'needs', 'toileting', 'taken', 'safety', 'meds', 'comfortable', 'bed']
# ['care', 'form', 'good', 'attended', 'given', 'appeared', 'morning', 'charted', 'resident', 'activities']
# ['administered', 'appears', 'nil', 'bright', 'concerns', 'alert', 'medications', 'home', 'new', 'skin']
#
#
# ----------------------------
# P11
# ----------------------------
# -------Coherence-------
# Number of Topics: 4
# ['checks', 'asleep', 'going', 'issues', 'comfortable', 'med', 'safety', 'new', 'nil', 'taken']
# ['adls', 'needed', 'settled', 'compliant', 'maintained', 'night', 'meds', 'assisted', 'checks', 'safety']
# ['care', 'good', 'form', 'attended', 'day', 'appeared', 'given', 'needs', 'charted', 'medication']
# ['concerns', 'appears', 'administered', 'medications', 'bright', 'nil', 'pottering', 'home', 'present', 'new']
#
#
# -------Diversity-------
# Number of Topics: 4
# ['checks', 'asleep', 'going', 'issues', 'comfortable', 'med', 'safety', 'new', 'nil', 'taken']
# ['adls', 'needed', 'settled', 'compliant', 'maintained', 'night', 'meds', 'assisted', 'checks', 'safety']
# ['care', 'good', 'form', 'attended', 'day', 'appeared', 'given', 'needs', 'charted', 'medication']
# ['concerns', 'appears', 'administered', 'medications', 'bright', 'nil', 'pottering', 'home', 'present', 'new']
#
#
# -------Redundancy-------
# Number of Topics: 4
# ['checks', 'asleep', 'going', 'issues', 'comfortable', 'med', 'safety', 'new', 'nil', 'taken']
# ['adls', 'needed', 'settled', 'compliant', 'maintained', 'night', 'meds', 'assisted', 'checks', 'safety']
# ['care', 'good', 'form', 'attended', 'day', 'appeared', 'given', 'needs', 'charted', 'medication']
# ['concerns', 'appears', 'administered', 'medications', 'bright', 'nil', 'pottering', 'home', 'present', 'new']
#
#
# ----------------------------
# P12
# ----------------------------
# -------Coherence-------
# Number of Topics: 4
# ['baseline', 'prescribed', 'wash', 'eye', 'took', 'care', 'rollator', 'skin', 'restaurant', 'mobility']
# ['early', 'nocte', 'self', 'overnight', 'caring', 'administered', 'watching', 'tele', 'sleeping', 'checks']
# ['night', 'sleep', 'medications', 'settled', 'issues', 'given', 'drinks', 'voiced', 'eye', 'care']
# ['care', 'charted', 'new', 'assisted', 'nil', 'meds', 'concerns', 'instilled', 'given', 'mobilizing']
#
#
# -------Diversity-------
# Number of Topics: 3
# ['care', 'eye', 'assisted', 'meds', 'nil', 'appears', 'attended', 'drops', 'concerns', 'good']
# ['early', 'nocte', 'self', 'overnight', 'caring', 'administered', 'watching', 'checks', 'sleeping', 'tele']
# ['night', 'sleep', 'medications', 'settled', 'issues', 'given', 'drinks', 'voiced', 'eye', 'care']
#
#
# -------Redundancy-------
# Number of Topics: 6
# ['baseline', 'prescribed', 'wash', 'took', 'eye', 'care', 'skin', 'rollator', 'appears', 'restaurant']
# ['early', 'nocte', 'self', 'caring', 'overnight', 'administered', 'watching', 'tele', 'sleeping', 'present']
# ['night', 'sleep', 'medications', 'settled', 'issues', 'drinks', 'voiced', 'given', 'eye', 'resident']
# ['charted', 'good', 'new', 'assisted', 'form', 'care', 'appeared', 'given', 'activities', 'mobilizing']
# ['checks', 'comfortable', 'needs', 'safety', 'asleep', 'concerns', 'meds', 'nil', 'ongoing', 'bed']
# ['care', 'planned', 'persist', 'eyes', 'chatty', 'discharge', 'content', 'place', 'right', 'plan']
#
#
# ----------------------------
# P13
# ----------------------------
# -------Coherence-------
# Number of Topics: 4
# ['good', 'intake', 'new', 'charted', 'mobilizing', 'meds', 'given', 'nil', 'adls', 'form']
# ['nocte', 'checks', 'overnight', 'met', 'safety', 'continued', 'mattress', 'alarm', 'needs', 'comfortable']
# ['night', 'staff', 'settled', 'medications', 'bed', 'sleep', 'given', 'issues', 'drinks', 'resident']
# ['attended', 'prescribed', 'baseline', 'skin', 'wash', 'mobility', 'took', 'care', 'restaurant', 'meals']
#
#
# -------Diversity-------
# Number of Topics: 3
# ['good', 'meds', 'nil', 'form', 'appears', 'charted', 'concerns', 'new', 'intake', 'attended']
# ['nocte', 'checks', 'overnight', 'met', 'safety', 'continued', 'mattress', 'alarm', 'needs', 'comfortable']
# ['night', 'staff', 'settled', 'medications', 'bed', 'sleep', 'given', 'issues', 'drinks', 'resident']
#
#
# -------Redundancy-------
# Number of Topics: 3
# ['good', 'meds', 'nil', 'form', 'appears', 'charted', 'concerns', 'new', 'intake', 'attended']
# ['nocte', 'checks', 'overnight', 'met', 'safety', 'continued', 'mattress', 'alarm', 'needs', 'comfortable']
# ['night', 'staff', 'settled', 'medications', 'bed', 'sleep', 'given', 'issues', 'drinks', 'resident']
#
#
# ----------------------------
# P14
# ----------------------------
# -------Coherence-------
# Number of Topics: 4
# ['given', 'nil', 'complaints', 'sitting', 'appears', 'form', 'good', 'room', 'voiced', 'content']
# ['asleep', 'ongoing', 'continued', 'checks', 'skin', 'care', 'peaceful', 'needs', 'comfortable', 'assisted']
# ['sleeping', 'checks', 'settled', 'medications', 'comfortably', 'night', 'safety', 'post', 'concerns', 'needs']
# ['adl', 'bright', 'staff', 'taken', 'good', 'appears', 'form', 'charted', 'meds', 'assisted']
#
#
# -------Diversity-------
# Number of Topics: 3
# ['appears', 'good', 'form', 'charted', 'meds', 'bright', 'taken', 'voiced', 'care', 'resident']
# ['asleep', 'ongoing', 'continued', 'checks', 'skin', 'care', 'peaceful', 'needs', 'comfortable', 'assisted']
# ['sleeping', 'settled', 'checks', 'medications', 'comfortably', 'night', 'safety', 'post', 'nil', 'needs']
#
#
# -------Redundancy-------
# Number of Topics: 3
# ['appears', 'good', 'form', 'charted', 'meds', 'bright', 'taken', 'voiced', 'care', 'resident']
# ['asleep', 'ongoing', 'continued', 'checks', 'skin', 'care', 'peaceful', 'needs', 'comfortable', 'assisted']
# ['sleeping', 'settled', 'checks', 'medications', 'comfortably', 'night', 'safety', 'post', 'nil', 'needs']
#
#
# ----------------------------
# P15
# ----------------------------
# -------Coherence-------
# Number of Topics: 3
# ['nocte', 'sleep', 'settled', 'administered', 'supervised', 'reach', 'safe', 'bell', 'continued', 'checks']
# ['good', 'nil', 'meds', 'appears', 'charted', 'assisted', 'new', 'concerns', 'adls', 'mobilizing']
# ['night', 'voiced', 'drinks', 'sleep', 'settled', 'issues', 'medications', 'given', 'resident', 'gradually']
#
#
# -------Diversity-------
# Number of Topics: 3
# ['nocte', 'sleep', 'settled', 'administered', 'supervised', 'reach', 'safe', 'bell', 'continued', 'checks']
# ['good', 'nil', 'meds', 'appears', 'charted', 'assisted', 'new', 'concerns', 'adls', 'mobilizing']
# ['night', 'voiced', 'drinks', 'sleep', 'settled', 'issues', 'medications', 'given', 'resident', 'gradually']
#
#
# -------Redundancy-------
# Number of Topics: 6
# ['nocte', 'sleep', 'settled', 'supervised', 'reach', 'safe', 'bell', 'administered', 'continued', 'checks']
# ['good', 'adls', 'intake', 'mobilizing', 'concerns', 'self', 'appears', 'charted', 'new', 'toileting']
# ['night', 'voiced', 'drinks', 'sleep', 'settled', 'medications', 'issues', 'given', 'resident', 'gradually']
# ['noted', 'time', 'received', 'till', 'room', 'good', 'appeared', 'observed', 'kept', 'ensured']
# ['prn', 'oxynorm', 'pain', 'facial', 'given', '5mg', 'effect', 'right', 'tegretol', 'resident']
# ['took', 'baseline', 'skin', 'attended', 'unit', 'care', 'wash', 'prescribed', 'morning', 'meals']
#
#
# ----------------------------
# P16
# ----------------------------
# -------Coherence-------
# Number of Topics: 3
# ['checks', 'asleep', 'toileting', 'going', 'taken', 'needs', 'bed', 'meds', 'comfortable', 'issues']
# ['adls', 'needed', 'compliant', 'night', 'settled', 'maintained', 'safety', 'checks', 'meds', 'charted']
# ['care', 'good', 'nil', 'medications', 'form', 'concerns', 'attended', 'skin', 'resident', 'given']
#
#
# -------Diversity-------
# Number of Topics: 3
# ['checks', 'asleep', 'toileting', 'going', 'taken', 'needs', 'bed', 'meds', 'comfortable', 'issues']
# ['adls', 'needed', 'compliant', 'night', 'settled', 'maintained', 'safety', 'checks', 'meds', 'charted']
# ['care', 'good', 'nil', 'medications', 'form', 'concerns', 'attended', 'skin', 'resident', 'given']
#
#
# -------Redundancy-------
# Number of Topics: 3
# ['checks', 'asleep', 'toileting', 'going', 'taken', 'needs', 'bed', 'meds', 'comfortable', 'issues']
# ['adls', 'needed', 'compliant', 'night', 'settled', 'maintained', 'safety', 'checks', 'meds', 'charted']
# ['care', 'good', 'nil', 'medications', 'form', 'concerns', 'attended', 'skin', 'resident', 'given']
#
#
# ----------------------------
# P17
# ----------------------------
# -------Coherence-------
# Number of Topics: 4
# ['caring', 'self', 'overnight', 'nocte', 'administered', 'settled', 'later', 'continued', 'early', 'checks']
# ['good', 'charted', 'new', 'meds', 'adls', 'intake', 'toileting', 'concerns', 'nil', 'given']
# ['night', 'sleep', 'medications', 'settled', 'given', 'issues', 'drinks', 'voiced', 'applied', 'drops']
# ['prescribed', 'independent', 'took', 'adl', 'attended', 'restaurant', 'meals', 'baseline', 'nil', 'appears']
#
#
# -------Diversity-------
# Number of Topics: 3
# ['caring', 'self', 'overnight', 'nocte', 'continued', 'administered', 'checks', 'settled', 'later', 'early']
# ['independent', 'meds', 'nil', 'appears', 'form', 'good', 'concerns', 'attended', 'meals', 'charted']
# ['night', 'sleep', 'medications', 'given', 'settled', 'issues', 'drinks', 'voiced', 'drops', 'applied']
#
#
# -------Redundancy-------
# Number of Topics: 3
# ['caring', 'self', 'overnight', 'nocte', 'continued', 'administered', 'checks', 'settled', 'later', 'early']
# ['independent', 'meds', 'nil', 'appears', 'form', 'good', 'concerns', 'attended', 'meals', 'charted']
# ['night', 'sleep', 'medications', 'given', 'settled', 'issues', 'drinks', 'voiced', 'drops', 'applied']
#
#
# ----------------------------
# P18
# ----------------------------
# -------Coherence-------
# Number of Topics: 8
# ['asleep', 'ongoing', 'skin', 'continued', 'checks', 'care', 'peaceful', 'needs', 'comfortable', 'assisted']
# ['adl', 'bright', 'eye', 'going', 'drops', 'alert', 'enjoys', 'appears', 'given', 'today']
# ['sleeping', 'medications', 'comfortably', 'settled', 'personal', 'post', 'voiced', 'checks', 'routine', 'nil']
# ['complaints', 'voiced', 'attended', 'nil', 'instilled', 'given', 'appears', 'care', 'social', 'club']
# ['planned', 'morning', 'good', 'breakfast', 'adls', 'chatty', 'concerns', 'dinning', 'unit', 'area']
# ['result', 'sugar', 'blood', 'weekly', 'bsl', '10', '12', 'fbsl', '14', '11']
# ['night', 'safety', 'checks', 'settled', 'concerns', 'comfortable', 'meds', 'bed', 'taken', 'new']
# ['taken', 'enjoyed', 'charted', 'usual', 'form', 'meds', 'activities', 'attending', 'attended', 'good']
#
#
# -------Diversity-------
# Number of Topics: 3
# ['ongoing', 'asleep', 'skin', 'continued', 'checks', 'care', 'peaceful', 'needs', 'comfortable', 'assisted']
# ['good', 'form', 'appears', 'charted', 'meds', 'given', 'eye', 'drops', 'bright', 'care']
# ['sleeping', 'settled', 'checks', 'medications', 'voiced', 'nil', 'personal', 'comfortably', 'concerns', 'needs']
#
#
# -------Redundancy-------
# Number of Topics: 8
# ['asleep', 'ongoing', 'skin', 'continued', 'checks', 'care', 'peaceful', 'needs', 'comfortable', 'assisted']
# ['adl', 'bright', 'eye', 'going', 'drops', 'alert', 'enjoys', 'appears', 'given', 'today']
# ['sleeping', 'medications', 'comfortably', 'settled', 'personal', 'post', 'voiced', 'checks', 'routine', 'nil']
# ['complaints', 'voiced', 'attended', 'nil', 'instilled', 'given', 'appears', 'care', 'social', 'club']
# ['planned', 'morning', 'good', 'breakfast', 'adls', 'chatty', 'concerns', 'dinning', 'unit', 'area']
# ['result', 'sugar', 'blood', 'weekly', 'bsl', '10', '12', 'fbsl', '14', '11']
# ['night', 'safety', 'checks', 'settled', 'concerns', 'comfortable', 'meds', 'bed', 'taken', 'new']
# ['taken', 'enjoyed', 'charted', 'usual', 'form', 'meds', 'activities', 'attending', 'attended', 'good']
#
#
# ----------------------------
# P19
# ----------------------------
# -------Coherence-------
# Number of Topics: 3
# ['good', 'form', 'nil', 'adl', 'complaints', 'independent', 'given', 'mobilising', 'walking', 'stick']
# ['checks', 'asleep', 'ongoing', 'self', 'comfortable', 'toiletting', 'resident', 'needs', 'assisted', 'peaceful']
# ['taken', 'unit', 'relaxed', 'content', 'mobilizing', 'charted', 'meds', 'appears', 'concerns', 'voiced']
#
#
# -------Diversity-------
# Number of Topics: 3
# ['good', 'form', 'nil', 'adl', 'complaints', 'independent', 'given', 'mobilising', 'walking', 'stick']
# ['checks', 'asleep', 'ongoing', 'self', 'comfortable', 'toiletting', 'resident', 'needs', 'assisted', 'peaceful']
# ['taken', 'unit', 'relaxed', 'content', 'mobilizing', 'charted', 'meds', 'appears', 'concerns', 'voiced']
#
#
# -------Redundancy-------
# Number of Topics: 3
# ['good', 'form', 'nil', 'adl', 'complaints', 'independent', 'given', 'mobilising', 'walking', 'stick']
# ['checks', 'asleep', 'ongoing', 'self', 'comfortable', 'toiletting', 'resident', 'needs', 'assisted', 'peaceful']
# ['taken', 'unit', 'relaxed', 'content', 'mobilizing', 'charted', 'meds', 'appears', 'concerns', 'voiced']
#
#
# ----------------------------
# P2
# ----------------------------
# -------Coherence-------
# Number of Topics: 4
# ['overnight', 'sitting', 'sleeping', 'tele', 'present', 'administered', 'continued', 'checks', 'medication', 'safety']
# ['charted', 'new', 'concerns', 'meds', 'nil', 'intake', 'appears', 'aid', 'good', 'adls']
# ['settled', 'night', 'medications', 'staff', 'drinks', 'bed', 'tv', 'midnight', 'given', 'voiced']
# ['rollator', 'wash', 'baseline', 'prescribed', 'took', 'restaurant', 'meals', 'form', 'meds', 'nil']
#
#
# -------Diversity-------
# Number of Topics: 3
# ['overnight', 'sitting', 'sleeping', 'tele', 'present', 'checks', 'administered', 'continued', 'medication', 'safety']
# ['meds', 'nil', 'appears', 'form', 'good', 'assisted', 'charted', 'mobilizing', 'concerns', 'care']
# ['settled', 'night', 'medications', 'staff', 'bed', 'drinks', 'tv', 'midnight', 'given', 'voiced']
#
#
# -------Redundancy-------
# Number of Topics: 3
# ['overnight', 'sitting', 'sleeping', 'tele', 'present', 'checks', 'administered', 'continued', 'medication', 'safety']
# ['meds', 'nil', 'appears', 'form', 'good', 'assisted', 'charted', 'mobilizing', 'concerns', 'care']
# ['settled', 'night', 'medications', 'staff', 'bed', 'drinks', 'tv', 'midnight', 'given', 'voiced']
#
#
# ----------------------------
# P20
# ----------------------------
# -------Coherence-------
# Number of Topics: 3
# ['checks', 'asleep', 'ongoing', 'continued', 'care', 'skin', 'needs', 'peaceful', 'comfortable', 'assisted']
# ['nil', 'given', 'voiced', 'mobilising', 'complaints', 'attended', 'rollator', 'form', 'charted', 'good']
# ['adl', 'taken', 'bright', 'walker', 'mobilizing', 'appears', 'charted', 'alert', 'meds', 'form']
#
#
# -------Diversity-------
# Number of Topics: 3
# ['checks', 'asleep', 'ongoing', 'continued', 'care', 'skin', 'needs', 'peaceful', 'comfortable', 'assisted']
# ['nil', 'given', 'voiced', 'mobilising', 'complaints', 'attended', 'rollator', 'form', 'charted', 'good']
# ['adl', 'taken', 'bright', 'walker', 'mobilizing', 'appears', 'charted', 'alert', 'meds', 'form']
#
#
# -------Redundancy-------
# Number of Topics: 3
# ['checks', 'asleep', 'ongoing', 'continued', 'care', 'skin', 'needs', 'peaceful', 'comfortable', 'assisted']
# ['nil', 'given', 'voiced', 'mobilising', 'complaints', 'attended', 'rollator', 'form', 'charted', 'good']
# ['adl', 'taken', 'bright', 'walker', 'mobilizing', 'appears', 'charted', 'alert', 'meds', 'form']
#
#
# ----------------------------
# P3
# ----------------------------
# -------Coherence-------
# Number of Topics: 3
# ['night', 'safety', 'checks', 'settled', 'sleeping', 'care', 'maintained', 'needs', 'resident', 'taken']
# ['ongoing', 'asleep', 'checks', 'self', 'toiletting', 'comfortable', 'peaceful', 'resident', 'needs', 'assisted']
# ['good', 'charted', 'form', 'attended', 'appears', 'meds', 'voiced', 'given', 'nil', 'complaints']
#
#
# -------Diversity-------
# Number of Topics: 3
# ['night', 'safety', 'checks', 'settled', 'sleeping', 'care', 'maintained', 'needs', 'resident', 'taken']
# ['ongoing', 'asleep', 'checks', 'self', 'toiletting', 'comfortable', 'peaceful', 'resident', 'needs', 'assisted']
# ['good', 'charted', 'form', 'attended', 'appears', 'meds', 'voiced', 'given', 'nil', 'complaints']
#
#
# -------Redundancy-------
# Number of Topics: 8
# ['checks', 'safety', 'care', 'sleeping', 'maintained', 'needs', 'taken', 'meds', 'settled', 'concerns']
# ['ongoing', 'asleep', 'self', 'checks', 'toiletting', 'comfortable', 'peaceful', 'resident', 'assisted', 'needs']
# ['attended', 'voiced', 'complaints', 'nil', 'good', 'appears', 'form', 'club', 'social', 'charted']
# ['taken', 'today', 'adl', 'charted', 'form', 'morning', 'meds', 'nebs', 'appears', 'good']
# ['plan', 'infection', 'evaluation', 'tract', 'respiratory', 'gp', 'antibiotic', 'completed', 'care', 'course']
# ['prn', 'naproxen', 'given', 'requested', 'exputex', 'pain', 'sciatica', 'request', 'cough', '30']
# ['night', 'settled', 'medications', 'noticed', 'early', 'checked', 'continued', 'staff', 'safety', 'resident']
# ['mood', 'low', 'room', 'reassured', 'reassurance', 'time', 'resident', 'early', 'chat', 'given']
#
#
# ----------------------------
# P4
# ----------------------------
# -------Coherence-------
# Number of Topics: 4
# ['ongoing', 'asleep', 'skin', 'checks', 'continued', 'care', 'peaceful', 'needs', 'assisted', 'comfortable']
# ['charted', 'form', 'inhalers', 'given', 'meds', 'good', 'appears', 'attended', 'voiced', 'nil']
# ['settled', 'checks', 'sleeping', 'comfortable', 'bed', 'night', 'kept', 'safety', 'eye', 'drops']
# ['bno', 'morning', 'planned', 'breakfast', 'intake', 'adls', 'content', 'area', 'appeared', 'dinning']
#
#
# -------Diversity-------
# Number of Topics: 4
# ['ongoing', 'asleep', 'skin', 'checks', 'continued', 'care', 'peaceful', 'needs', 'assisted', 'comfortable']
# ['charted', 'form', 'inhalers', 'given', 'meds', 'good', 'appears', 'attended', 'voiced', 'nil']
# ['settled', 'checks', 'sleeping', 'comfortable', 'bed', 'night', 'kept', 'safety', 'eye', 'drops']
# ['bno', 'morning', 'planned', 'breakfast', 'intake', 'adls', 'content', 'area', 'appeared', 'dinning']
#
#
# -------Redundancy-------
# Number of Topics: 4
# ['ongoing', 'asleep', 'skin', 'checks', 'continued', 'care', 'peaceful', 'needs', 'assisted', 'comfortable']
# ['charted', 'form', 'inhalers', 'given', 'meds', 'good', 'appears', 'attended', 'voiced', 'nil']
# ['settled', 'checks', 'sleeping', 'comfortable', 'bed', 'night', 'kept', 'safety', 'eye', 'drops']
# ['bno', 'morning', 'planned', 'breakfast', 'intake', 'adls', 'content', 'area', 'appeared', 'dinning']
#
#
# ----------------------------
# P5
# ----------------------------
# -------Coherence-------
# Number of Topics: 3
# ['room', 'form', 'independent', 'good', 'adl', 'appears', 'charted', 'meds', 'resident', 'voiced']
# ['ongoing', 'asleep', 'toiletting', 'self', 'checks', 'comfortable', 'peaceful', 'resident', 'changes', 'assisted']
# ['continued', 'night', 'checks', 'safety', 'settled', 'sleeping', 'toileting', 'medications', 'concerns', 'post']
#
#
# -------Diversity-------
# Number of Topics: 3
# ['room', 'form', 'independent', 'good', 'adl', 'appears', 'charted', 'meds', 'resident', 'voiced']
# ['ongoing', 'asleep', 'toiletting', 'self', 'checks', 'comfortable', 'peaceful', 'resident', 'changes', 'assisted']
# ['continued', 'night', 'checks', 'safety', 'settled', 'sleeping', 'toileting', 'medications', 'concerns', 'post']
#
#
# -------Redundancy-------
# Number of Topics: 3
# ['room', 'form', 'independent', 'good', 'adl', 'appears', 'charted', 'meds', 'resident', 'voiced']
# ['ongoing', 'asleep', 'toiletting', 'self', 'checks', 'comfortable', 'peaceful', 'resident', 'changes', 'assisted']
# ['continued', 'night', 'checks', 'safety', 'settled', 'sleeping', 'toileting', 'medications', 'concerns', 'post']
#
#
# ----------------------------
# P6
# ----------------------------
# -------Coherence-------
# Number of Topics: 4
# ['place', 'bell', 'situ', 'mat', 'bed', 'overnight', 'sensor', 'floor', 'administered', 'checks']
# ['charted', 'new', 'meds', 'assisted', 'care', 'concerns', 'good', 'given', 'nil', 'appears']
# ['sleep', 'night', 'settled', 'medications', 'voiced', 'given', 'issues', 'supplement', 'gradually', 'drinks']
# ['baseline', 'prescribed', 'wash', 'supplements', 'tolerated', 'assisted', 'skin', 'independent', 'stayed', 'took']
#
#
# -------Diversity-------
# Number of Topics: 3
# ['place', 'bell', 'bed', 'situ', 'mat', 'overnight', 'sensor', 'floor', 'administered', 'checks']
# ['assisted', 'care', 'meds', 'appears', 'nil', 'form', 'skin', 'charted', 'supplements', 'baseline']
# ['sleep', 'night', 'settled', 'given', 'medications', 'voiced', 'issues', 'supplement', 'gradually', 'drinks']
#
#
# -------Redundancy-------
# Number of Topics: 3
# ['place', 'bell', 'bed', 'situ', 'mat', 'overnight', 'sensor', 'floor', 'administered', 'checks']
# ['assisted', 'care', 'meds', 'appears', 'nil', 'form', 'skin', 'charted', 'supplements', 'baseline']
# ['sleep', 'night', 'settled', 'given', 'medications', 'voiced', 'issues', 'supplement', 'gradually', 'drinks']
#
#
# ----------------------------
# P7
# ----------------------------
# -------Coherence-------
# Number of Topics: 4
# ['good', 'new', 'charted', 'adls', 'toileting', 'intake', 'appears', 'meds', 'assisted', 'concerns']
# ['checks', 'safety', 'bed', 'administered', 'continued', 'nocte', 'caring', 'sleeping', 'overnight', 'self']
# ['night', 'sleep', 'medications', 'settled', 'issues', 'voiced', 'given', 'drinks', 'remained', 'independent']
# ['care', 'dining', 'attended', 'room', 'form', 'unit', 'meals', 'nil', 'skin', 'baseline']
#
#
# -------Diversity-------
# Number of Topics: 3
# ['good', 'meds', 'assisted', 'appears', 'charted', 'new', 'intake', 'concerns', 'form', 'adls']
# ['checks', 'safety', 'bed', 'administered', 'continued', 'nocte', 'caring', 'sleeping', 'overnight', 'self']
# ['night', 'sleep', 'medications', 'settled', 'issues', 'voiced', 'given', 'drinks', 'remained', 'independent']
#
#
# -------Redundancy-------
# Number of Topics: 3
# ['good', 'meds', 'assisted', 'appears', 'charted', 'new', 'intake', 'concerns', 'form', 'adls']
# ['checks', 'safety', 'bed', 'administered', 'continued', 'nocte', 'caring', 'sleeping', 'overnight', 'self']
# ['night', 'sleep', 'medications', 'settled', 'issues', 'voiced', 'given', 'drinks', 'remained', 'independent']
#
#
# ----------------------------
# P8
# ----------------------------
# -------Coherence-------
# Number of Topics: 4
# ['charted', 'new', 'meds', 'given', 'nil', 'concerns', 'good', 'assisted', 'resident', 'appears']
# ['settled', 'night', 'tts', 'medications', 'comfortably', 'hoisted', 'given', 'bed', 'staff', 'sleep']
# ['checks', 'bed', 'safety', 'administered', 'continued', 'attended', 'sleeping', 'watching', 'needs', 'overnight']
# ['took', 'prescribed', 'baseline', 'wash', 'wheelchair', 'transferred', 'electric', 'skin', 'appears', 'form']
#
#
# -------Diversity-------
# Number of Topics: 3
# ['meds', 'nil', 'appears', 'assisted', 'concerns', 'care', 'form', 'took', 'charted', 'skin']
# ['settled', 'night', 'tts', 'medications', 'comfortably', 'given', 'hoisted', 'bed', 'staff', 'sleep']
# ['checks', 'bed', 'safety', 'continued', 'administered', 'needs', 'attended', 'sleeping', 'watching', 'overnight']
#
#
# -------Redundancy-------
# Number of Topics: 5
# ['charted', 'new', 'meds', 'given', 'nil', 'concerns', 'good', 'assisted', 'appears', 'adls']
# ['settled', 'night', 'tts', 'medications', 'comfortably', 'hoisted', 'given', 'bed', 'staff', 'sleep']
# ['checks', 'bed', 'safety', 'administered', 'continued', 'attended', 'sleeping', 'watching', 'needs', 'overnight']
# ['took', 'prescribed', 'baseline', 'wash', 'wheelchair', 'transferred', 'electric', 'skin', 'appears', 'form']
# ['hospital', 'resident', 'remains', 'daughter', 'gp', 'today', 'plan', 'came', 'tomorrow', 'admission']
#
#
# ----------------------------
# P9
# ----------------------------
# -------Coherence-------
# Number of Topics: 4
# ['adls', 'night', 'needed', 'compliant', 'settled', 'maintained', 'safety', 'checks', 'meds', 'charted']
# ['appeared', 'attended', 'good', 'form', 'care', 'issues', 'new', 'needs', 'charted', 'nil']
# ['concerns', 'bright', 'appears', 'care', 'medications', 'administered', 'nil', 'alert', 'skin', 'assisted']
# ['checks', 'mat', 'place', 'sensor', 'asleep', 'comfortable', 'taken', 'safety', 'bed', 'going']
#
#
# -------Diversity-------
# Number of Topics: 3
# ['adls', 'night', 'needed', 'compliant', 'settled', 'maintained', 'safety', 'checks', 'meds', 'charted']
# ['mat', 'place', 'sensor', 'checks', 'asleep', 'taken', 'needs', 'comfortable', 'meds', 'safety']
# ['care', 'good', 'nil', 'form', 'medications', 'concerns', 'new', 'attended', 'resident', 'bright']
#
#
# -------Redundancy-------
# Number of Topics: 19
# ['adls', 'compliant', 'needed', 'maintained', 'night', 'settled', 'checks', 'safety', 'meds', 'charted']
# ['issues', 'appeared', 'mat', 'place', 'new', 'sensor', 'attended', 'ging', 'good', 'form']
# ['administered', 'bright', 'alert', 'appears', 'medications', 'concerns', 'new', 'adl', 'nil', 'house']
# ['nocte', 'early', 'comfortable', 'toilet', 'asleep', 'bed', 'checks', 'appears', 'place', 'mat']
# ['morning', 'given', 'care', 'form', 'personal', 'assisted', 'usual', 'charted', 'late', 'meds']
# ['night', 'check', 'noticed', 'slept', 'staff', 'continued', 'given', 'concerns', 'medications', 'resident']
# ['drinking', 'eating', 'care', 'issues', 'eye', 'appeared', 'given', 'new', 'morning', 'house']
# ['plan', 'care', 'evaluation', 'holistic', 'continue', 'changes', 'current', 'resident', 'review', 'planned']
# ['intake', 'continued', 'skin', 'care', 'took', 'chair', 'today', 'concerns', 'room', 'medicines']
# ['bed', 'insitu', 'bell', 'complaints', 'assistance', 'continue', 'alarm', 'continued', 'remains', 'actively']
# ['complaint', 'voiced', 'appeared', 'adl', 'medications', 'attended', 'form', 'good', 'needs', 'taken']
# ['entry', 'time', 'personal', 'concerns', 'pottering', 'room', 'given', 'voiced', 'bright', 'nil']
# ['toileting', 'gong', 'mat', 'place', 'settled', 'sensor', 'night', 'needs', 'going', 'taken']
# ['taken', 'medications', 'present', 'breakfast', 'low', 'fluids', 'mood', 'px', 'concerns', 'diet']
# ['patch', 'applied', 'pain', 'going', 'versatis', 'paracetamol', 'versatilis', 'half', 'pm', 'given']
# ['reports', 'altered', 'integrity', 'skin', 'hygiene', 'nil', 'needs', 'administered', 'restaurant', 'alert']
# ['activities', 'attended', 'enjoyed', 'form', 'good', 'meals', 'currently', 'required', 'house', 'eye']
# ['asleep', 'checks', 'comfortable', 'care', 'ongoing', 'needs', 'appears', 'concerns', 'meds', 'bed']
# ['gp', 'review', 'prn', 'reviewed', 'vagifen', 'rw', 'continue', 'tab', 'noted', 'declined']

# %%
all_texts_df = pd.DataFrame(nmf_analysis(all_texts, "All Texts"))
# Out:
# /Users/isabel/anaconda3/envs/realData/lib/python3.12/site-packages/sklearn/decomposition/_nmf.py:1720: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn(
# /Users/isabel/anaconda3/envs/realData/lib/python3.12/site-packages/sklearn/decomposition/_nmf.py:1720: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn(

# %%
get_top_topics(all_texts_df)
# Out:
# -------Coherence-------
# Number of Topics: 4
# ['checks', 'asleep', 'ongoing', 'comfortable', 'needs', 'care', 'skin', 'continued', 'peaceful', 'resident']
# ['good', 'form', 'appears', 'charted', 'meds', 'nil', 'care', 'given', 'assisted', 'resident']
# ['night', 'needed', 'maintained', 'compliant', 'adls', 'safety', 'settled', 'checks', 'charted', 'meds']
# ['settled', 'medications', 'night', 'sleep', 'nocte', 'bed', 'overnight', 'sleeping', 'continued', 'early']
#
#
# -------Diversity-------
# Number of Topics: 3
# ['checks', 'asleep', 'ongoing', 'comfortable', 'needs', 'care', 'skin', 'continued', 'peaceful', 'resident']
# ['good', 'form', 'appears', 'charted', 'meds', 'nil', 'care', 'given', 'assisted', 'resident']
# ['night', 'settled', 'safety', 'medications', 'checks', 'maintained', 'needed', 'sleep', 'compliant', 'resident']
#
#
# -------Redundancy-------
# Number of Topics: 17
# ['checks', 'comfortable', 'safety', 'asleep', 'taken', 'bed', 'going', 'meds', 'toileting', 'needs']
# ['complaints', 'voiced', 'nil', 'given', 'appears', 'charted', 'mobilising', 'meds', 'form', 'good']
# ['needed', 'compliant', 'maintained', 'adls', 'night', 'settled', 'safety', 'checks', 'charted', 'having']
# ['nocte', 'overnight', 'administered', 'early', 'bell', 'continued', 'caring', 'present', 'reach', 'bed']
# ['sleep', 'settled', 'medications', 'drinks', 'night', 'given', 'voiced', 'issues', 'eye', 'gradually']
# ['toiletting', 'self', 'ongoing', 'asleep', 'checks', 'comfortable', 'peaceful', 'resident', 'caring', 'changes']
# ['care', 'skin', 'ongoing', 'continued', 'asleep', 'needs', 'peaceful', 'assisted', 'checks', 'resident']
# ['night', 'check', 'noticed', 'staff', 'slept', 'continued', 'safety', 'checked', 'resident', 'comfortable']
# ['issues', 'new', 'nil', 'appeared', 'drinking', 'eating', 'given', 'assisted', 'morning', 'going']
# ['baseline', 'prescribed', 'took', 'meals', 'wash', 'restaurant', 'mobility', 'nil', 'appears', 'skin']
# ['sleeping', 'comfortably', 'post', 'settled', 'checks', 'medications', 'routine', 'personal', 'needs', 'concerns']
# ['adl', 'taken', 'bright', 'appears', 'charted', 'meds', 'alert', 'mobilizing', 'form', 'assisted']
# ['attended', 'needs', 'form', 'good', 'appeared', 'care', 'activities', 'complaint', 'taken', 'charted']
# ['morning', 'care', 'usual', 'planned', 'day', 'medication', 'diet', 'form', 'given', 'good']
# ['noted', 'room', 'time', 'till', 'received', 'ensured', 'kept', 'observed', 'met', 'good']
# ['plan', 'continues', 'care', 'changes', 'planned', 'report', 'evaluation', 'continue', 'concerns', 'holistic']
# ['intake', 'concerns', 'new', 'good', 'adls', 'mobilizing', 'toileting', 'given', 'appears', 'self']
