# %%
from gensim.models import LdaModel
import json
import time
import pandas as pd

from nltk.tokenize import word_tokenize
from gensim.models import CoherenceModel
from gensim.corpora import Dictionary
from itertools import combinations

# %%
K_RANGE = list(range(3, 20))
TOP_N = 10
RANDOM_STATE = 1618 # same random state as default for MATAVE topic model

# %%
try:
    with open('../dataProcessed/nurseNotes.json', 'r') as file:
        nurse_notes = json.load(file)
    print("File loaded successfully.")
    
except FileNotFoundError:
    print("Error: The file 'data.json' was not found.")
# Out:
# File loaded successfully.

# %%
# Make utility function to get coherence. - gensim implementation is also used in OCTIS (https://github.com/MIND-Lab/OCTIS/blob/master/octis/evaluation_metrics/coherence_metrics.py)
def get_coherence_score(topics, tokenized_texts, dictionary, coherence_type):
    coherence_model = CoherenceModel(
        topics=topics,
        texts=tokenized_texts,
        dictionary=dictionary,
        coherence=coherence_type # either 'c_npmi' or 'c_v'
    )
    return coherence_model.get_coherence()

# Make utility function to get diversity (always 10 words) - adapted from OCTIS (https://github.com/MIND-Lab/OCTIS/blob/master/octis/evaluation_metrics/diversity_metrics.py)
def get_diversity_score(topics):
    if len(topics) <= 0:
        return 0.0
    unique_words = set()
    for topic in topics:
        unique_words.update(topic[:10])
    return len(unique_words) / (10 * len(topics))

# Redundancy calculation. Higher the better, as closer to 1 means non-overlapping topics (inverted score). Adapted from https://aclanthology.org/2024.acl-long.11/.
def compute_topic_redundancy(topic_word_distributions, TOP_N=10):
    redundancy_scores = []
    for topic1, topic2 in combinations(topic_word_distributions, 2):
        overlap = len(set(topic1[:TOP_N]).intersection(set(topic2[:TOP_N])))
        redundancy = overlap / TOP_N
        redundancy_scores.append(redundancy)
    average_redundancy = sum(redundancy_scores) / len(redundancy_scores)
    return 1 - average_redundancy

# %%
def lda_analysis(texts, dataset_name):
    # Prepare components for evaluation.
    tokenized_texts = [word_tokenize(text.lower()) for text in texts]
    dictionary = Dictionary(tokenized_texts)
    corpus = [dictionary.doc2bow(text) for text in tokenized_texts]

    metric_results = {'Dataset Name': [], 'Algorithm Name': [], 'Coherence': [], 'Diversity': [], 'Redundancy': [], 'Time': [], 'Top Topic Words': []}
    
    for k in K_RANGE:
        start = time.time()

        lda_model = LdaModel(
            corpus=corpus,
            id2word=dictionary,
            num_topics=k,
            random_state=RANDOM_STATE,
            passes=10
        )

        lda_topics = [
            [word for word, _ in lda_model.show_topic(i, topn=TOP_N)]
            for i in range(k)
        ]

        end = time.time()

        metric_results['Algorithm Name'].append(f'LDA (K={k})')
        metric_results['Dataset Name'].append(dataset_name)
        metric_results['Coherence'].append(
            get_coherence_score(lda_topics, tokenized_texts, dictionary, 'c_v')
        )
        metric_results['Diversity'].append(get_diversity_score(lda_topics))
        metric_results['Redundancy'].append(compute_topic_redundancy(lda_topics))
        metric_results['Time'].append(end - start)
        metric_results['Top Topic Words'].append(lda_topics)
    
    return metric_results

# %%
all_results = []
all_texts = []
for key in nurse_notes:
    all_results.append(pd.DataFrame(lda_analysis(nurse_notes[key]['Note'], key)))
    all_texts.extend(nurse_notes[key]['Note'])
combined_df = pd.concat(all_results)

# %%
def get_top_topics(temp_df):
    metrics = ['Coherence', 'Diversity', 'Redundancy']

    for metric in metrics:
        print(f"-------{metric}-------")
        temp_top_row = temp_df.loc[temp_df[metric].idxmax()]['Top Topic Words']
        print(f"Number of Topics: {len(temp_top_row)}")
        for topic in temp_top_row:
            # print(' '.join(topic))
            print(topic)
        print("\n")

# %%
for patient in list(nurse_notes.keys()):
    print("----------------------------")
    print(patient)
    print("----------------------------")
    get_top_topics(combined_df[combined_df['Dataset Name'] == patient])
# Out:
# ----------------------------
# P1
# ----------------------------
# -------Coherence-------
# Number of Topics: 15
# ['plan', 'care', ':', '.', 'of', 'for', 'reviewed', 'evaluation', 'holistic', 'my']
# ['.', 'to', '[', ']', 'resident', 'sleeping', 'in', 'on', 'checks', 'settled']
# ['.', 'with', 'her', 'resident', '[', ']', 'assisted', 'due', 'and', 'as']
# ['.', ',', 'restaurant', ']', '[', 'charted', 'needs', 'due', 'meds', 'as']
# ['drops', ']', '[', 'doctor', 'with', 'ear', 'a', 'to', 'chat', 'had']
# ['.', 'in', ']', '[', 'with', 'resident', 'as', 'appears', 'good', 'care']
# ['.', '[', ']', 'resident', 'at', 'night', 'the', 'and', 'from', 'all']
# ['before', 'lunch', 'time', '15.20', 'physiotherapy', 'hospital', 'around', 'back', 'attended', '[']
# ['.', 'checks', 'resident', '[', ']', 'meds', 'needs', 'as', 'safety', 'care']
# ['.', 'as', 'care', 'with', ']', '[', 'resident', 'given', ',', 'morning']
# ['kept', 'slept', 'attended', 'complaints', 'well', 'voiced', 'nil', 'to', 'needs', 'nocte']
# ['.', 'well', 'and', 'caring', 'self', 'remains', 'no', 'to', 'sleeping', 'report']
# ['[', ']', 'doctor', ',', 'by', 'to', 'resident', '.', 'gp', 'seen']
# ['app', 'both', '.', 'and', 'feet', 'cream', 'filed', 'cut', 'toenails', 'foot']
# ['.', ']', '[', 'resident', 'asleep', 'ongoing', 'checks', 'self', 'toiletting', 'comfortable']
#
#
# -------Diversity-------
# Number of Topics: 3
# ['[', ']', '.', 'to', ',', 'resident', 'doctor', 'and', 'the', 'of']
# ['.', 'resident', '[', ']', 'to', 'in', 'as', 'meds', 'well', ',']
# ['.', 'resident', ']', '[', 'with', 'as', 'care', 'meds', 'due', 'assisted']
#
#
# -------Redundancy-------
# Number of Topics: 18
# [':', 'nocte', 'continues', 'routine', 'including', 'full', 'studies', 'details', 'iron', 'hba1c']
# ['.', 'to', '[', ']', 'resident', 'in', 'appears', 'on', 'sleeping', 'meds']
# ['with', '.', 'her', 'due', 'meds', ']', 'taken', '[', 'resident', 'assisted']
# ['.', ',', 'restaurant', 'as', 'needs', 'due', 'in', 'her', 'meds', 'charted']
# ['drops', 'ear', 'betnesol', 'gp', ',', 'had', 'hc', 'ears', 'chat', '.']
# ['.', ']', '[', 'to', 'resident', 'her', 'in', 'appointment', 'for', 'out']
# ['the', '.', '[', ']', 'and', ',', 'she', 'that', 'her', 'to']
# ['.', 'with', 'in', 'the', 'planned', 'was', 'staff', 'adls', 'reported', 'morning']
# ['.', 'resident', '[', ']', 'with', 'care', 'meds', 'as', 'needs', 'nil']
# ['.', 'care', ']', '[', 'with', 'resident', 'plan', 'as', ',', 'meds']
# ['chat', 'a', 'doctor', 'with', ']', '[', 'had', '.', 'this', 'pm']
# ['.', 'well', 'and', 'to', 'no', 'sleeping', 'self', 'pleasant', 'concerns', 'remains']
# [']', '[', 'doctor', 'to', ',', 'by', 'on', 'resident', '2/52', 'seen']
# ['other', 'is', 'complications', 'noted', 'toileting', 'no', 'all', 'continued', 'assisted', 'taken']
# ['.', 'checks', ']', '[', 'resident', 'asleep', 'ongoing', 'self', 'comfortable', 'toiletting']
# ['awaiting', 'commenced', 'patch', 'butrans', 'x-ray', 'mobile', 'this', 'pm', 'concerns', 'voiced']
# ['.', '[', ']', 'this', 'resident', 'morning', ',', 'and', 'doctor', 'to']
# ['.', 'as', 'care', ',', 'she', 'medication', 'given', 'was', 'resident', 'morning']
#
#
# ----------------------------
# P10
# ----------------------------
# -------Coherence-------
# Number of Topics: 4
# ['to', 'and', ',', '.', '[', ']', ':', 'resident', 'of', 'care']
# ['.', 'on', 'checks', 'resident', '[', ']', 'needs', 'due', 'safety', 'taken']
# ['as', 'meds', 'checks', ']', '[', 'resident', 'charted', 'safety', 'with', 'assisted']
# ['.', 'care', 'and', 'in', 'with', ']', '[', 'resident', 'the', 'nil']
#
#
# -------Diversity-------
# Number of Topics: 3
# ['.', 'and', 'the', 'to', '[', ']', 'in', 'care', 'resident', ',']
# ['.', 'resident', '[', ']', 'care', 'with', 'and', 'in', 'as', 'assisted']
# ['.', 'checks', 'as', 'on', 'meds', ']', '[', 'resident', 'safety', 'charted']
#
#
# -------Redundancy-------
# Number of Topics: 14
# ['-', ':', ',', '.', 'in', 'at', 'to', '[', ']', 'resident']
# ['.', 'overnight', 'and', 'sleeping', 'bedside', 'well', 'commode', 'no', 'toileting', 'as']
# ['no', 'morning', 'with', '[', ']', 'given', 'resident', 'issues', 'new', 'meds']
# ['.', 'the', 'care', 'as', 'in', 'and', 'with', '[', ']', 'resident']
# ['to', ',', 'and', '.', ']', '[', 'continue', 'resident', 'of', 'her']
# ['.', 'and', ']', '[', 'resident', ',', 'the', 'with', 'as', 'in']
# ['.', 'to', ',', 'pain', 'left', 'on', 'and', ']', '[', 'resident']
# ['care', 'and', 'with', 'resident', ']', 'all', '[', 'assisted', 'due', 'needs']
# ['passing', 'urine', 'keflex', '250mg', 'commenced', 'qds', 'positive', '5/7', 'when', 'care']
# ['.', 'on', 'checks', 'resident', ']', '[', 'needs', 'in', 'due', 'with']
# [':', 'cream', '.', 'date', 'both', 'foot', 'details', 'and', 'app', 'toenails']
# ['as', 'checks', 'and', 'resident', '[', ']', 'safety', 'with', 'meds', 'charted']
# ['care', 'and', ']', 'resident', '[', 'in', 'as', 'plan', 'with', 'up']
# [',', '2200hrs', 'during', 'regarding', 'phoned', '`', 's', 'daughter', 'cough', 'exputex']
#
#
# ----------------------------
# P11
# ----------------------------
# -------Coherence-------
# Number of Topics: 15
# ['[', ']', 'about', ',', 'up', 'px', 'resident', 'in', 'and', 'form']
# ['.', 'care', 'as', 'given', ',', 'resident', '[', ']', 'charted', 'medication']
# ['2000h-', 'keeps', 'safe', 'within', 'bell', 'continuity', 'call', '.', 'reach', ',']
# ['and', '.', 'good', 'in', 'all', 'noted', 'resident', '[', ']', 'safety']
# ['.', 'night', 'resident', 'at', 'well', '[', ']', 'safety', 'check', 'all']
# ['.', ':', 'of', 'date', 'service', 'new', 'optical', 'from', ']', '[']
# ['.', 'in', '[', ']', 'resident', 'good', 'with', 'care', 'form', 'nil']
# ['as', 'resident', ']', '[', 'attending', 'care', 'examined', 'today', 'chest', 'not']
# ['plan', 'care', 'for', ':', 'evaluation', 'of', 'my', 'holistic', 'same', 'reviewed']
# ['.', 'to', 'and', 'nil', 'the', 'her', ']', '[', 'resident', 'care']
# ['.', 'on', 'checks', 'asleep', 'safety', 'going', 'resident', ']', '[', 'new']
# ['care', 'and', 'plan', 'continue', 'of', 'symptoms', 'reviewed', 'review', 'evaluation', ':']
# ['as', 'meds', 'settled', 'assisted', 'checks', 'with', 'charted', ']', '[', 'safety']
# ['resident', 'care', 'plan', ']', '[', '.', 'of', 'for', ',', 'the']
# ['in', 'resident', ']', '[', 'care', 'checks', 'meds', 'concerns', 'safety', 'and']
#
#
# -------Diversity-------
# Number of Topics: 7
# ['in', 'and', '[', ']', 'attending', 'resident', 'as', 'about', 'form', 'personal']
# ['.', 'to', 'and', 'nil', ']', '[', 'resident', 'well', 'care', 'day']
# ['.', ',', 'batch', 'no', 'administered', 'vaccine', 'given', ':', 'hse', 'by']
# ['and', 'resident', 'care', '[', ']', 'plan', '.', 'of', 'noted', 'in']
# ['.', 'as', 'checks', 'night', 'resident', 'safety', '[', ']', 'charted', 'settled']
# ['is', 'continued', 'the', 'mobilizing', '.', 'took', 'dining', 'safety', 'noted', 'self']
# ['.', 'care', ']', '[', 'resident', 'in', 'good', 'needs', 'nil', 'with']
#
#
# -------Redundancy-------
# Number of Topics: 18
# ['present', 'at', ',', 'concerns', 'nil', 'personal', 'in', 'good', 'resident', '[']
# ['.', 'care', 'as', ',', 'resident', 'planned', '[', ']', 'given', 'medication']
# [',', '.', 'no', 'vaccine', 'batch', 'administered', 'booster', 'initial', ':', 'team']
# ['and', '.', 'noted', 'good', 'all', 'in', '[', 'kept', ']', 'resident']
# ['.', 'night', 'resident', 'at', '[', ']', 'well', 'check', 'no', 'or']
# ['daughter', 'drinking', 'eating', 'well', 'interacting', 'residents', 'from', 'and', 'alert', 'new']
# ['.', 'in', 'good', '[', ']', 'resident', 'form', 'care', 'needs', 'with']
# ['plan', 'care', 'and', 'of', ':', 'reviewed', 'evaluation', 'as', 'symptoms', 'dementia']
# ['.', 'appears', 'administered', 'minimal', 'assistance', 'concerns', 'bright', 'with', ']', '[']
# ['.', 'to', 'and', 'nil', 'well', 'care', '[', ']', 'the', 'safety']
# ['.', 'checks', 'on', 'asleep', 'safety', 'going', ']', '[', 'resident', 'nil']
# ['sleeping', 'well', 'ongoing', 'toileting', 'overnight', 'on', 'night', 'administered', 'checks', 'self']
# ['as', 'meds', 'settled', 'with', 'checks', 'assisted', 'safety', 'charted', ']', '[']
# ['care', 'resident', 'plan', ']', '[', 'of', 'for', '.', 'safeguarding', 'the']
# ['care', 'resident', ']', '[', 'in', 'and', 'is', 'checks', 'safety', 'concerns']
# ['ambulatory', 'actively', 'mobile', 'dining', 'interacting', 're-orientated', 'given', '.', 'and', 'breakfast']
# [':', '.', ',', 'batch', 'no', 'administered', '[', ']', 'hse', 'vaccine']
# ['.', ']', '[', 'as', 'with', 'resident', 'medications', 'taken', 'due', 'assisted']
#
#
# ----------------------------
# P12
# ----------------------------
# -------Coherence-------
# Number of Topics: 5
# ['care', 'plan', ':', '.', '[', ']', 'of', 'for', 'resident', 'evaluation']
# ['in', ',', 'with', '[', 'resident', ']', 'good', 'assisted', 'and', 'care']
# ['.', 'resident', ']', '[', 'and', 'care', 'given', 'night', 'to', 'no']
# [',', 'she', 'her', 'was', 'in', 'is', 'nocte', 'early', 'self', 'checks']
# ['.', 'care', 'with', 'and', 'eye', ']', '[', 'resident', 'in', 'nil']
#
#
# -------Diversity-------
# Number of Topics: 3
# ['.', '[', ']', 'resident', 'care', 'checks', 'on', 'safety', 'night', 'plan']
# [',', 'she', 'her', 'was', 'in', 'is', 'nocte', 'early', 'self', 'safety']
# ['.', 'care', 'and', 'with', 'resident', ']', '[', 'eye', 'in', 'assisted']
#
#
# -------Redundancy-------
# Number of Topics: 3
# ['.', '[', ']', 'resident', 'care', 'checks', 'on', 'safety', 'night', 'plan']
# [',', 'she', 'her', 'was', 'in', 'is', 'nocte', 'early', 'self', 'safety']
# ['.', 'care', 'and', 'with', 'resident', ']', '[', 'eye', 'in', 'assisted']
#
#
# ----------------------------
# P13
# ----------------------------
# -------Coherence-------
# Number of Topics: 3
# [',', 'she', 'her', 'to', 'was', 'in', 'checks', 'all', 'were', 'safety']
# ['.', 'in', ']', '[', 'resident', 'with', 'good', 'assisted', 'meds', 'nil']
# ['.', 'to', ',', 'resident', 'and', '[', ']', 'given', 'night', 'settled']
#
#
# -------Diversity-------
# Number of Topics: 3
# [',', 'she', 'her', 'to', 'was', 'in', 'checks', 'all', 'were', 'safety']
# ['.', 'in', ']', '[', 'resident', 'with', 'good', 'assisted', 'meds', 'nil']
# ['.', 'to', ',', 'resident', 'and', '[', ']', 'given', 'night', 'settled']
#
#
# -------Redundancy-------
# Number of Topics: 19
# ['and', 'all', 'noted', 'her', 'till', 'resident', ']', '[', 'room', 'with']
# ['.', 'in', 'the', 'with', 'as', 'good', '[', ']', 'concerns', 'care']
# [',', '1', 'to', 'used', 'file', 'nails', 'burr', 'machine', 'hba1c', 'details']
# ['.', ']', '[', 'vaccine', '4.8', 'by', 'no', 'administered', 'batch', 'rti']
# ['.', 'care', 'plan', ':', 'evaluation', 'infection', 'respiratory', 'tract', 'on', 'for']
# ['.', 'to', 'checks', 'safety', 'bed', 'settled', 'resident', ']', '[', 'sleeping']
# [',', '.', 'as', ']', '[', 'resident', 'in', 'attended', 'meds', 'form']
# ['good', 'in', 'resident', ']', '[', 'nil', 'as', 'meds', 'intake', 'given']
# ['.', 'resident', 'night', 'at', '[', ']', 'check', 'well', 'or', 'staff']
# ['.', 'with', 'attended', 'assisted', 'and', 'resident', '[', ']', 'in', 'this']
# ['.', 'to', 'and', '[', ']', 'night', 'resident', 'settled', 'sleep', 'medications']
# ['is', 'care', 'day', 'done', 'good', 'all', 'treatment', 'other', 'taken', 'today']
# ['.', 'with', 'good', 'as', 'in', 'resident', 'assisted', '[', ']', 'care']
# ['.', 'to', 'and', 'bed', 'resident', '[', ']', 'medications', 'given', 'night']
# ['chesty', 'reviewed', 'afternoon', ',', 'in', 'appeared', 'px', '.', 'clear', 'to']
# ['weekly', 'result', 'blood', '4.9', ':', 'sugar', 'noted', 'care', 'all', ',']
# [',', 'she', 'to', 'her', 'was', 'in', 'were', 'the', 'all', 'and']
# ['checks', 'care', '[', ']', 'resident', 'meds', 'needs', 'as', 'all', 'safety']
# [':', 'blood', 'sugar', 'result', 'bsl', '4.9', 'mmol/l', 'weekly', 'both', 'toenails']
#
#
# ----------------------------
# P14
# ----------------------------
# -------Coherence-------
# Number of Topics: 3
# ['.', '[', ']', 'resident', 'and', 'in', 'with', 'his', 'by', '`']
# ['.', 'care', 'resident', 'checks', '[', ']', 'needs', 'assisted', 'continued', 'skin']
# ['.', 'in', ']', '[', 'resident', 'as', 'care', 'form', 'charted', 'good']
#
#
# -------Diversity-------
# Number of Topics: 3
# ['.', '[', ']', 'resident', 'and', 'in', 'with', 'his', 'by', '`']
# ['.', 'care', 'resident', 'checks', '[', ']', 'needs', 'assisted', 'continued', 'skin']
# ['.', 'in', ']', '[', 'resident', 'as', 'care', 'form', 'charted', 'good']
#
#
# -------Redundancy-------
# Number of Topics: 16
# [':', 'monthly', 'routine', 'bloods', 'palexia', '.', 'for', 'blood', 'details', 'type']
# ['.', 'to', 'well', 'continues', 'planned', 'no', 'as', 'nocte', 'care', 'concerns']
# ['to', '.', ']', '[', 'and', 'resident', 'he', 'this', 'am', 'watching']
# ['an', 'and', 'hand', 'left', 'friend', 'arrange', 'tear', ']', 'he', '[']
# ['.', 'in', '[', ']', 'resident', 'as', 'form', 'care', 'charted', 'meds']
# [',', ']', '[', 'to', '.', 'applied', 'on', 'the', 'resident', '`']
# ['and', 'alert', 'hygiene', 'skin', 'attended', '[', ']', 'resident', 'as', 'by']
# ['all', 'assisted', 'issues', 'with', ']', '[', 'in', 'care', 'given', 'to']
# ['his', 'taken', '.', 's', '`', 'appears', 'due', 'adl', 'charted', 'meds']
# ['checks', 'safety', 'meds', 'care', 'due', 'resident', 'taken', '[', ']', 'needs']
# [':', 'of', 'date', 'the', 'review', 'pain', 'service', '07-05-2025', 'nail', 'lateral']
# ['.', 'care', 'resident', ']', '[', 'needs', 'assisted', 'checks', 'continued', 'skin']
# ['and', 'is', '.', 'cream', 'care', 'other', 'all', 'with', 'skin', 'keep']
# ['will', 'pharmacy', 'send', 'call', 'phone', 'to', 'from', 'and', 'for', 'received']
# ['to', '.', ',', 'with', 'pm', 'as', 'around', 'dose', 'tomorrow', 'rheumatology']
# [':', 'administered', 'orencia', 'inj', 'nordimet', '.', '-', 'yes', 'referral', 'acknowledge']
#
#
# ----------------------------
# P15
# ----------------------------
# -------Coherence-------
# Number of Topics: 3
# ['with', '.', 'good', 'in', 'resident', '[', ']', 'meds', 'nil', 'for']
# ['.', ']', '[', 'resident', 'and', ',', 'to', 'given', 'no', 'pain']
# [',', 'his', 'in', 'settled', 'all', 'to', 'nocte', 'sleep', 'he', 'was']
#
#
# -------Diversity-------
# Number of Topics: 3
# ['with', '.', 'good', 'in', 'resident', '[', ']', 'meds', 'nil', 'for']
# ['.', ']', '[', 'resident', 'and', ',', 'to', 'given', 'no', 'pain']
# [',', 'his', 'in', 'settled', 'all', 'to', 'nocte', 'sleep', 'he', 'was']
#
#
# -------Redundancy-------
# Number of Topics: 3
# ['with', '.', 'good', 'in', 'resident', '[', ']', 'meds', 'nil', 'for']
# ['.', ']', '[', 'resident', 'and', ',', 'to', 'given', 'no', 'pain']
# [',', 'his', 'in', 'settled', 'all', 'to', 'nocte', 'sleep', 'he', 'was']
#
#
# ----------------------------
# P16
# ----------------------------
# -------Coherence-------
# Number of Topics: 5
# ['care', ']', '[', 'checks', 'resident', 'safety', 'and', 'is', 'meds', 'needs']
# ['.', ',', 'for', ':', 'resident', '[', ']', 'to', 'and', 'plan']
# ['.', 'resident', '[', ']', 'in', 'the', ',', 'and', 'her', 'no']
# ['as', ']', '[', 'resident', 'with', 'charted', 'assisted', 'maintained', 'checks', 'settled']
# ['.', 'in', ']', '[', 'resident', 'nil', 'with', 'due', 'as', 'assisted']
#
#
# -------Diversity-------
# Number of Topics: 6
# ['care', 'is', 'and', 'resident', ']', '[', 'checks', 'safety', 'skin', 'done']
# ['plan', 'continue', 'reviewed', 'care', '.', 'and', 'unaltered', 'evaluation', 'x4', 'laxatives']
# ['.', 'resident', '[', ']', 'no', 'in', ',', 'given', 'the', 'all']
# ['as', '.', 'resident', ']', '[', 'with', 'charted', 'assisted', 'maintained', 'and']
# ['.', 'in', ']', '[', 'resident', 'nil', 'and', 'with', 'as', 'checks']
# ['u/a', 'completed', 'nad', 'has', 'med', 'unkown', 'person', 'poor', 'prescribed', 'provided']
#
#
# -------Redundancy-------
# Number of Topics: 10
# ['to', 'checks', 'safety', 'care', 'ongoing', 'needs', 'night', 'meds', ']', '[']
# ['sleeping', ':', 'overnight', 'care', 'well', 'for', 'plan', 'dietetic', 'see', 'notes']
# ['.', 'resident', '[', ']', ',', 'no', 'given', 'night', 'all', 'at']
# ['as', ']', '[', 'resident', 'with', 'charted', 'assisted', 'meds', 'checks', 'safety']
# ['.', 'in', 'and', ']', '[', 'resident', 'due', 'with', 'good', 'assisted']
# ['u/a', 'nad', 'completed', 'continuing', 'med', 'concern', 'checks', 'all', 'assisted', 'safety']
# ['.', 'and', 'in', 'the', 'her', 'nil', 'to', 'as', 'restaurant', 'had']
# ['.', 'is', ',', 'resident', 'care', 'and', ']', '[', 'done', 'the']
# ['.', 'checks', 'as', 'on', 'care', '[', ']', 'resident', 'charted', 'meds']
# ['.', ',', 'administered', 'no', 'reports', 'altered', 'integrity', 'vaccine', 'batch', '[']
#
#
# ----------------------------
# P17
# ----------------------------
# -------Coherence-------
# Number of Topics: 15
# ['both', 'app', '.', 'and', 'toenails', 'feet', 'cut', 'filed', 'foot', 'cream']
# ['.', 'with', 'independent', '`', 'resident', '[', ']', 's', 'nil', 'in']
# [']', '[', 'resident', 'in', 'had', 'dining', 'room', 'to', 'breakfast', 'and']
# ['.', 'as', 'with', 'care', 'for', 'planned', 'the', ',', 'content', 'day']
# ['.', '[', ']', 'resident', 'in', 'and', 'with', 'good', 'the', 'nil']
# [':', 'date', 'of', 'service', 'details', '.', 'new', 'optical', 'type', 'nad']
# ['.', ',', 'his', 'he', 'in', 'is', ']', '[', 'resident', 'settled']
# ['.', 'and', ']', '[', 'resident', 'to', 'medications', 'settled', 'sleep', 'given']
# ['pressure', 'areas', 'when', 'skin', 'is', 'continued', 'care', 'checked', 'conservatory', 'now']
# [',', 'to', ']', '[', '.', 'gp', 'daughter', 'by', 'and', 'hip']
# ['meds', ']', '[', 'as', 'resident', 'charted', 'nil', 'due', 'good', 'concerns']
# [',', 'he', 'is', 'settled', 'and', 'was', 'his', '[', ']', 'present']
# ['[', ']', ',', 'daughter', 'this', 'for', 'of', 'the', 'resident', 'to']
# ['in', 'care', 'plan', 'and', 'for', 'month', 'loss', 'weight', 'to', 'chart']
# ['.', 'resident', 'no', ',', 'and', '[', ']', 'well', 'at', 'night']
#
#
# -------Diversity-------
# Number of Topics: 5
# ['continuity', 'report', 'of', 'handover', 'nurse', 'staff', 'incident', 'supplements', 'made', 'nok']
# ['.', 'with', '[', ']', 'resident', 'in', 'nil', 'independent', 'meds', 'form']
# ['.', ']', '[', 'and', 'to', 'resident', 'given', 'settled', 'medications', 'sleep']
# ['.', 'care', 'for', 'planned', 'the', ',', 'day', 'reported', 'content', 'of']
# ['.', ',', 'resident', 'his', ']', '[', 'he', 'in', 'is', 'safety']
#
#
# -------Redundancy-------
# Number of Topics: 5
# ['continuity', 'report', 'of', 'handover', 'nurse', 'staff', 'incident', 'supplements', 'made', 'nok']
# ['.', 'with', '[', ']', 'resident', 'in', 'nil', 'independent', 'meds', 'form']
# ['.', ']', '[', 'and', 'to', 'resident', 'given', 'settled', 'medications', 'sleep']
# ['.', 'care', 'for', 'planned', 'the', ',', 'day', 'reported', 'content', 'of']
# ['.', ',', 'resident', 'his', ']', '[', 'he', 'in', 'is', 'safety']
#
#
# ----------------------------
# P18
# ----------------------------
# -------Coherence-------
# Number of Topics: 10
# ['she', 'her', 'for', 'i', 'to', '[', ']', 'is', 'resident', 'plan']
# [':', 'date', 'details', 'service', 'type', 'new', 'of', 'from', 'optical', 'check']
# ['.', 'to', 'and', 'well', 'care', ']', '[', 'no', 'continues', 'as']
# ['.', 'resident', 'and', 'night', '[', ']', 'care', 'at', 'the', 'given']
# ['.', 'care', 'checks', '[', ']', 'resident', 'needs', 'asleep', 'skin', 'ongoing']
# ['.', ']', '[', 'of', ',', 'appointment', 'her', 'resident', 'on', 'for']
# ['.', '[', ']', 'resident', 'care', 'in', 'with', 'as', 'needs', 'assisted']
# ['and', 'in', 'her', 'resident', 'due', ']', '[', 'meds', 'charted', 'taken']
# ['.', 'care', 'as', 'in', 'charted', 'given', '[', ']', 'resident', 'form']
# ['to', '.', ']', '[', 'red', 'by', 'small', 'with', 's', '`']
#
#
# -------Diversity-------
# Number of Topics: 4
# ['[', ']', 'resident', 'for', 'to', 'her', 'is', 'and', '.', 'on']
# [':', 'blood', 'result', ',', 'sugar', 'bsl', 'weekly', 'of', '.', 'to']
# ['.', 'care', 'resident', ']', '[', 'needs', 'checks', 'assisted', 'as', 'with']
# ['.', 'and', 'in', 'resident', '[', ']', 'as', 'care', 'charted', 'good']
#
#
# -------Redundancy-------
# Number of Topics: 18
# ['plan', 'care', 'for', 'holistic', 'my', 'evaluation', ':', ']', '[', 'resident']
# ['10.4', ':', 'weekly', 'bsl', 'sugar', 'result', 'blood', 'care', 'all', ']']
# ['.', 'to', 'no', 'continues', 'well', 'concerns', 'care', 'and', 'planned', 'report']
# ['.', 'resident', '[', ']', 'and', 'night', 'at', 'care', ',', 'all']
# ['.', 'care', 'skin', 'checks', 'needs', 'resident', '[', ']', 'asleep', 'continued']
# ['.', 'both', 'and', 'cream', 'app', 'filed', 'feet', 'toenails', 'cut', 'foot']
# ['.', '[', ']', 'resident', 'care', 'needs', 'checks', 'on', 'sleeping', 'as']
# ['and', 'in', 'her', '`', 's', 'adl', '[', ']', 'taken', 'resident']
# ['.', 'care', 'as', '[', ']', 'resident', 'assisted', 'planned', 'given', 'and']
# ['to', 'red', ',', '.', 'small', 'dressing', 'area', 'spot', 'buttocks', 'on']
# [']', '[', 'doctor', '.', 'to', 'a', 'for', 'on', 'by', 'pessary']
# ['checks', 'care', 'safety', '[', ']', 'resident', 'meds', 'needs', 'due', 'assisted']
# ['given', 'care', 'due', 'skin', 'medications', 'well', 'the', 'during', 'maintained', 'nil']
# [':', 'of', '.', ']', '[', 'date', 'on', 'new', ',', 'appointment']
# ['.', 'care', 'in', 'as', 'charted', 'meds', 'resident', 'due', ']', '[']
# ['.', 'in', 'good', 'with', ',', 'care', 'the', 'morning', ']', '[']
# ['blood', ':', 'result', 'sugar', 'bsl', 'weekly', 'full', 'bloods', 'prolia', '10.8']
# ['.', 'ring', 'overnight', 'on', 'pessary', 'tuesday', 'for', 'to', 'thigh', 'complained']
#
#
# ----------------------------
# P19
# ----------------------------
# -------Coherence-------
# Number of Topics: 8
# [',', 'observations', '.', 'in', 'min', 'per', 'cnm', 'stable', 'are', 'blood']
# ['and', '[', ']', '.', 'resident', ',', 'in', 'good', 'to', 'with']
# ['plan', 'care', ':', 'sensor', 'evaluation', 'an', 'risk', 'fall', 'falls', 'of']
# ['around', 'taken', 'and', 'appears', 'charted', 'due', 'meds', 'as', 'resident', 'content']
# ['hb', 'monthly', 'aware', 'doctor', 'continue', ',', ')', '(', 'hemacue', 'check']
# ['checks', 'resident', ']', '[', 'safety', 'care', 'meds', 'needs', 'due', 'night']
# ['.', 'resident', '[', ']', 'with', 'as', 'in', 'charted', 'meds', 'due']
# ['.', ']', '[', 'resident', 'to', ',', 'checks', 'on', 'self', 'asleep']
#
#
# -------Diversity-------
# Number of Topics: 3
# ['.', '[', ']', 'resident', 'to', ',', 'and', 'the', 'at', 'night']
# ['.', 'resident', '[', ']', 'as', 'meds', 'charted', 'due', 'with', 'in']
# ['.', 'care', 'on', 'checks', ',', 'safety', 'resident', 'and', 'plan', ']']
#
#
# -------Redundancy-------
# Number of Topics: 8
# [',', 'observations', '.', 'in', 'min', 'per', 'cnm', 'stable', 'are', 'blood']
# ['and', '[', ']', '.', 'resident', ',', 'in', 'good', 'to', 'with']
# ['plan', 'care', ':', 'sensor', 'evaluation', 'an', 'risk', 'fall', 'falls', 'of']
# ['around', 'taken', 'and', 'appears', 'charted', 'due', 'meds', 'as', 'resident', 'content']
# ['hb', 'monthly', 'aware', 'doctor', 'continue', ',', ')', '(', 'hemacue', 'check']
# ['checks', 'resident', ']', '[', 'safety', 'care', 'meds', 'needs', 'due', 'night']
# ['.', 'resident', '[', ']', 'with', 'as', 'in', 'charted', 'meds', 'due']
# ['.', ']', '[', 'resident', 'to', ',', 'checks', 'on', 'self', 'asleep']
#
#
# ----------------------------
# P2
# ----------------------------
# -------Coherence-------
# Number of Topics: 11
# ['she', 'the', 'doctor', 'that', 'name', 'same', ';', 'nurse', 'to', 'was']
# [',', 'her', 'all', 'was', 'she', 'checks', 'in', 'is', 'on', 'needs']
# ['urine', ':', 'negative', '6', 'dipstick-', 'analysis', 'na', 'urinalysis', 'treatment', 'ph']
# ['.', ':', ']', '[', ',', 'of', 'to', 'resident', 'no', 'date']
# ['fluid', 'is', 'alert', 'medicines', 'bright', 'food', 'raised', 'today', 'the', 'intact']
# ['.', 'with', 'resident', ']', '[', 'as', 'meds', 'assisted', 'nil', 'care']
# ['.', 'with', 'to', 'in', 'and', 'rollator', 'prescribed', 'be', 'took', 'baseline']
# ['.', 'care', '[', ']', 'resident', 'plan', 'with', 'needs', 'for', 'of']
# ['.', 'to', 'and', 'by', 'settled', 'resident', ']', '[', 'medications', 'given']
# [',', 'her', ']', '[', 'in', 'resident', 'was', 'she', 'to', 'and']
# ['.', 'to', ']', '[', 'and', 'resident', ',', 'the', 'pain', 'on']
#
#
# -------Diversity-------
# Number of Topics: 3
# ['.', 'and', 'to', '[', ']', 'resident', 'by', 'settled', 'she', 'night']
# [',', 'her', '[', ']', 'resident', '.', 'care', 'in', 'all', 'was']
# ['.', 'with', 'in', ']', 'resident', '[', 'and', 'form', 'assisted', 'nil']
#
#
# -------Redundancy-------
# Number of Topics: 11
# ['she', 'the', 'doctor', 'that', 'name', 'same', ';', 'nurse', 'to', 'was']
# [',', 'her', 'all', 'was', 'she', 'checks', 'in', 'is', 'on', 'needs']
# ['urine', ':', 'negative', '6', 'dipstick-', 'analysis', 'na', 'urinalysis', 'treatment', 'ph']
# ['.', ':', ']', '[', ',', 'of', 'to', 'resident', 'no', 'date']
# ['fluid', 'is', 'alert', 'medicines', 'bright', 'food', 'raised', 'today', 'the', 'intact']
# ['.', 'with', 'resident', ']', '[', 'as', 'meds', 'assisted', 'nil', 'care']
# ['.', 'with', 'to', 'in', 'and', 'rollator', 'prescribed', 'be', 'took', 'baseline']
# ['.', 'care', '[', ']', 'resident', 'plan', 'with', 'needs', 'for', 'of']
# ['.', 'to', 'and', 'by', 'settled', 'resident', ']', '[', 'medications', 'given']
# [',', 'her', ']', '[', 'in', 'resident', 'was', 'she', 'to', 'and']
# ['.', 'to', ']', '[', 'and', 'resident', ',', 'the', 'pain', 'on']
#
#
# ----------------------------
# P20
# ----------------------------
# -------Coherence-------
# Number of Topics: 8
# ['.', 'and', 'filed', 'pared', 'toe', 'app', 'toenails', 'cut', 'cream', 'foot']
# ['with', 'her', '[', ']', 'in', 'resident', 'and', 'meds', 'due', 'assisted']
# ['.', 'resident', ']', '[', ',', 'as', 'charted', 'in', 'meds', 'needs']
# ['.', 'with', 'in', 'nil', 'charted', 'given', 'as', 'meds', 'form', '[']
# ['time', 'noted', 'issues', 'till', 'all', 'nil', ']', 'small', '[', 'received']
# ['.', 'to', '[', ']', 'resident', 'sleeping', 'care', 'on', 'with', 'needs']
# [':', 'antibiotic', 'plan', 'urinary', 'doctor', 'care', 'blood', 'post', 'tract', 'infection']
# ['.', 'care', 'checks', 'needs', ']', '[', 'resident', 'continued', 'assisted', 'asleep']
#
#
# -------Diversity-------
# Number of Topics: 3
# ['.', 'to', ',', ':', 'plan', 'of', ']', '[', 'care', 'and']
# ['.', 'resident', '[', ']', 'care', 'assisted', 'checks', 'with', 'needs', 'meds']
# ['.', 'resident', ']', '[', 'with', 'in', 'as', 'care', 'needs', 'charted']
#
#
# -------Redundancy-------
# Number of Topics: 19
# ['left', '?', 'of', ',', 'mark', '3rd', 'corn', 'bruise', 'to', 'the']
# ['[', ']', 'resident', 'with', 'and', 'assisted', 'needs', 'nil', '.', 'concerns']
# ['.', 'in', 'with', 'and', 'assisted', 'resident', '[', ']', 'the', 'her']
# ['.', 'and', 'filed', 'wound', 'both', 'pared', 'feet', 'app', 'toenails', 'cut']
# ['seems', 'left', 'area', 'small', 'on', 'to', 'bruising', 'and', 'noted', 'arm']
# ['.', 'to', 'care', 'well', 'continues', ',', 'as', 'plan', '[', ']']
# [',', 'call', 'bell', ';', 'blood', ']', '[', 'to', 'use', 'no']
# ['antibiotic', 'plan', 'care', ':', 'family', '[', ']', '.', 'resident', 'evaluation']
# ['.', 'on', 'checks', 'needs', '[', ']', 'resident', 'sleeping', 'comfortably', 'care']
# ['still', 'with', 'evident', 'and', 'noted', 'old', 'is', 'bruise', 'right', 'safety']
# ['medication', 'voiced', '[', ']', 'complaints', 'drink', 'doctor', 'by', 'discontinued', 'ensure']
# ['.', 'with', 'in', 'given', 'nil', 'good', '[', ']', 'appears', 'resident']
# ['.', 'care', 'as', 'was', 'morning', 'with', ',', 'she', 'a', 'resident']
# ['.', 'night', 'at', 'resident', 'no', 'well', 'with', 'or', 'from', 'continued']
# ['her', 'with', 'in', '.', 'and', ']', '[', 'resident', 'due', 's']
# ['.', 'care', 'checks', 'needs', ']', '[', 'resident', 'continued', 'asleep', 'ongoing']
# ['checks', 'as', 'charted', 'due', 'meds', 'safety', 'taken', 'needs', 'with', 'maintained']
# ['nil', 'resident', 'as', 'good', 'in', 'form', 'on', 'well', 'assisted', 'needs']
# ['.', 'resident', ']', '[', 'as', 'in', ',', 'meds', 'needs', 'charted']
#
#
# ----------------------------
# P3
# ----------------------------
# -------Coherence-------
# Number of Topics: 7
# ['.', 'resident', ']', '[', 'checks', 'care', 'needs', 'as', 'in', 'meds']
# ['.', 'in', 'as', '[', 'meds', ']', 'due', 'charted', 'resident', 'form']
# ['.', ']', '[', 'resident', 'to', 'and', ',', 'on', 'night', 'at']
# ['prn', 'for', 'requested', '[', ']', 'resident', 'given', 'naproxen', '.', 'same']
# ['.', 'and', 'in', ']', '[', 'her', 'resident', 'the', 'with', 'to']
# ['she', '.', 'to', 'her', ',', 'and', 'a', 'had', 'happy', ']']
# [']', '[', 'with', '.', 'resident', 'in', 'assisted', 'as', 'meds', 'due']
#
#
# -------Diversity-------
# Number of Topics: 3
# ['.', 'resident', ']', '[', 'checks', 'care', 'needs', 'given', 'as', 'assisted']
# ['.', 'in', '[', ']', 'as', 'resident', 'meds', 'due', 'charted', 'with']
# ['.', ']', '[', 'to', 'resident', 'and', ',', 'her', 'she', 'with']
#
#
# -------Redundancy-------
# Number of Topics: 17
# ['.', 'complaints', 'voiced', 'nil', 'attended', 'given', 'appears', 'in', 'form', 'charted']
# ['in', 'room', 'her', 'to', 'taken', 'due', 'music', 'listening', 'charted', 'as']
# ['.', 'to', ']', '[', 'and', 'on', ',', 'resident', 'of', 'the']
# ['prn', '.', 'mouth', 'cough', 'given', 'dry', 'exputex', 'for', 'of', 'gel']
# ['she', 'is', 'her', '.', 'to', 'and', 'the', 'was', 'with', 'about']
# ['.', '500', 'mg', 'pain', 'leg', 'back', 'complained', 'around', 'score', 'cannard']
# ['in', 'her', 'and', 'with', ']', '[', 'resident', 'meds', 'due', 'taken']
# [':', '.', 'plan', 'care', ',', 'gp', 'infection', 'evaluation', ']', '[']
# ['.', ']', '[', 'resident', 'to', ',', 'for', 'and', 'this', 'in']
# ['.', 'and', '[', ']', 'resident', 'bed', 'at', 'concerns', 'no', 'to']
# ['.', 'night', 'at', 'resident', 'given', '[', ']', 'prn', 'and', 'with']
# ['.', 'in', '[', ']', 'resident', 'as', 'meds', 'due', ',', 'charted']
# ['.', 'and', 'resident', ']', '[', 'reassured', ',', 'taken', 'meds', 'in']
# ['.', 'checks', ']', '[', 'resident', 'care', 'needs', 'as', 'assisted', 'meds']
# ['[', ']', 'resident', '.', 'doctor', 'to', 'and', 'a', 'her', ',']
# ['with', 'and', 'new', 'all', 'the', 'issues', 'in', 'to', 'meds', 'assisted']
# ['.', 'to', 'her', 'in', 'the', 'and', '[', ']', 'resident', 'received']
#
#
# ----------------------------
# P4
# ----------------------------
# -------Coherence-------
# Number of Topics: 6
# ['daily', 'betadine', 'paint', 'dressing', 'of', '.', 'continued', 'toes', 'to', 'moisturized']
# ['.', 'and', ']', '[', 'in', 'resident', 'as', 'meds', 'due', 'charted']
# [',', ']', '[', 'appointment', 'this', '.', 'her', 'doctor', 'for', 'law']
# ['.', 'care', 'resident', '[', ']', 'needs', 'assisted', 'checks', 'continued', 'to']
# [',', '.', 'and', 'noted', 'of', 'the', ']', '[', 'this', 'small']
# ['.', '[', ']', 'to', 'resident', 'and', ',', 'care', 'with', 'in']
#
#
# -------Diversity-------
# Number of Topics: 4
# ['.', 'to', 'of', 'daily', 'betadine', 'paint', 'dressing', 'continued', '[', ']']
# ['.', 'and', ']', '[', 'resident', 'care', 'in', 'as', 'due', 'meds']
# [',', ']', '[', '.', 'to', 'for', 'her', 'doctor', 'appointment', 'this']
# ['.', 'resident', 'care', '[', ']', 'needs', 'assisted', 'to', 'checks', ',']
#
#
# -------Redundancy-------
# Number of Topics: 15
# ['to', 'eye', 'late', 'appears', '[', 'needs', 'settled', 'bed', 'checks', 'asleep']
# ['meds', 'due', 'charted', 'care', ']', 'as', '[', 'resident', 'with', 'and']
# ['days', 'as', 'bno', 'safety', 'laxatives', '4', 'needed', 'x', 'having', 'with']
# ['in', '.', '[', ']', 'her', 'given', 'resident', 'with', 'as', 'assisted']
# [',', '++', '.', 'rest', 'leu', 'now', 'chesty', 'noted', 'u/a', 'this']
# ['.', '[', ']', 'resident', 'to', 'her', 'for', 'it', 'care', 'on']
# ['care', '.', 'plan', 'wound', 'and', '2nd', ':', 'evaluation', 'on', ']']
# ['.', 'right', 'to', 'resident', ']', '[', 'on', 'and', 'heel', 'toe']
# ['.', 'dressing', 'daily', 'of', 'betadine', 'paint', 'toes', 'to', 'continued', 'on']
# ['examined', 'doctor', ',', '10.45', 'pm', 'now', 'chest', 'by', '7/7', 'back']
# ['and', 'by', 'in', 'staff', 'appears', 'form', 'due', 'good', 'meds', 'charted']
# [',', '.', '[', ']', 'appointment', 'to', 'resident', 'her', 'daughter', 'law']
# ['.', 'care', ']', '[', 'resident', 'needs', 'assisted', 'in', 'as', 'continued']
# ['.', 'resident', '[', ']', 'settled', 'care', 'and', 'checks', 'night', 'safety']
# ['.', 'to', ']', '[', 'resident', ',', 'and', 'of', 'with', 'for']
#
#
# ----------------------------
# P5
# ----------------------------
# -------Coherence-------
# Number of Topics: 8
# ['.', ']', '[', 'resident', 'checks', 'ongoing', 'asleep', 'self', 'toiletting', 'comfortable']
# ['.', 'resident', 'night', 'care', 'all', 'at', '[', ']', 'with', 'and']
# ['.', 'checks', '[', ']', 'resident', 'self', 'sleeping', 'continued', 'as', 'on']
# ['her', 'in', 'with', ']', 'resident', '[', 'meds', 'as', 'due', 'taken']
# ['pain', 'tramadol', 'prn', 'given', 'of', 'requested', 'leg', 'complained', 'this', 'at']
# ['.', ']', '[', 'to', ',', 'resident', 'and', 'same', 'her', 'of']
# ['.', '[', ']', 'in', 'resident', 'with', 'as', 'charted', 'meds', 'due']
# ['checks', 'care', '[', ']', 'resident', 'meds', 'safety', 'needs', 'due', 'taken']
#
#
# -------Diversity-------
# Number of Topics: 3
# ['.', ']', '[', 'resident', 'asleep', 'checks', 'ongoing', 'self', 'toiletting', 'comfortable']
# ['.', 'in', '[', ']', 'resident', 'with', 'her', 'as', 'charted', 'meds']
# ['.', 'resident', 'checks', '[', ']', 'safety', 'night', 'on', 'settled', 'as']
#
#
# -------Redundancy-------
# Number of Topics: 19
# ['.', 'asleep', ']', '[', 'resident', 'checks', 'ongoing', 'self', 'toiletting', 'comfortable']
# ['.', 'night', 'resident', 'at', 'all', 'the', '[', ']', 'well', 'no']
# ['.', 'checks', '[', ']', 'resident', 'meds', 'continued', 'self', 'on', 'safety']
# ['her', 'with', 'in', 'resident', ']', '[', 'taken', 'meds', 'due', 'as']
# ['both', 'cream', '.', 'and', 'filed', 'app', 'foot', 'feet', 'cut', 'toenails']
# [']', '[', 'to', 'doctor', '.', ',', 'by', 'her', 'seen', 'of']
# ['.', '[', ']', 'in', 'resident', 'with', 'due', 'charted', 'as', 'meds']
# ['changes', 'nil', ',', 'issues', 'ongoing', 'checks', '[', 'resident', ']', 'safety']
# ['is', ']', '[', 'resident', 'and', 'with', 'care', '.', 'intake', 'due']
# ['progress', ':', 'medication', 'px', 'expressed', 'blood', 'full', 'safety', 'checks', '.']
# ['.', 'in', 'as', 'with', '[', ']', 'resident', 'care', 'form', 'morning']
# ['.', 'to', 'well', 'and', 'no', ']', '[', 'sleeping', 'resident', 'continues']
# [':', 'date', ',', 'of', 'dental', 'service', '25-08-2025', 'from', 'provider', 'and']
# ['.', ',', 'of', 'pain', 'tramadol', 'given', 'prn', 'for', 'leg', 'resident']
# ['.', 'given', 'pain', 'on', 'nocte', 'this', 'observed', 'due', 'medications', 'otherwise']
# ['.', 'chnages', 'assessments', 'reviewed', 'roomand', '06.45', 'painful', 'arms', 'stayed', 'mobilized']
# ['care', 'checks', 'needs', 'plan', 'ongoing', 'resident', '[', ']', 'assisted', 'safety']
# ['care', 'noted', 'assisted', 'all', 'new', 'needs', 'with', 'and', '.', 'is']
# ['.', '[', ']', 'resident', 'with', 'this', 'in', 'am', '`', 'charted']
#
#
# ----------------------------
# P6
# ----------------------------
# -------Coherence-------
# Number of Topics: 3
# ['[', ']', 'in', 'resident', 'as', 'charted', 'with', 'assisted', 'care', 'due']
# ['.', 'and', ']', '[', 'resident', 'to', 'with', 'in', 'care', 'given']
# [',', 'in', 'was', 'his', '.', 'he', 'and', 'place', 'bed', 'the']
#
#
# -------Diversity-------
# Number of Topics: 3
# ['[', ']', 'in', 'resident', 'as', 'charted', 'with', 'assisted', 'care', 'due']
# ['.', 'and', ']', '[', 'resident', 'to', 'with', 'in', 'care', 'given']
# [',', 'in', 'was', 'his', '.', 'he', 'and', 'place', 'bed', 'the']
#
#
# -------Redundancy-------
# Number of Topics: 16
# ['and', 'all', '[', ']', 'nil', 'new', 'kept', 'resident', 'due', 'in']
# ['.', 'and', 'resident', ']', '[', 'with', 'to', 'in', 'assisted', 'given']
# [',', 'in', 'was', 'his', '.', 'he', 'place', 'and', 'bed', 'were']
# ['plan', ':', 'care', 'sensor', 'evaluation', 'floor', '.', 'getting', 'dresses', 'washed']
# ['bnox3/7', 'bno', 'microlax', '4', 'prn', 'given', 'x', '.', 'lactulose', 'observe']
# ['checks', 'resident', '[', ']', 'care', 'as', 'safety', 'needs', 'meds', 'in']
# ['and', 'in', 'the', 'resident', ']', '[', ',', 'good', 'was', 'well']
# ['.', 'as', 'care', ',', 'in', 'charted', '[', ']', 'resident', 'his']
# ['with', 'assisted', ']', '[', 'given', 'in', 'resident', 'new', 'as', 'charted']
# ['ear', 'drops', 'cerumol', 'on', 'applied', 'remain', 'night', 'can', 'that', 'it']
# ['care', 'is', '.', 'and', 'concerns', 'safety', ']', 'the', 'resident', '[']
# ['sent', 'chiropody', 'referral', 'for', 'toenails', 'nok', 'spent', 'and', 'voiced', 'on']
# [',', '.', 'to', 'and', ']', '[', 'he', 'resident', 'his', 'the']
# ['to', 'he', 'and', 'it', 'falls', ',', 'the', 'risk', 'when', 'high']
# [',', 's/b', 'gp', 'ears', 'pain', 'examined', 'wax', 'noted', 'no', 'any']
# ['.', 'to', 'the', ',', '[', ']', 'and', 'on', 'resident', 'of']
#
#
# ----------------------------
# P7
# ----------------------------
# -------Coherence-------
# Number of Topics: 7
# [':', 'details', 'date', ',', 'of', 'type', 'dental', '29-01-2025', '-', '.']
# [']', '[', 'resident', 'checks', 'meds', 'with', 'due', 'in', 'care', 'safety']
# ['.', 'night', 'resident', 'to', ']', '[', 'given', 'sleep', 'medications', 'and']
# ['.', 'filed', 'foot', 'toenails', 'cream', 'app', 'cut', 'and', 'both', 'feet']
# [',', 'he', 'his', 'is', 'in', 'bed', ']', 'self', '[', 'checks']
# [',', '.', 'in', 'and', 'is', 'was', 'resident', ']', '[', 'the']
# ['.', 'good', '[', ']', 'resident', 'in', 'with', 'assisted', 'as', 'meds']
#
#
# -------Diversity-------
# Number of Topics: 3
# ['good', '.', 'as', '[', ']', 'resident', ',', 'meds', 'given', 'charted']
# ['.', ',', 'in', ']', '[', 'resident', 'his', 'he', 'is', 'checks']
# ['.', 'and', 'resident', ']', '[', 'night', 'medications', 'settled', 'to', 'all']
#
#
# -------Redundancy-------
# Number of Topics: 6
# [':', 'details', 'date', '-', ',', '.', 'of', 'type', 'dental', '29-01-2025']
# [']', '[', 'good', 'resident', 'meds', 'with', 'as', 'charted', 'assisted', 'due']
# ['.', 'night', 'resident', 'to', ']', '[', 'given', 'sleep', 'and', 'settled']
# ['.', 'it', 'gp', 'eyes', 'by', 'drops', 'r/v', 'sore', 'but', ',']
# [',', 'is', 'he', 'his', 'in', ']', 'was', 'checks', '[', 'bed']
# ['.', 'in', ',', 'and', '[', ']', 'resident', 'the', 'good', 'as']
#
#
# ----------------------------
# P8
# ----------------------------
# -------Coherence-------
# Number of Topics: 9
# ['the', '.', 'of', ']', '[', 'to', 'resident', 'in', 'and', 'tilt']
# ['.', 'care', 'as', 'with', '[', ']', ',', 'resident', 'in', 'assisted']
# ['.', 'to', 'and', 'with', 'her', ']', '[', 'this', 'in', 'resident']
# ['with', '[', ']', 'resident', 'as', 'given', 'appears', 'meds', 'assisted', 'nil']
# [',', 'her', 'she', 'to', 'in', 'was', '.', 'all', 'bed', 'resident']
# ['checks', 'in', 'care', '[', ']', 'safety', 'resident', 'all', 'nil', 'meds']
# ['.', ']', '[', 'and', 'to', 'resident', 'night', 'settled', 'given', 'medications']
# [',', 'the', ']', '[', 'to', 'on', '.', 'resident', 'her', 'and']
# ['.', 'and', 'is', 'to', 'no', ']', '[', 'from', 'with', 'resident']
#
#
# -------Diversity-------
# Number of Topics: 3
# ['.', '[', ']', 'resident', ',', 'to', 'and', 'the', 'for', 'of']
# ['.', 'and', '[', ']', 'resident', 'to', 'with', 'given', 'as', 'care']
# ['.', ',', 'her', 'to', 'in', 'she', 'was', 'resident', ']', '[']
#
#
# -------Redundancy-------
# Number of Topics: 17
# ['the', 'of', 'ot', 'tilt', 'using', 'function', 'cushion', 'to', '.', '[']
# ['.', ',', 'care', 'as', 'with', 'to', '[', ']', 'resident', 'in']
# ['.', 'to', 'with', 'and', 'her', 'in', 'this', ']', '[', 'resident']
# [',', 'room', '[', ']', 'served', 'resident', 'of', 'meals', 'gp', 'and']
# [',', 'her', 'she', 'to', 'in', 'was', 'all', 'bed', '.', 'were']
# ['care', 'in', 'resident', 'needs', 'all', '[', ']', 'checks', 'meds', 'due']
# ['.', '[', ']', 'resident', 'to', ':', ',', 'she', 'and', 'bno']
# [',', 'the', 'her', 'on', 'in', 'to', 'she', 'and', '.', ']']
# ['is', 'alert', 'bright', 'and', 'intake', 'fluid', 'food', 'took', 'the', 'no']
# [',', ']', '[', '.', 'on', ':', 'resident', 'left', 'batch', 'administered']
# ['.', 'and', 'to', 'night', 'resident', 'settled', '[', ']', 'given', 'all']
# ['and', 'personal', ',', 'fluids', 'morning', 'food', 'breakfast', 'looks', 'medications', 'rectal']
# ['.', 'in', '[', ']', 'morning', 'hospital', 'resident', 'no', 'this', 'form']
# ['.', 'the', 'foot', 'raised', 'observe', 'app', 'concern', 'cream', 'appears', 'tolerated']
# ['her', 'checks', 'due', 'care', 'all', 'medications', 'issues', 'on', 'resident', 'given']
# ['.', ']', '[', 'resident', 'with', ',', 'and', 'as', 'in', 'to']
# ['gp', 'for', 'and', 'reviewed', 'to', ',', 'plan', 'see', 'in', 'notes']
#
#
# ----------------------------
# P9
# ----------------------------
# -------Coherence-------
# Number of Topics: 3
# ['as', '[', ']', 'resident', 'charted', 'and', 'safety', 'with', 'meds', 'assisted']
# ['.', 'and', ']', '[', 'in', 'resident', 'care', 'with', ',', 'her']
# ['.', 'in', 'checks', 'on', 'resident', '[', ']', 'safety', 'meds', 'as']
#
#
# -------Diversity-------
# Number of Topics: 3
# ['as', '[', ']', 'resident', 'charted', 'and', 'safety', 'with', 'meds', 'assisted']
# ['.', 'and', ']', '[', 'in', 'resident', 'care', 'with', ',', 'her']
# ['.', 'in', 'checks', 'on', 'resident', '[', ']', 'safety', 'meds', 'as']
#
#
# -------Redundancy-------
# Number of Topics: 18
# ['found', 'sitting', 'floor', 'review', 'gp', 'the', 'post', 'on', 'issues', '.']
# ['.', 'in', 'care', ']', '[', 'resident', 'and', 'with', 'due', 'taken']
# ['gp', 'changes', 'made', 'by', 'reviewed', 'nil', 'seen', 'lower', 'review', 'for']
# ['.', 'to', 'her', 'in', 'as', 'for', 'of', 'checks', 'bed', 'with']
# ['.', 'to', 'planned', ',', 'care', 'within', 'reach', 'handover', 'call', 'report']
# [']', '[', 'and', 'resident', '.', 'care', 'plan', 'is', 'her', 'of']
# [':', 'infection', '.', 'interactions', '5', 'amoxicillin', '500mg', 'days', 'tds', 'tooth']
# ['overnight', 'planned', 'complaints', 'reported', 'knee', 'hourly', 'continue', '.', 'pain', 'no']
# ['.', 'in', 'needs', '[', ']', 'resident', 'as', 'nil', 'care', 'attended']
# ['well', 'overnight', 'sleeping', 'seems', 'nil', 'ongoing', 'checks', 'new', 'continued', 'needs']
# ['.', 'on', ']', 'for', 'checks', '[', 'resident', 'as', 'settled', 'toileting']
# ['as', 'checks', 'charted', 'resident', '[', 'safety', ']', 'meds', 'with', 'maintained']
# ['patch', ':', 'applied', 'half', 'versatilis', 'of', '[', ']', 'dental', 'date']
# ['.', 'resident', ']', '[', 'at', 'with', 'night', 'given', 'and', 'as']
# ['and', 'to', '.', 'her', 'had', ',', 'tear', 'left', 'head', 'she']
# ['.', 'in', 'checks', 'on', '[', ']', 'as', 'resident', 'and', 'safety']
# ['.', ',', 'in', 'this', '[', ']', 'her', 'morning', 'to', 'with']
# ['care', 'and', 'no', 'assisted', 'with', 'done', 'in', 'eye', 'given', 'new']

# %%
all_texts_df = pd.DataFrame(lda_analysis(all_texts, "All Texts"))

# %%
get_top_topics(all_texts_df)
# Out:
# -------Coherence-------
# Number of Topics: 19
# ['care', 'plan', '.', ':', 'evaluation', 'resident', ']', '[', 'for', 'continue']
# [',', 'in', 'was', 'her', 'she', 'is', 'all', 'bed', 'he', 'checks']
# ['checks', 'on', 'safety', 'meds', '[', ']', 'resident', 'needs', 'due', 'taken']
# ['at', '.', 'pain', 'of', 'prn', ',', 'present', 'given', 'resident', 'requested']
# ['with', 'new', 'concerns', ']', '[', 'resident', 'good', 'in', 'assisted', 'and']
# ['both', 'cream', 'foot', 'app', '.', 'cut', 'feet', 'and', 'filed', 'toenails']
# ['.', 'in', 'as', 'care', 'needs', ']', '[', 'charted', 'resident', 'form']
# ['s', '`', 'her', 'resident', '[', ']', 'adl', 'with', 'due', 'in']
# [',', 'diet', 'as', 'good', 'in', '[', 'given', ']', 'resident', 'well']
# ['morning', 'this', ']', 'with', '[', 'as', 'meds', 'in', 'charted', 'resident']
# ['.', 'in', 'and', 'the', 'place', 'her', 'to', 'bed', 'as', 'with']
# [']', '[', 'to', '.', ',', 'resident', 'and', 'on', 'she', 'the']
# [':', 'paracetamol', 'of', 'gp', 'review', 'pain', '-', 'left', 'i', 'knee']
# ['care', 'eye', 'and', 'is', 'done', 'with', 'skin', 'continued', 'all', 'resident']
# ['as', 'safety', 'checks', 'charted', 'night', 'maintained', 'meds', 'with', 'needed', 'assisted']
# ['.', 'with', 'this', 'to', 'took', 'be', 'nil', '[', ']', 'in']
# ['.', 'resident', 'night', 'and', 'to', '[', ']', 'settled', 'his', 'medications']
# ['and', 'in', 'all', 'tolerated', 'with', 'room', '[', ']', 'resident', 'till']
# ['.', 'asleep', 'checks', 'resident', ']', '[', 'ongoing', 'care', 'needs', 'assisted']
#
#
# -------Diversity-------
# Number of Topics: 4
# ['.', ']', '[', 'to', ',', 'resident', 'and', 'of', 'for', 'on']
# [',', 'in', 'was', 'and', 'is', 'bed', 'all', 'her', 'to', 'she']
# ['.', 'checks', 'resident', '[', ']', 'as', 'safety', 'night', 'assisted', 'settled']
# ['.', 'in', 'with', ']', '[', 'resident', 'as', 'care', 'good', 'form']
#
#
# -------Redundancy-------
# Number of Topics: 16
# ['sensor', 'place', 'care', 'mat', 'plan', '.', 'for', ':', 'evaluation', 'resident']
# [',', 'in', 'was', 'her', 'she', 'bed', 'nocte', 'all', 'is', 'to']
# ['.', 'checks', ']', '[', 'resident', 'on', 'needs', 'asleep', 'care', 'safety']
# ['prn', '.', 'given', ',', 'continues', 'pain', 'paracetamol', 'administered', 'late', 'at']
# ['in', 'with', 'good', ']', '[', 'resident', 'new', 'assisted', 'given', 'as']
# [':', 'reach', 'call', 'safe', 'bell', 'within', 'date', '-', 'tonight', 'details']
# ['.', 'in', 'as', 'care', ']', '[', 'charted', 'resident', 'form', 'with']
# ['`', 's', 'resident', '[', ']', 'with', 'adl', 'her', 'in', 'due']
# ['a', 'having', 'is', 'had', 'night', 'as', 'evening', 'oral', 'throughout', 'charted']
# ['her', 'in', 'room', 'other', 'the', 'visited', 'by', 'so', 'dressing', 'stayed']
# ['.', 'and', 'resident', 'to', '[', ']', 'night', 'settled', 'medications', 'his']
# ['.', ']', '[', 'to', ',', 'resident', 'and', 'the', 'her', 'of']
# ['on', 'pain', 'of', ',', 'applied', 'left', 'hourly', 'noted', '2', 'right']
# ['care', 'and', 'eye', 'is', 'done', 'with', 'skin', 'continued', 'in', '[']
# ['as', 'safety', 'checks', 'maintained', 'charted', 'with', 'meds', 'assisted', 'settled', 'night']
# ['.', 'with', 'this', 'in', 'to', 'and', 'be', 'nil', 'took', 'for']
