# %%
import random
import torch
import os
import umap
import glob
import json
import numpy as np
import pandas as pd
import polars as pl

from sklearn.model_selection import (
    StratifiedKFold, cross_validate, GridSearchCV
)
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, FunctionTransformer
from sklearn.impute import SimpleImputer
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score, balanced_accuracy_score, make_scorer, confusion_matrix
)
from sklearn.linear_model import LogisticRegression, RidgeClassifier, SGDClassifier
from sklearn.svm import SVC, LinearSVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier, GradientBoostingClassifier, HistGradientBoostingClassifier, AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB

from scipy import sparse

import warnings
warnings.simplefilter("ignore", UserWarning)

# %%
N_SPLITS_CV = 5
N_JOBS = 1  # prioritizing no leakage
INPUT_DIR = '.'
OUTPUT_DIR = './machineLearningOutputs'

os.makedirs(OUTPUT_DIR, exist_ok=True)

# %%
# Set random states.
def set_random_states(random_state):
    # Set various random seeds.
    np.random.seed(random_state)
    pl.set_random_seed(random_state)
    pd.core.common.random_state(random_state)
    random.seed(random_state)
    torch.manual_seed(random_state)
    torch.cuda.manual_seed_all(random_state)
    os.environ["PYTHONHASHSEED"] = str(random_state)
    os.environ["TOKENIZERS_PARALLELISM"] = "false"
    try:
        torch.use_deterministic_algorithms(True)
    except Exception:
        pass
    return random_state

RANDOM_STATE = set_random_states(1618)

# %%
# get models - broad coverage across linear, margin, instance-based, and nonlinear tree ensembles
def build_models(random_state):
    models = {
        # high numbers of iterations (max_iter) avoids convergence warnings in high-dimensional spaces
        "LogisticRegression": LogisticRegression(max_iter=20000, class_weight="balanced", random_state=random_state), # strong baseline
        "RidgeClassifier": RidgeClassifier(class_weight="balanced", random_state=random_state), # strong baseline
        "LinearSVC": LinearSVC(max_iter=20000, class_weight="balanced", random_state=random_state), # strong baseline
        "SVC-RBF": SVC(probability=False, random_state=random_state, class_weight="balanced"), # probability set to false saves on compute
        "SGD-Hinge": SGDClassifier(loss="hinge", max_iter=20000, random_state=random_state, class_weight="balanced"), # hinge loss is good for binary classification problems - fast on large data
        "KNN": KNeighborsClassifier(), # deterministic - sensitive to scaling (good to test with and without standard scaler)
        "DecisionTree": DecisionTreeClassifier(random_state=random_state, class_weight="balanced"), # don't need scaling and captures nonlinear splits
        "RandomForest": RandomForestClassifier(random_state=random_state, class_weight="balanced"), # don't need scaling and captures nonlinear splits
        "ExtraTrees": ExtraTreesClassifier(random_state=random_state, class_weight="balanced"), # don't need scaling and captures nonlinear splits
        "GradientBoosting": GradientBoostingClassifier(random_state=random_state), # don't need scaling and captures nonlinear splits
        "HistGB": HistGradientBoostingClassifier(random_state=random_state), # don't need scaling and captures nonlinear splits
        "AdaBoost": AdaBoostClassifier(random_state=random_state), # don't need scaling and captures nonlinear splits
        "GaussianNaiveBayes": GaussianNB(), # deterministic - interpretable
    }
    return models

# get parameter grid to test
def small_param_grid(name): # high-leverage parameter sweeps (runtime will be effected if we test everything)
    grids = {
        # lowered c values due to convergence issues
        "LogisticRegression": {"clf__C": [0.1, 0.5, 1.0]},
        "LinearSVC":          {"clf__C": [0.1, 0.5, 1.0]},
        "SVC-RBF":            {"clf__C": [0.1, 0.5, 1.0], "clf__gamma": ["scale", "auto"]},
        "KNN":                {"clf__n_neighbors": [3, 5, 11]},
        "RandomForest":       {"clf__n_estimators": [300, 600], "clf__max_depth": [None, 10, 20]},
        "ExtraTrees":         {"clf__n_estimators": [300, 600], "clf__max_depth": [None, 10, 20]},
        "HistGB":             {"clf__max_depth": [None, 6, 10]},
    }
    return grids.get(name, None)

# make pipeline with and without scaling
def preprocessor(scale):
    # median ensures it is robust to outliers
    steps = [("imputer", SimpleImputer(strategy="median"))]
    if scale:
        # scales data to benefit models such as SVM and KNN
        steps.append(("scaler", StandardScaler(with_mean=True)))
    else:
        steps.append(("scaler", FunctionTransformer(lambda X: X, feature_names_out="one-to-one")))
    return Pipeline(steps)


def build_scorers():
    return {
        "accuracy": "accuracy", # normal accuracy
        "balanced_accuracy": make_scorer(balanced_accuracy_score), # balanced accuracy
        "precision": make_scorer(precision_score, average="macro", zero_division=0),
        "recall": make_scorer(recall_score, average="macro", zero_division=0),
        "f1": make_scorer(f1_score, average="macro", zero_division=0)
    }

# %%
def evaluate_one(X_train, y_train, X_test, y_test, variant,
                 random_state=RANDOM_STATE, n_splits=N_SPLITS_CV, n_jobs=N_JOBS):

    inner_cv = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=random_state)
    outer_cv = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=random_state)
    scorers = build_scorers()
    results = []

    for name, clf in build_models(random_state).items():
        # scaling decision
        X_tr, X_te = X_train, X_test

        # Convert sparse to dense for models that need dense arrays
        if sparse.issparse(X_tr):
            if name in ["HistGB", "GradientBoosting", "GaussianNaiveBayes"]:
                X_tr = X_tr.toarray()
                X_te = X_te.toarray()

        # Scaling decision
        if variant == "scaled":
            scaler = StandardScaler(with_mean=False if sparse.issparse(X_tr) else True)
        else:
            scaler = FunctionTransformer(lambda X: X, feature_names_out="one-to-one")

        pipe = Pipeline([
            ("scale", scaler),
            ("clf", clf)
        ])

        grid = small_param_grid(name)
        model_for_cv = GridSearchCV(pipe, grid, scoring=scorers, cv=inner_cv,
                                    n_jobs=n_jobs, refit="f1") if grid else pipe

        cv_out = cross_validate(model_for_cv, X_tr, y_train, cv=outer_cv,
                                scoring=scorers, return_train_score=False,
                                n_jobs=n_jobs, return_estimator=True)

        # Fit on full training
        model_for_cv.fit(X_tr, y_train)
        y_pred = model_for_cv.predict(X_te)

        # best estimator info
        if isinstance(model_for_cv, GridSearchCV):
            chosen = model_for_cv.best_estimator_
            tuned = model_for_cv.best_params_
        else:
            chosen = model_for_cv
            tuned = {}

        clf_params = chosen.named_steps["clf"].get_params()
        tuned_json = json.dumps(tuned, default=str)
        clf_json = json.dumps(clf_params, default=str)

        row = {
            "variant": variant,
            "model": name,
            "tuned_parameters": tuned_json,
            "clf_parameters": clf_json,
            **{f"cv_{k.replace('test_','')}_mean": float(np.mean(v))
               for k,v in cv_out.items() if k.startswith("test_")},
            **{f"cv_{k.replace('test_','')}_std": float(np.std(v))
               for k,v in cv_out.items() if k.startswith("test_")},
            "holdout_accuracy": accuracy_score(y_test, y_pred),
            "holdout_bal_acc": balanced_accuracy_score(y_test, y_pred),
            "holdout_precision": precision_score(y_test, y_pred, average="macro", zero_division=0),
            "holdout_recall": recall_score(y_test, y_pred, average="macro", zero_division=0),
            "holdout_f1": f1_score(y_test, y_pred, average="macro", zero_division=0),
        }

        results.append(row)
        print(row)
    return pd.DataFrame(results)

# %%
def make_input_data(file_paths="./outputsTrain/*/mean_model_zero_shot_classification.csv"):
    # Get all CSV files.
    all_files = glob.glob(file_paths)  # change this to your folder path

    # Loop through files.
    all_dfs = []

    for f in all_files:
        df = pd.read_csv(f)
        df['category'] = df['doc_id'].apply(lambda x: x.split('_')[0])
        
        # Aggregate numeric factor columns by category
        factor_cols = [f"factor_{i}" for i in range(1, 7)]
        df_agg = df.groupby('category')[factor_cols].mean().reset_index()
        all_dfs.append(df_agg)

    # Concatenate all aggregated DataFrames
    dfs = pd.concat(all_dfs, ignore_index=True)

    dfs['category_codes'] = dfs['category'].astype('category').cat.codes
    # Return x and y arrays.
    return dfs[[f"factor_{i}" for i in range(1, 7)]].values, dfs['category_codes'].values

# %%
# Assess zero-shot performance. 
X_train, y_train = make_input_data(file_paths="./outputsTrain/*/mean_model_zero_shot_classification.csv")
X_test, y_test = make_input_data(file_paths="./outputsTest/*/mean_model_zero_shot_classification.csv")

all_results = []
for variant in ("raw", "scaled"):
    df_res = evaluate_one(X_train, y_train, X_test, y_test, variant)
    all_results.append(df_res)

# Concatenate all results and save.
final_results = pd.concat(all_results, ignore_index=True)
final_results.to_csv(f"./{OUTPUT_DIR}/zeroShotResults.csv", index=False)

for metric in ['holdout_accuracy', 'holdout_bal_acc', 'holdout_precision', 'holdout_recall', 'holdout_f1']:
    print(f"Highest: {final_results.sort_values(by=metric, ascending=False)[metric].tolist()[0]}")
    print(pl.from_pandas(final_results.sort_values(by=metric, ascending=False).head()))
# Out:
# {'variant': 'raw', 'model': 'LogisticRegression', 'tuned_parameters': '{"clf__C": 0.5}', 'clf_parameters': '{"C": 0.5, "class_weight": "balanced", "dual": false, "fit_intercept": true, "intercept_scaling": 1, "l1_ratio": 0.0, "max_iter": 20000, "n_jobs": null, "penalty": "deprecated", "random_state": 1618, "solver": "lbfgs", "tol": 0.0001, "verbose": 0, "warm_start": false}', 'cv_accuracy_mean': 0.914, 'cv_balanced_accuracy_mean': 0.914, 'cv_precision_mean': 0.9166532789192233, 'cv_recall_mean': 0.914, 'cv_f1_mean': 0.9133634784533372, 'cv_accuracy_std': 0.01685229954635273, 'cv_balanced_accuracy_std': 0.016852299546352763, 'cv_precision_std': 0.015945472176814038, 'cv_recall_std': 0.016852299546352763, 'cv_f1_std': 0.016889882940537657, 'holdout_accuracy': 0.921, 'holdout_bal_acc': 0.9209999999999999, 'holdout_precision': 0.9215867394106848, 'holdout_recall': 0.9209999999999999, 'holdout_f1': 0.9201795792963635}
# {'variant': 'raw', 'model': 'RidgeClassifier', 'tuned_parameters': '{}', 'clf_parameters': '{"alpha": 1.0, "class_weight": "balanced", "copy_X": true, "fit_intercept": true, "max_iter": null, "positive": false, "random_state": 1618, "solver": "auto", "tol": 0.0001}', 'cv_accuracy_mean': 0.76, 'cv_balanced_accuracy_mean': 0.76, 'cv_precision_mean': 0.801476841146607, 'cv_recall_mean': 0.76, 'cv_f1_mean': 0.7258009567614657, 'cv_accuracy_std': 0.01140175425099139, 'cv_balanced_accuracy_std': 0.01140175425099141, 'cv_precision_std': 0.018310249691044313, 'cv_recall_std': 0.01140175425099141, 'cv_f1_std': 0.010827981288913862, 'holdout_accuracy': 0.743, 'holdout_bal_acc': 0.7430000000000001, 'holdout_precision': 0.7814707620266363, 'holdout_recall': 0.7430000000000001, 'holdout_f1': 0.7090544007883095}
# {'variant': 'raw', 'model': 'LinearSVC', 'tuned_parameters': '{"clf__C": 1.0}', 'clf_parameters': '{"C": 1.0, "class_weight": "balanced", "dual": "auto", "fit_intercept": true, "intercept_scaling": 1, "loss": "squared_hinge", "max_iter": 20000, "multi_class": "ovr", "penalty": "l2", "random_state": 1618, "tol": 0.0001, "verbose": 0}', 'cv_accuracy_mean': 0.876, 'cv_balanced_accuracy_mean': 0.876, 'cv_precision_mean': 0.8822170709751205, 'cv_recall_mean': 0.876, 'cv_f1_mean': 0.8731892477090554, 'cv_accuracy_std': 0.01593737745050924, 'cv_balanced_accuracy_std': 0.0159373774505092, 'cv_precision_std': 0.013581022749392073, 'cv_recall_std': 0.0159373774505092, 'cv_f1_std': 0.01568311554742471, 'holdout_accuracy': 0.889, 'holdout_bal_acc': 0.889, 'holdout_precision': 0.8903624873134305, 'holdout_recall': 0.889, 'holdout_f1': 0.8871635563885345}
# {'variant': 'raw', 'model': 'SVC-RBF', 'tuned_parameters': '{"clf__C": 1.0, "clf__gamma": "auto"}', 'clf_parameters': '{"C": 1.0, "break_ties": false, "cache_size": 200, "class_weight": "balanced", "coef0": 0.0, "decision_function_shape": "ovr", "degree": 3, "gamma": "auto", "kernel": "rbf", "max_iter": -1, "probability": false, "random_state": 1618, "shrinking": true, "tol": 0.001, "verbose": false}', 'cv_accuracy_mean': 0.923, 'cv_balanced_accuracy_mean': 0.923, 'cv_precision_mean': 0.9255581663023713, 'cv_recall_mean': 0.923, 'cv_f1_mean': 0.922175425833346, 'cv_accuracy_std': 0.010295630140986972, 'cv_balanced_accuracy_std': 0.010295630140987071, 'cv_precision_std': 0.009801394267973312, 'cv_recall_std': 0.010295630140987071, 'cv_f1_std': 0.010458320440062145, 'holdout_accuracy': 0.94, 'holdout_bal_acc': 0.9400000000000001, 'holdout_precision': 0.9404637301475629, 'holdout_recall': 0.9400000000000001, 'holdout_f1': 0.9397777002824161}
# {'variant': 'raw', 'model': 'SGD-Hinge', 'tuned_parameters': '{}', 'clf_parameters': '{"alpha": 0.0001, "average": false, "class_weight": "balanced", "early_stopping": false, "epsilon": 0.1, "eta0": 0.01, "fit_intercept": true, "l1_ratio": 0.15, "learning_rate": "optimal", "loss": "hinge", "max_iter": 20000, "n_iter_no_change": 5, "n_jobs": null, "penalty": "l2", "power_t": 0.5, "random_state": 1618, "shuffle": true, "tol": 0.001, "validation_fraction": 0.1, "verbose": 0, "warm_start": false}', 'cv_accuracy_mean': 0.845, 'cv_balanced_accuracy_mean': 0.845, 'cv_precision_mean': 0.8644583844623888, 'cv_recall_mean': 0.845, 'cv_f1_mean': 0.8359590922164083, 'cv_accuracy_std': 0.017029386365926418, 'cv_balanced_accuracy_std': 0.017029386365926404, 'cv_precision_std': 0.007308718837711164, 'cv_recall_std': 0.017029386365926404, 'cv_f1_std': 0.02542793622955041, 'holdout_accuracy': 0.88, 'holdout_bal_acc': 0.8800000000000001, 'holdout_precision': 0.8826548111790931, 'holdout_recall': 0.8800000000000001, 'holdout_f1': 0.8768216772451656}
# {'variant': 'raw', 'model': 'KNN', 'tuned_parameters': '{"clf__n_neighbors": 11}', 'clf_parameters': '{"algorithm": "auto", "leaf_size": 30, "metric": "minkowski", "metric_params": null, "n_jobs": null, "n_neighbors": 11, "p": 2, "weights": "uniform"}', 'cv_accuracy_mean': 0.9110000000000001, 'cv_balanced_accuracy_mean': 0.9109999999999999, 'cv_precision_mean': 0.9130502372920599, 'cv_recall_mean': 0.9109999999999999, 'cv_f1_mean': 0.9091845147298645, 'cv_accuracy_std': 0.01019803902718558, 'cv_balanced_accuracy_std': 0.010198039027185555, 'cv_precision_std': 0.009837731852827958, 'cv_recall_std': 0.010198039027185555, 'cv_f1_std': 0.010485077465105117, 'holdout_accuracy': 0.928, 'holdout_bal_acc': 0.9279999999999999, 'holdout_precision': 0.9282388946759687, 'holdout_recall': 0.9279999999999999, 'holdout_f1': 0.9271520951998712}
# {'variant': 'raw', 'model': 'DecisionTree', 'tuned_parameters': '{}', 'clf_parameters': '{"ccp_alpha": 0.0, "class_weight": "balanced", "criterion": "gini", "max_depth": null, "max_features": null, "max_leaf_nodes": null, "min_impurity_decrease": 0.0, "min_samples_leaf": 1, "min_samples_split": 2, "min_weight_fraction_leaf": 0.0, "monotonic_cst": null, "random_state": 1618, "splitter": "best"}', 'cv_accuracy_mean': 0.857, 'cv_balanced_accuracy_mean': 0.857, 'cv_precision_mean': 0.8606607881208095, 'cv_recall_mean': 0.857, 'cv_f1_mean': 0.8562993916226832, 'cv_accuracy_std': 0.012884098726725137, 'cv_balanced_accuracy_std': 0.012884098726725114, 'cv_precision_std': 0.010224095244311051, 'cv_recall_std': 0.012884098726725114, 'cv_f1_std': 0.01250349640598179, 'holdout_accuracy': 0.839, 'holdout_bal_acc': 0.8390000000000001, 'holdout_precision': 0.8412814731782635, 'holdout_recall': 0.8390000000000001, 'holdout_f1': 0.8376449366223084}
# {'variant': 'raw', 'model': 'RandomForest', 'tuned_parameters': '{"clf__max_depth": 10, "clf__n_estimators": 600}', 'clf_parameters': '{"bootstrap": true, "ccp_alpha": 0.0, "class_weight": "balanced", "criterion": "gini", "max_depth": 10, "max_features": "sqrt", "max_leaf_nodes": null, "max_samples": null, "min_impurity_decrease": 0.0, "min_samples_leaf": 1, "min_samples_split": 2, "min_weight_fraction_leaf": 0.0, "monotonic_cst": null, "n_estimators": 600, "n_jobs": null, "oob_score": false, "random_state": 1618, "verbose": 0, "warm_start": false}', 'cv_accuracy_mean': 0.9100000000000001, 'cv_balanced_accuracy_mean': 0.9100000000000001, 'cv_precision_mean': 0.9159609409749402, 'cv_recall_mean': 0.9100000000000001, 'cv_f1_mean': 0.9099354291464319, 'cv_accuracy_std': 0.025099800796022257, 'cv_balanced_accuracy_std': 0.025099800796022295, 'cv_precision_std': 0.02176294293505128, 'cv_recall_std': 0.025099800796022295, 'cv_f1_std': 0.024265346087274483, 'holdout_accuracy': 0.928, 'holdout_bal_acc': 0.9279999999999999, 'holdout_precision': 0.9292838474581959, 'holdout_recall': 0.9279999999999999, 'holdout_f1': 0.9277261745047793}
# {'variant': 'raw', 'model': 'ExtraTrees', 'tuned_parameters': '{"clf__max_depth": 10, "clf__n_estimators": 300}', 'clf_parameters': '{"bootstrap": false, "ccp_alpha": 0.0, "class_weight": "balanced", "criterion": "gini", "max_depth": 10, "max_features": "sqrt", "max_leaf_nodes": null, "max_samples": null, "min_impurity_decrease": 0.0, "min_samples_leaf": 1, "min_samples_split": 2, "min_weight_fraction_leaf": 0.0, "monotonic_cst": null, "n_estimators": 300, "n_jobs": null, "oob_score": false, "random_state": 1618, "verbose": 0, "warm_start": false}', 'cv_accuracy_mean': 0.921, 'cv_balanced_accuracy_mean': 0.9209999999999999, 'cv_precision_mean': 0.9245314430637489, 'cv_recall_mean': 0.9209999999999999, 'cv_f1_mean': 0.9200913522887015, 'cv_accuracy_std': 0.011135528725660017, 'cv_balanced_accuracy_std': 0.0111355287256601, 'cv_precision_std': 0.0111954047711933, 'cv_recall_std': 0.0111355287256601, 'cv_f1_std': 0.011179825019358394, 'holdout_accuracy': 0.931, 'holdout_bal_acc': 0.9309999999999998, 'holdout_precision': 0.9315788102926023, 'holdout_recall': 0.9309999999999998, 'holdout_f1': 0.9303423341975023}
# {'variant': 'raw', 'model': 'GradientBoosting', 'tuned_parameters': '{}', 'clf_parameters': '{"ccp_alpha": 0.0, "criterion": "friedman_mse", "init": null, "learning_rate": 0.1, "loss": "log_loss", "max_depth": 3, "max_features": null, "max_leaf_nodes": null, "min_impurity_decrease": 0.0, "min_samples_leaf": 1, "min_samples_split": 2, "min_weight_fraction_leaf": 0.0, "n_estimators": 100, "n_iter_no_change": null, "random_state": 1618, "subsample": 1.0, "tol": 0.0001, "validation_fraction": 0.1, "verbose": 0, "warm_start": false}', 'cv_accuracy_mean': 0.8869999999999999, 'cv_balanced_accuracy_mean': 0.8869999999999999, 'cv_precision_mean': 0.8928711986604501, 'cv_recall_mean': 0.8869999999999999, 'cv_f1_mean': 0.8872402539622997, 'cv_accuracy_std': 0.017492855684535916, 'cv_balanced_accuracy_std': 0.017492855684535867, 'cv_precision_std': 0.016280838849422146, 'cv_recall_std': 0.017492855684535867, 'cv_f1_std': 0.0174143939693387, 'holdout_accuracy': 0.899, 'holdout_bal_acc': 0.899, 'holdout_precision': 0.8998543831866683, 'holdout_recall': 0.899, 'holdout_f1': 0.8982448031009074}
# {'variant': 'raw', 'model': 'HistGB', 'tuned_parameters': '{"clf__max_depth": 10}', 'clf_parameters': '{"categorical_features": "from_dtype", "class_weight": null, "early_stopping": "auto", "interaction_cst": null, "l2_regularization": 0.0, "learning_rate": 0.1, "loss": "log_loss", "max_bins": 255, "max_depth": 10, "max_features": 1.0, "max_iter": 100, "max_leaf_nodes": 31, "min_samples_leaf": 20, "monotonic_cst": null, "n_iter_no_change": 10, "random_state": 1618, "scoring": "loss", "tol": 1e-07, "validation_fraction": 0.1, "verbose": 0, "warm_start": false}', 'cv_accuracy_mean': 0.89, 'cv_balanced_accuracy_mean': 0.89, 'cv_precision_mean': 0.8932746794716776, 'cv_recall_mean': 0.89, 'cv_f1_mean': 0.8894247161803959, 'cv_accuracy_std': 0.025298221281347056, 'cv_balanced_accuracy_std': 0.02529822128134701, 'cv_precision_std': 0.024980673518662098, 'cv_recall_std': 0.02529822128134701, 'cv_f1_std': 0.02545728064912981, 'holdout_accuracy': 0.916, 'holdout_bal_acc': 0.916, 'holdout_precision': 0.9161961214310287, 'holdout_recall': 0.916, 'holdout_f1': 0.9148745308596951}
# {'variant': 'raw', 'model': 'AdaBoost', 'tuned_parameters': '{}', 'clf_parameters': '{"estimator": null, "learning_rate": 1.0, "n_estimators": 50, "random_state": 1618}', 'cv_accuracy_mean': 0.484, 'cv_balanced_accuracy_mean': 0.484, 'cv_precision_mean': 0.472941236581515, 'cv_recall_mean': 0.484, 'cv_f1_mean': 0.412829510805814, 'cv_accuracy_std': 0.1081387996974259, 'cv_balanced_accuracy_std': 0.1081387996974259, 'cv_precision_std': 0.13853548198826607, 'cv_recall_std': 0.1081387996974259, 'cv_f1_std': 0.11844762262045797, 'holdout_accuracy': 0.352, 'holdout_bal_acc': 0.352, 'holdout_precision': 0.32749602648841963, 'holdout_recall': 0.352, 'holdout_f1': 0.27648011550764146}
# {'variant': 'raw', 'model': 'GaussianNaiveBayes', 'tuned_parameters': '{}', 'clf_parameters': '{"priors": null, "var_smoothing": 1e-09}', 'cv_accuracy_mean': 0.913, 'cv_balanced_accuracy_mean': 0.913, 'cv_precision_mean': 0.9144854938438867, 'cv_recall_mean': 0.913, 'cv_f1_mean': 0.9125005786206192, 'cv_accuracy_std': 0.017204650534085233, 'cv_balanced_accuracy_std': 0.01720465053408529, 'cv_precision_std': 0.01763884511600582, 'cv_recall_std': 0.01720465053408529, 'cv_f1_std': 0.017670917102993233, 'holdout_accuracy': 0.932, 'holdout_bal_acc': 0.932, 'holdout_precision': 0.9327644672170209, 'holdout_recall': 0.932, 'holdout_f1': 0.9319467519944913}
# {'variant': 'scaled', 'model': 'LogisticRegression', 'tuned_parameters': '{"clf__C": 1.0}', 'clf_parameters': '{"C": 1.0, "class_weight": "balanced", "dual": false, "fit_intercept": true, "intercept_scaling": 1, "l1_ratio": 0.0, "max_iter": 20000, "n_jobs": null, "penalty": "deprecated", "random_state": 1618, "solver": "lbfgs", "tol": 0.0001, "verbose": 0, "warm_start": false}', 'cv_accuracy_mean': 0.9170000000000001, 'cv_balanced_accuracy_mean': 0.917, 'cv_precision_mean': 0.9199822337172856, 'cv_recall_mean': 0.917, 'cv_f1_mean': 0.9164642868905041, 'cv_accuracy_std': 0.014352700094407337, 'cv_balanced_accuracy_std': 0.014352700094407355, 'cv_precision_std': 0.013822137561775055, 'cv_recall_std': 0.014352700094407355, 'cv_f1_std': 0.014406385104005203, 'holdout_accuracy': 0.922, 'holdout_bal_acc': 0.922, 'holdout_precision': 0.9225293782130392, 'holdout_recall': 0.922, 'holdout_f1': 0.9215370159007421}
# {'variant': 'scaled', 'model': 'RidgeClassifier', 'tuned_parameters': '{}', 'clf_parameters': '{"alpha": 1.0, "class_weight": "balanced", "copy_X": true, "fit_intercept": true, "max_iter": null, "positive": false, "random_state": 1618, "solver": "auto", "tol": 0.0001}', 'cv_accuracy_mean': 0.759, 'cv_balanced_accuracy_mean': 0.7590000000000001, 'cv_precision_mean': 0.8008371670478537, 'cv_recall_mean': 0.7590000000000001, 'cv_f1_mean': 0.7241909665116413, 'cv_accuracy_std': 0.012409673645990868, 'cv_balanced_accuracy_std': 0.012409673645990887, 'cv_precision_std': 0.017335787561274817, 'cv_recall_std': 0.012409673645990887, 'cv_f1_std': 0.0126212727100402, 'holdout_accuracy': 0.743, 'holdout_bal_acc': 0.7430000000000001, 'holdout_precision': 0.7814771007092283, 'holdout_recall': 0.7430000000000001, 'holdout_f1': 0.7088023005434175}
# {'variant': 'scaled', 'model': 'LinearSVC', 'tuned_parameters': '{"clf__C": 1.0}', 'clf_parameters': '{"C": 1.0, "class_weight": "balanced", "dual": "auto", "fit_intercept": true, "intercept_scaling": 1, "loss": "squared_hinge", "max_iter": 20000, "multi_class": "ovr", "penalty": "l2", "random_state": 1618, "tol": 0.0001, "verbose": 0}', 'cv_accuracy_mean': 0.8739999999999999, 'cv_balanced_accuracy_mean': 0.874, 'cv_precision_mean': 0.8792567254383042, 'cv_recall_mean': 0.874, 'cv_f1_mean': 0.8714354895800485, 'cv_accuracy_std': 0.015297058540778369, 'cv_balanced_accuracy_std': 0.01529705854077831, 'cv_precision_std': 0.014471455731954413, 'cv_recall_std': 0.01529705854077831, 'cv_f1_std': 0.015429589765662954, 'holdout_accuracy': 0.888, 'holdout_bal_acc': 0.8880000000000001, 'holdout_precision': 0.8896370523913009, 'holdout_recall': 0.8880000000000001, 'holdout_f1': 0.8864076715298875}
# {'variant': 'scaled', 'model': 'SVC-RBF', 'tuned_parameters': '{"clf__C": 1.0, "clf__gamma": "scale"}', 'clf_parameters': '{"C": 1.0, "break_ties": false, "cache_size": 200, "class_weight": "balanced", "coef0": 0.0, "decision_function_shape": "ovr", "degree": 3, "gamma": "scale", "kernel": "rbf", "max_iter": -1, "probability": false, "random_state": 1618, "shrinking": true, "tol": 0.001, "verbose": false}', 'cv_accuracy_mean': 0.922, 'cv_balanced_accuracy_mean': 0.922, 'cv_precision_mean': 0.92466253107581, 'cv_recall_mean': 0.922, 'cv_f1_mean': 0.921149374211032, 'cv_accuracy_std': 0.011224972160321799, 'cv_balanced_accuracy_std': 0.011224972160321905, 'cv_precision_std': 0.01052873647932947, 'cv_recall_std': 0.011224972160321905, 'cv_f1_std': 0.011214986242918569, 'holdout_accuracy': 0.941, 'holdout_bal_acc': 0.9410000000000001, 'holdout_precision': 0.9417724536986402, 'holdout_recall': 0.9410000000000001, 'holdout_f1': 0.9405909118292761}
# {'variant': 'scaled', 'model': 'SGD-Hinge', 'tuned_parameters': '{}', 'clf_parameters': '{"alpha": 0.0001, "average": false, "class_weight": "balanced", "early_stopping": false, "epsilon": 0.1, "eta0": 0.01, "fit_intercept": true, "l1_ratio": 0.15, "learning_rate": "optimal", "loss": "hinge", "max_iter": 20000, "n_iter_no_change": 5, "n_jobs": null, "penalty": "l2", "power_t": 0.5, "random_state": 1618, "shuffle": true, "tol": 0.001, "validation_fraction": 0.1, "verbose": 0, "warm_start": false}', 'cv_accuracy_mean': 0.8559999999999999, 'cv_balanced_accuracy_mean': 0.8559999999999999, 'cv_precision_mean': 0.8659380506566485, 'cv_recall_mean': 0.8559999999999999, 'cv_f1_mean': 0.8520902334269488, 'cv_accuracy_std': 0.018275666882497082, 'cv_balanced_accuracy_std': 0.01827566688249704, 'cv_precision_std': 0.024624025645949628, 'cv_recall_std': 0.01827566688249704, 'cv_f1_std': 0.020497178915890604, 'holdout_accuracy': 0.859, 'holdout_bal_acc': 0.859, 'holdout_precision': 0.8839245149767112, 'holdout_recall': 0.859, 'holdout_f1': 0.8559853177677208}
# {'variant': 'scaled', 'model': 'KNN', 'tuned_parameters': '{"clf__n_neighbors": 11}', 'clf_parameters': '{"algorithm": "auto", "leaf_size": 30, "metric": "minkowski", "metric_params": null, "n_jobs": null, "n_neighbors": 11, "p": 2, "weights": "uniform"}', 'cv_accuracy_mean': 0.909, 'cv_balanced_accuracy_mean': 0.9089999999999998, 'cv_precision_mean': 0.9120004114758725, 'cv_recall_mean': 0.9089999999999998, 'cv_f1_mean': 0.9072701435245859, 'cv_accuracy_std': 0.014628738838327807, 'cv_balanced_accuracy_std': 0.014628738838327826, 'cv_precision_std': 0.014477853152730097, 'cv_recall_std': 0.014628738838327826, 'cv_f1_std': 0.015008225727768807, 'holdout_accuracy': 0.919, 'holdout_bal_acc': 0.9189999999999999, 'holdout_precision': 0.919243286982821, 'holdout_recall': 0.9189999999999999, 'holdout_f1': 0.9179583503617483}
# {'variant': 'scaled', 'model': 'DecisionTree', 'tuned_parameters': '{}', 'clf_parameters': '{"ccp_alpha": 0.0, "class_weight": "balanced", "criterion": "gini", "max_depth": null, "max_features": null, "max_leaf_nodes": null, "min_impurity_decrease": 0.0, "min_samples_leaf": 1, "min_samples_split": 2, "min_weight_fraction_leaf": 0.0, "monotonic_cst": null, "random_state": 1618, "splitter": "best"}', 'cv_accuracy_mean': 0.857, 'cv_balanced_accuracy_mean': 0.857, 'cv_precision_mean': 0.8606607881208095, 'cv_recall_mean': 0.857, 'cv_f1_mean': 0.8562993916226832, 'cv_accuracy_std': 0.012884098726725137, 'cv_balanced_accuracy_std': 0.012884098726725114, 'cv_precision_std': 0.010224095244311051, 'cv_recall_std': 0.012884098726725114, 'cv_f1_std': 0.01250349640598179, 'holdout_accuracy': 0.839, 'holdout_bal_acc': 0.8390000000000001, 'holdout_precision': 0.8412814731782635, 'holdout_recall': 0.8390000000000001, 'holdout_f1': 0.8376449366223084}
# {'variant': 'scaled', 'model': 'RandomForest', 'tuned_parameters': '{"clf__max_depth": 10, "clf__n_estimators": 600}', 'clf_parameters': '{"bootstrap": true, "ccp_alpha": 0.0, "class_weight": "balanced", "criterion": "gini", "max_depth": 10, "max_features": "sqrt", "max_leaf_nodes": null, "max_samples": null, "min_impurity_decrease": 0.0, "min_samples_leaf": 1, "min_samples_split": 2, "min_weight_fraction_leaf": 0.0, "monotonic_cst": null, "n_estimators": 600, "n_jobs": null, "oob_score": false, "random_state": 1618, "verbose": 0, "warm_start": false}', 'cv_accuracy_mean': 0.9100000000000001, 'cv_balanced_accuracy_mean': 0.9100000000000001, 'cv_precision_mean': 0.9159609409749402, 'cv_recall_mean': 0.9100000000000001, 'cv_f1_mean': 0.9099354291464319, 'cv_accuracy_std': 0.025099800796022257, 'cv_balanced_accuracy_std': 0.025099800796022295, 'cv_precision_std': 0.02176294293505128, 'cv_recall_std': 0.025099800796022295, 'cv_f1_std': 0.024265346087274483, 'holdout_accuracy': 0.928, 'holdout_bal_acc': 0.9279999999999999, 'holdout_precision': 0.9292838474581959, 'holdout_recall': 0.9279999999999999, 'holdout_f1': 0.9277261745047793}
# {'variant': 'scaled', 'model': 'ExtraTrees', 'tuned_parameters': '{"clf__max_depth": 10, "clf__n_estimators": 300}', 'clf_parameters': '{"bootstrap": false, "ccp_alpha": 0.0, "class_weight": "balanced", "criterion": "gini", "max_depth": 10, "max_features": "sqrt", "max_leaf_nodes": null, "max_samples": null, "min_impurity_decrease": 0.0, "min_samples_leaf": 1, "min_samples_split": 2, "min_weight_fraction_leaf": 0.0, "monotonic_cst": null, "n_estimators": 300, "n_jobs": null, "oob_score": false, "random_state": 1618, "verbose": 0, "warm_start": false}', 'cv_accuracy_mean': 0.921, 'cv_balanced_accuracy_mean': 0.9209999999999999, 'cv_precision_mean': 0.9245314430637489, 'cv_recall_mean': 0.9209999999999999, 'cv_f1_mean': 0.9200913522887015, 'cv_accuracy_std': 0.011135528725660017, 'cv_balanced_accuracy_std': 0.0111355287256601, 'cv_precision_std': 0.0111954047711933, 'cv_recall_std': 0.0111355287256601, 'cv_f1_std': 0.011179825019358394, 'holdout_accuracy': 0.931, 'holdout_bal_acc': 0.9309999999999998, 'holdout_precision': 0.9315788102926023, 'holdout_recall': 0.9309999999999998, 'holdout_f1': 0.9303423341975023}
# {'variant': 'scaled', 'model': 'GradientBoosting', 'tuned_parameters': '{}', 'clf_parameters': '{"ccp_alpha": 0.0, "criterion": "friedman_mse", "init": null, "learning_rate": 0.1, "loss": "log_loss", "max_depth": 3, "max_features": null, "max_leaf_nodes": null, "min_impurity_decrease": 0.0, "min_samples_leaf": 1, "min_samples_split": 2, "min_weight_fraction_leaf": 0.0, "n_estimators": 100, "n_iter_no_change": null, "random_state": 1618, "subsample": 1.0, "tol": 0.0001, "validation_fraction": 0.1, "verbose": 0, "warm_start": false}', 'cv_accuracy_mean': 0.8869999999999999, 'cv_balanced_accuracy_mean': 0.8869999999999999, 'cv_precision_mean': 0.8928711986604501, 'cv_recall_mean': 0.8869999999999999, 'cv_f1_mean': 0.8872402539622997, 'cv_accuracy_std': 0.017492855684535916, 'cv_balanced_accuracy_std': 0.017492855684535867, 'cv_precision_std': 0.016280838849422146, 'cv_recall_std': 0.017492855684535867, 'cv_f1_std': 0.0174143939693387, 'holdout_accuracy': 0.899, 'holdout_bal_acc': 0.899, 'holdout_precision': 0.8998543831866683, 'holdout_recall': 0.899, 'holdout_f1': 0.8982448031009074}
# {'variant': 'scaled', 'model': 'HistGB', 'tuned_parameters': '{"clf__max_depth": 10}', 'clf_parameters': '{"categorical_features": "from_dtype", "class_weight": null, "early_stopping": "auto", "interaction_cst": null, "l2_regularization": 0.0, "learning_rate": 0.1, "loss": "log_loss", "max_bins": 255, "max_depth": 10, "max_features": 1.0, "max_iter": 100, "max_leaf_nodes": 31, "min_samples_leaf": 20, "monotonic_cst": null, "n_iter_no_change": 10, "random_state": 1618, "scoring": "loss", "tol": 1e-07, "validation_fraction": 0.1, "verbose": 0, "warm_start": false}', 'cv_accuracy_mean': 0.89, 'cv_balanced_accuracy_mean': 0.89, 'cv_precision_mean': 0.8932746794716776, 'cv_recall_mean': 0.89, 'cv_f1_mean': 0.8894247161803959, 'cv_accuracy_std': 0.025298221281347056, 'cv_balanced_accuracy_std': 0.02529822128134701, 'cv_precision_std': 0.024980673518662098, 'cv_recall_std': 0.02529822128134701, 'cv_f1_std': 0.02545728064912981, 'holdout_accuracy': 0.916, 'holdout_bal_acc': 0.916, 'holdout_precision': 0.9161961214310287, 'holdout_recall': 0.916, 'holdout_f1': 0.9148745308596951}
# {'variant': 'scaled', 'model': 'AdaBoost', 'tuned_parameters': '{}', 'clf_parameters': '{"estimator": null, "learning_rate": 1.0, "n_estimators": 50, "random_state": 1618}', 'cv_accuracy_mean': 0.484, 'cv_balanced_accuracy_mean': 0.484, 'cv_precision_mean': 0.472941236581515, 'cv_recall_mean': 0.484, 'cv_f1_mean': 0.412829510805814, 'cv_accuracy_std': 0.1081387996974259, 'cv_balanced_accuracy_std': 0.1081387996974259, 'cv_precision_std': 0.13853548198826607, 'cv_recall_std': 0.1081387996974259, 'cv_f1_std': 0.11844762262045797, 'holdout_accuracy': 0.352, 'holdout_bal_acc': 0.352, 'holdout_precision': 0.32749602648841963, 'holdout_recall': 0.352, 'holdout_f1': 0.27648011550764146}
# {'variant': 'scaled', 'model': 'GaussianNaiveBayes', 'tuned_parameters': '{}', 'clf_parameters': '{"priors": null, "var_smoothing": 1e-09}', 'cv_accuracy_mean': 0.913, 'cv_balanced_accuracy_mean': 0.913, 'cv_precision_mean': 0.9144854938438867, 'cv_recall_mean': 0.913, 'cv_f1_mean': 0.9125005786206192, 'cv_accuracy_std': 0.017204650534085233, 'cv_balanced_accuracy_std': 0.01720465053408529, 'cv_precision_std': 0.01763884511600582, 'cv_recall_std': 0.01720465053408529, 'cv_f1_std': 0.017670917102993233, 'holdout_accuracy': 0.932, 'holdout_bal_acc': 0.932, 'holdout_precision': 0.9327644672170209, 'holdout_recall': 0.932, 'holdout_f1': 0.9319467519944913}
# Highest: 0.941
# shape: (5, 19)
# ┌─────────┬────────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ variant ┆ model      ┆ tuned_par ┆ clf_param ┆ … ┆ holdout_b ┆ holdout_p ┆ holdout_r ┆ holdout_f │
# │ ---     ┆ ---        ┆ ameters   ┆ eters     ┆   ┆ al_acc    ┆ recision  ┆ ecall     ┆ 1         │
# │ str     ┆ str        ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │         ┆            ┆ str       ┆ str       ┆   ┆ f64       ┆ f64       ┆ f64       ┆ f64       │
# ╞═════════╪════════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ scaled  ┆ SVC-RBF    ┆ {"clf__C" ┆ {"C":     ┆ … ┆ 0.941     ┆ 0.941772  ┆ 0.941     ┆ 0.940591  │
# │         ┆            ┆ : 1.0,    ┆ 1.0, "bre ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ "clf__gam ┆ ak_ties": ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ ma": …    ┆ false…    ┆   ┆           ┆           ┆           ┆           │
# │ raw     ┆ SVC-RBF    ┆ {"clf__C" ┆ {"C":     ┆ … ┆ 0.94      ┆ 0.940464  ┆ 0.94      ┆ 0.939778  │
# │         ┆            ┆ : 1.0,    ┆ 1.0, "bre ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ "clf__gam ┆ ak_ties": ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ ma": …    ┆ false…    ┆   ┆           ┆           ┆           ┆           │
# │ scaled  ┆ GaussianNa ┆ {}        ┆ {"priors" ┆ … ┆ 0.932     ┆ 0.932764  ┆ 0.932     ┆ 0.931947  │
# │         ┆ iveBayes   ┆           ┆ : null,   ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ "var_smoo ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ thin…     ┆   ┆           ┆           ┆           ┆           │
# │ raw     ┆ GaussianNa ┆ {}        ┆ {"priors" ┆ … ┆ 0.932     ┆ 0.932764  ┆ 0.932     ┆ 0.931947  │
# │         ┆ iveBayes   ┆           ┆ : null,   ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ "var_smoo ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ thin…     ┆   ┆           ┆           ┆           ┆           │
# │ scaled  ┆ ExtraTrees ┆ {"clf__ma ┆ {"bootstr ┆ … ┆ 0.931     ┆ 0.931579  ┆ 0.931     ┆ 0.930342  │
# │         ┆            ┆ x_depth": ┆ ap":      ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ 10,       ┆ false,    ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ "clf__n…  ┆ "ccp_alph ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ …         ┆   ┆           ┆           ┆           ┆           │
# └─────────┴────────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘
# Highest: 0.9410000000000001
# shape: (5, 19)
# ┌─────────┬────────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ variant ┆ model      ┆ tuned_par ┆ clf_param ┆ … ┆ holdout_b ┆ holdout_p ┆ holdout_r ┆ holdout_f │
# │ ---     ┆ ---        ┆ ameters   ┆ eters     ┆   ┆ al_acc    ┆ recision  ┆ ecall     ┆ 1         │
# │ str     ┆ str        ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │         ┆            ┆ str       ┆ str       ┆   ┆ f64       ┆ f64       ┆ f64       ┆ f64       │
# ╞═════════╪════════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ scaled  ┆ SVC-RBF    ┆ {"clf__C" ┆ {"C":     ┆ … ┆ 0.941     ┆ 0.941772  ┆ 0.941     ┆ 0.940591  │
# │         ┆            ┆ : 1.0,    ┆ 1.0, "bre ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ "clf__gam ┆ ak_ties": ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ ma": …    ┆ false…    ┆   ┆           ┆           ┆           ┆           │
# │ raw     ┆ SVC-RBF    ┆ {"clf__C" ┆ {"C":     ┆ … ┆ 0.94      ┆ 0.940464  ┆ 0.94      ┆ 0.939778  │
# │         ┆            ┆ : 1.0,    ┆ 1.0, "bre ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ "clf__gam ┆ ak_ties": ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ ma": …    ┆ false…    ┆   ┆           ┆           ┆           ┆           │
# │ scaled  ┆ GaussianNa ┆ {}        ┆ {"priors" ┆ … ┆ 0.932     ┆ 0.932764  ┆ 0.932     ┆ 0.931947  │
# │         ┆ iveBayes   ┆           ┆ : null,   ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ "var_smoo ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ thin…     ┆   ┆           ┆           ┆           ┆           │
# │ raw     ┆ GaussianNa ┆ {}        ┆ {"priors" ┆ … ┆ 0.932     ┆ 0.932764  ┆ 0.932     ┆ 0.931947  │
# │         ┆ iveBayes   ┆           ┆ : null,   ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ "var_smoo ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ thin…     ┆   ┆           ┆           ┆           ┆           │
# │ scaled  ┆ ExtraTrees ┆ {"clf__ma ┆ {"bootstr ┆ … ┆ 0.931     ┆ 0.931579  ┆ 0.931     ┆ 0.930342  │
# │         ┆            ┆ x_depth": ┆ ap":      ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ 10,       ┆ false,    ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ "clf__n…  ┆ "ccp_alph ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ …         ┆   ┆           ┆           ┆           ┆           │
# └─────────┴────────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘
# Highest: 0.9417724536986402
# shape: (5, 19)
# ┌─────────┬────────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ variant ┆ model      ┆ tuned_par ┆ clf_param ┆ … ┆ holdout_b ┆ holdout_p ┆ holdout_r ┆ holdout_f │
# │ ---     ┆ ---        ┆ ameters   ┆ eters     ┆   ┆ al_acc    ┆ recision  ┆ ecall     ┆ 1         │
# │ str     ┆ str        ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │         ┆            ┆ str       ┆ str       ┆   ┆ f64       ┆ f64       ┆ f64       ┆ f64       │
# ╞═════════╪════════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ scaled  ┆ SVC-RBF    ┆ {"clf__C" ┆ {"C":     ┆ … ┆ 0.941     ┆ 0.941772  ┆ 0.941     ┆ 0.940591  │
# │         ┆            ┆ : 1.0,    ┆ 1.0, "bre ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ "clf__gam ┆ ak_ties": ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ ma": …    ┆ false…    ┆   ┆           ┆           ┆           ┆           │
# │ raw     ┆ SVC-RBF    ┆ {"clf__C" ┆ {"C":     ┆ … ┆ 0.94      ┆ 0.940464  ┆ 0.94      ┆ 0.939778  │
# │         ┆            ┆ : 1.0,    ┆ 1.0, "bre ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ "clf__gam ┆ ak_ties": ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ ma": …    ┆ false…    ┆   ┆           ┆           ┆           ┆           │
# │ scaled  ┆ GaussianNa ┆ {}        ┆ {"priors" ┆ … ┆ 0.932     ┆ 0.932764  ┆ 0.932     ┆ 0.931947  │
# │         ┆ iveBayes   ┆           ┆ : null,   ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ "var_smoo ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ thin…     ┆   ┆           ┆           ┆           ┆           │
# │ raw     ┆ GaussianNa ┆ {}        ┆ {"priors" ┆ … ┆ 0.932     ┆ 0.932764  ┆ 0.932     ┆ 0.931947  │
# │         ┆ iveBayes   ┆           ┆ : null,   ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ "var_smoo ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ thin…     ┆   ┆           ┆           ┆           ┆           │
# │ scaled  ┆ ExtraTrees ┆ {"clf__ma ┆ {"bootstr ┆ … ┆ 0.931     ┆ 0.931579  ┆ 0.931     ┆ 0.930342  │
# │         ┆            ┆ x_depth": ┆ ap":      ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ 10,       ┆ false,    ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ "clf__n…  ┆ "ccp_alph ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ …         ┆   ┆           ┆           ┆           ┆           │
# └─────────┴────────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘
# Highest: 0.9410000000000001
# shape: (5, 19)
# ┌─────────┬────────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ variant ┆ model      ┆ tuned_par ┆ clf_param ┆ … ┆ holdout_b ┆ holdout_p ┆ holdout_r ┆ holdout_f │
# │ ---     ┆ ---        ┆ ameters   ┆ eters     ┆   ┆ al_acc    ┆ recision  ┆ ecall     ┆ 1         │
# │ str     ┆ str        ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │         ┆            ┆ str       ┆ str       ┆   ┆ f64       ┆ f64       ┆ f64       ┆ f64       │
# ╞═════════╪════════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ scaled  ┆ SVC-RBF    ┆ {"clf__C" ┆ {"C":     ┆ … ┆ 0.941     ┆ 0.941772  ┆ 0.941     ┆ 0.940591  │
# │         ┆            ┆ : 1.0,    ┆ 1.0, "bre ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ "clf__gam ┆ ak_ties": ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ ma": …    ┆ false…    ┆   ┆           ┆           ┆           ┆           │
# │ raw     ┆ SVC-RBF    ┆ {"clf__C" ┆ {"C":     ┆ … ┆ 0.94      ┆ 0.940464  ┆ 0.94      ┆ 0.939778  │
# │         ┆            ┆ : 1.0,    ┆ 1.0, "bre ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ "clf__gam ┆ ak_ties": ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ ma": …    ┆ false…    ┆   ┆           ┆           ┆           ┆           │
# │ scaled  ┆ GaussianNa ┆ {}        ┆ {"priors" ┆ … ┆ 0.932     ┆ 0.932764  ┆ 0.932     ┆ 0.931947  │
# │         ┆ iveBayes   ┆           ┆ : null,   ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ "var_smoo ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ thin…     ┆   ┆           ┆           ┆           ┆           │
# │ raw     ┆ GaussianNa ┆ {}        ┆ {"priors" ┆ … ┆ 0.932     ┆ 0.932764  ┆ 0.932     ┆ 0.931947  │
# │         ┆ iveBayes   ┆           ┆ : null,   ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ "var_smoo ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ thin…     ┆   ┆           ┆           ┆           ┆           │
# │ scaled  ┆ ExtraTrees ┆ {"clf__ma ┆ {"bootstr ┆ … ┆ 0.931     ┆ 0.931579  ┆ 0.931     ┆ 0.930342  │
# │         ┆            ┆ x_depth": ┆ ap":      ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ 10,       ┆ false,    ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ "clf__n…  ┆ "ccp_alph ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ …         ┆   ┆           ┆           ┆           ┆           │
# └─────────┴────────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘
# Highest: 0.9405909118292761
# shape: (5, 19)
# ┌─────────┬────────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ variant ┆ model      ┆ tuned_par ┆ clf_param ┆ … ┆ holdout_b ┆ holdout_p ┆ holdout_r ┆ holdout_f │
# │ ---     ┆ ---        ┆ ameters   ┆ eters     ┆   ┆ al_acc    ┆ recision  ┆ ecall     ┆ 1         │
# │ str     ┆ str        ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │         ┆            ┆ str       ┆ str       ┆   ┆ f64       ┆ f64       ┆ f64       ┆ f64       │
# ╞═════════╪════════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ scaled  ┆ SVC-RBF    ┆ {"clf__C" ┆ {"C":     ┆ … ┆ 0.941     ┆ 0.941772  ┆ 0.941     ┆ 0.940591  │
# │         ┆            ┆ : 1.0,    ┆ 1.0, "bre ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ "clf__gam ┆ ak_ties": ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ ma": …    ┆ false…    ┆   ┆           ┆           ┆           ┆           │
# │ raw     ┆ SVC-RBF    ┆ {"clf__C" ┆ {"C":     ┆ … ┆ 0.94      ┆ 0.940464  ┆ 0.94      ┆ 0.939778  │
# │         ┆            ┆ : 1.0,    ┆ 1.0, "bre ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ "clf__gam ┆ ak_ties": ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ ma": …    ┆ false…    ┆   ┆           ┆           ┆           ┆           │
# │ scaled  ┆ GaussianNa ┆ {}        ┆ {"priors" ┆ … ┆ 0.932     ┆ 0.932764  ┆ 0.932     ┆ 0.931947  │
# │         ┆ iveBayes   ┆           ┆ : null,   ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ "var_smoo ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ thin…     ┆   ┆           ┆           ┆           ┆           │
# │ raw     ┆ GaussianNa ┆ {}        ┆ {"priors" ┆ … ┆ 0.932     ┆ 0.932764  ┆ 0.932     ┆ 0.931947  │
# │         ┆ iveBayes   ┆           ┆ : null,   ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ "var_smoo ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ thin…     ┆   ┆           ┆           ┆           ┆           │
# │ scaled  ┆ ExtraTrees ┆ {"clf__ma ┆ {"bootstr ┆ … ┆ 0.931     ┆ 0.931579  ┆ 0.931     ┆ 0.930342  │
# │         ┆            ┆ x_depth": ┆ ap":      ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ 10,       ┆ false,    ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ "clf__n…  ┆ "ccp_alph ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ …         ┆   ┆           ┆           ┆           ┆           │
# └─────────┴────────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
# Assess MDA performance. 
X_train, y_train = make_input_data(file_paths="./outputsTrain/*/mda_dim_scores.csv")
X_test, y_test = make_input_data(file_paths="./outputsTest/*/mda_dim_scores.csv")

all_results = []
for variant in ("raw", "scaled"):
    df_res = evaluate_one(X_train, y_train, X_test, y_test, variant)
    all_results.append(df_res)

# Concatenate all results and save.
final_results = pd.concat(all_results, ignore_index=True)
final_results.to_csv(f"./{OUTPUT_DIR}/mdaResults.csv", index=False)

for metric in ['holdout_accuracy', 'holdout_bal_acc', 'holdout_precision', 'holdout_recall', 'holdout_f1']:
    print(f"Highest: {final_results.sort_values(by=metric, ascending=False)[metric].tolist()[0]}")
    print(pl.from_pandas(final_results.sort_values(by=metric, ascending=False).head()))
# Out:
# {'variant': 'raw', 'model': 'LogisticRegression', 'tuned_parameters': '{"clf__C": 1.0}', 'clf_parameters': '{"C": 1.0, "class_weight": "balanced", "dual": false, "fit_intercept": true, "intercept_scaling": 1, "l1_ratio": 0.0, "max_iter": 20000, "n_jobs": null, "penalty": "deprecated", "random_state": 1618, "solver": "lbfgs", "tol": 0.0001, "verbose": 0, "warm_start": false}', 'cv_accuracy_mean': 0.8619999999999999, 'cv_balanced_accuracy_mean': 0.8619999999999999, 'cv_precision_mean': 0.8641728060754847, 'cv_recall_mean': 0.8619999999999999, 'cv_f1_mean': 0.8607806171467693, 'cv_accuracy_std': 0.021587033144922923, 'cv_balanced_accuracy_std': 0.021587033144922847, 'cv_precision_std': 0.02078524931808598, 'cv_recall_std': 0.021587033144922847, 'cv_f1_std': 0.021434092741046896, 'holdout_accuracy': 0.864, 'holdout_bal_acc': 0.8640000000000001, 'holdout_precision': 0.860846564141078, 'holdout_recall': 0.8640000000000001, 'holdout_f1': 0.8610305796873756}
# {'variant': 'raw', 'model': 'RidgeClassifier', 'tuned_parameters': '{}', 'clf_parameters': '{"alpha": 1.0, "class_weight": "balanced", "copy_X": true, "fit_intercept": true, "max_iter": null, "positive": false, "random_state": 1618, "solver": "auto", "tol": 0.0001}', 'cv_accuracy_mean': 0.6910000000000001, 'cv_balanced_accuracy_mean': 0.6910000000000001, 'cv_precision_mean': 0.7040594389401891, 'cv_recall_mean': 0.6910000000000001, 'cv_f1_mean': 0.6423421620563994, 'cv_accuracy_std': 0.020346989949375772, 'cv_balanced_accuracy_std': 0.02034698994937583, 'cv_precision_std': 0.0528751585016984, 'cv_recall_std': 0.02034698994937583, 'cv_f1_std': 0.030264775704857753, 'holdout_accuracy': 0.697, 'holdout_bal_acc': 0.697, 'holdout_precision': 0.7262760195796347, 'holdout_recall': 0.697, 'holdout_f1': 0.6518405387333122}
# {'variant': 'raw', 'model': 'LinearSVC', 'tuned_parameters': '{"clf__C": 1.0}', 'clf_parameters': '{"C": 1.0, "class_weight": "balanced", "dual": "auto", "fit_intercept": true, "intercept_scaling": 1, "loss": "squared_hinge", "max_iter": 20000, "multi_class": "ovr", "penalty": "l2", "random_state": 1618, "tol": 0.0001, "verbose": 0}', 'cv_accuracy_mean': 0.835, 'cv_balanced_accuracy_mean': 0.835, 'cv_precision_mean': 0.8335180376002155, 'cv_recall_mean': 0.835, 'cv_f1_mean': 0.8301557133002623, 'cv_accuracy_std': 0.01140175425099139, 'cv_balanced_accuracy_std': 0.01140175425099134, 'cv_precision_std': 0.011828540692443833, 'cv_recall_std': 0.01140175425099134, 'cv_f1_std': 0.012492052493508942, 'holdout_accuracy': 0.831, 'holdout_bal_acc': 0.8310000000000001, 'holdout_precision': 0.8235167029527652, 'holdout_recall': 0.8310000000000001, 'holdout_f1': 0.8239741958380623}
# {'variant': 'raw', 'model': 'SVC-RBF', 'tuned_parameters': '{"clf__C": 0.5, "clf__gamma": "scale"}', 'clf_parameters': '{"C": 0.5, "break_ties": false, "cache_size": 200, "class_weight": "balanced", "coef0": 0.0, "decision_function_shape": "ovr", "degree": 3, "gamma": "scale", "kernel": "rbf", "max_iter": -1, "probability": false, "random_state": 1618, "shrinking": true, "tol": 0.001, "verbose": false}', 'cv_accuracy_mean': 0.873, 'cv_balanced_accuracy_mean': 0.873, 'cv_precision_mean': 0.8740025886715548, 'cv_recall_mean': 0.873, 'cv_f1_mean': 0.8716664855945389, 'cv_accuracy_std': 0.011224972160321834, 'cv_balanced_accuracy_std': 0.011224972160321905, 'cv_precision_std': 0.012456807345496262, 'cv_recall_std': 0.011224972160321905, 'cv_f1_std': 0.011539377897261362, 'holdout_accuracy': 0.882, 'holdout_bal_acc': 0.882, 'holdout_precision': 0.87989440199439, 'holdout_recall': 0.882, 'holdout_f1': 0.8800795777443842}
# {'variant': 'raw', 'model': 'SGD-Hinge', 'tuned_parameters': '{}', 'clf_parameters': '{"alpha": 0.0001, "average": false, "class_weight": "balanced", "early_stopping": false, "epsilon": 0.1, "eta0": 0.01, "fit_intercept": true, "l1_ratio": 0.15, "learning_rate": "optimal", "loss": "hinge", "max_iter": 20000, "n_iter_no_change": 5, "n_jobs": null, "penalty": "l2", "power_t": 0.5, "random_state": 1618, "shuffle": true, "tol": 0.001, "validation_fraction": 0.1, "verbose": 0, "warm_start": false}', 'cv_accuracy_mean': 0.8030000000000002, 'cv_balanced_accuracy_mean': 0.8030000000000002, 'cv_precision_mean': 0.8357599355732687, 'cv_recall_mean': 0.8030000000000002, 'cv_f1_mean': 0.8021459059082942, 'cv_accuracy_std': 0.01805547008526776, 'cv_balanced_accuracy_std': 0.01805547008526778, 'cv_precision_std': 0.016325889582194292, 'cv_recall_std': 0.01805547008526778, 'cv_f1_std': 0.01943907085732958, 'holdout_accuracy': 0.82, 'holdout_bal_acc': 0.8200000000000001, 'holdout_precision': 0.8372758018149312, 'holdout_recall': 0.8200000000000001, 'holdout_f1': 0.8216454139500045}
# {'variant': 'raw', 'model': 'KNN', 'tuned_parameters': '{"clf__n_neighbors": 11}', 'clf_parameters': '{"algorithm": "auto", "leaf_size": 30, "metric": "minkowski", "metric_params": null, "n_jobs": null, "n_neighbors": 11, "p": 2, "weights": "uniform"}', 'cv_accuracy_mean': 0.8470000000000001, 'cv_balanced_accuracy_mean': 0.8470000000000001, 'cv_precision_mean': 0.8451830669345611, 'cv_recall_mean': 0.8470000000000001, 'cv_f1_mean': 0.8418528881909181, 'cv_accuracy_std': 0.02063976744055031, 'cv_balanced_accuracy_std': 0.0206397674405503, 'cv_precision_std': 0.02074286503526539, 'cv_recall_std': 0.0206397674405503, 'cv_f1_std': 0.02131861400718592, 'holdout_accuracy': 0.863, 'holdout_bal_acc': 0.8630000000000001, 'holdout_precision': 0.8581850341221948, 'holdout_recall': 0.8630000000000001, 'holdout_f1': 0.8589873550740542}
# {'variant': 'raw', 'model': 'DecisionTree', 'tuned_parameters': '{}', 'clf_parameters': '{"ccp_alpha": 0.0, "class_weight": "balanced", "criterion": "gini", "max_depth": null, "max_features": null, "max_leaf_nodes": null, "min_impurity_decrease": 0.0, "min_samples_leaf": 1, "min_samples_split": 2, "min_weight_fraction_leaf": 0.0, "monotonic_cst": null, "random_state": 1618, "splitter": "best"}', 'cv_accuracy_mean': 0.798, 'cv_balanced_accuracy_mean': 0.798, 'cv_precision_mean': 0.8071459011056197, 'cv_recall_mean': 0.798, 'cv_f1_mean': 0.7979959943267574, 'cv_accuracy_std': 0.01805547008526776, 'cv_balanced_accuracy_std': 0.018055470085267804, 'cv_precision_std': 0.019584750502867, 'cv_recall_std': 0.018055470085267804, 'cv_f1_std': 0.017573949970591, 'holdout_accuracy': 0.787, 'holdout_bal_acc': 0.787, 'holdout_precision': 0.7912960001695011, 'holdout_recall': 0.787, 'holdout_f1': 0.788355466650455}
# {'variant': 'raw', 'model': 'RandomForest', 'tuned_parameters': '{"clf__max_depth": null, "clf__n_estimators": 300}', 'clf_parameters': '{"bootstrap": true, "ccp_alpha": 0.0, "class_weight": "balanced", "criterion": "gini", "max_depth": null, "max_features": "sqrt", "max_leaf_nodes": null, "max_samples": null, "min_impurity_decrease": 0.0, "min_samples_leaf": 1, "min_samples_split": 2, "min_weight_fraction_leaf": 0.0, "monotonic_cst": null, "n_estimators": 300, "n_jobs": null, "oob_score": false, "random_state": 1618, "verbose": 0, "warm_start": false}', 'cv_accuracy_mean': 0.875, 'cv_balanced_accuracy_mean': 0.875, 'cv_precision_mean': 0.8767613260268394, 'cv_recall_mean': 0.875, 'cv_f1_mean': 0.8741839192693, 'cv_accuracy_std': 0.01581138830084191, 'cv_balanced_accuracy_std': 0.015811388300841916, 'cv_precision_std': 0.01479852760009557, 'cv_recall_std': 0.015811388300841916, 'cv_f1_std': 0.015067072442379297, 'holdout_accuracy': 0.883, 'holdout_bal_acc': 0.8829999999999998, 'holdout_precision': 0.8805009379135967, 'holdout_recall': 0.8829999999999998, 'holdout_f1': 0.8809645785772775}
# {'variant': 'raw', 'model': 'ExtraTrees', 'tuned_parameters': '{"clf__max_depth": 10, "clf__n_estimators": 600}', 'clf_parameters': '{"bootstrap": false, "ccp_alpha": 0.0, "class_weight": "balanced", "criterion": "gini", "max_depth": 10, "max_features": "sqrt", "max_leaf_nodes": null, "max_samples": null, "min_impurity_decrease": 0.0, "min_samples_leaf": 1, "min_samples_split": 2, "min_weight_fraction_leaf": 0.0, "monotonic_cst": null, "n_estimators": 600, "n_jobs": null, "oob_score": false, "random_state": 1618, "verbose": 0, "warm_start": false}', 'cv_accuracy_mean': 0.875, 'cv_balanced_accuracy_mean': 0.875, 'cv_precision_mean': 0.8757143060608197, 'cv_recall_mean': 0.875, 'cv_f1_mean': 0.8731872631837915, 'cv_accuracy_std': 0.010488088481701525, 'cv_balanced_accuracy_std': 0.010488088481701536, 'cv_precision_std': 0.010037138809167102, 'cv_recall_std': 0.010488088481701536, 'cv_f1_std': 0.011008861726868727, 'holdout_accuracy': 0.89, 'holdout_bal_acc': 0.89, 'holdout_precision': 0.8877501970707943, 'holdout_recall': 0.89, 'holdout_f1': 0.8870138311783927}
# {'variant': 'raw', 'model': 'GradientBoosting', 'tuned_parameters': '{}', 'clf_parameters': '{"ccp_alpha": 0.0, "criterion": "friedman_mse", "init": null, "learning_rate": 0.1, "loss": "log_loss", "max_depth": 3, "max_features": null, "max_leaf_nodes": null, "min_impurity_decrease": 0.0, "min_samples_leaf": 1, "min_samples_split": 2, "min_weight_fraction_leaf": 0.0, "n_estimators": 100, "n_iter_no_change": null, "random_state": 1618, "subsample": 1.0, "tol": 0.0001, "validation_fraction": 0.1, "verbose": 0, "warm_start": false}', 'cv_accuracy_mean': 0.845, 'cv_balanced_accuracy_mean': 0.845, 'cv_precision_mean': 0.8505955826258964, 'cv_recall_mean': 0.845, 'cv_f1_mean': 0.8455218894929383, 'cv_accuracy_std': 0.017320508075688787, 'cv_balanced_accuracy_std': 0.01732050807568877, 'cv_precision_std': 0.018773855743313216, 'cv_recall_std': 0.01732050807568877, 'cv_f1_std': 0.017757630443527714, 'holdout_accuracy': 0.863, 'holdout_bal_acc': 0.8629999999999999, 'holdout_precision': 0.8655322712249347, 'holdout_recall': 0.8629999999999999, 'holdout_f1': 0.8638005997272439}
# {'variant': 'raw', 'model': 'HistGB', 'tuned_parameters': '{"clf__max_depth": 6}', 'clf_parameters': '{"categorical_features": "from_dtype", "class_weight": null, "early_stopping": "auto", "interaction_cst": null, "l2_regularization": 0.0, "learning_rate": 0.1, "loss": "log_loss", "max_bins": 255, "max_depth": 6, "max_features": 1.0, "max_iter": 100, "max_leaf_nodes": 31, "min_samples_leaf": 20, "monotonic_cst": null, "n_iter_no_change": 10, "random_state": 1618, "scoring": "loss", "tol": 1e-07, "validation_fraction": 0.1, "verbose": 0, "warm_start": false}', 'cv_accuracy_mean': 0.852, 'cv_balanced_accuracy_mean': 0.8520000000000001, 'cv_precision_mean': 0.8564466947001339, 'cv_recall_mean': 0.8520000000000001, 'cv_f1_mean': 0.8521314688256011, 'cv_accuracy_std': 0.01029563014098701, 'cv_balanced_accuracy_std': 0.01029563014098698, 'cv_precision_std': 0.009793957411384505, 'cv_recall_std': 0.01029563014098698, 'cv_f1_std': 0.010590963205684872, 'holdout_accuracy': 0.856, 'holdout_bal_acc': 0.8560000000000001, 'holdout_precision': 0.8578233783488708, 'holdout_recall': 0.8560000000000001, 'holdout_f1': 0.8565984703845985}
# {'variant': 'raw', 'model': 'AdaBoost', 'tuned_parameters': '{}', 'clf_parameters': '{"estimator": null, "learning_rate": 1.0, "n_estimators": 50, "random_state": 1618}', 'cv_accuracy_mean': 0.46799999999999997, 'cv_balanced_accuracy_mean': 0.46799999999999997, 'cv_precision_mean': 0.4018463968061513, 'cv_recall_mean': 0.46799999999999997, 'cv_f1_mean': 0.38687644135073623, 'cv_accuracy_std': 0.07046985170979148, 'cv_balanced_accuracy_std': 0.07046985170979145, 'cv_precision_std': 0.11137838376537658, 'cv_recall_std': 0.07046985170979145, 'cv_f1_std': 0.09652269129030568, 'holdout_accuracy': 0.406, 'holdout_bal_acc': 0.406, 'holdout_precision': 0.3714047557699236, 'holdout_recall': 0.406, 'holdout_f1': 0.33562791413784926}
# {'variant': 'raw', 'model': 'GaussianNaiveBayes', 'tuned_parameters': '{}', 'clf_parameters': '{"priors": null, "var_smoothing": 1e-09}', 'cv_accuracy_mean': 0.8780000000000001, 'cv_balanced_accuracy_mean': 0.8779999999999999, 'cv_precision_mean': 0.8817762378712507, 'cv_recall_mean': 0.8779999999999999, 'cv_f1_mean': 0.8773683399384506, 'cv_accuracy_std': 0.008124038404635967, 'cv_balanced_accuracy_std': 0.008124038404635969, 'cv_precision_std': 0.007142470411498798, 'cv_recall_std': 0.008124038404635969, 'cv_f1_std': 0.0075824467153412095, 'holdout_accuracy': 0.881, 'holdout_bal_acc': 0.8809999999999999, 'holdout_precision': 0.8811818950192487, 'holdout_recall': 0.8809999999999999, 'holdout_f1': 0.8804058961263627}
# {'variant': 'scaled', 'model': 'LogisticRegression', 'tuned_parameters': '{"clf__C": 1.0}', 'clf_parameters': '{"C": 1.0, "class_weight": "balanced", "dual": false, "fit_intercept": true, "intercept_scaling": 1, "l1_ratio": 0.0, "max_iter": 20000, "n_jobs": null, "penalty": "deprecated", "random_state": 1618, "solver": "lbfgs", "tol": 0.0001, "verbose": 0, "warm_start": false}', 'cv_accuracy_mean': 0.868, 'cv_balanced_accuracy_mean': 0.868, 'cv_precision_mean': 0.8706279210873034, 'cv_recall_mean': 0.868, 'cv_f1_mean': 0.8671289828030343, 'cv_accuracy_std': 0.021118712081942895, 'cv_balanced_accuracy_std': 0.021118712081942853, 'cv_precision_std': 0.019713098015347735, 'cv_recall_std': 0.021118712081942853, 'cv_f1_std': 0.02091572567098008, 'holdout_accuracy': 0.864, 'holdout_bal_acc': 0.8640000000000001, 'holdout_precision': 0.8616445212249527, 'holdout_recall': 0.8640000000000001, 'holdout_f1': 0.8618007106000496}
# {'variant': 'scaled', 'model': 'RidgeClassifier', 'tuned_parameters': '{}', 'clf_parameters': '{"alpha": 1.0, "class_weight": "balanced", "copy_X": true, "fit_intercept": true, "max_iter": null, "positive": false, "random_state": 1618, "solver": "auto", "tol": 0.0001}', 'cv_accuracy_mean': 0.6910000000000001, 'cv_balanced_accuracy_mean': 0.6910000000000001, 'cv_precision_mean': 0.7040594389401891, 'cv_recall_mean': 0.6910000000000001, 'cv_f1_mean': 0.6423421620563994, 'cv_accuracy_std': 0.020346989949375772, 'cv_balanced_accuracy_std': 0.02034698994937583, 'cv_precision_std': 0.0528751585016984, 'cv_recall_std': 0.02034698994937583, 'cv_f1_std': 0.030264775704857753, 'holdout_accuracy': 0.698, 'holdout_bal_acc': 0.698, 'holdout_precision': 0.7310665623701774, 'holdout_recall': 0.698, 'holdout_f1': 0.6534194412350164}
# {'variant': 'scaled', 'model': 'LinearSVC', 'tuned_parameters': '{"clf__C": 0.5}', 'clf_parameters': '{"C": 0.5, "class_weight": "balanced", "dual": "auto", "fit_intercept": true, "intercept_scaling": 1, "loss": "squared_hinge", "max_iter": 20000, "multi_class": "ovr", "penalty": "l2", "random_state": 1618, "tol": 0.0001, "verbose": 0}', 'cv_accuracy_mean': 0.836, 'cv_balanced_accuracy_mean': 0.8360000000000001, 'cv_precision_mean': 0.8347012274977681, 'cv_recall_mean': 0.8360000000000001, 'cv_f1_mean': 0.8316418409230886, 'cv_accuracy_std': 0.013564659966250548, 'cv_balanced_accuracy_std': 0.013564659966250536, 'cv_precision_std': 0.013931029205321754, 'cv_recall_std': 0.013564659966250536, 'cv_f1_std': 0.014707204528358936, 'holdout_accuracy': 0.831, 'holdout_bal_acc': 0.8310000000000001, 'holdout_precision': 0.8236124693990947, 'holdout_recall': 0.8310000000000001, 'holdout_f1': 0.8237237343960659}
# {'variant': 'scaled', 'model': 'SVC-RBF', 'tuned_parameters': '{"clf__C": 0.5, "clf__gamma": "scale"}', 'clf_parameters': '{"C": 0.5, "break_ties": false, "cache_size": 200, "class_weight": "balanced", "coef0": 0.0, "decision_function_shape": "ovr", "degree": 3, "gamma": "scale", "kernel": "rbf", "max_iter": -1, "probability": false, "random_state": 1618, "shrinking": true, "tol": 0.001, "verbose": false}', 'cv_accuracy_mean': 0.865, 'cv_balanced_accuracy_mean': 0.865, 'cv_precision_mean': 0.8653629521568005, 'cv_recall_mean': 0.865, 'cv_f1_mean': 0.8640275520308658, 'cv_accuracy_std': 0.015811388300841913, 'cv_balanced_accuracy_std': 0.01581138830084191, 'cv_precision_std': 0.017217900189958685, 'cv_recall_std': 0.01581138830084191, 'cv_f1_std': 0.016066198048844158, 'holdout_accuracy': 0.872, 'holdout_bal_acc': 0.8719999999999999, 'holdout_precision': 0.8720205476282687, 'holdout_recall': 0.8719999999999999, 'holdout_f1': 0.8707926022207501}
# {'variant': 'scaled', 'model': 'SGD-Hinge', 'tuned_parameters': '{}', 'clf_parameters': '{"alpha": 0.0001, "average": false, "class_weight": "balanced", "early_stopping": false, "epsilon": 0.1, "eta0": 0.01, "fit_intercept": true, "l1_ratio": 0.15, "learning_rate": "optimal", "loss": "hinge", "max_iter": 20000, "n_iter_no_change": 5, "n_jobs": null, "penalty": "l2", "power_t": 0.5, "random_state": 1618, "shuffle": true, "tol": 0.001, "validation_fraction": 0.1, "verbose": 0, "warm_start": false}', 'cv_accuracy_mean': 0.7759999999999999, 'cv_balanced_accuracy_mean': 0.776, 'cv_precision_mean': 0.8185035590926717, 'cv_recall_mean': 0.776, 'cv_f1_mean': 0.7729942552542075, 'cv_accuracy_std': 0.03056141357987224, 'cv_balanced_accuracy_std': 0.030561413579872264, 'cv_precision_std': 0.01638166611407553, 'cv_recall_std': 0.030561413579872264, 'cv_f1_std': 0.03663658574241768, 'holdout_accuracy': 0.794, 'holdout_bal_acc': 0.794, 'holdout_precision': 0.840589831043504, 'holdout_recall': 0.794, 'holdout_f1': 0.7918720923153592}
# {'variant': 'scaled', 'model': 'KNN', 'tuned_parameters': '{"clf__n_neighbors": 5}', 'clf_parameters': '{"algorithm": "auto", "leaf_size": 30, "metric": "minkowski", "metric_params": null, "n_jobs": null, "n_neighbors": 5, "p": 2, "weights": "uniform"}', 'cv_accuracy_mean': 0.8300000000000001, 'cv_balanced_accuracy_mean': 0.8300000000000001, 'cv_precision_mean': 0.8253760510925338, 'cv_recall_mean': 0.8300000000000001, 'cv_f1_mean': 0.8238429601967979, 'cv_accuracy_std': 0.023021728866442666, 'cv_balanced_accuracy_std': 0.023021728866442725, 'cv_precision_std': 0.025301954758798772, 'cv_recall_std': 0.023021728866442725, 'cv_f1_std': 0.024333781974988037, 'holdout_accuracy': 0.836, 'holdout_bal_acc': 0.836, 'holdout_precision': 0.8339495332899471, 'holdout_recall': 0.836, 'holdout_f1': 0.8321596480123971}
# {'variant': 'scaled', 'model': 'DecisionTree', 'tuned_parameters': '{}', 'clf_parameters': '{"ccp_alpha": 0.0, "class_weight": "balanced", "criterion": "gini", "max_depth": null, "max_features": null, "max_leaf_nodes": null, "min_impurity_decrease": 0.0, "min_samples_leaf": 1, "min_samples_split": 2, "min_weight_fraction_leaf": 0.0, "monotonic_cst": null, "random_state": 1618, "splitter": "best"}', 'cv_accuracy_mean': 0.798, 'cv_balanced_accuracy_mean': 0.798, 'cv_precision_mean': 0.8071459011056197, 'cv_recall_mean': 0.798, 'cv_f1_mean': 0.7979959943267574, 'cv_accuracy_std': 0.01805547008526776, 'cv_balanced_accuracy_std': 0.018055470085267804, 'cv_precision_std': 0.019584750502867, 'cv_recall_std': 0.018055470085267804, 'cv_f1_std': 0.017573949970591, 'holdout_accuracy': 0.787, 'holdout_bal_acc': 0.787, 'holdout_precision': 0.7912960001695011, 'holdout_recall': 0.787, 'holdout_f1': 0.788355466650455}
# {'variant': 'scaled', 'model': 'RandomForest', 'tuned_parameters': '{"clf__max_depth": null, "clf__n_estimators": 300}', 'clf_parameters': '{"bootstrap": true, "ccp_alpha": 0.0, "class_weight": "balanced", "criterion": "gini", "max_depth": null, "max_features": "sqrt", "max_leaf_nodes": null, "max_samples": null, "min_impurity_decrease": 0.0, "min_samples_leaf": 1, "min_samples_split": 2, "min_weight_fraction_leaf": 0.0, "monotonic_cst": null, "n_estimators": 300, "n_jobs": null, "oob_score": false, "random_state": 1618, "verbose": 0, "warm_start": false}', 'cv_accuracy_mean': 0.875, 'cv_balanced_accuracy_mean': 0.875, 'cv_precision_mean': 0.8767613260268394, 'cv_recall_mean': 0.875, 'cv_f1_mean': 0.8741839192693, 'cv_accuracy_std': 0.01581138830084191, 'cv_balanced_accuracy_std': 0.015811388300841916, 'cv_precision_std': 0.01479852760009557, 'cv_recall_std': 0.015811388300841916, 'cv_f1_std': 0.015067072442379297, 'holdout_accuracy': 0.883, 'holdout_bal_acc': 0.8829999999999998, 'holdout_precision': 0.8805009379135967, 'holdout_recall': 0.8829999999999998, 'holdout_f1': 0.8809645785772775}
# {'variant': 'scaled', 'model': 'ExtraTrees', 'tuned_parameters': '{"clf__max_depth": 10, "clf__n_estimators": 600}', 'clf_parameters': '{"bootstrap": false, "ccp_alpha": 0.0, "class_weight": "balanced", "criterion": "gini", "max_depth": 10, "max_features": "sqrt", "max_leaf_nodes": null, "max_samples": null, "min_impurity_decrease": 0.0, "min_samples_leaf": 1, "min_samples_split": 2, "min_weight_fraction_leaf": 0.0, "monotonic_cst": null, "n_estimators": 600, "n_jobs": null, "oob_score": false, "random_state": 1618, "verbose": 0, "warm_start": false}', 'cv_accuracy_mean': 0.875, 'cv_balanced_accuracy_mean': 0.875, 'cv_precision_mean': 0.8757143060608197, 'cv_recall_mean': 0.875, 'cv_f1_mean': 0.8731872631837915, 'cv_accuracy_std': 0.010488088481701525, 'cv_balanced_accuracy_std': 0.010488088481701536, 'cv_precision_std': 0.010037138809167102, 'cv_recall_std': 0.010488088481701536, 'cv_f1_std': 0.011008861726868727, 'holdout_accuracy': 0.89, 'holdout_bal_acc': 0.89, 'holdout_precision': 0.8877501970707943, 'holdout_recall': 0.89, 'holdout_f1': 0.8870138311783927}
# {'variant': 'scaled', 'model': 'GradientBoosting', 'tuned_parameters': '{}', 'clf_parameters': '{"ccp_alpha": 0.0, "criterion": "friedman_mse", "init": null, "learning_rate": 0.1, "loss": "log_loss", "max_depth": 3, "max_features": null, "max_leaf_nodes": null, "min_impurity_decrease": 0.0, "min_samples_leaf": 1, "min_samples_split": 2, "min_weight_fraction_leaf": 0.0, "n_estimators": 100, "n_iter_no_change": null, "random_state": 1618, "subsample": 1.0, "tol": 0.0001, "validation_fraction": 0.1, "verbose": 0, "warm_start": false}', 'cv_accuracy_mean': 0.845, 'cv_balanced_accuracy_mean': 0.845, 'cv_precision_mean': 0.8505955826258964, 'cv_recall_mean': 0.845, 'cv_f1_mean': 0.8455218894929383, 'cv_accuracy_std': 0.017320508075688787, 'cv_balanced_accuracy_std': 0.01732050807568877, 'cv_precision_std': 0.018773855743313216, 'cv_recall_std': 0.01732050807568877, 'cv_f1_std': 0.017757630443527714, 'holdout_accuracy': 0.863, 'holdout_bal_acc': 0.8629999999999999, 'holdout_precision': 0.8655322712249347, 'holdout_recall': 0.8629999999999999, 'holdout_f1': 0.8638005997272439}
# {'variant': 'scaled', 'model': 'HistGB', 'tuned_parameters': '{"clf__max_depth": null}', 'clf_parameters': '{"categorical_features": "from_dtype", "class_weight": null, "early_stopping": "auto", "interaction_cst": null, "l2_regularization": 0.0, "learning_rate": 0.1, "loss": "log_loss", "max_bins": 255, "max_depth": null, "max_features": 1.0, "max_iter": 100, "max_leaf_nodes": 31, "min_samples_leaf": 20, "monotonic_cst": null, "n_iter_no_change": 10, "random_state": 1618, "scoring": "loss", "tol": 1e-07, "validation_fraction": 0.1, "verbose": 0, "warm_start": false}', 'cv_accuracy_mean': 0.8539999999999999, 'cv_balanced_accuracy_mean': 0.8540000000000001, 'cv_precision_mean': 0.8584466947001339, 'cv_recall_mean': 0.8540000000000001, 'cv_f1_mean': 0.854131468825601, 'cv_accuracy_std': 0.011575836902790236, 'cv_balanced_accuracy_std': 0.011575836902790192, 'cv_precision_std': 0.011012950710101678, 'cv_recall_std': 0.011575836902790192, 'cv_f1_std': 0.011926397963848546, 'holdout_accuracy': 0.855, 'holdout_bal_acc': 0.8550000000000001, 'holdout_precision': 0.8567493319391855, 'holdout_recall': 0.8550000000000001, 'holdout_f1': 0.8555238116510105}
# {'variant': 'scaled', 'model': 'AdaBoost', 'tuned_parameters': '{}', 'clf_parameters': '{"estimator": null, "learning_rate": 1.0, "n_estimators": 50, "random_state": 1618}', 'cv_accuracy_mean': 0.46799999999999997, 'cv_balanced_accuracy_mean': 0.46799999999999997, 'cv_precision_mean': 0.4018463968061513, 'cv_recall_mean': 0.46799999999999997, 'cv_f1_mean': 0.38687644135073623, 'cv_accuracy_std': 0.07046985170979148, 'cv_balanced_accuracy_std': 0.07046985170979145, 'cv_precision_std': 0.11137838376537658, 'cv_recall_std': 0.07046985170979145, 'cv_f1_std': 0.09652269129030568, 'holdout_accuracy': 0.406, 'holdout_bal_acc': 0.406, 'holdout_precision': 0.3714047557699236, 'holdout_recall': 0.406, 'holdout_f1': 0.33562791413784926}
# {'variant': 'scaled', 'model': 'GaussianNaiveBayes', 'tuned_parameters': '{}', 'clf_parameters': '{"priors": null, "var_smoothing": 1e-09}', 'cv_accuracy_mean': 0.8780000000000001, 'cv_balanced_accuracy_mean': 0.8779999999999999, 'cv_precision_mean': 0.8817762378712507, 'cv_recall_mean': 0.8779999999999999, 'cv_f1_mean': 0.8773683399384506, 'cv_accuracy_std': 0.008124038404635967, 'cv_balanced_accuracy_std': 0.008124038404635969, 'cv_precision_std': 0.007142470411498798, 'cv_recall_std': 0.008124038404635969, 'cv_f1_std': 0.0075824467153412095, 'holdout_accuracy': 0.881, 'holdout_bal_acc': 0.8809999999999999, 'holdout_precision': 0.8811818950192487, 'holdout_recall': 0.8809999999999999, 'holdout_f1': 0.8804058961263627}
# Highest: 0.89
# shape: (5, 19)
# ┌─────────┬────────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ variant ┆ model      ┆ tuned_par ┆ clf_param ┆ … ┆ holdout_b ┆ holdout_p ┆ holdout_r ┆ holdout_f │
# │ ---     ┆ ---        ┆ ameters   ┆ eters     ┆   ┆ al_acc    ┆ recision  ┆ ecall     ┆ 1         │
# │ str     ┆ str        ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │         ┆            ┆ str       ┆ str       ┆   ┆ f64       ┆ f64       ┆ f64       ┆ f64       │
# ╞═════════╪════════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ raw     ┆ ExtraTrees ┆ {"clf__ma ┆ {"bootstr ┆ … ┆ 0.89      ┆ 0.88775   ┆ 0.89      ┆ 0.887014  │
# │         ┆            ┆ x_depth": ┆ ap":      ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ 10,       ┆ false,    ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ "clf__n…  ┆ "ccp_alph ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ …         ┆   ┆           ┆           ┆           ┆           │
# │ scaled  ┆ ExtraTrees ┆ {"clf__ma ┆ {"bootstr ┆ … ┆ 0.89      ┆ 0.88775   ┆ 0.89      ┆ 0.887014  │
# │         ┆            ┆ x_depth": ┆ ap":      ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ 10,       ┆ false,    ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ "clf__n…  ┆ "ccp_alph ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ …         ┆   ┆           ┆           ┆           ┆           │
# │ scaled  ┆ RandomFore ┆ {"clf__ma ┆ {"bootstr ┆ … ┆ 0.883     ┆ 0.880501  ┆ 0.883     ┆ 0.880965  │
# │         ┆ st         ┆ x_depth": ┆ ap":      ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ null,     ┆ true, "cc ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ "clf_…    ┆ p_alpha…  ┆   ┆           ┆           ┆           ┆           │
# │ raw     ┆ RandomFore ┆ {"clf__ma ┆ {"bootstr ┆ … ┆ 0.883     ┆ 0.880501  ┆ 0.883     ┆ 0.880965  │
# │         ┆ st         ┆ x_depth": ┆ ap":      ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ null,     ┆ true, "cc ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ "clf_…    ┆ p_alpha…  ┆   ┆           ┆           ┆           ┆           │
# │ raw     ┆ SVC-RBF    ┆ {"clf__C" ┆ {"C":     ┆ … ┆ 0.882     ┆ 0.879894  ┆ 0.882     ┆ 0.88008   │
# │         ┆            ┆ : 0.5,    ┆ 0.5, "bre ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ "clf__gam ┆ ak_ties": ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ ma": …    ┆ false…    ┆   ┆           ┆           ┆           ┆           │
# └─────────┴────────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘
# Highest: 0.89
# shape: (5, 19)
# ┌─────────┬────────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ variant ┆ model      ┆ tuned_par ┆ clf_param ┆ … ┆ holdout_b ┆ holdout_p ┆ holdout_r ┆ holdout_f │
# │ ---     ┆ ---        ┆ ameters   ┆ eters     ┆   ┆ al_acc    ┆ recision  ┆ ecall     ┆ 1         │
# │ str     ┆ str        ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │         ┆            ┆ str       ┆ str       ┆   ┆ f64       ┆ f64       ┆ f64       ┆ f64       │
# ╞═════════╪════════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ raw     ┆ ExtraTrees ┆ {"clf__ma ┆ {"bootstr ┆ … ┆ 0.89      ┆ 0.88775   ┆ 0.89      ┆ 0.887014  │
# │         ┆            ┆ x_depth": ┆ ap":      ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ 10,       ┆ false,    ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ "clf__n…  ┆ "ccp_alph ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ …         ┆   ┆           ┆           ┆           ┆           │
# │ scaled  ┆ ExtraTrees ┆ {"clf__ma ┆ {"bootstr ┆ … ┆ 0.89      ┆ 0.88775   ┆ 0.89      ┆ 0.887014  │
# │         ┆            ┆ x_depth": ┆ ap":      ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ 10,       ┆ false,    ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ "clf__n…  ┆ "ccp_alph ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ …         ┆   ┆           ┆           ┆           ┆           │
# │ scaled  ┆ RandomFore ┆ {"clf__ma ┆ {"bootstr ┆ … ┆ 0.883     ┆ 0.880501  ┆ 0.883     ┆ 0.880965  │
# │         ┆ st         ┆ x_depth": ┆ ap":      ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ null,     ┆ true, "cc ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ "clf_…    ┆ p_alpha…  ┆   ┆           ┆           ┆           ┆           │
# │ raw     ┆ RandomFore ┆ {"clf__ma ┆ {"bootstr ┆ … ┆ 0.883     ┆ 0.880501  ┆ 0.883     ┆ 0.880965  │
# │         ┆ st         ┆ x_depth": ┆ ap":      ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ null,     ┆ true, "cc ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ "clf_…    ┆ p_alpha…  ┆   ┆           ┆           ┆           ┆           │
# │ raw     ┆ SVC-RBF    ┆ {"clf__C" ┆ {"C":     ┆ … ┆ 0.882     ┆ 0.879894  ┆ 0.882     ┆ 0.88008   │
# │         ┆            ┆ : 0.5,    ┆ 0.5, "bre ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ "clf__gam ┆ ak_ties": ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ ma": …    ┆ false…    ┆   ┆           ┆           ┆           ┆           │
# └─────────┴────────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘
# Highest: 0.8877501970707943
# shape: (5, 19)
# ┌─────────┬────────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ variant ┆ model      ┆ tuned_par ┆ clf_param ┆ … ┆ holdout_b ┆ holdout_p ┆ holdout_r ┆ holdout_f │
# │ ---     ┆ ---        ┆ ameters   ┆ eters     ┆   ┆ al_acc    ┆ recision  ┆ ecall     ┆ 1         │
# │ str     ┆ str        ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │         ┆            ┆ str       ┆ str       ┆   ┆ f64       ┆ f64       ┆ f64       ┆ f64       │
# ╞═════════╪════════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ scaled  ┆ ExtraTrees ┆ {"clf__ma ┆ {"bootstr ┆ … ┆ 0.89      ┆ 0.88775   ┆ 0.89      ┆ 0.887014  │
# │         ┆            ┆ x_depth": ┆ ap":      ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ 10,       ┆ false,    ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ "clf__n…  ┆ "ccp_alph ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ …         ┆   ┆           ┆           ┆           ┆           │
# │ raw     ┆ ExtraTrees ┆ {"clf__ma ┆ {"bootstr ┆ … ┆ 0.89      ┆ 0.88775   ┆ 0.89      ┆ 0.887014  │
# │         ┆            ┆ x_depth": ┆ ap":      ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ 10,       ┆ false,    ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ "clf__n…  ┆ "ccp_alph ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ …         ┆   ┆           ┆           ┆           ┆           │
# │ scaled  ┆ GaussianNa ┆ {}        ┆ {"priors" ┆ … ┆ 0.881     ┆ 0.881182  ┆ 0.881     ┆ 0.880406  │
# │         ┆ iveBayes   ┆           ┆ : null,   ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ "var_smoo ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ thin…     ┆   ┆           ┆           ┆           ┆           │
# │ raw     ┆ GaussianNa ┆ {}        ┆ {"priors" ┆ … ┆ 0.881     ┆ 0.881182  ┆ 0.881     ┆ 0.880406  │
# │         ┆ iveBayes   ┆           ┆ : null,   ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ "var_smoo ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ thin…     ┆   ┆           ┆           ┆           ┆           │
# │ scaled  ┆ RandomFore ┆ {"clf__ma ┆ {"bootstr ┆ … ┆ 0.883     ┆ 0.880501  ┆ 0.883     ┆ 0.880965  │
# │         ┆ st         ┆ x_depth": ┆ ap":      ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ null,     ┆ true, "cc ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ "clf_…    ┆ p_alpha…  ┆   ┆           ┆           ┆           ┆           │
# └─────────┴────────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘
# Highest: 0.89
# shape: (5, 19)
# ┌─────────┬────────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ variant ┆ model      ┆ tuned_par ┆ clf_param ┆ … ┆ holdout_b ┆ holdout_p ┆ holdout_r ┆ holdout_f │
# │ ---     ┆ ---        ┆ ameters   ┆ eters     ┆   ┆ al_acc    ┆ recision  ┆ ecall     ┆ 1         │
# │ str     ┆ str        ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │         ┆            ┆ str       ┆ str       ┆   ┆ f64       ┆ f64       ┆ f64       ┆ f64       │
# ╞═════════╪════════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ raw     ┆ ExtraTrees ┆ {"clf__ma ┆ {"bootstr ┆ … ┆ 0.89      ┆ 0.88775   ┆ 0.89      ┆ 0.887014  │
# │         ┆            ┆ x_depth": ┆ ap":      ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ 10,       ┆ false,    ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ "clf__n…  ┆ "ccp_alph ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ …         ┆   ┆           ┆           ┆           ┆           │
# │ scaled  ┆ ExtraTrees ┆ {"clf__ma ┆ {"bootstr ┆ … ┆ 0.89      ┆ 0.88775   ┆ 0.89      ┆ 0.887014  │
# │         ┆            ┆ x_depth": ┆ ap":      ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ 10,       ┆ false,    ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ "clf__n…  ┆ "ccp_alph ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ …         ┆   ┆           ┆           ┆           ┆           │
# │ scaled  ┆ RandomFore ┆ {"clf__ma ┆ {"bootstr ┆ … ┆ 0.883     ┆ 0.880501  ┆ 0.883     ┆ 0.880965  │
# │         ┆ st         ┆ x_depth": ┆ ap":      ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ null,     ┆ true, "cc ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ "clf_…    ┆ p_alpha…  ┆   ┆           ┆           ┆           ┆           │
# │ raw     ┆ RandomFore ┆ {"clf__ma ┆ {"bootstr ┆ … ┆ 0.883     ┆ 0.880501  ┆ 0.883     ┆ 0.880965  │
# │         ┆ st         ┆ x_depth": ┆ ap":      ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ null,     ┆ true, "cc ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ "clf_…    ┆ p_alpha…  ┆   ┆           ┆           ┆           ┆           │
# │ raw     ┆ SVC-RBF    ┆ {"clf__C" ┆ {"C":     ┆ … ┆ 0.882     ┆ 0.879894  ┆ 0.882     ┆ 0.88008   │
# │         ┆            ┆ : 0.5,    ┆ 0.5, "bre ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ "clf__gam ┆ ak_ties": ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ ma": …    ┆ false…    ┆   ┆           ┆           ┆           ┆           │
# └─────────┴────────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘
# Highest: 0.8870138311783927
# shape: (5, 19)
# ┌─────────┬────────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ variant ┆ model      ┆ tuned_par ┆ clf_param ┆ … ┆ holdout_b ┆ holdout_p ┆ holdout_r ┆ holdout_f │
# │ ---     ┆ ---        ┆ ameters   ┆ eters     ┆   ┆ al_acc    ┆ recision  ┆ ecall     ┆ 1         │
# │ str     ┆ str        ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │         ┆            ┆ str       ┆ str       ┆   ┆ f64       ┆ f64       ┆ f64       ┆ f64       │
# ╞═════════╪════════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ scaled  ┆ ExtraTrees ┆ {"clf__ma ┆ {"bootstr ┆ … ┆ 0.89      ┆ 0.88775   ┆ 0.89      ┆ 0.887014  │
# │         ┆            ┆ x_depth": ┆ ap":      ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ 10,       ┆ false,    ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ "clf__n…  ┆ "ccp_alph ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ …         ┆   ┆           ┆           ┆           ┆           │
# │ raw     ┆ ExtraTrees ┆ {"clf__ma ┆ {"bootstr ┆ … ┆ 0.89      ┆ 0.88775   ┆ 0.89      ┆ 0.887014  │
# │         ┆            ┆ x_depth": ┆ ap":      ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ 10,       ┆ false,    ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ "clf__n…  ┆ "ccp_alph ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ …         ┆   ┆           ┆           ┆           ┆           │
# │ scaled  ┆ RandomFore ┆ {"clf__ma ┆ {"bootstr ┆ … ┆ 0.883     ┆ 0.880501  ┆ 0.883     ┆ 0.880965  │
# │         ┆ st         ┆ x_depth": ┆ ap":      ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ null,     ┆ true, "cc ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ "clf_…    ┆ p_alpha…  ┆   ┆           ┆           ┆           ┆           │
# │ raw     ┆ RandomFore ┆ {"clf__ma ┆ {"bootstr ┆ … ┆ 0.883     ┆ 0.880501  ┆ 0.883     ┆ 0.880965  │
# │         ┆ st         ┆ x_depth": ┆ ap":      ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ null,     ┆ true, "cc ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆ "clf_…    ┆ p_alpha…  ┆   ┆           ┆           ┆           ┆           │
# │ scaled  ┆ GaussianNa ┆ {}        ┆ {"priors" ┆ … ┆ 0.881     ┆ 0.881182  ┆ 0.881     ┆ 0.880406  │
# │         ┆ iveBayes   ┆           ┆ : null,   ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ "var_smoo ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆ thin…     ┆   ┆           ┆           ┆           ┆           │
# └─────────┴────────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘
