# %%
from gensim.models import LdaModel
import json
import time
import pandas as pd

from nltk.tokenize import word_tokenize
from gensim.models import CoherenceModel
from gensim.corpora import Dictionary
from itertools import combinations

# %%
K_RANGE = list(range(3, 20))
TOP_N = 10
RANDOM_STATE = 1618 # same random state as default for MATAVE topic model

# %%
try:
    with open('../dataProcessed/nurseNotes.json', 'r') as file:
        nurse_notes = json.load(file)
    print("File loaded successfully.")
    
except FileNotFoundError:
    print("Error: The file 'data.json' was not found.")
# Out:
# File loaded successfully.

# %%
# Make utility function to get coherence. - gensim implementation is also used in OCTIS (https://github.com/MIND-Lab/OCTIS/blob/master/octis/evaluation_metrics/coherence_metrics.py)
def get_coherence_score(topics, tokenized_texts, dictionary, coherence_type):
    coherence_model = CoherenceModel(
        topics=topics,
        texts=tokenized_texts,
        dictionary=dictionary,
        coherence=coherence_type # either 'c_npmi' or 'c_v'
    )
    return coherence_model.get_coherence()

# Make utility function to get diversity (always 10 words) - adapted from OCTIS (https://github.com/MIND-Lab/OCTIS/blob/master/octis/evaluation_metrics/diversity_metrics.py)
def get_diversity_score(topics):
    if len(topics) <= 0:
        return 0.0
    unique_words = set()
    for topic in topics:
        unique_words.update(topic[:10])
    return len(unique_words) / (10 * len(topics))

# Redundancy calculation. Higher the better, as closer to 1 means non-overlapping topics (inverted score). Adapted from https://aclanthology.org/2024.acl-long.11/.
def compute_topic_redundancy(topic_word_distributions, TOP_N=10):
    redundancy_scores = []
    for topic1, topic2 in combinations(topic_word_distributions, 2):
        overlap = len(set(topic1[:TOP_N]).intersection(set(topic2[:TOP_N])))
        redundancy = overlap / TOP_N
        redundancy_scores.append(redundancy)
    average_redundancy = sum(redundancy_scores) / len(redundancy_scores)
    return 1 - average_redundancy

# %%
def lda_analysis(texts, dataset_name):
    # Prepare components for evaluation.
    tokenized_texts = [word_tokenize(text.lower()) for text in texts]
    dictionary = Dictionary(tokenized_texts)
    corpus = [dictionary.doc2bow(text) for text in tokenized_texts]

    metric_results = {'Dataset Name': [], 'Algorithm Name': [], 'Coherence': [], 'Diversity': [], 'Redundancy': [], 'Time': [], 'Top Topic Words': []}
    
    for k in K_RANGE:
        start = time.time()

        lda_model = LdaModel(
            corpus=corpus,
            id2word=dictionary,
            num_topics=k,
            random_state=RANDOM_STATE,
            passes=10
        )

        lda_topics = [
            [word for word, _ in lda_model.show_topic(i, topn=TOP_N)]
            for i in range(k)
        ]

        end = time.time()

        metric_results['Algorithm Name'].append(f'LDA (K={k})')
        metric_results['Dataset Name'].append(dataset_name)
        metric_results['Coherence'].append(
            get_coherence_score(lda_topics, tokenized_texts, dictionary, 'c_v')
        )
        metric_results['Diversity'].append(get_diversity_score(lda_topics))
        metric_results['Redundancy'].append(compute_topic_redundancy(lda_topics))
        metric_results['Time'].append(end - start)
        metric_results['Top Topic Words'].append(lda_topics)
    
    return metric_results

# %%
all_results = []
all_texts = []
for key in nurse_notes:
    all_results.append(pd.DataFrame(lda_analysis(nurse_notes[key], key)))
    all_texts.extend(nurse_notes[key])
combined_df = pd.concat(all_results)
# Out:
# python(7358) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(7359) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(7360) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(7361) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(7362) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(7363) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(7364) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(7426) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(7429) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(7431) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(7432) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(7436) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(7437) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(7438) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(7498) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(7509) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(7512) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(7514) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(7516) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(7517) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(7518) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(7547) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(7548) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(7549) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(7550) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(7551) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(7552) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(7553) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(7618) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(7619) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(7620) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(7621) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(7622) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(7623) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(7624) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(7675) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(7676) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(7677) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(7678) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(7679) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(7680) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(7681) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(7733) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(7734) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(7735) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(7736) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(7737) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(7738) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(7739) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(7796) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(7797) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(7798) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(7799) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(7800) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(7801) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(7802) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(7849) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(7850) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(7851) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(7852) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(7853) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(7854) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(7855) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(7910) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(7911) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(7912) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(7913) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(7914) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(7916) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(7917) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(7961) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(7962) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(7963) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(7964) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(7965) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(7966) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(7967) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8020) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8021) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8022) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8023) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8024) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8025) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8026) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8073) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8078) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8079) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8080) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8081) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8082) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8083) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8137) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8138) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8139) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8140) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8141) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8142) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8143) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8198) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8199) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8201) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8202) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8203) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8204) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8205) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8248) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8249) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8250) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8251) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8252) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8253) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8254) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8304) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8305) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8306) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8307) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8308) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8309) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8310) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8354) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8355) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8356) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8357) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8359) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8361) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8367) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8412) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8413) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8414) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8415) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8416) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8417) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8418) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8461) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8462) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8463) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8464) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8465) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8466) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8467) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8503) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8504) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8505) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8506) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8507) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8508) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8509) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8552) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8553) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8554) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8555) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8556) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8557) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8558) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8621) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8622) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8623) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8624) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8626) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8628) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8629) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8664) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8665) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8666) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8667) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8668) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8669) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8670) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8710) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8713) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8715) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8716) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8719) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8720) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8721) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8760) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8761) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8762) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8763) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8764) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8765) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8766) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8825) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8826) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8827) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8828) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8829) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8830) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8831) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8885) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8886) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8887) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8888) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8889) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8890) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8891) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8922) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8923) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8924) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8925) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8926) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8927) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8928) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8989) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8991) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8993) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(8995) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9000) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9001) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9002) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9050) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9051) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9052) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9053) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9054) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9055) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9063) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9117) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9118) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9119) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9120) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9121) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9122) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9123) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9178) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9185) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9187) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9188) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9189) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9190) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9191) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9225) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9226) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9227) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9228) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9229) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9230) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9231) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9285) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9289) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9291) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9293) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9294) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9295) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9296) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9347) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9348) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9349) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9350) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9351) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9352) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9354) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9410) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9412) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9413) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9414) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9416) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9417) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9418) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9461) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9462) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9463) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9464) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9465) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9466) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9467) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9511) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9512) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9513) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9514) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9515) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9516) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9517) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9554) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9555) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9556) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9557) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9558) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9559) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9560) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9610) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9611) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9612) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9613) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9614) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9615) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9616) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9673) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9674) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9675) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9676) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9677) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9678) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9679) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9717) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9718) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9719) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9720) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9721) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9722) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9723) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9791) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9792) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9793) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9794) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9795) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9796) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9797) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9869) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9870) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9871) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9872) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9873) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9874) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9875) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9972) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9973) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9974) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9975) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9976) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9977) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(9978) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10055) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10056) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10057) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10058) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10059) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10060) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10061) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10121) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10122) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10123) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10124) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10125) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10126) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10127) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10181) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10186) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10189) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10192) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10195) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10198) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10201) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10280) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10281) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10282) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10283) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10284) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10285) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10286) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10359) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10360) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10361) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10362) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10363) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10364) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10365) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10420) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10421) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10422) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10423) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10424) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10425) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10426) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10491) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10492) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10493) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10494) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10495) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10496) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10497) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10544) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10545) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10546) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10547) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10548) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10549) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10550) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10609) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10610) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10611) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10612) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10613) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10614) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10615) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10660) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10661) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10662) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10663) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10664) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10665) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10666) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10725) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10728) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10729) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10730) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10731) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10732) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10733) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10790) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10791) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10792) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10793) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10794) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10795) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10796) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10842) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10843) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10844) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10845) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10846) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10847) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10848) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10894) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10895) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10896) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10897) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10898) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10899) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10900) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10943) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10944) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10945) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10946) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10947) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10948) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10949) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10993) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10994) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10995) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10996) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10997) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10998) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(10999) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(11041) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(11042) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(11043) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(11044) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(11045) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(11046) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(11047) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(11103) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(11104) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(11105) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(11106) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(11107) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(11108) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(11109) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(11138) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(11139) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(11140) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(11141) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(11142) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(11143) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(11144) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(11194) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(11195) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(11197) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(11204) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(11205) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(11206) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(11207) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(11243) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(11244) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(11245) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(11246) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(11247) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(11248) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(11249) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(11293) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(11294) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(11295) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(11296) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(11297) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(11298) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(11299) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(11347) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(11348) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(11349) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(11350) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(11351) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(11352) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(11355) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(11413) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(11414) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(11415) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(11416) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(11417) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(11418) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(11419) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(11463) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(11464) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(11465) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# ...
# python(12744) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12745) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12746) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12747) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12748) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12749) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12750) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12751) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12752) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12754) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12755) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12756) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12757) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12758) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12759) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12760) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12768) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12769) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12770) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12771) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12772) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12773) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12774) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12779) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12780) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12781) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12782) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12783) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12784) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12785) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12788) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12790) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12791) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12792) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12793) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12794) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12795) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12800) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12801) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12802) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12803) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12804) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12805) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12806) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12809) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12810) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12811) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12812) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12813) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12814) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12815) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12817) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12818) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12819) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12820) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12821) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12822) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12823) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12824) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12825) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12826) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12827) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12828) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12829) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12830) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12833) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12834) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12835) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12836) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12837) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12838) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12839) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12840) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12841) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12842) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12843) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12844) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12845) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12846) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12852) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12853) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12854) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12855) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12856) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12857) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12858) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12860) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12861) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12862) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12863) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12864) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12865) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12866) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12867) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12868) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12869) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12870) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12871) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12872) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12873) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12874) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12875) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12876) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12877) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12878) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12879) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12880) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12886) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12887) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12888) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12889) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12890) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12891) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12892) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12906) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12907) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12908) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12909) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12910) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12911) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12912) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12915) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12916) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12917) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12918) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12919) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12920) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12922) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12943) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12944) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12945) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12946) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12947) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12948) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12949) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12951) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12952) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12953) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12954) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12955) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12956) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12957) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12958) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12959) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12960) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12961) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12962) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12963) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12964) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12967) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12968) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12969) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12970) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12971) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12972) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12973) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12974) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12975) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12976) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12977) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12978) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12979) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(12980) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.

# %%
def get_top_topics(temp_df):
    metrics = ['Coherence', 'Diversity', 'Redundancy']

    for metric in metrics:
        print(f"-------{metric}-------")
        temp_top_row = temp_df.loc[temp_df[metric].idxmax()]['Top Topic Words']
        print(f"Number of Topics: {len(temp_top_row)}")
        for topic in temp_top_row:
            # print(' '.join(topic))
            print(topic)
        print("\n")

# %%
for patient in list(nurse_notes.keys()):
    print("----------------------------")
    print(patient)
    print("----------------------------")
    get_top_topics(combined_df[combined_df['Dataset Name'] == patient])
# Out:
# ----------------------------
# P1
# ----------------------------
# -------Coherence-------
# Number of Topics: 3
# ['resident', 'staff', 'care', 'assist', 'night', 'morning', 'good', 'content', 'plan', 'take']
# ['check', 'resident', 'self', 'asleep', 'ongoing', 'comfortable', 'sleep', 'safety', 'settle', 'concern']
# ['resident', 'chart', 'care', 'med', 'need', 'appear', 'form', 'give', 'assist', 'good']
#
#
# -------Diversity-------
# Number of Topics: 3
# ['resident', 'staff', 'care', 'assist', 'night', 'morning', 'good', 'content', 'plan', 'take']
# ['check', 'resident', 'self', 'asleep', 'ongoing', 'comfortable', 'sleep', 'safety', 'settle', 'concern']
# ['resident', 'chart', 'care', 'med', 'need', 'appear', 'form', 'give', 'assist', 'good']
#
#
# -------Redundancy-------
# Number of Topics: 7
# ['morning', 'staff', 'breakfast', 'report', 'good', 'adls', 'intake', 'assist', 'concern', 'room']
# ['resident', 'check', 'asleep', 'ongoing', 'self', 'toilette', 'comfortable', 'peaceful', 'care', 'change']
# ['check', 'resident', 'med', 'safety', 'comfortable', 'night', 'take', 'need', 'care', 'chart']
# ['care', 'resident', 'sleep', 'concern', 'appear', 'form', 'medication', 'continue', 'plan', 'morning']
# ['resident', 'doctor', 'mg', 'today', 'x', 'commence', 'ear', 'chart', 'drop', 'review']
# ['resident', 'med', 'chart', 'care', 'appear', 'form', 'need', 'assist', 'good', 'take']
# ['give', 'doctor', 'appointment', 'leave', 'resident', 'hospital', 'gp', 'message', 'complete', 'tomorrow']
#
#
# ----------------------------
# P10
# ----------------------------
# -------Coherence-------
# Number of Topics: 3
# ['care', 'resident', 'nil', 'assist', 'good', 'chart', 'give', 'med', 'form', 'morning']
# ['check', 'need', 'resident', 'take', 'chart', 'assist', 'appear', 'care', 'med', 'safety']
# ['resident', 'check', 'night', 'safety', 'settle', 'need', 'maintain', 'assisted', 'adls', 'meds']
#
#
# -------Diversity-------
# Number of Topics: 3
# ['care', 'resident', 'nil', 'assist', 'good', 'chart', 'give', 'med', 'form', 'morning']
# ['check', 'need', 'resident', 'take', 'chart', 'assist', 'appear', 'care', 'med', 'safety']
# ['resident', 'check', 'night', 'safety', 'settle', 'need', 'maintain', 'assisted', 'adls', 'meds']
#
#
# -------Redundancy-------
# Number of Topics: 18
# ['abx', 'cream', 'uti', 'foot', 'doctor', 'review', 'app', 'cut', 'toenail', 'file']
# ['check', 'need', 'med', 'chart', 'safety', 'resident', 'take', 'asleep', 'go', 'appear']
# ['pain', 'resident', 'paracetamol', 'rib', 'shoulder', 'morning', 'complain', 'hour', 'doctor', 'rest']
# ['administer', 'batch', 'vaccine', 'sit', 'give', 'number', 'initial', 'vaccination', 'right', 'team']
# ['c', 'o', 'give', 'prn', 'exputex', 'note', 'night', 'update', 'cough', 'pain']
# ['dining', 'breakfast', 'room', 'self', 'care', 'concern', 'need', 'assist', 'resident', 'uti']
# ['resident', 'check', 'date', 'medicine', 'bright', 'continue', 'safety', 'assist', 'detail', 'mobilizing']
# ['continue', 'resident', 'gp', 'review', 'prn', 'keflex', 'care', 'plan', 'pass', 'feel']
# ['night', 'resident', 'check', 'safety', 'settle', 'need', 'maintain', 'assisted', 'meds', 'adls']
# ['need', 'resident', 'care', 'form', 'bell', 'attend', 'report', 'good', 'safety', 'check']
# ['care', 'plan', 'resident', 'continue', 'check', 'pain', 'review', 'evaluation', 'monitor', 'safety']
# ['care', 'resident', 'need', 'assist', 'continue', 'check', 'take', 'skin', 'safety', 'med']
# ['attend', 'resident', 'medication', 'take', 'form', 'assist', 'care', 'activity', 'appear', 'chart']
# ['resident', 'nil', 'receive', 'note', 'till', 'care', 'time', 'new', 'need', 'keep']
# ['care', 'nil', 'resident', 'appear', 'skin', 'medication', 'maintain', 'assist', 'bright', 'take']
# ['resident', 'day', 'conservatory', 'main', 'chart', 'med', 'check', 'meal', 'take', 'restaurant']
# ['stay', 'generally', 'content', 'restaurant', 'meal', 'med', 'chart', 'day', 'garden', 'have']
# ['care', 'give', 'resident', 'good', 'assist', 'chart', 'form', 'med', 'morning', 'concern']
#
#
# ----------------------------
# P11
# ----------------------------
# -------Coherence-------
# Number of Topics: 3
# ['resident', 'care', 'nil', 'good', 'assist', 'form', 'chart', 'appear', 'medication', 'need']
# ['resident', 'night', 'check', 'safety', 'settle', 'need', 'maintain', 'assisted', 'adls', 'charted']
# ['check', 'resident', 'safety', 'asleep', 'go', 'nil', 'new', 'chart', 'care', 'need']
#
#
# -------Diversity-------
# Number of Topics: 3
# ['resident', 'care', 'nil', 'good', 'assist', 'form', 'chart', 'appear', 'medication', 'need']
# ['resident', 'night', 'check', 'safety', 'settle', 'need', 'maintain', 'assisted', 'adls', 'charted']
# ['check', 'resident', 'safety', 'asleep', 'go', 'nil', 'new', 'chart', 'care', 'need']
#
#
# -------Redundancy-------
# Number of Topics: 18
# ['day', 'care', 'resident', 'good', 'nil', 'need', 'form', 'attend', 'safety', 'check']
# ['assisted', 'settle', 'need', 'check', 'resident', 'safety', 'night', 'maintain', 'adls', 'charted']
# ['remain', 'new', 'form', 'need', 'good', 'enjoy', 'assist', 'meal', 'note', 'care']
# ['continue', 'review', 'care', 'check', 'settle', 'sleep', 'safety', 'resident', 'maintain', 'concern']
# ['check', 'med', 'resident', 'safety', 'take', 'chart', 'comfortable', 'nil', 'asleep', 'new']
# ['plan', 'care', 'resident', 'evaluation', 'incident', 'safeguard', 'commence', 'fellow', 'follow', 'male']
# ['note', 'good', 'observe', 'time', 'ensure', 'safety', 'keep', 'receive', 'form', 'resident']
# ['night', 'resident', 'check', 'give', 'medication', 'continue', 'safety', 'staff', 'notice', 'settle']
# ['resident', 'check', 'safety', 'independently', 'toilet', 'come', 'nil', 'maintain', 'unit', 'med']
# ['check', 'appear', 'safety', 'resident', 'good', 'attend', 'need', 'go', 'form', 'care']
# ['report', 'fall', 'handover', 'check', 'safety', 'sleep', 'update', 'complete', 'rgn', 'hourly']
# ['pain', 'resident', 'hip', 'left', 'prn', 'deny', 'gp', 'maintain', 'check', 'ongoing']
# ['nil', 'resident', 'continue', 'report', 'care', 'issue', 'med', 'integrity', 'chart', 'post']
# ['bright', 'appear', 'nil', 'concern', 'medication', 'administer', 'resident', 'new', 'assist', 'potter']
# ['resident', 'care', 'take', 'good', 'intake', 'continue', 'nil', 'concern', 'skin', 'need']
# ['med', 'chart', 'good', 'resident', 'give', 'assist', 'form', 'today', 'need', 'new']
# ['batch', 'administer', 'vaccine', 'hse', 'vaccination', 'adverse', 'team', 'number', 'exp', 'initial']
# ['care', 'resident', 'form', 'good', 'assist', 'chart', 'attend', 'nil', 'medication', 'appear']
#
#
# ----------------------------
# P12
# ----------------------------
# -------Coherence-------
# Number of Topics: 3
# ['resident', 'care', 'chart', 'give', 'good', 'nil', 'assist', 'concern', 'check', 'med']
# ['care', 'eye', 'resident', 'assist', 'skin', 'nil', 'take', 'rollator', 'continue', 'form']
# ['resident', 'care', 'sleep', 'medication', 'settle', 'nocte', 'early', 'continue', 'self', 'safety']
#
#
# -------Diversity-------
# Number of Topics: 3
# ['resident', 'care', 'chart', 'give', 'good', 'nil', 'assist', 'concern', 'check', 'med']
# ['care', 'eye', 'resident', 'assist', 'skin', 'nil', 'take', 'rollator', 'continue', 'form']
# ['resident', 'care', 'sleep', 'medication', 'settle', 'nocte', 'early', 'continue', 'self', 'safety']
#
#
# -------Redundancy-------
# Number of Topics: 14
# ['good', 'resident', 'give', 'issue', 'nil', 'intake', 'med', 'report', 'check', 'form']
# ['resident', 'check', 'chart', 'have', 'settle', 'safety', 'med', 'need', 'day', 'voice']
# ['early', 'nocte', 'sleep', 'self', 'check', 'safety', 'continue', 'resident', 'settle', 'administer']
# ['care', 'resident', 'eye', 'night', 'check', 'give', 'safety', 'skin', 'continue', 'comfortable']
# ['chart', 'care', 'form', 'good', 'resident', 'assist', 'give', 'new', 'appear', 'morning']
# ['care', 'eye', 'nil', 'resident', 'concern', 'med', 'assist', 'appear', 'attend', 'take']
# ['resident', 'tv', 'enjoy', 'money', 'give', 'eye', 'night', 'care', 'watch', 'medication']
# ['resident', 'concern', 'report', 'good', 'remain', 'alert', 'home', 'take', 'staff', 'bright']
# ['gp', 'foot', 'breast', 'right', 'review', 'cream', 'file', 'cut', 'app', 'toenail']
# ['care', 'plan', 'resident', 'continue', 'evaluation', 'commence', 'safeguard', 'give', 'prn', 'await']
# ['bruise', 'fade', 'assistance', 'good', 'attend', 'resident', 'form', 'evident', 'change', 'left']
# ['medication', 'eye', 'resident', 'give', 'sleep', 'settle', 'issue', 'care', 'night', 'voice']
# ['batch', 'administer', 'vaccine', 'give', 'adverse', 'hse', 'exp', 'team', 'number', 'vaccination']
# ['resident', 'receive', 'time', 'note', 'good', 'room', 'assist', 'till', 'safety', 'form']
#
#
# ----------------------------
# P13
# ----------------------------
# -------Coherence-------
# Number of Topics: 3
# ['good', 'resident', 'med', 'give', 'form', 'nil', 'assist', 'chart', 'new', 'concern']
# ['resident', 'bed', 'medication', 'sleep', 'settle', 'check', 'assist', 'night', 'safety', 'nocte']
# ['care', 'resident', 'attend', 'assist', 'skin', 'nil', 'concern', 'good', 'med', 'form']
#
#
# -------Diversity-------
# Number of Topics: 3
# ['good', 'resident', 'med', 'give', 'form', 'nil', 'assist', 'chart', 'new', 'concern']
# ['resident', 'bed', 'medication', 'sleep', 'settle', 'check', 'assist', 'night', 'safety', 'nocte']
# ['care', 'resident', 'attend', 'assist', 'skin', 'nil', 'concern', 'good', 'med', 'form']
#
#
# -------Redundancy-------
# Number of Topics: 16
# ['resident', 'good', 'chart', 'form', 'give', 'med', 'assist', 'attend', 'care', 'need']
# ['son', 'home', 'effect', 'reassure', 'chesty', 'medical', 'resident', 'good', 'cough', 'intermittent']
# ['report', 'ray', 'chest', 'god', 'await', 'x', 'home', 'official', 'cnm', 'right']
# ['resident', 'nocte', 'continue', 'bed', 'safety', 'medication', 'overnight', 'meet', 'need', 'check']
# ['care', 'plan', 'evaluation', 'resident', 'infection', 'tract', 'respiratory', 'continue', 'independent', 'change']
# ['night', 'resident', 'check', 'give', 'medication', 'continue', 'concern', 'safety', 'staff', 'notice']
# ['settle', 'sleep', 'bed', 'nocte', 'resident', 'hourly', 'post', 'medication', 'maintain', 'require']
# ['blood', 'day', 'sugar', 'settle', 'result', 'great', 'bsl', 'l', 'mmol', 'resident']
# ['attend', 'assist', 'resident', 'nil', 'good', 'care', 'skin', 'concern', 'meal', 'form']
# ['female', 'coughing', 'change', 'foot', 'file', 'clothe', 'resident', 'room', 'occasional', 'sleep']
# ['nocte', 'nurse', 'near', 'resident', 'post', 'bed', 'station', 'medication', 'sleep', 'settle']
# ['early', 'gp', 'abx', 's', 'b', 'tds', 'mg', 'note', 'cough', 'order']
# ['check', 'need', 'care', 'resident', 'safety', 'med', 'concern', 'take', 'assist', 'nil']
# ['good', 'resident', 'form', 'nil', 'intake', 'med', 'give', 'new', 'conservatory', 'appear']
# ['resident', 'assist', 'appear', 'nil', 'new', 'content', 'med', 'need', 'chart', 'attend']
# ['resident', 'medication', 'bed', 'night', 'settle', 'sleep', 'give', 'assist', 'staff', 'issue']
#
#
# ----------------------------
# P14
# ----------------------------
# -------Coherence-------
# Number of Topics: 3
# ['care', 'check', 'resident', 'need', 'assist', 'continue', 'skin', 'asleep', 'ongoing', 'sleep']
# ['resident', 'care', 'med', 'form', 'assist', 'need', 'chart', 'take', 'good', 'usual']
# ['resident', 'chart', 'appear', 'good', 'form', 'care', 'med', 'assist', 'give', 'voice']
#
#
# -------Diversity-------
# Number of Topics: 3
# ['care', 'check', 'resident', 'need', 'assist', 'continue', 'skin', 'asleep', 'ongoing', 'sleep']
# ['resident', 'care', 'med', 'form', 'assist', 'need', 'chart', 'take', 'good', 'usual']
# ['resident', 'chart', 'appear', 'good', 'form', 'care', 'med', 'assist', 'give', 'voice']
#
#
# -------Redundancy-------
# Number of Topics: 19
# ['settle', 'arrange', 'area', 'resident', 'friend', 'bed', 'chair', 'receive', 'opd', 'zovirax']
# ['injection', 'administer', 'weekly', 'today', 'give', 'resident', 'shower', 'nordimet', 'observe', 'assist']
# ['take', 'chart', 'appear', 'good', 'med', 'resident', 'form', 'assist', 'bright', 'care']
# ['sleep', 'continue', 'report', 'plan', 'nocte', 'concern', 'care', 'settle', 'bed', 'routine']
# ['care', 'appear', 'resident', 'need', 'med', 'chart', 'form', 'good', 'give', 'complaint']
# ['foot', 'cream', 'afternoon', 'leg', 'file', 'app', 'resident', 'sore', 'cut', 'toenail']
# ['resident', 'take', 'chart', 'form', 'med', 'need', 'enjoy', 'care', 'assist', 'usual']
# ['groin', 'remain', 'red', 'renew', 'ichtopaste', 'apply', 'leave', 'night', 'looking', 'angry']
# ['inj', 'mg', 'nordimet', 'orencia', 'nordiment', 'pharmacy', 'tomorrow', 'ml', 'administered', 'contact']
# ['care', 'check', 'resident', 'need', 'continue', 'asleep', 'ongoing', 'assist', 'skin', 'comfortable']
# ['resident', 'med', 'form', 'need', 'chart', 'nil', 'appear', 'good', 'care', 'room']
# ['night', 'resident', 'safety', 'check', 'continue', 'assist', 'care', 'settle', 'comfortable', 'medication']
# ['hand', 'walk', 'dress', 'skin', 'fall', 'today', 'left', 'tear', 'nail', 'lateral']
# ['bed', 'resident', 'dentist', 'assist', 'late', 'keep', 'area', 'review', 'acknowledged', 'yes']
# ['resident', 'apply', 'room', 'groin', 'cream', 'personal', 'date', 'skin', 'red', 'right']
# ['check', 'care', 'sleep', 'need', 'resident', 'settle', 'medication', 'assist', 'comfortably', 'chart']
# ['care', 'resident', 'assist', 'med', 'good', 'form', 'chart', 'take', 'need', 'skin']
# ['room', 'dining', 'walk', 'resident', 'canesten', 'cream', 'progress', 'groin', 'visitor', 'apply']
# ['care', 'plan', 'blood', 'change', 'monthly', 'resident', 'routine', 'continue', 'pleasant', 'remain']
#
#
# ----------------------------
# P15
# ----------------------------
# -------Coherence-------
# Number of Topics: 3
# ['resident', 'good', 'give', 'med', 'nil', 'new', 'appear', 'chart', 'concern', 'assist']
# ['settle', 'sleep', 'resident', 'medication', 'nocte', 'check', 'pain', 'safety', 'care', 'continue']
# ['resident', 'pain', 'care', 'take', 'morning', 'appear', 'form', 'assist', 'nil', 'gp']
#
#
# -------Diversity-------
# Number of Topics: 4
# ['pain', 'oxynorm', 'prn', 'give', 'resident', 'facial', 'mg', 'effect', 'complain', 'tegretol']
# ['settle', 'sleep', 'nocte', 'medication', 'resident', 'check', 'safety', 'pain', 'bed', 'continue']
# ['gp', 'resident', 'administer', 'pain', 'evening', 'fall', 'right', 'report', 'review', 's']
# ['resident', 'give', 'good', 'nil', 'med', 'appear', 'assist', 'form', 'new', 'chart']
#
#
# -------Redundancy-------
# Number of Topics: 16
# ['tea', 'doctor', 'travacort', 'prescribe', 'buttock', 'leg', 'lesion', 'b', 'week', 'cream']
# ['settle', 'medication', 'sleep', 'night', 'resident', 'give', 'voice', 'issue', 'drink', 'nocte']
# ['administer', 'batch', 'pain', 'right', 'give', 'reaction', 'fall', 'number', 'vaccination', 'adverse']
# ['resident', 'toilet', 'pain', 'tv', 'inform', 'watch', 'staff', 'frame', 'raise', 'call']
# ['resident', 'level', 'difficulty', 'regular', 'diet', 'today', 'dentition', 'eat', 'refer', 'fluid']
# ['enjoy', 'new', 'independent', 'meal', 'note', 'good', 'day', 'activity', 'resident', 'rash']
# ['ear', 'pleasant', 'gentleman', 'require', 'resident', 'activity', 'receive', 'wax', 'review', 'ask']
# ['assist', 'care', 'resident', 'form', 'take', 'good', 'appear', 'nil', 'med', 'morning']
# ['settle', 'sleep', 'nocte', 'safety', 'check', 'continue', 'medication', 'bed', 'administer', 'bell']
# ['pain', 'resident', 'give', 'oxynorm', 'prn', 'facial', 'o', 'c', 'mg', 'complain']
# ['resident', 'check', 'care', 'night', 'continue', 'safety', 'concern', 'plan', 'bed', 'comfortable']
# ['daughter', 's', 'gp', 'increase', 'order', 'appointment', 'morning', 'b', 'mg', 'resident']
# ['right', 'side', 'later', 'reassess', 'facial', 'cap', 'deny', 'administer', 'pain', 'check']
# ['good', 'give', 'concern', 'appear', 'med', 'resident', 'nil', 'chart', 'new', 'intake']
# ['resident', 'receive', 'note', 'good', 'nil', 'room', 'time', 'safety', 'new', 'form']
# ['resident', 's', 'urinal', 'b', 'daughter', 'pu', 'home', 'provide', 'bedside', 'restaurant']
#
#
# ----------------------------
# P16
# ----------------------------
# -------Coherence-------
# Number of Topics: 5
# ['resident', 'nil', 'care', 'medication', 'appear', 'concern', 'take', 'assist', 'bright', 'good']
# ['resident', 'good', 'med', 'give', 'chart', 'assist', 'care', 'form', 'new', 'today']
# ['resident', 'weight', 'nutritional', 'note', 'dietetic', 'loss', 'diet', 'protein', 'review', 'intake']
# ['check', 'resident', 'need', 'safety', 'night', 'settle', 'med', 'take', 'chart', 'care']
# ['care', 'resident', 'nil', 'chart', 'good', 'attend', 'form', 'assist', 'complaint', 'need']
#
#
# -------Diversity-------
# Number of Topics: 3
# ['care', 'resident', 'nil', 'good', 'assist', 'medication', 'appear', 'form', 'chart', 'attend']
# ['check', 'resident', 'safety', 'need', 'night', 'med', 'settle', 'chart', 'take', 'assist']
# ['resident', 'plan', 'care', 'weight', 'mat', 'sensor', 'note', 'gp', 'place', 'dietetic']
#
#
# -------Redundancy-------
# Number of Topics: 14
# ['bno', 'prn', 'day', 'laxative', 'remain', 'give', 'movicol', 'result', 'await', 'resident']
# ['note', 'resident', 'ensure', 'till', 'weight', 'time', 'observe', 'keep', 'receive', 'meet']
# ['w', 'c', 'plan', 'care', 'watch', 'note', 'dietetic', 'mdt', 'afternoon', 'humor']
# ['night', 'check', 'resident', 'safety', 'settle', 'need', 'maintain', 'assisted', 'adls', 'meds']
# ['pain', 'regular', 'sleep', 'resident', 'continue', 'settle', 'need', 'nocte', 'monitor', 'paracetamol']
# ['check', 'med', 'safety', 'resident', 'take', 'care', 'need', 'chart', 'asleep', 'assist']
# ['administer', 'vaccine', 'batch', 'give', 'gp', 'initial', 'deltoid', 'hse', 'vaccination', 'team']
# ['nil', 'restaurant', 'safety', 'meal', 'check', 'post', 'med', 'issue', 'complaint', 'chart']
# ['need', 'chart', 'resident', 'appear', 'assist', 'med', 'take', 'bed', 'check', 'comfortable']
# ['nil', 'resident', 'care', 'appear', 'medication', 'take', 'assist', 'concern', 'skin', 'bright']
# ['resident', 'bright', 'attend', 'good', 'form', 'need', 'alert', 'enjoy', 'px', 'chair']
# ['resident', 'continue', 'care', 'give', 'staff', 'medication', 'chart', 'need', 'assist', 'good']
# ['need', 'care', 'attend', 'resident', 'continue', 'chart', 'area', 'ongoe', 'pressure', 'assist']
# ['care', 'good', 'give', 'assist', 'resident', 'form', 'chart', 'med', 'morning', 'appear']
#
#
# ----------------------------
# P17
# ----------------------------
# -------Coherence-------
# Number of Topics: 6
# ['good', 'resident', 'concern', 'self', 'intake', 'adls', 'nil', 'appear', 'give', 'toilete']
# ['resident', 'chart', 'good', 'nil', 'med', 'appear', 'form', 'give', 'new', 'independent']
# ['plan', 'fall', 'report', 'care', 'resident', 'appear', 'foot', 'gp', 'pleasantly', 'content']
# ['check', 'resident', 'sleep', 'settle', 'safety', 'care', 'continue', 'night', 'self', 'medication']
# ['resident', 'give', 'settle', 'medication', 'sleep', 'issue', 'night', 'voice', 'eye', 'drink']
# ['resident', 'nil', 'med', 'independent', 'concern', 'take', 'form', 'attend', 'appear', 'meal']
#
#
# -------Diversity-------
# Number of Topics: 3
# ['resident', 'give', 'medication', 'night', 'settle', 'sleep', 'issue', 'voice', 'good', 'concern']
# ['resident', 'nil', 'check', 'med', 'safety', 'care', 'self', 'independent', 'form', 'take']
# ['resident', 'daughter', 'care', 'plan', 'walk', 'nil', 'morning', 'unit', 'gp', 'report']
#
#
# -------Redundancy-------
# Number of Topics: 3
# ['resident', 'give', 'medication', 'night', 'settle', 'sleep', 'issue', 'voice', 'good', 'concern']
# ['resident', 'nil', 'check', 'med', 'safety', 'care', 'self', 'independent', 'form', 'take']
# ['resident', 'daughter', 'care', 'plan', 'walk', 'nil', 'morning', 'unit', 'gp', 'report']
#
#
# ----------------------------
# P18
# ----------------------------
# -------Coherence-------
# Number of Topics: 6
# ['review', 'right', 'eye', 'gp', 'date', 'appointment', 'blood', 'resident', 'new', 'order']
# ['care', 'resident', 'concern', 'plan', 'assist', 'good', 'nil', 'morning', 'form', 'take']
# ['care', 'check', 'resident', 'need', 'asleep', 'continue', 'assist', 'skin', 'ongoing', 'comfortable']
# ['care', 'resident', 'chart', 'med', 'attend', 'need', 'form', 'good', 'assist', 'give']
# ['resident', 'take', 'chart', 'med', 'appear', 'good', 'form', 'bright', 'eye', 'give']
# ['resident', 'sleep', 'check', 'need', 'nil', 'care', 'voice', 'medication', 'settle', 'post']
#
#
# -------Diversity-------
# Number of Topics: 4
# ['review', 'eye', 'appointment', 'blood', 'doctor', 'right', 'gp', 'resident', 'new', 'date']
# ['care', 'resident', 'assist', 'check', 'concern', 'sleep', 'need', 'nil', 'settle', 'medication']
# ['care', 'check', 'resident', 'need', 'asleep', 'skin', 'continue', 'ongoing', 'assist', 'comfortable']
# ['resident', 'care', 'chart', 'med', 'form', 'good', 'appear', 'give', 'take', 'attend']
#
#
# -------Redundancy-------
# Number of Topics: 4
# ['review', 'eye', 'appointment', 'blood', 'doctor', 'right', 'gp', 'resident', 'new', 'date']
# ['care', 'resident', 'assist', 'check', 'concern', 'sleep', 'need', 'nil', 'settle', 'medication']
# ['care', 'check', 'resident', 'need', 'asleep', 'skin', 'continue', 'ongoing', 'assist', 'comfortable']
# ['resident', 'care', 'chart', 'med', 'form', 'good', 'appear', 'give', 'take', 'attend']
#
#
# ----------------------------
# P19
# ----------------------------
# -------Coherence-------
# Number of Topics: 5
# ['content', 'resident', 'take', 'unit', 'appear', 'relaxed', 'med', 'chart', 'voice', 'concern']
# ['resident', 'check', 'asleep', 'ongoing', 'med', 'care', 'self', 'need', 'comfortable', 'safety']
# ['resident', 'medication', 'check', 'settle', 'night', 'continue', 'post', 'sleep', 'care', 'assist']
# ['resident', 'floor', 'plan', 'care', 'fall', 'sensor', 'left', 'evaluation', 'small', 'note']
# ['resident', 'chart', 'med', 'form', 'good', 'appear', 'nil', 'give', 'complaint', 'walk']
#
#
# -------Diversity-------
# Number of Topics: 3
# ['resident', 'chart', 'med', 'appear', 'form', 'take', 'voice', 'good', 'nil', 'complaint']
# ['resident', 'check', 'care', 'need', 'asleep', 'ongoing', 'med', 'safety', 'comfortable', 'self']
# ['resident', 'night', 'medication', 'check', 'continue', 'settle', 'post', 'care', 'sleep', 'sensor']
#
#
# -------Redundancy-------
# Number of Topics: 19
# ['plan', 'care', 'son', 'update', 'mg', 'review', 'resident', 'gp', 'quetiapine', 'say']
# ['resident', 'pain', 'continue', 'doctor', 'monitor', 'sign', 'today', 'chart', 'medication', 'paralief']
# ['night', 'resident', 'medication', 'check', 'care', 'continue', 'staff', 'settle', 'give', 'assist']
# ['sensor', 'resident', 'require', 'floor', 'mat', 'need', 'assistance', 'note', 'form', 'care']
# ['resident', 'eye', 'review', 'explain', 'note', 'gp', 'attend', 'baseline', 'prescribe', 'pain']
# ['take', 'med', 'chart', 'resident', 'mobilize', 'need', 'attend', 'usual', 'form', 'restaurant']
# ['check', 'asleep', 'ongoing', 'resident', 'self', 'comfortable', 'toilette', 'need', 'peaceful', 'assist']
# ['doctor', 'hb', 'monthly', 'blood', 'hemocue', 'aware', 'inform', 'incident', 'send', 'result']
# ['care', 'resident', 'plan', 'fall', 'observe', 'take', 'medication', 'nil', 'skin', 'raise']
# ['check', 'resident', 'safety', 'med', 'take', 'care', 'chart', 'concern', 'need', 'sleep']
# ['resident', 'nocte', 'anxious', 'state', 'document', 'effect', 'reassurance', 'report', 'administer', 'appear']
# ['care', 'morning', 'assist', 'tolerate', 'resident', 'corridor', 'enjoy', 'med', 'shower', 'attend']
# ['issue', 'hourly', 'reassure', 'continue', 'overnight', 'blood', 'doctor', 'undisturbed', 'bed', 'resident']
# ['content', 'resident', 'appear', 'med', 'chart', 'take', 'walk', 'relaxed', 'unit', 'enjoy']
# ['resident', 'take', 'appear', 'chart', 'med', 'unit', 'relaxed', 'content', 'mobilizing', 'voice']
# ['resident', 'note', 'small', 'time', 'left', 'gp', 'review', 'get', 'face', 'report']
# ['pain', 'prn', 'paracetamol', 'give', 'request', 'sleep', 'resident', 'report', 'settle', 'hip']
# ['resident', 'post', 'continue', 'sleep', 'medication', 'settle', 'check', 'self', 'comfortably', 'toileting']
# ['good', 'form', 'resident', 'chart', 'appear', 'med', 'nil', 'give', 'voice', 'complaint']
#
#
# ----------------------------
# P2
# ----------------------------
# -------Coherence-------
# Number of Topics: 6
# ['administer', 'sleep', 'check', 'overnight', 'resident', 'continue', 'watch', 'need', 'present', 'medication']
# ['care', 'resident', 'plan', 'continue', 'check', 'sleep', 'need', 'female', 'safety', 'content']
# ['resident', 'nil', 'assist', 'wash', 'form', 'rollator', 'med', 'baseline', 'appear', 'prescribe']
# ['resident', 'concern', 'new', 'intake', 'med', 'appear', 'nil', 'chart', 'aid', 'assist']
# ['resident', 'settle', 'give', 'night', 'bed', 'medication', 'staff', 'assist', 'drink', 'tv']
# ['resident', 'care', 'good', 'chart', 'nil', 'assist', 'med', 'check', 'concern', 'need']
#
#
# -------Diversity-------
# Number of Topics: 3
# ['sleep', 'resident', 'medication', 'check', 'watch', 'continue', 'chair', 'overnight', 'need', 'room']
# ['resident', 'care', 'check', 'safety', 'need', 'night', 'plan', 'continue', 'concern', 'nil']
# ['resident', 'assist', 'give', 'form', 'good', 'nil', 'med', 'appear', 'care', 'take']
#
#
# -------Redundancy-------
# Number of Topics: 11
# ['date', 'service', 'administer', 'batch', 'request', 'type', 'detail', 'vaccine', 'optical', 'o']
# ['care', 'plan', 'resident', 'evaluation', 'eye', 'commence', 'continue', 'need', 'staff', 'safeguard']
# ['resident', 'nil', 'assist', 'wash', 'form', 'med', 'baseline', 'rollator', 'appear', 'prescribe']
# ['resident', 'good', 'nil', 'appear', 'chart', 'form', 'take', 'need', 'assist', 'care']
# ['give', 'resident', 'care', 'drink', 'morning', 'new', 'eating', 'assist', 'good', 'appear']
# ['resident', 'good', 'care', 'assist', 'form', 'med', 'chart', 'nil', 'give', 'concern']
# ['pain', 'resident', 'paracetamol', 'shoulder', 'o', 'c', 'prn', 'discomfort', 'administer', 'refuse']
# ['sleep', 'resident', 'medication', 'overnight', 'check', 'continue', 'need', 'sit', 'care', 'present']
# ['night', 'resident', 'settle', 'give', 'medication', 'staff', 'bed', 'assist', 'tv', 'watch']
# ['resident', 'check', 'appear', 'safety', 'concern', 'med', 'nil', 'assist', 'chart', 'content']
# ['gp', 'prn', 'review', 'small', 'b', 'monitor', 'request', 'encourage', 's', 'right']
#
#
# ----------------------------
# P20
# ----------------------------
# -------Coherence-------
# Number of Topics: 3
# ['plan', 'care', 'resident', 'continue', 'note', 'concern', 'sensor', 'report', 'bed', 'sleep']
# ['care', 'check', 'resident', 'need', 'assist', 'continue', 'asleep', 'ongoing', 'night', 'skin']
# ['resident', 'chart', 'med', 'form', 'appear', 'good', 'care', 'take', 'need', 'attend']
#
#
# -------Diversity-------
# Number of Topics: 3
# ['plan', 'care', 'resident', 'continue', 'note', 'concern', 'sensor', 'report', 'bed', 'sleep']
# ['care', 'check', 'resident', 'need', 'assist', 'continue', 'asleep', 'ongoing', 'night', 'skin']
# ['resident', 'chart', 'med', 'form', 'appear', 'good', 'care', 'take', 'need', 'attend']
#
#
# -------Redundancy-------
# Number of Topics: 12
# ['foot', 'file', 'par', 'app', 'toenail', 'cut', 'cream', 'evening', 'callus', 'plan']
# ['check', 'resident', 'night', 'need', 'care', 'sleep', 'assist', 'safety', 'settle', 'comfortably']
# ['appear', 'resident', 'take', 'med', 'chart', 'good', 'form', 'bright', 'walker', 'alert']
# ['nil', 'change', 'note', 'right', 'new', 'resident', 'give', 'complaint', 'bruise', 'review']
# ['mobile', 'content', 'take', 'restaurant', 'resident', 'med', 'need', 'chart', 'independent', 'form']
# ['care', 'check', 'asleep', 'need', 'ongoing', 'resident', 'continue', 'skin', 'assist', 'peaceful']
# ['med', 'resident', 'take', 'chart', 'need', 'care', 'assist', 'attend', 'concern', 'nil']
# ['resident', 'good', 'form', 'care', 'chart', 'nil', 'appear', 'med', 'give', 'need']
# ['resident', 'bruise', 'arm', 'note', 'currently', 'appear', 'evident', 'left', 'hygiene', 'leave']
# ['leave', 'skin', 'leg', 'note', 'mark', 'low', 'red', 'chart', 'pain', 'bruise']
# ['plan', 'resident', 'care', 'continue', 'sleep', 'bed', 'assist', 'sensor', 'concern', 'report']
# ['wound', 'look', 'skin', 'movicol', 'enjoy', 'knit', 'sunday', 'prayers', 'prn', 'constipation']
#
#
# ----------------------------
# P3
# ----------------------------
# -------Coherence-------
# Number of Topics: 10
# ['check', 'resident', 'need', 'care', 'ongoing', 'safety', 'assist', 'med', 'night', 'asleep']
# ['week', 'resident', 'commence', 'report', 'sleep', 'examine', 'x', 'doctor', 'mg', 'see']
# ['resident', 'prn', 'give', 'request', 'pain', 'cough', 'naproxen', 'exputex', 'chart', 'bed']
# ['resident', 'complaint', 'give', 'appear', 'voice', 'care', 'nil', 'chart', 'med', 'form']
# ['resident', 'med', 'chart', 'form', 'take', 'appear', 'care', 'good', 'assist', 'attend']
# ['doctor', 'resident', 'foot', 'chest', 'order', 'new', 'request', 'tag', 'date', 'skin']
# ['resident', 'give', 'report', 'great', 'remain', 'well', 'chesty', 'referral', 'feel', 'form']
# ['resident', 'low', 'chat', 'mood', 'request', 'room', 'time', 'give', 'feel', 'well']
# ['plan', 'gp', 'review', 'evaluation', 'care', 'infection', 'respiratory', 'tract', 'complete', 'chest']
# ['resident', 'settle', 'sleep', 'medication', 'post', 'continue', 'check', 'safety', 'nocte', 'appear']
#
#
# -------Diversity-------
# Number of Topics: 3
# ['resident', 'med', 'chart', 'care', 'form', 'need', 'appear', 'assist', 'take', 'check']
# ['resident', 'doctor', 'report', 'sleep', 'mood', 'see', 'time', 'chat', 'give', 'week']
# ['resident', 'give', 'prn', 'night', 'request', 'care', 'check', 'continue', 'plan', 'cough']
#
#
# -------Redundancy-------
# Number of Topics: 15
# ['check', 'resident', 'need', 'care', 'ongoing', 'safety', 'asleep', 'med', 'assist', 'comfortable']
# ['examine', 'doctor', 'week', 'phone', 'referral', 'carer', 'resident', 'find', 'talk', 'report']
# ['resident', 'bed', 'request', 'rest', 'assistance', 'sit', 'chesty', 'decline', 'room', 'give']
# ['chest', 'clear', 'antibiotic', 'have', 'today', 'good', 'doctor', 'resident', 'bed', 'day']
# ['resident', 'med', 'chart', 'form', 'take', 'care', 'appear', 'good', 'assist', 'attend']
# ['resident', 'foot', 'chest', 'file', 'asleep', 'c', 'o', 'mild', 'obs', 'l']
# ['resident', 'ongoing', 'check', 'early', 'form', 'night', 'toilette', 'low', 'self', 'reassure']
# ['resident', 'chat', 'feel', 'request', 'doctor', 'come', 'form', 'happy', 'room', 'tell']
# ['plan', 'gp', 'review', 'care', 'evaluation', 'infection', 'tract', 'respiratory', 'complete', 'course']
# ['sleep', 'resident', 'settle', 'continue', 'concern', 'report', 'mood', 'hourly', 'appear', 'maintain']
# ['resident', 'doctor', 'blood', 'tag', 'book', 'appointment', 'cataract', 'right', 'advise', 'fall']
# ['administer', 'batch', 'vaccine', 'team', 'give', 'hse', 'exp', 'initial', 'vaccination', 'deltoid']
# ['far', 'resident', 'time', 'give', 'send', 'support', 'referral', 'happy', 'sit', 'pastoral']
# ['prn', 'give', 'resident', 'request', 'naproxen', 'pain', 'sciatica', 'low', 'mood', 'time']
# ['resident', 'give', 'med', 'appear', 'care', 'chart', 'form', 'complaint', 'need', 'good']
#
#
# ----------------------------
# P4
# ----------------------------
# -------Coherence-------
# Number of Topics: 4
# ['resident', 'care', 'give', 'good', 'chart', 'med', 'form', 'assist', 'appear', 'attend']
# ['care', 'resident', 'plan', 'wound', 'continue', 'right', 'toe', 'doctor', 'evaluation', 'dressing']
# ['resident', 'check', 'care', 'need', 'assist', 'comfortable', 'continue', 'settle', 'sleep', 'safety']
# ['care', 'resident', 'continue', 'need', 'ongoing', 'skin', 'asleep', 'check', 'assist', 'peaceful']
#
#
# -------Diversity-------
# Number of Topics: 3
# ['resident', 'care', 'give', 'med', 'good', 'chart', 'form', 'assist', 'appear', 'attend']
# ['resident', 'care', 'plan', 'right', 'wound', 'continue', 'toe', 'doctor', 'evaluation', 'dressing']
# ['care', 'resident', 'check', 'need', 'assist', 'continue', 'comfortable', 'asleep', 'settle', 'skin']
#
#
# -------Redundancy-------
# Number of Topics: 17
# ['resident', 'morning', 'bno', 'breakfast', 'x', 'content', 'assist', 'plan', 'care', 'unit']
# ['complete', 'toe', 'appointment', 'resident', 'course', 'dress', 'right', 'big', 'antibiotic', 'dose']
# ['resident', 'leave', 'doctor', 'present', 'note', 'aspiration', 'level', 'sign', 'shin', 'incident']
# ['doctor', 'send', 'resident', 'chart', 'toe', 'big', 'entry', 'podiatrist', 'dress', 'appear']
# ['resident', 'night', 'settle', 'continue', 'sleep', 'check', 'safety', 'care', 'assist', 'medication']
# ['qds', 'flucloxacillin', 'prescribe', 'gp', 'observe', 'monday', 'mg', 'result', 'review', 'leu']
# ['care', 'resident', 'take', 'good', 'skin', 'morning', 'assist', 'form', 'medication', 'chart']
# ['resident', 'assist', 'bright', 'appear', 'decline', 'continue', 'concern', 'discomfort', 'evening', 'time']
# ['resident', 'concern', 'personal', 'room', 'assist', 'dining', 'nil', 'report', 'issue', 'mood']
# ['care', 'plan', 'wound', 'continue', 'right', 'resident', 'dressing', 'evaluation', 'toe', 'left']
# ['resident', 'med', 'chart', 'give', 'form', 'care', 'good', 'need', 'assist', 'appear']
# ['check', 'care', 'need', 'resident', 'comfortable', 'settle', 'med', 'assist', 'sleep', 'attend']
# ['appointment', 'resident', 'daughter', 'law', 'pain', 'doctor', 'gp', 'infection', 'commence', 'mg']
# ['care', 'check', 'resident', 'need', 'continue', 'assist', 'ongoing', 'skin', 'asleep', 'peaceful']
# ['resident', 'take', 'appear', 'med', 'care', 'chart', 'content', 'staff', 'give', 'form']
# ['laxatives', 'resident', 'chesty', 'independent', 'cough', 'observe', 'prefer', 'bno', 'seed', 'flax']
# ['resident', 'prn', 'chesty', 'remain', 'nebs', 'give', 'tomorrow', 'chart', 'toilet', 'chest']
#
#
# ----------------------------
# P5
# ----------------------------
# -------Coherence-------
# Number of Topics: 3
# ['resident', 'appear', 'nil', 'voice', 'chart', 'med', 'complaint', 'give', 'form', 'good']
# ['check', 'resident', 'care', 'self', 'asleep', 'safety', 'ongoing', 'comfortable', 'night', 'continue']
# ['resident', 'take', 'chart', 'med', 'form', 'room', 'independent', 'good', 'appear', 'need']
#
#
# -------Diversity-------
# Number of Topics: 3
# ['resident', 'appear', 'nil', 'voice', 'chart', 'med', 'complaint', 'give', 'form', 'good']
# ['check', 'resident', 'care', 'self', 'asleep', 'safety', 'ongoing', 'comfortable', 'night', 'continue']
# ['resident', 'take', 'chart', 'med', 'form', 'room', 'independent', 'good', 'appear', 'need']
#
#
# -------Redundancy-------
# Number of Topics: 19
# ['settle', 'post', 'resident', 'voice', 'sleep', 'check', 'medication', 'comfortably', 'continue', 'self']
# ['check', 'care', 'resident', 'need', 'med', 'chart', 'safety', 'new', 'ongoing', 'issue']
# ['resident', 'appear', 'review', 'observe', 'apply', 'voiced', 'betnovate', 'itch', 'hip', 'dose']
# ['evening', 'prayer', 'fair', 'bedroom', 'complaint', 'watch', 'instead', 'paracetamol', 'leg', 'request']
# ['check', 'med', 'safety', 'resident', 'nil', 'concern', 'take', 'night', 'care', 'settle']
# ['care', 'continue', 'maintain', 'sleep', 'safety', 'check', 'hourly', 'change', 'plan', 'self']
# ['resident', 'take', 'receive', 'remain', 'breakfast', 'need', 'independence', 'pleasantly', 'personal', 'independent']
# ['care', 'plan', 'resident', 'morning', 'evaluation', 'holistic', 'time', 'assist', 'spend', 'husband']
# ['give', 'resident', 'nil', 'chart', 'voice', 'med', 'complaint', 'time', 'remain', 'appear']
# ['pain', 'tramadol', 'give', 'prn', 'leg', 'request', 'resident', 'complain', 'morning', 'paracetamol']
# ['ongoing', 'check', 'asleep', 'resident', 'self', 'toilette', 'comfortable', 'peaceful', 'need', 'assist']
# ['resident', 'take', 'med', 'good', 'bright', 'mobilizing', 'appear', 'chart', 'form', 'room']
# ['resident', 'chart', 'med', 'take', 'independent', 'form', 'room', 'need', 'good', 'appear']
# ['resident', 'med', 'chart', 'independent', 'appear', 'room', 'form', 'good', 'voice', 'nil']
# ['sleep', 'report', 'appear', 'nocte', 'routine', 'content', 'resident', 'concern', 'settle', 'bed']
# ['foot', 'cut', 'cream', 'toenail', 'file', 'app', 'form', 'visit', 'doctor', 'today']
# ['resident', 'care', 'need', 'assist', 'skin', 'night', 'continue', 'form', 'fair', 'chart']
# ['food', 'intake', 'medication', 'fluid', 'day', 'good', 'resident', 'spend', 'today', 'independent']
# ['resident', 'night', 'check', 'continue', 'safety', 'comfortable', 'self', 'medication', 'take', 'settle']
#
#
# ----------------------------
# P6
# ----------------------------
# -------Coherence-------
# Number of Topics: 8
# ['care', 'resident', 'concern', 'take', 'assist', 'nil', 'med', 'note', 'wife', 'skin']
# ['resident', 'good', 'give', 'care', 'form', 'chart', 'morning', 'assist', 'new', 'take']
# ['place', 'bed', 'bell', 'continue', 'check', 'sensor', 'safety', 'resident', 'comfortable', 'overnight']
# ['administer', 'batch', 'vaccine', 'give', 'team', 'hse', 'initial', 'number', 'vaccination', 'exp']
# ['sleep', 'settle', 'resident', 'give', 'medication', 'issue', 'night', 'voice', 'supplement', 'gradually']
# ['assist', 'care', 'resident', 'nil', 'supplement', 'skin', 'med', 'form', 'appear', 'baseline']
# ['care', 'plan', 'continue', 'resident', 'concern', 'floor', 'fall', 'evaluation', 'sleep', 'hourly']
# ['resident', 'nil', 'chart', 'check', 'assist', 'give', 'med', 'concern', 'appear', 'new']
#
#
# -------Diversity-------
# Number of Topics: 3
# ['resident', 'care', 'check', 'need', 'safety', 'nil', 'concern', 'chart', 'assist', 'med']
# ['resident', 'assist', 'care', 'nil', 'med', 'appear', 'form', 'give', 'bed', 'chart']
# ['resident', 'sleep', 'bed', 'medication', 'settle', 'place', 'continue', 'check', 'safety', 'bell']
#
#
# -------Redundancy-------
# Number of Topics: 18
# ['care', 'need', 'take', 'resident', 'nil', 'assist', 'form', 'good', 'chart', 'med']
# ['resident', 'keep', 'observe', 'receive', 'ensure', 'form', 'med', 'good', 'give', 'safety']
# ['place', 'bed', 'bell', 'sensor', 'comfortable', 'continue', 'floor', 'safety', 'resident', 'mat']
# ['administer', 'batch', 'normal', 'obs', 'vaccine', 'review', 'left', 'team', 'hse', 'initial']
# ['settle', 'give', 'sleep', 'resident', 'medication', 'night', 'issue', 'voice', 'supplement', 'gradually']
# ['care', 'plan', 'resident', 'sensor', 'floor', 'fall', 'wheelchair', 'go', 'stroll', 'continue']
# ['mat', 'resident', 'fall', 'risk', 'alarm', 'staff', 'continue', 'concern', 'floor', 'consider']
# ['resident', 'nil', 'med', 'chart', 'concern', 'assist', 'give', 'new', 'appear', 'intake']
# ['order', 'new', 'o', 'c', 'sign', 'tea', 'nil', 'sleep', 'abdominal', 'pain']
# ['assist', 'resident', 'nil', 'med', 'baseline', 'prescribe', 'appear', 'form', 'supplement', 'wash']
# ['ear', 'resident', 'b', 'appear', 's', 'observation', 'examine', 'gp', 'wife', 'wax']
# ['check', 'safety', 'resident', 'continue', 'care', 'comfortable', 'need', 'concern', 'settle', 'bed']
# ['sleep', 'pleasantly', 'require', 'content', 'use', 'bell', 'effectively', 'continue', 'provide', 'handover']
# ['bed', 'resident', 'settle', 'sleep', 'asleep', 'give', 'safe', 'medication', 'lower', 'need']
# ['small', 'dress', 'require', 'contact', 'remain', 'eliquis', 'need', 'wife', 'fall', 'explain']
# ['care', 'good', 'resident', 'day', 'skin', 'plan', 'intake', 'regular', 'morning', 'assist']
# ['note', 'new', 'till', 'issue', 'resident', 'time', 'room', 'care', 'nil', 'assist']
# ['care', 'resident', 'give', 'assist', 'chart', 'morning', 'form', 'bed', 'appear', 'medication']
#
#
# ----------------------------
# P7
# ----------------------------
# -------Coherence-------
# Number of Topics: 3
# ['good', 'resident', 'med', 'assist', 'chart', 'give', 'appear', 'concern', 'new', 'intake']
# ['care', 'resident', 'nil', 'skin', 'assist', 'continue', 'baseline', 'form', 'meal', 'attend']
# ['resident', 'medication', 'sleep', 'check', 'settle', 'night', 'bed', 'safety', 'continue', 'nocte']
#
#
# -------Diversity-------
# Number of Topics: 3
# ['good', 'resident', 'med', 'assist', 'chart', 'give', 'appear', 'concern', 'new', 'intake']
# ['care', 'resident', 'nil', 'skin', 'assist', 'continue', 'baseline', 'form', 'meal', 'attend']
# ['resident', 'medication', 'sleep', 'check', 'settle', 'night', 'bed', 'safety', 'continue', 'nocte']
#
#
# -------Redundancy-------
# Number of Topics: 17
# ['good', 'appear', 'self', 'toilete', 'chart', 'concern', 'new', 'assist', 'give', 'med']
# ['nil', 'meal', 'resident', 'dining', 'assist', 'form', 'attend', 'baseline', 'room', 'care']
# ['medication', 'resident', 'independently', 'take', 'wash', 'need', 'water', 'tolerate', 'supervision', 'feed']
# ['sister', 'request', 'ring', 'afternoon', 'state', 'talk', 'resident', 'hca', 'house', 'answer']
# ['good', 'note', 'resident', 'med', 'form', 'chart', 'assist', 'new', 'care', 'give']
# ['plan', 'care', 'fall', 'falls', 'evaluation', 'continue', 'risk', 'detail', 'type', 'high']
# ['resident', 'safely', 'reposition', 'edge', 'bed', 'lean', 'happy', 'review', 'px', 'keep']
# ['night', 'resident', 'check', 'staff', 'safety', 'continue', 'notice', 'medication', 'give', 'concern']
# ['date', 'dental', 'detail', 'vaccine', 'check', 'request', 'service', 'acknowledged', 'referral', 'yes']
# ['eye', 'drop', 'attend', 'room', 'resident', 'personal', 'day', 'today', 'accept', 'care']
# ['continue', 'sleep', 'care', 'plan', 'change', 'resident', 'concern', 'night', 'observe', 'report']
# ['good', 'form', 'resident', 'attend', 'give', 'care', 'intake', 'room', 'med', 'need']
# ['gp', 'batch', 'administer', 'vaccination', 'advise', 'scan', 'bladder', 'exp', 'adverse', 'number']
# ['resident', 'bed', 'check', 'sleep', 'administer', 'medication', 'continue', 'nocte', 'self', 'safety']
# ['medication', 'settle', 'give', 'resident', 'night', 'sleep', 'issue', 'voice', 'drink', 'independent']
# ['check', 'resident', 'med', 'nil', 'safety', 'care', 'concern', 'need', 'take', 'chart']
# ['foot', 'toenail', 'cream', 'file', 'app', 'cut', 'pressure', 'left', 'toe', 'big']
#
#
# ----------------------------
# P8
# ----------------------------
# -------Coherence-------
# Number of Topics: 3
# ['resident', 'care', 'assist', 'nil', 'med', 'take', 'appear', 'form', 'concern', 'morning']
# ['resident', 'check', 'bed', 'safety', 'continue', 'care', 'need', 'assist', 'medication', 'sleep']
# ['resident', 'settle', 'give', 'bed', 'medication', 'night', 'tts', 'comfortably', 'staff', 'sleep']
#
#
# -------Diversity-------
# Number of Topics: 4
# ['resident', 'care', 'assist', 'take', 'nil', 'med', 'appear', 'form', 'skin', 'concern']
# ['resident', 'concern', 'assist', 'nil', 'med', 'give', 'chart', 'new', 'appear', 'intake']
# ['resident', 'plan', 'review', 'care', 'daughter', 'pressure', 'referral', 'gp', 'note', 'weight']
# ['resident', 'bed', 'medication', 'check', 'night', 'sleep', 'settle', 'safety', 'continue', 'need']
#
#
# -------Redundancy-------
# Number of Topics: 14
# ['care', 'resident', 'assist', 'take', 'form', 'med', 'nil', 'appear', 'skin', 'good']
# ['concern', 'give', 'nil', 'med', 'chart', 'appear', 'new', 'resident', 'assist', 'adls']
# ['protein', 'weight', 'pressure', 'high', 'resident', 'dietitian', 'wound', 'grade', 'current', 'sinemet']
# ['care', 'plan', 'eye', 'continue', 'change', 'resident', 'report', 'evaluation', 'nil', 'observe']
# ['resident', 'remain', 'administer', 'bowel', 'prn', 'chart', 'daughter', 'today', 'continue', 'give']
# ['toilete', 'husband', 'bo', 'medium', 'vomit', 'usual', 'uti', 'routine', 'small', 'need']
# ['care', 'plan', 'note', 'resident', 'right', 'foot', 'mdt', 'dietetic', 'raise', 'wound']
# ['resident', 'assist', 'concern', 'morning', 'take', 'wash', 'nil', 'electric', 'care', 'wheelchair']
# ['resident', 'gp', 'b', 'nausea', 's', 'review', 'o', 'mg', 'feel', 'vomiting']
# ['resident', 'settle', 'night', 'give', 'medication', 'bed', 'sleep', 'tts', 'staff', 'comfortably']
# ['resident', 'gp', 'send', 'referral', 'hospital', 'advise', 'chair', 'admission', 'review', 'staff']
# ['check', 'bed', 'safety', 'resident', 'continue', 'need', 'care', 'assist', 'administer', 'attend']
# ['gp', 'r', 'v', 'plan', 'care', 'maintain', 'detail', 'referral', 'abx', 'yes']
# ['microlax', 'right', 'agb', 'b', 'day', 'bunion', 'prn', 'rectal', 'solution', 'cm']
#
#
# ----------------------------
# P9
# ----------------------------
# -------Coherence-------
# Number of Topics: 6
# ['continue', 'resident', 'check', 'safety', 'bed', 'nil', 'sensor', 'care', 'med', 'chart']
# ['resident', 'check', 'night', 'safety', 'maintain', 'need', 'settle', 'assisted', 'adls', 'meds']
# ['care', 'resident', 'give', 'assist', 'morning', 'appear', 'good', 'eye', 'continue', 'bright']
# ['resident', 'take', 'check', 'chart', 'need', 'care', 'med', 'appear', 'nil', 'assist']
# ['resident', 'care', 'plan', 'bed', 'continue', 'evaluation', 'sensor', 'fall', 'review', 'note']
# ['resident', 'med', 'assist', 'morning', 'chart', 'concern', 'give', 'personal', 'form', 'care']
#
#
# -------Diversity-------
# Number of Topics: 3
# ['resident', 'bed', 'continue', 'check', 'safety', 'sensor', 'care', 'med', 'need', 'chart']
# ['check', 'resident', 'safety', 'need', 'night', 'settle', 'med', 'maintain', 'chart', 'take']
# ['care', 'resident', 'assist', 'good', 'form', 'nil', 'chart', 'appear', 'take', 'medication']
#
#
# -------Redundancy-------
# Number of Topics: 15
# ['daughter', 'resident', 'continue', 'concern', 'care', 'assist', 'morning', 'aid', 'safety', 'day']
# ['resident', 'administer', 'need', 'check', 'safety', 'maintain', 'appear', 'medication', 'bright', 'assist']
# ['continue', 'care', 'check', 'change', 'assist', 'resident', 'safety', 'plan', 'general', 'sleep']
# ['resident', 'need', 'check', 'med', 'safety', 'chart', 'toilete', 'settle', 'take', 'gong']
# ['care', 'plan', 'resident', 'evaluation', 'continue', 'review', 'holistic', 'pain', 'fall', 'change']
# ['assisted', 'maintain', 'night', 'resident', 'check', 'need', 'safety', 'adls', 'settle', 'meds']
# ['night', 'resident', 'check', 'give', 'concern', 'safety', 'continue', 'medication', 'notice', 'staff']
# ['administer', 'vaccine', 'batch', 'give', 'hse', 'vaccination', 'team', 'comirnaty', 'booster', 'number']
# ['care', 'new', 'resident', 'appear', 'assist', 'good', 'medication', 'bright', 'concern', 'give']
# ['resident', 'bed', 'decline', 'staff', 'continue', 'sensor', 'alarm', 'meal', 'monitor', 'note']
# ['resident', 'care', 'form', 'good', 'take', 'nil', 'attend', 'medication', 'need', 'appear']
# ['assist', 'med', 'resident', 'chart', 'care', 'give', 'concern', 'check', 'nil', 'need']
# ['check', 'sensor', 'resident', 'place', 'med', 'mat', 'take', 'chart', 'appear', 'safety']
# ['resident', 'continue', 'care', 'bed', 'good', 'bell', 'check', 'remain', 'safety', 'chair']
# ['interaction', 'relaxed', 'pu', 'chatty', 'writing', 'bo', 'kardex', 'choose', 'accept', 'stay']

# %%
all_texts_df = pd.DataFrame(lda_analysis(all_texts, "All Texts"))

# %%
get_top_topics(all_texts_df)
# Out:
# -------Coherence-------
# Number of Topics: 13
# ['prescribe', 'baseline', 'nil', 'wash', 'assist', 'med', 'resident', 'take', 'meal', 'skin']
# ['resident', 'bright', 'care', 'take', 'nil', 'alert', 'concern', 'assist', 'appear', 'medication']
# ['sleep', 'bed', 'nocte', 'resident', 'continue', 'early', 'administer', 'medication', 'check', 'overnight']
# ['pain', 'prn', 'request', 'right', 'resident', 'inform', 'give', 'gp', 'paracetamol', 'eating']
# ['resident', 'note', 'time', 'low', 'receive', 'room', 'fall', 'till', 'observe', 'daughter']
# ['night', 'resident', 'settle', 'sleep', 'medication', 'give', 'check', 'staff', 'continue', 'voice']
# ['complaint', 'chart', 'resident', 'voice', 'nil', 'form', 'need', 'appear', 'care', 'attend']
# ['care', 'form', 'good', 'resident', 'chart', 'med', 'appear', 'assist', 'attend', 'give']
# ['resident', 'med', 'good', 'chart', 'concern', 'appear', 'assist', 'give', 'form', 'nil']
# ['sensor', 'place', 'mat', 'safety', 'check', 'bed', 'appear', 'toilet', 'alarm', 'content']
# ['maintain', 'safety', 'check', 'need', 'assisted', 'resident', 'night', 'settle', 'adls', 'meds']
# ['check', 'resident', 'care', 'need', 'safety', 'med', 'assist', 'asleep', 'comfortable', 'take']
# ['plan', 'care', 'bell', 'continue', 'resident', 'evaluation', 'reach', 'report', 'change', 'discomfort']
#
#
# -------Diversity-------
# Number of Topics: 4
# ['resident', 'pain', 'prn', 'prescribe', 'gp', 'baseline', 'wash', 'give', 'request', 'eye']
# ['resident', 'care', 'med', 'chart', 'nil', 'good', 'appear', 'form', 'assist', 'take']
# ['check', 'resident', 'safety', 'settle', 'night', 'need', 'sleep', 'care', 'continue', 'medication']
# ['sensor', 'resident', 'care', 'plan', 'mat', 'bed', 'place', 'continue', 'evaluation', 'floor']
#
#
# -------Redundancy-------
# Number of Topics: 14
# ['prescribe', 'baseline', 'wash', 'skin', 'assist', 'nil', 'meal', 'med', 'take', 'laxative']
# ['place', 'present', 'sit', 'chair', 'later', 'watch', 'room', 'foot', 'assist', 'female']
# ['sensor', 'bed', 'mat', 'resident', 'daughter', 'fall', 'toilet', 'request', 'go', 'staff']
# ['reach', 'bno', 'administer', 'safe', 'evening', 'knee', 'arm', 'batch', 'state', 'give']
# ['resident', 'prn', 'pain', 'note', 'gp', 'low', 'observe', 'request', 'review', 'till']
# ['sleep', 'settle', 'resident', 'medication', 'give', 'night', 'bed', 'issue', 'voice', 'comfortably']
# ['complaint', 'voice', 'chart', 'resident', 'form', 'appear', 'nil', 'need', 'care', 'attend']
# ['form', 'good', 'care', 'chart', 'resident', 'appear', 'med', 'attend', 'issue', 'give']
# ['resident', 'med', 'good', 'chart', 'concern', 'assist', 'room', 'intake', 'nil', 'form']
# ['check', 'sleep', 'continue', 'nocte', 'safety', 'early', 'resident', 'bed', 'medication', 'overnight']
# ['care', 'resident', 'medication', 'bright', 'skin', 'alert', 'nil', 'appear', 'assist', 'take']
# ['check', 'resident', 'need', 'safety', 'care', 'med', 'assist', 'asleep', 'comfortable', 'take']
# ['care', 'plan', 'eye', 'continue', 'resident', 'evaluation', 'drop', 'report', 'change', 'review']
# ['night', 'resident', 'check', 'safety', 'settle', 'need', 'maintain', 'assisted', 'adls', 'meds']
