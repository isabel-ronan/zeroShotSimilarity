# %%
import os
import pandas as pd

# %%
first_folder = 'data'
data_dictionary = {}
for folder in os.listdir(f'./{first_folder}/'):
    if '.' not in folder:
        data_dictionary[folder] = {}
        for sub_folder in os.listdir(f'./{first_folder}/{folder}'):
            if '.' not in sub_folder:
                data_dictionary[folder][sub_folder] = {}
                for sub_sub_folder in os.listdir(f'./{first_folder}/{folder}/{sub_folder}'):
                    if '.' not in sub_sub_folder: 
                        data_dictionary[folder][sub_folder][sub_sub_folder] = {}   
                        for file in os.listdir(f'./{first_folder}/{folder}/{sub_folder}/{sub_sub_folder}'):
                            if file[0] != '.' and 'xlsx' in file:
                                if 'carerNotes' in file:
                                    df = pd.read_excel(f'./{first_folder}/{folder}/{sub_folder}/{sub_sub_folder}/{file}', skiprows= 3, header=[0, 1])
                                    df.columns = [
                                        "_".join([str(x) for x in col if "Unnamed" not in str(x)]).strip()
                                        for col in df.columns
                                    ]
                                    data_dictionary[folder][sub_folder][sub_sub_folder][file.replace('.xlsx', '')] = df
                                else:
                                    data_dictionary[folder][sub_folder][sub_sub_folder][file.replace('.xlsx', '')] = pd.read_excel(f'./{first_folder}/{folder}/{sub_folder}/{sub_sub_folder}/{file}')
# Out:
# /Users/isabel/anaconda3/envs/realData/lib/python3.12/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# /Users/isabel/anaconda3/envs/realData/lib/python3.12/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# /Users/isabel/anaconda3/envs/realData/lib/python3.12/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# /Users/isabel/anaconda3/envs/realData/lib/python3.12/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# /Users/isabel/anaconda3/envs/realData/lib/python3.12/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# ...

# %%
list(data_dictionary[list(data_dictionary.keys())[0]]['T1']['P1'].keys())
# Out:
# ['carerNotes1_P1',
#  'carerNotes2_P1',
#  'dailyNurseNotes_P1',
#  'meds_P1',
#  'monthly_P1',
#  'multiDisciplinaryNotes_P1',
#  'quarterly_P1',
#  't1_P1']

# %%
# data_dictionary[list(data_dictionary.keys())[0]]['T1']['P1']['carerNotes1_P1']

# %%
# data_dictionary[list(data_dictionary.keys())[0]]['T1']['P1']['carerNotes2_P1']

# %%
# data_dictionary[list(data_dictionary.keys())[0]]['T1']['P1']['dailyNurseNotes_P1']

# %%
# data_dictionary[list(data_dictionary.keys())[0]]['T1']['P1']['meds_P1']

# %%
# data_dictionary[list(data_dictionary.keys())[0]]['T1']['P1']['monthly_P1']

# %%
# data_dictionary[list(data_dictionary.keys())[0]]['T1']['P1']['multiDisciplinaryNotes_P1']

# %%
# data_dictionary[list(data_dictionary.keys())[0]]['T1']['P1']['quarterly_P1']

# %%
# data_dictionary[list(data_dictionary.keys())[0]]['T1']['P1']['t1_P1']
