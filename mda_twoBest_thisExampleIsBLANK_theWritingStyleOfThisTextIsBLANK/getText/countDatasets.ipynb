# %%
import os
import pandas as pd

# %%
for folder in os.listdir('./datasetsPrep'):
    if os.path.isdir(f'./datasetsPrep/{folder}'):
        for file in os.listdir(f'./datasetsPrep/{folder}'):
            if file.endswith('.csv'):
                temp_df = pd.read_csv(f'./datasetsPrep/{folder}/{file}')
                print(file, len(temp_df))
# Out:
# yahoo.csv 87362
# banking77.csv 13069
# huffPostNews.csv 209527
# clinc150.csv 23700
# atis.csv 4978
# medicalAbstracts.csv 14438
# dementiaAudio.csv 549
# syntheticCareHomeNurseNotes.csv 5783
# clinicalDialogueSummarizations.csv 3603
# simSUM.csv 10000
